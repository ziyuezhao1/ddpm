# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyuezhao1/ddpm/blob/main/DDPMnew2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 模型

# %%
# no problem
import os
import math
from abc import abstractmethod

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm

# %%
# 无需更改
def timestep_embedding(timesteps, dim, max_period=10000):
    """Create sinusoidal timestep embeddings.

    Args:
        timesteps (Tensor): a 1-D Tensor of N indices, one per batch element. These may be fractional.
        dim (int): the dimension of the output.
        max_period (int, optional): controls the minimum frequency of the embeddings. Defaults to 10000.

    Returns:
        Tensor: an [N x dim] Tensor of positional embeddings.
    """
    half = dim // 2
    freqs = torch.exp(
        -math.log(max_period) * torch.arange(start=0, end=half, dtype=torch.float32) / half
    ).to(device=timesteps.device)
    args = timesteps[:, None].float() * freqs[None]
    embedding = torch.cat([torch.cos(args), torch.sin(args)], dim=-1)
    if dim % 2:
        embedding = torch.cat([embedding, torch.zeros_like(embedding[:, :1])], dim=-1)
    return embedding


class TimestepBlock(nn.Module):
    """
    Any module where forward() takes timestep embeddings as a second argument.
    """

    @abstractmethod
    def forward(self, x, t):
        """
        Apply the module to `x` given `t` timestep embeddings.
        """
        pass


class TimestepEmbedSequential(nn.Sequential, TimestepBlock):
    """
    A sequential module that passes timestep embeddings to the children that support it as an extra input.
    """

    def forward(self, x, t):
        for layer in self:
            if isinstance(layer, TimestepBlock):
                x = layer(x, t)
            else:
                x = layer(x)
        return x


def norm_layer(channels):
    return nn.GroupNorm(32, channels)


class ResidualBlock(TimestepBlock):
    def __init__(self, in_channels, out_channels, time_channels, dropout):
        super().__init__()
        self.conv1 = nn.Sequential(
            norm_layer(in_channels),
            nn.SiLU(),
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        )

        # pojection for time step embedding
        self.time_emb = nn.Sequential(
            nn.SiLU(),
            nn.Linear(time_channels, out_channels)
        )

        self.conv2 = nn.Sequential(
            norm_layer(out_channels),
            nn.SiLU(),
            nn.Dropout(p=dropout),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        )

        if in_channels != out_channels:
            self.shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        else:
            self.shortcut = nn.Identity()


    def forward(self, x, t):
        """
        `x` has shape `[batch_size, in_dim, height, width]`
        `t` has shape `[batch_size, time_dim]`
        """
        h = self.conv1(x)
        # Add time step embeddings
        h += self.time_emb(t)[:, :, None, None]
        h = self.conv2(h)
        return h + self.shortcut(x)


class AttentionBlock(nn.Module):
    def __init__(self, channels, num_heads=1):
        """
        Attention block with shortcut

        Args:
            channels (int): channels
            num_heads (int, optional): attention heads. Defaults to 1.
        """
        super().__init__()
        self.num_heads = num_heads
        assert channels % num_heads == 0

        self.norm = norm_layer(channels)
        self.qkv = nn.Conv2d(channels, channels * 3, kernel_size=1, bias=False)
        self.proj = nn.Conv2d(channels, channels, kernel_size=1)

    def forward(self, x):
        B, C, H, W = x.shape
        qkv = self.qkv(self.norm(x))
        q, k, v = qkv.reshape(B*self.num_heads, -1, H*W).chunk(3, dim=1)
        scale = 1. / math.sqrt(math.sqrt(C // self.num_heads))
        attn = torch.einsum("bct,bcs->bts", q * scale, k * scale)
        attn = attn.softmax(dim=-1)
        h = torch.einsum("bts,bcs->bct", attn, v)
        h = h.reshape(B, -1, H, W)
        h = self.proj(h)
        return h + x


class Upsample(nn.Module):
    def __init__(self, channels, use_conv):
        super().__init__()
        self.use_conv = use_conv
        if use_conv:
            self.conv = nn.Conv2d(channels, channels, kernel_size=3, padding=1)

    def forward(self, x):
        x = F.interpolate(x, scale_factor=2, mode="nearest")
        if self.use_conv:
            x = self.conv(x)
        return x


class Downsample(nn.Module):
    def __init__(self, channels, use_conv):
        super().__init__()
        self.use_conv = use_conv
        if use_conv:
            self.op = nn.Conv2d(channels, channels, kernel_size=3, stride=2, padding=1)
        else:
            self.op = nn.AvgPool2d(stride=2)

    def forward(self, x):
        return self.op(x)


class UNetModel(nn.Module):
    """
    The full UNet model with attention and timestep embedding
    """
    def __init__(
        self,
        in_channels=3,
        model_channels=128,
        out_channels=3,
        num_res_blocks=2,
        attention_resolutions=(8, 16),
        dropout=0,
        channel_mult=(1, 2, 2, 2),
        conv_resample=True,
        num_heads=4
    ):
        super().__init__()

        self.in_channels = in_channels
        self.model_channels = model_channels
        self.out_channels = out_channels
        self.num_res_blocks = num_res_blocks
        self.attention_resolutions = attention_resolutions
        self.dropout = dropout
        self.channel_mult = channel_mult
        self.conv_resample = conv_resample
        self.num_heads = num_heads

        # time embedding
        time_embed_dim = model_channels * 4
        self.time_embed = nn.Sequential(
            nn.Linear(model_channels, time_embed_dim),
            nn.SiLU(),
            nn.Linear(time_embed_dim, time_embed_dim),
        )

        # down blocks
        self.down_blocks = nn.ModuleList([
            TimestepEmbedSequential(nn.Conv2d(in_channels, model_channels, kernel_size=3, padding=1))
        ])
        down_block_chans = [model_channels]
        ch = model_channels
        ds = 1
        for level, mult in enumerate(channel_mult):
            for _ in range(num_res_blocks):
                layers = [
                    ResidualBlock(ch, mult * model_channels, time_embed_dim, dropout)
                ]
                ch = mult * model_channels
                if ds in attention_resolutions:
                    layers.append(AttentionBlock(ch, num_heads=num_heads))
                self.down_blocks.append(TimestepEmbedSequential(*layers))
                down_block_chans.append(ch)
            if level != len(channel_mult) - 1: # don't use downsample for the last stage
                self.down_blocks.append(TimestepEmbedSequential(Downsample(ch, conv_resample)))
                down_block_chans.append(ch)
                ds *= 2

        # middle block
        self.middle_block = TimestepEmbedSequential(
            ResidualBlock(ch, ch, time_embed_dim, dropout),
            AttentionBlock(ch, num_heads=num_heads),
            ResidualBlock(ch, ch, time_embed_dim, dropout)
        )

        # up blocks
        self.up_blocks = nn.ModuleList([])
        for level, mult in list(enumerate(channel_mult))[::-1]:
            for i in range(num_res_blocks + 1):
                layers = [
                    ResidualBlock(
                        ch + down_block_chans.pop(),
                        model_channels * mult,
                        time_embed_dim,
                        dropout
                    )
                ]
                ch = model_channels * mult
                if ds in attention_resolutions:
                    layers.append(AttentionBlock(ch, num_heads=num_heads))
                if level and i == num_res_blocks:
                    layers.append(Upsample(ch, conv_resample))
                    ds //= 2
                self.up_blocks.append(TimestepEmbedSequential(*layers))

        self.out = nn.Sequential(
            norm_layer(ch),
            nn.SiLU(),
            nn.Conv2d(model_channels, out_channels, kernel_size=3, padding=1),
        )

    def forward(self, x, timesteps):
        """Apply the model to an input batch.

        Args:
            x (Tensor): [N x C x H x W]
            timesteps (Tensor): a 1-D batch of timesteps.

        Returns:
            Tensor: [N x C x ...]
        """
        hs = []
        # time step embedding
        emb = self.time_embed(timestep_embedding(timesteps, self.model_channels))

        # down stage
        h = x
        for module in self.down_blocks:
            h = module(h, emb)
            hs.append(h)
        # middle stage
        h = self.middle_block(h, emb)
        # up stage
        for module in self.up_blocks:
            cat_in = torch.cat([h, hs.pop()], dim=1)
            h = module(cat_in, emb)
        return self.out(h)


def linear_beta_schedule(timesteps):
    """
    beta schedule
    """
    scale = 10 / timesteps
    beta_start = scale * 0.01
    beta_end = scale * 0.9
    return torch.linspace(beta_start, beta_end, timesteps, dtype=torch.float64)


def cosine_beta_schedule(timesteps, s=0.008):
    """
    cosine schedule
    as proposed in https://arxiv.org/abs/2102.09672
    """
    steps = timesteps + 1
    x = torch.linspace(0, timesteps, steps, dtype=torch.float64)
    alphas_cumprod = torch.cos(((x / timesteps) + s) / (1 + s) * math.pi * 0.5) ** 2
    alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
    betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
    return torch.clip(betas, 0, 0.999)

# %%
# 需要更改
class GaussianDiffusion:
    def __init__(
        self,
        timesteps=1000,
        beta_schedule='linear'
    ):
        self.timesteps = timesteps

        if beta_schedule == 'linear':
            betas = linear_beta_schedule(timesteps)
        elif beta_schedule == 'cosine':
            betas = cosine_beta_schedule(timesteps)
        else:
            raise ValueError(f'unknown beta schedule {beta_schedule}')
        self.betas = betas

        self.alphas = 1. - self.betas
        self.alphas_cumprod = torch.cumprod(self.alphas, axis=0)
        self.alphas_cumprod_prev = F.pad(self.alphas_cumprod[:-1], (1, 0), value=0.99)

        # calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = torch.sqrt(self.alphas_cumprod)
        self.sqrt_one_minus_alphas_cumprod = torch.sqrt(1.0 - self.alphas_cumprod)
        self.log_one_minus_alphas_cumprod = torch.log(1.0 - self.alphas_cumprod)
        self.sqrt_recip_alphas_cumprod = torch.sqrt(1.0 / self.alphas_cumprod)
        self.sqrt_recipm1_alphas_cumprod = torch.sqrt(1.0 / self.alphas_cumprod - 1)

        # calculations for posterior q(x_{t-1} | x_t, x_0)
        self.posterior_variance = (
            self.betas * (1.0 - self.alphas_cumprod_prev) / (1.0 - self.alphas_cumprod)
        )
        # below: log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = torch.log(self.posterior_variance.clamp(min =1e-20))

        self.posterior_mean_coef1 = (
            self.betas * torch.sqrt(self.alphas_cumprod_prev) / (1.0 - self.alphas_cumprod)
        )
        self.posterior_mean_coef2 = (
            (1.0 - self.alphas_cumprod_prev)
            * torch.sqrt(self.alphas)
            / (1.0 - self.alphas_cumprod)
        )

    def _extract(self, a, t, x_shape):
        # get the param of given timestep t
        batch_size = t.shape[0]
        out = a.to(t.device).gather(0, t).float()
        out = out.reshape(batch_size, *((1,) * (len(x_shape) - 1)))
        return out

    def q_sample(self, x_start, t, noise=None):
        # forward diffusion (using the nice property): q(x_t | x_0)
        if noise is None:
            noise = torch.randn_like(x_start)

        sqrt_alphas_cumprod_t = self._extract(self.sqrt_alphas_cumprod, t, x_start.shape)
        sqrt_one_minus_alphas_cumprod_t = self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start.shape)

        return sqrt_alphas_cumprod_t * x_start + sqrt_one_minus_alphas_cumprod_t * noise

    def q_mean_variance(self, x_start, t):
        # Get the mean and variance of q(x_t | x_0).
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start.shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start.shape)
        log_variance = self._extract(self.log_one_minus_alphas_cumprod, t, x_start.shape)
        return mean, variance, log_variance

    def q_posterior_mean_variance(self, x_start, x_t, t):
        # Compute the mean and variance of the diffusion posterior: q(x_{t-1} | x_t, x_0)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t.shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t.shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t.shape)
        posterior_log_variance_clipped = self._extract(self.posterior_log_variance_clipped, t, x_t.shape)
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def predict_start_from_noise(self, x_t, t, noise):
        # compute x_0 from x_t and pred noise: the reverse of `q_sample`

        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t.shape) * x_t -
            self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t.shape) * noise
        )
    def predict_t_1_from_t(self, x_t, noise,t):
        # compute x_t_1 from x_t and pred noise: the reverse of `q_sample`
        #print(self.alphas[t].to(x_t.device).device)
        #print(self.betas[t].to(x_t.device).device)
        return (
            (1.0/self.alphas[t].to(x_t.device)) * (x_t -
            self.betas[t].to(x_t.device) * noise)
        )

    def p_mean_variance(self, model, x_t, t, clip_denoised=True):
        # compute predicted mean and variance of p(x_{t-1} | x_t)
        # predict noise using model
        pred_noise = model(x_t, t)
        # get the predicted x_0: different from the algorithm2 in the paper
        x_recon = self.predict_start_from_noise(x_t, t, pred_noise)

        if clip_denoised:
            x_recon = torch.clamp(x_recon, min=-1., max=1.)
        model_mean, posterior_variance, posterior_log_variance = self.q_posterior_mean_variance(x_recon, x_t, t)
        return model_mean, posterior_variance, posterior_log_variance

    @torch.no_grad()
    def p_sample(self, model, x_t, t, clip_denoised=True):
        # denoise_step: sample x_{t-1} from x_t and pred_noise
        # predict mean and variance
        model_mean, _, model_log_variance = self.p_mean_variance(model, x_t, t, clip_denoised=clip_denoised)
        noise = torch.randn_like(x_t)
        # no noise when t == 0
        nonzero_mask = ((t != 0).float().view(-1, *([1] * (len(x_t.shape) - 1))))
        # compute x_{t-1}
        pred_img = model_mean + nonzero_mask * (0.5 * model_log_variance).exp() * noise
        return pred_img

    @torch.no_grad()
    def p_sample_loop(self, model, shape):
        # denoise: reverse diffusion
        batch_size = shape[0]
        device = next(model.parameters()).device
        # start from pure noise (for each example in the batch)
        img = torch.randn(shape, device=device)
        imgs = []
        for i in tqdm(reversed(range(0, timesteps)), desc='sampling loop time step', total=timesteps):
            img = self.p_sample(model, img, torch.full((batch_size,), i, device=device, dtype=torch.long))
            imgs.append(img.cpu().numpy())
        return imgs

    @torch.no_grad()
    def p_sample_loop_new(self, model, image):
        # denoise: reverse diffusion
        batch_size = image.shape[0]
        device = next(model.parameters()).device
        img=image
        imgs = []
        for i in tqdm(reversed(range(0, timesteps)), desc='sampling loop time step', total=timesteps):
            img = self.p_sample(model, img, torch.full((batch_size,), i, device=device, dtype=torch.long))
            imgs.append(img.cpu().numpy())
        return imgs


    @torch.no_grad()
    def sample(self, model, image_size, batch_size=8, channels=3):
        # sample new images
        return self.p_sample_loop(model, shape=(batch_size, channels, image_size, image_size))



    def train_losses(self, model, x_start, t):
        # compute train losses
        # generate random noise
        noise = torch.randn_like(x_start)
        # get x_t
        x_noisy = self.q_sample(x_start, t, noise=noise)
        predicted_noise = model(x_noisy, t)
        loss = F.mse_loss(noise, predicted_noise)
        return loss

    def get_parameter(self, model, x_start, t):
        noise = torch.randn_like(x_start)
        # get x_t
        x_noisy = self.q_sample(x_start, t, noise=noise)

        predicted_noise = model(x_noisy, t)

        alphas=self.alphas.to(t.device)
        betas=self.betas.to(t.device)

        sqrt_one_minus_alphas_cumprod=self.sqrt_one_minus_alphas_cumprod.to(t.device)
        mean1,variance_all,posterior_log_variance=self.p_mean_variance(model, x_noisy, t)

        #mean1=alphas[t]*x_noisy-predicted_noise*betas[t]/sqrt_one_minus_alphas_cumprod

        return mean1,variance_all

    def get_parameter2(self, model, x_t, t):
        # get x_t
        #predicted_noise = model(x_t, t)
        #noise = torch.randn_like(x_final)

        predicted_noise = model(x_t, t)

        alphas=self.alphas.to(t.device)
        betas=self.betas.to(t.device)

        sqrt_one_minus_alphas_cumprod=self.sqrt_one_minus_alphas_cumprod.to(t.device)
        mean1,variance_all,posterior_log_variance=self.p_mean_variance(model, x_t, t)

        #mean1=alphas[t]*x_noisy-predicted_noise*betas[t]/sqrt_one_minus_alphas_cumprod

        return mean1,variance_all

# %% [markdown]
# 看看效果

# %%
from PIL import Image
import requests
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

# %matplotlib inline

# %%
url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
image = Image.open(requests.get(url, stream=True).raw)
# image = Image.open("/data/000000039769.jpg")

image_size = 128
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.PILToTensor(),
    transforms.ConvertImageDtype(torch.float),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

x_start = transform(image).unsqueeze(0)

gaussian_diffusion = GaussianDiffusion(timesteps=500)

plt.figure(figsize=(16, 8))
for idx, t in enumerate([0, 50, 100, 200, 499]):
    x_noisy = gaussian_diffusion.q_sample(x_start, t=torch.tensor([t]))
    noisy_image = (x_noisy.squeeze().permute(1, 2, 0) + 1) * 127.5
    noisy_image = noisy_image.numpy().astype(np.uint8)
    plt.subplot(1, 5, 1 + idx)
    plt.imshow(noisy_image)
    plt.axis("off")
    plt.title(f"t={t}")

# %% [markdown]
# ## 训练

# %% [markdown]
# 准备数据集

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset

# %%
class TrainSet(Dataset):
  def __init__(self, original_dataset,label):
    self.original_dataset = original_dataset
    self.label = label

  def __getitem__(self, index):
      image = self.original_dataset[index]
      return image, self.label[index]

  def __len__(self):
      return len(self.original_dataset)

# %%
class BinaryDataset(torch.utils.data.Dataset):
    def __init__(self, original_dataset,indices,label):
        self.original_dataset = original_dataset
        self.indices  = indices
        self.label = label

    def __getitem__(self, index):
        image, _ = self.original_dataset[self.indices[index]]
        return image, self.label

    def __len__(self):
        return len(self.indices)

# %%
batch_size = 64
timesteps = 5

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

# use MNIST dataset
dataset = datasets.MNIST('./data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 68901263.23it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 31341706.03it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 19238009.84it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 3929564.51it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
# use cifar10
dataset = datasets.CIFAR10('./dataset', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./dataset/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:10<00:00, 15861428.26it/s]
# Extracting ./dataset/cifar-10-python.tar.gz to ./dataset

# %%
mnist_indices = [i for i in range(len(dataset)) if dataset[i][1] == 3]
mnist2_indices = [i for i in range(len(dataset)) if dataset[i][1] == 9]
dataset_image_number=256

mnist_dataset = BinaryDataset(dataset, mnist_indices[0:dataset_image_number],label=3 )
mnist2_dataset = BinaryDataset(dataset, mnist2_indices[0:dataset_image_number],label=9 )

mnist_dataset_v = BinaryDataset(dataset, mnist_indices[dataset_image_number+1:dataset_image_number+dataset_image_number],label=3)
mnist2_dataset_v = BinaryDataset(dataset, mnist2_indices[dataset_image_number+1:dataset_image_number+dataset_image_number],label=9 )

# %%
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])

val_dataset=torch.utils.data.ConcatDataset([mnist_dataset_v, mnist2_dataset_v])
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=1, shuffle=True,pin_memory=True)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True,num_workers=4,pin_memory=True)

# %%
train_features, train_labels = next(iter(train_loader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")

img = (train_features[1])
label = train_labels[0]
print(img.size())
plt.imshow(img.permute(1,2,0))
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Feature batch shape: torch.Size([64, 3, 32, 32])
# Labels batch shape: torch.Size([64])
# torch.Size([3, 32, 32])

# %% [markdown]
# 模型

# %% [markdown]
# 开始训练

# %%
import torch,gc
gc.collect()
torch.cuda.empty_cache()
from torch.utils.data import Dataset

# %%
# define model and diffusion
device = "cuda" if torch.cuda.is_available() else "cpu"
model = UNetModel(
    in_channels=1,
    model_channels=96,
    out_channels=1,
    channel_mult=(1, 2, 2),
    attention_resolutions=[]
)
model.to(device)

gaussian_diffusion = GaussianDiffusion(timesteps=timesteps)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
epochs = 10
batch_size = 64
timesteps = 5
loss_batch_average=torch.zeros([epochs,timesteps,int(dataset_image_number/batch_size)])
model_parameters=dict()

x_t_train_dataset1=torch.utils.data.ConcatDataset([mnist_dataset])
x_t_train_dataset2=torch.utils.data.ConcatDataset([mnist2_dataset])
best_acc=0
model = UNetModel(
    in_channels=3,
    model_channels=128,
    out_channels=3,
    #channel_mult=(1, 2, 2),
    attention_resolutions=[]
  )
model.to(device)
for t in range(timesteps-1,-1,-1):
  #build the model for each timestep
  optimizer.zero_grad(set_to_none=True)
  torch.cuda.empty_cache()

  time = torch.full((batch_size,),t, device=device).long()
  train_loader1 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=True,pin_memory=True)
  train_loader2 = torch.utils.data.DataLoader(x_t_train_dataset2, batch_size=batch_size, shuffle=True,pin_memory=True)
  for epoch in range(epochs):#256 batch 64
    batch_size=batch_size
    iteration_of_train_loader2=iter(train_loader2)
    for step, (images1, _) in enumerate(train_loader1):

      xt1 = images1.to(device)
      images2,_=next(iteration_of_train_loader2)
      xt2 = images2.to(device)
      #torch.autograd.set_detect_anomaly(True)

      predicted_noise1 = model(xt1, time)
      predicted_noise2 = model(xt2, time)
      out1 = model(xt1, time)
      out2 = model(xt2, time)
      #loss=0

      m1=out1.reshape(batch_size,3*32*32)
      m2=out2.reshape(batch_size,3*32*32)

      difference=m1.mean(0)-m2.mean(0)
      d=difference.t()

      s1=torch.var(m1, dim=0)
      s2=torch.var(m2, dim=0)
      loss1=-torch.log(d.t()@d)
      loss2=torch.log(s1.mean(0)+s2.mean(0))
      loss=loss1+(loss1/loss2).detach()*loss2

      del s1,s2,d,difference
      #sigma_inverse
      print(" this is time ",t," this is epoch",epoch,"this is step ",step)
      print("loss",loss)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      loss_batch_average[epoch,t,step]=loss
      print("loss1",loss1)
      print("loss2",loss2)
      del loss
  #save the model parameters
  model_parameters[t]=model.state_dict()

  x_t_train_dataset1_1=torch.zeros([dataset_image_number,3,32,32])
  x_t_train_dataset2_2=torch.zeros([dataset_image_number,3,32,32])

  labels_1=torch.zeros([dataset_image_number])
  labels_2=torch.zeros([dataset_image_number])

  model.eval()
  #establish xt_1 for the next loop
  with torch.no_grad():
    for step, (images1, labels) in enumerate(train_loader1):
      xt1 = images1.to(device)

      predicted_noise = model(xt1, time)
      images1=gaussian_diffusion.predict_t_1_from_t(xt1, predicted_noise,t)

      x_t_train_dataset1_1[step*batch_size:(step+1)*batch_size,:,:,:]=images1
      labels_1[step*batch_size:(step+1)*batch_size]=labels
      del predicted_noise
    x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset1_1,labels_1)])

  with torch.no_grad():
    for step, (images2, labels2) in enumerate(train_loader2):
      xt2 = images2.to(device)

      predicted_noise2 = model(xt2, time)
      images2=gaussian_diffusion.predict_t_1_from_t(xt2, predicted_noise2,t)

      x_t_train_dataset2_2[step*batch_size:(step+1)*batch_size,:,:,:]=images2
      labels_2[step*batch_size:(step+1)*batch_size]=labels2
      del predicted_noise2

    x_t_train_dataset2=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset2_2,labels_2)])

  model.eval()
  #establish xt_1 for the next loop
  val_acc=0
  with torch.no_grad():
    for step, (image, label) in enumerate(val_loader):
      image = image.to(device)
      x0=image
      for t_v in range(timesteps-1,t-1,-1):

        model.load_state_dict(model_parameters[t_v],strict=True)
        time=torch.full((1,),t_v, device=device)
        predicted_noiset = model(x0, time)
        x=gaussian_diffusion.predict_t_1_from_t(x0,predicted_noiset,t_v)
        x0=x

      a=torch.norm(x0[0,0,:,:]-x_t_train_dataset1_1.mean(0).to(device)).to(device)# distance between 3 and pred
      b=torch.norm(x0[0,0,:,:]-x_t_train_dataset2_2.mean(0).to(device)).to(device)# distance between 2 and pred
      if a >= b:
        pred_label= 9
        #print(a,"and",b)
      else:
        pred_label= 3
        #print(a,"and",b)
      if pred_label==label:
        val_acc=val_acc+1
        #print("exact!", pred_label,"the true is ",label)
      else:
        print("find different label at step ", step, pred_label,"the true is ",label)
    print("val_acc",val_acc/len(val_dataset))
    if val_acc/len(val_dataset)>best_acc:
      best_acc=val_acc/len(val_dataset)
      print(best_acc)
      epochs_without_improvement = 0
    else:
      epochs_without_improvement+=1
      print("early stopping at timestep", t,val_acc/len(val_dataset))
      break

  print("done")

#torch.cuda.empty_cache()
# Out:
#  this is time  4  this is epoch 0 this is step  0
# loss tensor(-7.2834, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.6417, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8509, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 0 this is step  1
# loss tensor(-8.4576, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.2288, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8470, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 0 this is step  2
# loss tensor(-7.9725, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.9862, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8466, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 0 this is step  3
# loss tensor(-7.9795, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.9898, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8196, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 1 this is step  0
# loss tensor(-7.4785, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.7393, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8667, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 1 this is step  1
# loss tensor(-7.2991, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.6495, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8044, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 1 this is step  2
# loss tensor(-7.3959, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.6980, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8121, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 1 this is step  3
# loss tensor(-9.1427, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.5713, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8687, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 2 this is step  0
# loss tensor(-7.5972, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.7986, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8210, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 2 this is step  1
# loss tensor(-7.2186, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.6093, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8366, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 2 this is step  2
# loss tensor(-9.3195, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.6598, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8865, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 2 this is step  3
# loss tensor(-7.2055, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.6027, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8161, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 3 this is step  0
# loss tensor(-8.1216, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.0608, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8327, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 3 this is step  1
# loss tensor(-7.9248, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.9624, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8344, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 3 this is step  2
# loss tensor(-7.9446, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.9723, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8513, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 3 this is step  3
# loss tensor(-7.6061, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.8031, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8203, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 4 this is step  0
# loss tensor(-6.9760, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.4880, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8074, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 4 this is step  1
# loss tensor(-7.8339, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.9170, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8463, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 4 this is step  2
# loss tensor(-8.2898, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.1449, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8607, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 4 this is step  3
# loss tensor(-8.3552, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.1776, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8350, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 5 this is step  0
# loss tensor(-7.7822, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.8911, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8562, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 5 this is step  1
# loss tensor(-8.2252, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.1126, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8500, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 5 this is step  2
# loss tensor(-7.0732, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.5366, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8217, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 5 this is step  3
# loss tensor(-8.5690, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.2845, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8219, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 6 this is step  0
# loss tensor(-8.3344, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.1672, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8264, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 6 this is step  1
# loss tensor(-7.7593, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.8796, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8413, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 6 this is step  2
# loss tensor(-7.1593, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.5796, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8420, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 6 this is step  3
# loss tensor(-8.2391, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.1196, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8332, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 7 this is step  0
# loss tensor(-7.5600, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.7800, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8380, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 7 this is step  1
# loss tensor(-8.2651, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.1325, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8192, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 7 this is step  2
# loss tensor(-7.3075, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.6537, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8345, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 7 this is step  3
# loss tensor(-8.4709, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.2355, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8478, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 8 this is step  0
# loss tensor(-8.6058, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.3029, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8484, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 8 this is step  1
# loss tensor(-8.4344, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.2172, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8758, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 8 this is step  2
# loss tensor(-7.9990, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.9995, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8076, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 8 this is step  3
# loss tensor(-6.3670, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.1835, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8185, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 9 this is step  0
# loss tensor(-8.3493, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.1746, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8370, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 9 this is step  1
# loss tensor(-8.1727, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-4.0864, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8513, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 9 this is step  2
# loss tensor(-7.8761, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.9380, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8481, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  4  this is epoch 9 this is step  3
# loss tensor(-7.3068, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.6534, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.8131, device='cuda:0', grad_fn=<LogBackward0>)
# find different label at step  5 3 the true is  tensor([9])
# find different label at step  7 3 the true is  tensor([9])
# find different label at step  12 9 the true is  tensor([3])
# find different label at step  16 3 the true is  tensor([9])
# find different label at step  17 3 the true is  tensor([9])
# find different label at step  22 3 the true is  tensor([9])
# find different label at step  29 9 the true is  tensor([3])
# find different label at step  32 3 the true is  tensor([9])
# find different label at step  33 9 the true is  tensor([3])
# find different label at step  41 3 the true is  tensor([9])
# find different label at step  42 3 the true is  tensor([9])
# find different label at step  46 9 the true is  tensor([3])
# find different label at step  48 9 the true is  tensor([3])
# find different label at step  50 3 the true is  tensor([9])
# find different label at step  51 3 the true is  tensor([9])
# find different label at step  60 3 the true is  tensor([9])
# find different label at step  66 3 the true is  tensor([9])
# find different label at step  67 3 the true is  tensor([9])
# find different label at step  69 3 the true is  tensor([9])
# find different label at step  72 3 the true is  tensor([9])
# find different label at step  73 9 the true is  tensor([3])
# find different label at step  77 3 the true is  tensor([9])
# find different label at step  80 3 the true is  tensor([9])
# find different label at step  81 3 the true is  tensor([9])
# find different label at step  84 3 the true is  tensor([9])
# find different label at step  87 9 the true is  tensor([3])
# find different label at step  88 9 the true is  tensor([3])
# find different label at step  92 9 the true is  tensor([3])
# find different label at step  93 9 the true is  tensor([3])
# find different label at step  94 3 the true is  tensor([9])
# find different label at step  98 3 the true is  tensor([9])
# find different label at step  100 9 the true is  tensor([3])
# find different label at step  107 3 the true is  tensor([9])
# find different label at step  109 9 the true is  tensor([3])
# find different label at step  112 3 the true is  tensor([9])
# find different label at step  117 9 the true is  tensor([3])
# find different label at step  124 3 the true is  tensor([9])
# find different label at step  125 3 the true is  tensor([9])
# find different label at step  128 3 the true is  tensor([9])
# find different label at step  129 3 the true is  tensor([9])
# find different label at step  137 9 the true is  tensor([3])
# find different label at step  140 3 the true is  tensor([9])
# find different label at step  141 3 the true is  tensor([9])
# find different label at step  143 3 the true is  tensor([9])
# find different label at step  152 3 the true is  tensor([9])
# find different label at step  157 3 the true is  tensor([9])
# find different label at step  164 9 the true is  tensor([3])
# find different label at step  166 3 the true is  tensor([9])
# find different label at step  167 3 the true is  tensor([9])
# find different label at step  168 3 the true is  tensor([9])
# find different label at step  169 3 the true is  tensor([9])
# find different label at step  173 3 the true is  tensor([9])
# find different label at step  174 9 the true is  tensor([3])
# find different label at step  176 3 the true is  tensor([9])
# find different label at step  179 3 the true is  tensor([9])
# find different label at step  181 3 the true is  tensor([9])
# find different label at step  184 3 the true is  tensor([9])
# find different label at step  185 3 the true is  tensor([9])
# find different label at step  187 3 the true is  tensor([9])
# find different label at step  189 3 the true is  tensor([9])
# find different label at step  191 3 the true is  tensor([9])
# find different label at step  203 3 the true is  tensor([9])
# find different label at step  208 3 the true is  tensor([9])
# find different label at step  209 3 the true is  tensor([9])
# find different label at step  210 3 the true is  tensor([9])
# find different label at step  212 3 the true is  tensor([9])
# find different label at step  213 9 the true is  tensor([3])
# find different label at step  216 3 the true is  tensor([9])
# find different label at step  218 3 the true is  tensor([9])
# find different label at step  221 9 the true is  tensor([3])
# find different label at step  227 9 the true is  tensor([3])
# find different label at step  228 3 the true is  tensor([9])
# find different label at step  229 3 the true is  tensor([9])
# find different label at step  232 3 the true is  tensor([9])
# find different label at step  234 9 the true is  tensor([3])
# find different label at step  237 9 the true is  tensor([3])
# find different label at step  239 3 the true is  tensor([9])
# find different label at step  244 9 the true is  tensor([3])
# find different label at step  245 3 the true is  tensor([9])
# find different label at step  246 9 the true is  tensor([3])
# find different label at step  252 9 the true is  tensor([3])
# find different label at step  253 3 the true is  tensor([9])
# find different label at step  254 3 the true is  tensor([9])
# find different label at step  256 3 the true is  tensor([9])
# find different label at step  259 9 the true is  tensor([3])
# find different label at step  261 3 the true is  tensor([9])
# find different label at step  262 9 the true is  tensor([3])
# find different label at step  263 3 the true is  tensor([9])
# find different label at step  271 9 the true is  tensor([3])
# find different label at step  275 9 the true is  tensor([3])
# find different label at step  277 3 the true is  tensor([9])
# find different label at step  280 9 the true is  tensor([3])
# find different label at step  284 3 the true is  tensor([9])
# find different label at step  289 3 the true is  tensor([9])
# find different label at step  290 3 the true is  tensor([9])
# find different label at step  293 3 the true is  tensor([9])
# find different label at step  300 3 the true is  tensor([9])
# find different label at step  315 3 the true is  tensor([9])
# find different label at step  318 3 the true is  tensor([9])
# find different label at step  319 3 the true is  tensor([9])
# find different label at step  326 9 the true is  tensor([3])
# find different label at step  329 3 the true is  tensor([9])
# find different label at step  330 3 the true is  tensor([9])
# find different label at step  332 3 the true is  tensor([9])
# find different label at step  334 3 the true is  tensor([9])
# find different label at step  335 3 the true is  tensor([9])
# find different label at step  336 3 the true is  tensor([9])
# find different label at step  339 3 the true is  tensor([9])
# find different label at step  340 3 the true is  tensor([9])
# find different label at step  342 9 the true is  tensor([3])
# find different label at step  346 9 the true is  tensor([3])
# find different label at step  348 3 the true is  tensor([9])
# find different label at step  349 3 the true is  tensor([9])
# find different label at step  353 9 the true is  tensor([3])
# find different label at step  354 3 the true is  tensor([9])
# find different label at step  358 3 the true is  tensor([9])
# find different label at step  359 3 the true is  tensor([9])
# find different label at step  367 3 the true is  tensor([9])
# find different label at step  381 3 the true is  tensor([9])
# find different label at step  384 9 the true is  tensor([3])
# find different label at step  386 9 the true is  tensor([3])
# find different label at step  387 3 the true is  tensor([9])
# find different label at step  388 9 the true is  tensor([3])
# find different label at step  392 3 the true is  tensor([9])
# find different label at step  394 3 the true is  tensor([9])
# find different label at step  395 9 the true is  tensor([3])
# find different label at step  396 3 the true is  tensor([9])
# find different label at step  397 3 the true is  tensor([9])
# find different label at step  400 3 the true is  tensor([9])
# find different label at step  401 3 the true is  tensor([9])
# find different label at step  403 3 the true is  tensor([9])
# find different label at step  408 3 the true is  tensor([9])
# find different label at step  409 3 the true is  tensor([9])
# find different label at step  411 3 the true is  tensor([9])
# find different label at step  412 3 the true is  tensor([9])
# find different label at step  414 3 the true is  tensor([9])
# find different label at step  415 9 the true is  tensor([3])
# find different label at step  418 3 the true is  tensor([9])
# find different label at step  419 9 the true is  tensor([3])
# find different label at step  423 3 the true is  tensor([9])
# find different label at step  424 3 the true is  tensor([9])
# find different label at step  425 3 the true is  tensor([9])
# find different label at step  432 3 the true is  tensor([9])
# find different label at step  434 3 the true is  tensor([9])
# find different label at step  435 9 the true is  tensor([3])
# find different label at step  436 3 the true is  tensor([9])
# find different label at step  437 3 the true is  tensor([9])
# find different label at step  441 3 the true is  tensor([9])
# find different label at step  447 3 the true is  tensor([9])
# find different label at step  448 3 the true is  tensor([9])
# find different label at step  451 3 the true is  tensor([9])
# find different label at step  452 3 the true is  tensor([9])
# find different label at step  456 3 the true is  tensor([9])
# find different label at step  457 9 the true is  tensor([3])
# find different label at step  458 3 the true is  tensor([9])
# find different label at step  460 3 the true is  tensor([9])
# find different label at step  465 9 the true is  tensor([3])
# find different label at step  466 3 the true is  tensor([9])
# find different label at step  471 3 the true is  tensor([9])
# find different label at step  477 3 the true is  tensor([9])
# find different label at step  479 3 the true is  tensor([9])
# find different label at step  485 3 the true is  tensor([9])
# find different label at step  495 3 the true is  tensor([9])
# find different label at step  498 3 the true is  tensor([9])
# find different label at step  500 3 the true is  tensor([9])
# find different label at step  504 9 the true is  tensor([3])
# find different label at step  505 3 the true is  tensor([9])
# val_acc 0.6725490196078432
# 0.6725490196078432
# done
#  this is time  3  this is epoch 0 this is step  0
# loss tensor(-7.4330, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.7165, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.7051, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 0 this is step  1
# loss tensor(-6.3811, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.1906, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6922, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 0 this is step  2
# loss tensor(-7.2282, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.6141, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6808, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 0 this is step  3
# loss tensor(-6.4210, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.2105, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6912, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 1 this is step  0
# loss tensor(-6.8473, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.4236, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6797, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 1 this is step  1
# loss tensor(-6.6218, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.3109, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6861, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 1 this is step  2
# loss tensor(-6.6874, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.3437, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6969, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 1 this is step  3
# loss tensor(-6.9162, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.4581, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6977, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 2 this is step  0
# loss tensor(-7.1988, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.5994, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6938, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 2 this is step  1
# loss tensor(-6.3135, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.1567, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6701, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 2 this is step  2
# loss tensor(-6.6753, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.3377, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6949, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 2 this is step  3
# loss tensor(-6.8680, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.4340, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.7022, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 3 this is step  0
# loss tensor(-7.2593, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.6297, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6946, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 3 this is step  1
# loss tensor(-6.9506, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.4753, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6832, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 3 this is step  2
# loss tensor(-6.6880, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.3440, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6796, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 3 this is step  3
# loss tensor(-6.1686, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.0843, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.7040, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 4 this is step  0
# loss tensor(-6.9421, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.4710, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.7157, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 4 this is step  1
# loss tensor(-7.2561, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.6280, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6962, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 4 this is step  2
# loss tensor(-6.1550, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.0775, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6676, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 4 this is step  3
# loss tensor(-6.9374, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.4687, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6864, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 5 this is step  0
# loss tensor(-6.8066, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.4033, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.7012, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 5 this is step  1
# loss tensor(-6.5581, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.2790, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6902, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 5 this is step  2
# loss tensor(-6.6738, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.3369, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6786, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 5 this is step  3
# loss tensor(-6.8724, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.4362, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6903, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 6 this is step  0
# loss tensor(-7.1631, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.5815, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.7019, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 6 this is step  1
# loss tensor(-6.3691, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.1845, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6764, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 6 this is step  2
# loss tensor(-6.7444, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.3722, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6849, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 6 this is step  3
# loss tensor(-6.4797, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.2399, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6936, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 7 this is step  0
# loss tensor(-6.1637, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.0818, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6910, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 7 this is step  1
# loss tensor(-6.8064, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.4032, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6965, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 7 this is step  2
# loss tensor(-7.3259, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.6630, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6830, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 7 this is step  3
# loss tensor(-6.5557, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.2779, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6909, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 8 this is step  0
# loss tensor(-6.6247, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.3123, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6876, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 8 this is step  1
# loss tensor(-6.6668, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.3334, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6728, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 8 this is step  2
# loss tensor(-6.4629, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.2315, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6808, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 8 this is step  3
# loss tensor(-7.0792, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.5396, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.7177, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 9 this is step  0
# loss tensor(-7.1462, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.5731, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6742, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 9 this is step  1
# loss tensor(-7.1101, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.5551, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.7126, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 9 this is step  2
# loss tensor(-6.1716, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.0858, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6871, device='cuda:0', grad_fn=<LogBackward0>)
#  this is time  3  this is epoch 9 this is step  3
# loss tensor(-6.3979, device='cuda:0', grad_fn=<AddBackward0>)
# loss1 tensor(-3.1989, device='cuda:0', grad_fn=<NegBackward0>)
# loss2 tensor(-1.6883, device='cuda:0', grad_fn=<LogBackward0>)
# find different label at step  0 3 the true is  tensor([9])
# find different label at step  7 3 the true is  tensor([9])
# find different label at step  9 3 the true is  tensor([9])
# find different label at step  11 3 the true is  tensor([9])
# find different label at step  14 9 the true is  tensor([3])
# find different label at step  17 9 the true is  tensor([3])
# find different label at step  19 3 the true is  tensor([9])
# find different label at step  21 3 the true is  tensor([9])
# find different label at step  22 3 the true is  tensor([9])
# find different label at step  23 3 the true is  tensor([9])
# find different label at step  24 9 the true is  tensor([3])
# find different label at step  25 3 the true is  tensor([9])
# find different label at step  31 3 the true is  tensor([9])
# find different label at step  33 9 the true is  tensor([3])
# find different label at step  36 3 the true is  tensor([9])
# find different label at step  39 9 the true is  tensor([3])
# find different label at step  46 9 the true is  tensor([3])
# find different label at step  50 3 the true is  tensor([9])
# find different label at step  53 3 the true is  tensor([9])
# find different label at step  55 3 the true is  tensor([9])
# find different label at step  57 3 the true is  tensor([9])
# find different label at step  58 9 the true is  tensor([3])
# find different label at step  62 3 the true is  tensor([9])
# find different label at step  65 3 the true is  tensor([9])
# find different label at step  66 3 the true is  tensor([9])
# find different label at step  68 3 the true is  tensor([9])
# find different label at step  69 3 the true is  tensor([9])
# find different label at step  70 9 the true is  tensor([3])
# find different label at step  71 3 the true is  tensor([9])
# find different label at step  73 3 the true is  tensor([9])
# find different label at step  74 3 the true is  tensor([9])
# find different label at step  75 3 the true is  tensor([9])
# find different label at step  78 3 the true is  tensor([9])
# find different label at step  81 3 the true is  tensor([9])
# find different label at step  83 3 the true is  tensor([9])
# find different label at step  84 3 the true is  tensor([9])
# find different label at step  90 3 the true is  tensor([9])
# find different label at step  97 3 the true is  tensor([9])
# find different label at step  99 3 the true is  tensor([9])
# find different label at step  106 3 the true is  tensor([9])
# find different label at step  107 3 the true is  tensor([9])
# find different label at step  108 9 the true is  tensor([3])
# find different label at step  110 9 the true is  tensor([3])
# find different label at step  112 3 the true is  tensor([9])
# find different label at step  114 3 the true is  tensor([9])
# find different label at step  118 3 the true is  tensor([9])
# find different label at step  122 3 the true is  tensor([9])
# find different label at step  125 3 the true is  tensor([9])
# find different label at step  128 3 the true is  tensor([9])
# find different label at step  129 3 the true is  tensor([9])
# find different label at step  134 3 the true is  tensor([9])
# find different label at step  135 3 the true is  tensor([9])
# find different label at step  136 9 the true is  tensor([3])
# find different label at step  140 3 the true is  tensor([9])
# find different label at step  143 3 the true is  tensor([9])
# find different label at step  145 9 the true is  tensor([3])
# find different label at step  156 9 the true is  tensor([3])
# find different label at step  159 9 the true is  tensor([3])
# find different label at step  162 3 the true is  tensor([9])
# find different label at step  163 9 the true is  tensor([3])
# find different label at step  165 3 the true is  tensor([9])
# find different label at step  175 9 the true is  tensor([3])
# find different label at step  176 3 the true is  tensor([9])
# find different label at step  177 9 the true is  tensor([3])
# find different label at step  178 3 the true is  tensor([9])
# find different label at step  179 3 the true is  tensor([9])
# find different label at step  183 3 the true is  tensor([9])
# find different label at step  185 3 the true is  tensor([9])
# find different label at step  186 3 the true is  tensor([9])
# find different label at step  195 3 the true is  tensor([9])
# find different label at step  197 9 the true is  tensor([3])
# find different label at step  201 3 the true is  tensor([9])
# find different label at step  205 3 the true is  tensor([9])
# find different label at step  206 3 the true is  tensor([9])
# find different label at step  207 3 the true is  tensor([9])
# find different label at step  209 3 the true is  tensor([9])
# find different label at step  210 3 the true is  tensor([9])
# find different label at step  211 3 the true is  tensor([9])
# find different label at step  219 3 the true is  tensor([9])
# find different label at step  220 3 the true is  tensor([9])
# find different label at step  224 3 the true is  tensor([9])
# find different label at step  234 3 the true is  tensor([9])
# find different label at step  237 3 the true is  tensor([9])
# find different label at step  239 3 the true is  tensor([9])
# find different label at step  240 3 the true is  tensor([9])
# find different label at step  241 3 the true is  tensor([9])
# find different label at step  243 9 the true is  tensor([3])
# find different label at step  247 3 the true is  tensor([9])
# find different label at step  249 9 the true is  tensor([3])
# find different label at step  253 3 the true is  tensor([9])
# find different label at step  257 9 the true is  tensor([3])
# find different label at step  259 3 the true is  tensor([9])
# find different label at step  261 3 the true is  tensor([9])
# find different label at step  270 3 the true is  tensor([9])
# find different label at step  272 3 the true is  tensor([9])
# find different label at step  274 9 the true is  tensor([3])
# find different label at step  276 9 the true is  tensor([3])
# find different label at step  285 3 the true is  tensor([9])
# find different label at step  289 3 the true is  tensor([9])
# find different label at step  292 3 the true is  tensor([9])
# find different label at step  295 9 the true is  tensor([3])
# find different label at step  297 3 the true is  tensor([9])
# find different label at step  299 3 the true is  tensor([9])
# find different label at step  300 3 the true is  tensor([9])
# find different label at step  302 9 the true is  tensor([3])
# find different label at step  305 3 the true is  tensor([9])
# find different label at step  307 3 the true is  tensor([9])
# find different label at step  308 3 the true is  tensor([9])
# find different label at step  309 3 the true is  tensor([9])
# find different label at step  310 9 the true is  tensor([3])
# find different label at step  312 3 the true is  tensor([9])
# find different label at step  314 3 the true is  tensor([9])
# find different label at step  315 9 the true is  tensor([3])
# find different label at step  334 3 the true is  tensor([9])
# find different label at step  337 9 the true is  tensor([3])
# find different label at step  338 9 the true is  tensor([3])
# find different label at step  339 3 the true is  tensor([9])
# find different label at step  340 3 the true is  tensor([9])
# find different label at step  342 3 the true is  tensor([9])
# find different label at step  344 3 the true is  tensor([9])
# find different label at step  345 3 the true is  tensor([9])
# find different label at step  347 3 the true is  tensor([9])
# find different label at step  351 9 the true is  tensor([3])
# find different label at step  354 9 the true is  tensor([3])
# find different label at step  355 3 the true is  tensor([9])
# find different label at step  365 3 the true is  tensor([9])
# find different label at step  370 3 the true is  tensor([9])
# find different label at step  375 3 the true is  tensor([9])
# find different label at step  391 3 the true is  tensor([9])
# find different label at step  393 9 the true is  tensor([3])
# find different label at step  400 9 the true is  tensor([3])
# find different label at step  402 3 the true is  tensor([9])
# find different label at step  406 3 the true is  tensor([9])
# find different label at step  407 9 the true is  tensor([3])
# find different label at step  410 9 the true is  tensor([3])
# find different label at step  411 3 the true is  tensor([9])
# find different label at step  412 9 the true is  tensor([3])
# find different label at step  414 3 the true is  tensor([9])
# find different label at step  419 3 the true is  tensor([9])
# find different label at step  423 3 the true is  tensor([9])
# find different label at step  424 3 the true is  tensor([9])
# find different label at step  425 3 the true is  tensor([9])
# find different label at step  429 3 the true is  tensor([9])
# find different label at step  433 3 the true is  tensor([9])
# find different label at step  434 9 the true is  tensor([3])
# find different label at step  437 3 the true is  tensor([9])
# find different label at step  438 3 the true is  tensor([9])
# find different label at step  440 3 the true is  tensor([9])
# find different label at step  441 3 the true is  tensor([9])
# find different label at step  447 9 the true is  tensor([3])
# find different label at step  450 9 the true is  tensor([3])
# find different label at step  452 9 the true is  tensor([3])
# find different label at step  454 9 the true is  tensor([3])
# find different label at step  455 3 the true is  tensor([9])
# find different label at step  456 9 the true is  tensor([3])
# find different label at step  459 9 the true is  tensor([3])
# find different label at step  462 3 the true is  tensor([9])
# find different label at step  472 9 the true is  tensor([3])
# find different label at step  475 3 the true is  tensor([9])
# find different label at step  476 3 the true is  tensor([9])
# find different label at step  477 3 the true is  tensor([9])
# find different label at step  479 3 the true is  tensor([9])
# find different label at step  481 3 the true is  tensor([9])
# find different label at step  483 3 the true is  tensor([9])
# find different label at step  489 3 the true is  tensor([9])
# find different label at step  491 3 the true is  tensor([9])
# find different label at step  493 9 the true is  tensor([3])
# find different label at step  501 3 the true is  tensor([9])
# find different label at step  506 9 the true is  tensor([3])
# find different label at step  509 3 the true is  tensor([9])
# val_acc 0.6666666666666666
# early stopping at timestep 3 0.6666666666666666

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.plot(timesteps_list,a[:,4].detach().numpy())
plt.show()
# Out:
# torch.Size([10, 5])

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.plot(timesteps_list,a[:,3].detach().numpy())
plt.show()
# Out:
# torch.Size([10, 5])

# %% [markdown]
# ## 测试

# %%
# direct calculate the distance and compare them for original images
batch_size=256
train_dataset1 = torch.utils.data.ConcatDataset([mnist_dataset])# this is label 3
train_loader1 = torch.utils.data.DataLoader(train_dataset1, batch_size=batch_size, shuffle=True,pin_memory=True)
x_=torch.zeros([dataset_image_number,3,32,32])
for step, (images, labels) in enumerate(train_loader1):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    x_[step*batch_size:(step+1)*batch_size,:,:,:]=images
x_general=x_[0].mean(0)
print(x_general.shape)
print(x_.shape)
# Out:
# torch.Size([32, 32])
# torch.Size([256, 3, 32, 32])

# %%
# direct calculate the distance and compare them for original images
batch_size=256
train_dataset2 = torch.utils.data.ConcatDataset([mnist2_dataset])# this is label 2
train_loader2 = torch.utils.data.DataLoader(train_dataset2, batch_size=batch_size, shuffle=True,pin_memory=True)
y_=torch.zeros([dataset_image_number,3,32,32])
for step, (images, labels) in enumerate(train_loader2):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    y_[step*batch_size:(step+1)*batch_size,:,:,:]=images
y_general=y_[0].mean(0)
print(y_general.shape)
print(y_.shape)
# Out:
# torch.Size([32, 32])
# torch.Size([256, 3, 32, 32])

# %%
# direct calculate the distance and compare them for original images
accuaracy=0
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=1, shuffle=True,num_workers=4,pin_memory=True)

with torch.no_grad():
  for step, (image, label) in enumerate(train_loader11):
    batch_size = image.shape[0]
    image = image.to(device)
    x0=image
    a=torch.norm(x0[0,0,:,:]-x_general.to(device)).to(device)# distance between 3 and pred
    b=torch.norm(x0[0,0,:,:]-y_general.to(device)).to(device)# distance between 2 and pred
    if a >= b:
      pred_label= 9
      #print(a,"and",b)
    else:
      pred_label= 3
      #print(a,"and",b)
    if pred_label==label:
      accuaracy=accuaracy+1
      #print("exact!", pred_label,"the true is ",label)
print(accuaracy/len(train_dataset))
# Out:
# 0.546875

# %% [markdown]
# This is the test

# %%
# establish the x0,x1,x2,x3,x4 for class 1 label3
batch_size=256
early_stop_time=3
train_dataset1 = torch.utils.data.ConcatDataset([mnist_dataset])# this is label 3
train_loader1 = torch.utils.data.DataLoader(train_dataset1, batch_size=batch_size, shuffle=True,pin_memory=True)
T=torch.full((batch_size,),timesteps-1, device=device)
model = UNetModel(
    in_channels=3,
    model_channels=128,
    out_channels=3,
    #channel_mult=(1, 2, 2),
    attention_resolutions=[]
)
timsteps=5
model.to(device)
x_1=torch.zeros([timesteps,dataset_image_number,3,32,32])
for step, (images, labels) in enumerate(train_loader1):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    x0=images
    for t in range(timesteps-1,early_stop_time-1,-1):
      time = torch.full((batch_size,),t, device=device).long()
      # this is label 3
      model.load_state_dict(model_parameters[t],strict=True)
      model.eval()
      time=torch.full((batch_size,),t, device=device)
      predicted_noiset = model(x0, time)
      x0=gaussian_diffusion.predict_t_1_from_t(x0,predicted_noiset,t)
      x_1[t,step*batch_size:(step+1)*batch_size,:,:,:]=x0
x_1_general=x_1[early_stop_time].mean(0)
print(x_1_general.shape)
print(x_1.shape)
# Out:
# torch.Size([3, 32, 32])
# torch.Size([5, 256, 3, 32, 32])

# %%
# establish the x0,x1,x2,x3,x4 for class 2 label 2
batch_size=256
train_dataset2 = torch.utils.data.ConcatDataset([mnist2_dataset])# this is label 2
train_loader2 = torch.utils.data.DataLoader(train_dataset2, batch_size=batch_size, shuffle=True,pin_memory=True)
T=torch.full((batch_size,),timesteps-1, device=device)
model = UNetModel(
    in_channels=3,
    model_channels=128,
    out_channels=3,
    #channel_mult=(1, 2, 2),
    attention_resolutions=[]
)
early_stop_time=3
model.to(device)
timesteps
x_2=torch.zeros([timesteps,dataset_image_number,3,32,32])

for step, (images, labels) in enumerate(train_loader2):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    x0=images
    for t in range(timesteps-1,early_stop_time-1,-1):
      time = torch.full((batch_size,),t, device=device).long()
      # this is label 3
      model.load_state_dict(model_parameters[t],strict=True)
      model.eval()
      time=torch.full((batch_size,),t, device=device)
      predicted_noiset = model(x0, time)
      x0=gaussian_diffusion.predict_t_1_from_t(x0,predicted_noiset,t)
      x_2[t,step*batch_size:(step+1)*batch_size,:,:,:]=x0

x_2_general=x_2[early_stop_time].mean(0)
print(x_2_general.shape)
print(x_2.shape)
# Out:
# torch.Size([3, 32, 32])
# torch.Size([5, 256, 3, 32, 32])

# %%
#calculate the mean distance and variances within differenct class
for t in range(timesteps-1,early_stop_time-1,-1):
  print("distance",torch.norm(x_1[t].mean(0)-x_2[t].mean(0)))
  m1=x_1[t].reshape(batch_size,3*32*32)
  m2=x_2[t].reshape(batch_size,3*32*32)

  s1=torch.var(m1, dim=0)
  s2=torch.var(m2, dim=0)
  print("variance",s1.mean(0),s2.mean(0))
# Out:
# distance tensor(21.8233)
# variance tensor(0.8695) tensor(0.8783)
# distance tensor(68.7225)
# variance tensor(8.9876) tensor(9.2726)

# %%
#T=torch.full((1,),timesteps-1, device=device)
accuaracy=0
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=1, shuffle=True,num_workers=4,pin_memory=True)
acc=torch.zeros(timesteps)

with torch.no_grad():
  for step, (image, label) in enumerate(train_loader11):
    batch_size = image.shape[0]
    image = image.to(device)
    x0=image
    for t in range(timesteps-1,early_stop_time-1,-1):

      model.load_state_dict(model_parameters[t],strict=True)
      model.eval()
      time=torch.full((batch_size,),t, device=device)
      predicted_noiset = model(x0, time)
      x=gaussian_diffusion.predict_t_1_from_t(x0,predicted_noiset,t)
      x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset1_1,labels_1)])
      x0=x
      a=torch.norm(x0[0,:,:,:]-x_1[t].mean(0)[:,:,:].to(device)).to(device)# distance between 3 and pred
      b=torch.norm(x0[0,:,:,:]-x_2[t].mean(0)[:,:,:].to(device)).to(device)# distance between 2 and pred
      if a >= b:
        pred_label= 9
        #print(a,"and",b)
      else:
        pred_label= 3
        #print(a,"and",b)
        print(pred_label,label)
      if pred_label==label:
        acc[t]=acc[t]+1
      #print("exact!", pred_label,"the true is ",label)
      else:
        print("timestep", t, " find different label at step ", step, pred_label,"the true is ",label)
# Out:
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  2 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  2 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  7 9 the true is  tensor([3])
# timestep 3  find different label at step  7 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  15 9 the true is  tensor([3])
# timestep 3  find different label at step  15 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  29 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  29 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  32 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  32 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  39 9 the true is  tensor([3])
# timestep 3  find different label at step  39 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  40 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  40 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  43 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  43 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  46 9 the true is  tensor([3])
# timestep 3  find different label at step  46 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  47 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  47 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  49 9 the true is  tensor([3])
# timestep 3  find different label at step  49 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  55 9 the true is  tensor([3])
# timestep 3  find different label at step  55 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  59 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  59 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 3  find different label at step  78 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  89 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  89 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  91 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  91 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  99 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  99 3 the true is  tensor([9])
# timestep 4  find different label at step  100 9 the true is  tensor([3])
# timestep 3  find different label at step  100 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  104 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  104 3 the true is  tensor([9])
# timestep 4  find different label at step  105 9 the true is  tensor([3])
# timestep 3  find different label at step  105 9 the true is  tensor([3])
# timestep 4  find different label at step  107 9 the true is  tensor([3])
# timestep 3  find different label at step  107 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  109 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  109 3 the true is  tensor([9])
# timestep 4  find different label at step  111 9 the true is  tensor([3])
# timestep 3  find different label at step  111 9 the true is  tensor([3])
# timestep 4  find different label at step  112 9 the true is  tensor([3])
# timestep 3  find different label at step  112 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  115 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  115 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  127 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  135 9 the true is  tensor([3])
# timestep 3  find different label at step  135 9 the true is  tensor([3])
# timestep 4  find different label at step  137 9 the true is  tensor([3])
# timestep 3  find different label at step  137 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  138 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  138 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  139 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  139 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  141 9 the true is  tensor([3])
# timestep 3  find different label at step  141 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  147 9 the true is  tensor([3])
# timestep 3  find different label at step  147 9 the true is  tensor([3])
# timestep 4  find different label at step  148 9 the true is  tensor([3])
# timestep 3  find different label at step  148 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  159 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  159 3 the true is  tensor([9])
# timestep 4  find different label at step  161 9 the true is  tensor([3])
# timestep 3  find different label at step  161 9 the true is  tensor([3])
# timestep 4  find different label at step  163 9 the true is  tensor([3])
# timestep 3  find different label at step  163 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  170 9 the true is  tensor([3])
# timestep 3  find different label at step  170 9 the true is  tensor([3])
# timestep 4  find different label at step  172 9 the true is  tensor([3])
# timestep 3  find different label at step  172 9 the true is  tensor([3])
# timestep 4  find different label at step  173 9 the true is  tensor([3])
# timestep 3  find different label at step  173 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  175 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  175 3 the true is  tensor([9])
# timestep 4  find different label at step  176 9 the true is  tensor([3])
# timestep 3  find different label at step  176 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  179 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  179 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  181 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  181 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 3  find different label at step  186 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  195 9 the true is  tensor([3])
# timestep 3  find different label at step  195 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  211 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  211 3 the true is  tensor([9])
# timestep 4  find different label at step  213 9 the true is  tensor([3])
# timestep 3  find different label at step  213 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  215 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  215 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  216 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  227 9 the true is  tensor([3])
# timestep 3  find different label at step  227 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  230 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  230 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  233 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  233 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  239 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  239 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  241 9 the true is  tensor([3])
# timestep 3  find different label at step  241 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  246 9 the true is  tensor([3])
# timestep 3  find different label at step  246 9 the true is  tensor([3])
# timestep 4  find different label at step  247 9 the true is  tensor([3])
# timestep 3  find different label at step  247 9 the true is  tensor([3])
# timestep 4  find different label at step  248 9 the true is  tensor([3])
# timestep 3  find different label at step  248 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  254 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  254 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  262 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  262 3 the true is  tensor([9])
# timestep 4  find different label at step  263 9 the true is  tensor([3])
# timestep 3  find different label at step  263 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  270 9 the true is  tensor([3])
# timestep 3  find different label at step  270 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  272 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  272 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  274 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  274 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  277 9 the true is  tensor([3])
# timestep 3  find different label at step  277 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  287 9 the true is  tensor([3])
# timestep 3  find different label at step  287 9 the true is  tensor([3])
# timestep 4  find different label at step  288 9 the true is  tensor([3])
# timestep 3  find different label at step  288 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  290 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  290 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  296 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  296 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  302 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  302 3 the true is  tensor([9])
# timestep 4  find different label at step  303 9 the true is  tensor([3])
# timestep 3  find different label at step  303 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  306 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  306 3 the true is  tensor([9])
# timestep 4  find different label at step  307 9 the true is  tensor([3])
# timestep 3  find different label at step  307 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  316 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  316 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  320 9 the true is  tensor([3])
# timestep 3  find different label at step  320 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  329 9 the true is  tensor([3])
# timestep 3  find different label at step  329 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  336 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  336 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  341 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  341 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  342 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  342 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  348 9 the true is  tensor([3])
# timestep 3  find different label at step  348 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  354 9 the true is  tensor([3])
# timestep 3  find different label at step  354 9 the true is  tensor([3])
# timestep 4  find different label at step  356 9 the true is  tensor([3])
# timestep 3  find different label at step  356 9 the true is  tensor([3])
# timestep 4  find different label at step  358 9 the true is  tensor([3])
# timestep 3  find different label at step  358 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  364 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  364 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  369 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  369 3 the true is  tensor([9])
# timestep 4  find different label at step  372 9 the true is  tensor([3])
# timestep 3  find different label at step  372 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  373 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  373 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  376 9 the true is  tensor([3])
# timestep 3  find different label at step  376 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  379 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  379 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  386 9 the true is  tensor([3])
# timestep 3  find different label at step  386 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  388 9 the true is  tensor([3])
# timestep 3  find different label at step  388 9 the true is  tensor([3])
# timestep 4  find different label at step  389 9 the true is  tensor([3])
# timestep 3  find different label at step  389 9 the true is  tensor([3])
# timestep 4  find different label at step  391 9 the true is  tensor([3])
# timestep 3  find different label at step  391 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  393 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  393 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  397 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  397 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  404 9 the true is  tensor([3])
# timestep 3  find different label at step  404 9 the true is  tensor([3])
# timestep 4  find different label at step  405 9 the true is  tensor([3])
# timestep 3  find different label at step  405 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  411 9 the true is  tensor([3])
# timestep 3  find different label at step  411 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  414 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  414 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  416 9 the true is  tensor([3])
# timestep 3  find different label at step  416 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  417 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  417 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  418 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  418 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  419 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  420 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  420 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  421 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  421 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  428 3 the true is  tensor([9])
# timestep 4  find different label at step  429 9 the true is  tensor([3])
# timestep 3  find different label at step  429 9 the true is  tensor([3])
# timestep 4  find different label at step  431 9 the true is  tensor([3])
# timestep 3  find different label at step  431 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  435 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  435 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  436 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  436 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  438 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  438 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  445 9 the true is  tensor([3])
# timestep 3  find different label at step  445 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  447 9 the true is  tensor([3])
# timestep 3  find different label at step  447 9 the true is  tensor([3])
# timestep 4  find different label at step  449 9 the true is  tensor([3])
# timestep 3  find different label at step  449 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  450 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  450 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  451 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  451 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  456 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  457 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  457 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  463 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  463 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  465 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  465 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  470 9 the true is  tensor([3])
# timestep 3  find different label at step  470 9 the true is  tensor([3])
# timestep 4  find different label at step  471 9 the true is  tensor([3])
# timestep 3  find different label at step  471 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  472 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  472 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  474 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  474 3 the true is  tensor([9])
# timestep 4  find different label at step  475 9 the true is  tensor([3])
# timestep 3  find different label at step  475 9 the true is  tensor([3])
# timestep 4  find different label at step  476 9 the true is  tensor([3])
# timestep 3  find different label at step  476 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  479 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  479 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# timestep 4  find different label at step  483 9 the true is  tensor([3])
# timestep 3  find different label at step  483 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  485 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  485 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  490 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  490 3 the true is  tensor([9])
# timestep 4  find different label at step  491 9 the true is  tensor([3])
# timestep 3  find different label at step  491 9 the true is  tensor([3])
# timestep 4  find different label at step  492 9 the true is  tensor([3])
# timestep 3  find different label at step  492 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 3  find different label at step  493 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  494 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  494 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  504 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  504 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])

# %%
(acc/len(train_dataset))
# Out:
# tensor([0.0000, 0.0000, 0.0000, 0.7480, 0.7441])

# %%
# test dataset
test_dataset = datasets.CIFAR10('./data', train=False, download=True, transform=transform)
#test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

mnist3_indices_test = [i for i in range(len(test_dataset)) if test_dataset[i][1] == 3]
mnist2_indices_test = [i for i in range(len(test_dataset)) if test_dataset[i][1] == 9]

mnist_dataset_test3 = BinaryDataset(test_dataset, mnist3_indices_test,label=3 )
mnist_dataset_test2 = BinaryDataset(test_dataset, mnist2_indices_test,label=9 )

test_dataset = torch.utils.data.ConcatDataset([mnist_dataset_test3, mnist_dataset_test2])
print(len(mnist3_indices_test)/len(test_dataset))
print(len(mnist2_indices_test)/len(test_dataset))
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:07<00:00, 23179021.30it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# 0.5
# 0.5

# %%
# test on testset
test_acc=0
model.eval()
with torch.no_grad():
  for step, (image, label) in enumerate(test_loader):
    batch_size = image.shape[0]
    image = image.to(device)
    x0=image
    for t in range(timesteps-1,early_stop_time-1,-1):

      model.load_state_dict(model_parameters[t],strict=True)
      time=torch.full((batch_size,),t, device=device)
      predicted_noiset = model(x0, time)
      x=gaussian_diffusion.predict_t_1_from_t(x0,predicted_noiset,t)
      #x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset1_1,labels_1)])
      x0=x

    a=torch.norm(x0[0,:,:,:]-x_1[early_stop_time].mean(0)[:,:,:].to(device)).to(device)# distance between 3 and pred
    b=torch.norm(x0[0,:,:,:]-x_2[early_stop_time].mean(0)[:,:,:].to(device)).to(device)# distance between 2 and pred
    if a >= b:
      pred_label= 9
      #print(a,"and",b)
    else:
      pred_label= 3
      #print(a,"and",b)
    print(pred_label,label)
    if pred_label==label:
      test_acc=test_acc+1
      #print("exact!", pred_label,"the true is ",label)
    else:
      print("find different label at step ", step, pred_label,"the true is ",label)

print(test_acc/len(test_dataset))
# Out:
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  2 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  3 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  4 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  9 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  17 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  22 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  23 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  26 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  35 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  36 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  37 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  48 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  56 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  62 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  69 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  76 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  77 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  83 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  88 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  91 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  104 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  105 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  110 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  115 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  117 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  119 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  121 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  128 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  133 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  138 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  145 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  147 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  148 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  152 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  155 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  161 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  163 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  164 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  169 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  171 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  174 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  179 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  180 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  185 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  186 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  188 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  190 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  192 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  196 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  197 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  201 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  211 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  214 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  219 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  220 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  221 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  223 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  226 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  227 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  229 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  230 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  231 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  232 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  233 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  234 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  236 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  245 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  250 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  255 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  263 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  264 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  266 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  269 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  271 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  272 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  277 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  278 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  287 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  289 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  292 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  293 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  298 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  301 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  302 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  310 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  312 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  319 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  334 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  336 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  337 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  338 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  341 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  342 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  345 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  350 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  365 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  369 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  375 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  382 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  383 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  390 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  414 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  424 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  431 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  439 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  442 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  446 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  449 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  451 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  454 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  457 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  460 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  463 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  467 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  469 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  470 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  473 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  476 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  477 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  478 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  480 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  483 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  485 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  487 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  489 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  490 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  498 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  503 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  514 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  516 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  523 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  524 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  525 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  526 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  531 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  532 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  542 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  544 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  548 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  557 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  560 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  563 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  565 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  570 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  575 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  578 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  585 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  586 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  594 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  601 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  603 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  612 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  622 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  628 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  632 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  633 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  637 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  645 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  649 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  652 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  654 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  666 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  669 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  670 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  671 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  681 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  686 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  689 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  694 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  696 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  699 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  700 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  706 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  711 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  720 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  728 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  730 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  733 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  743 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  745 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  754 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  756 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  762 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  767 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  768 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  769 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  772 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  773 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  774 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  778 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  780 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  782 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  783 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  789 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  791 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  798 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  801 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  809 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  810 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  813 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  827 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  829 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  834 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  839 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  841 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  843 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  847 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  850 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  851 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  853 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  857 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  858 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  859 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  861 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  879 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  880 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  887 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  891 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  892 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  897 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  904 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  911 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  913 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  914 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  915 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  921 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  925 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  926 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  929 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  934 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  935 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  937 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  941 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  943 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  944 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  953 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  963 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  964 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  967 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  972 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  974 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  976 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  983 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  984 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  987 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  993 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1001 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1011 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1012 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1014 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1015 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1024 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1026 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1036 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1048 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1051 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1068 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1070 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1083 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1091 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1097 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1098 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1100 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1110 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1113 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1116 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1117 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1120 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1123 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1125 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1131 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1132 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1134 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1136 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1137 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1139 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1141 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1143 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1144 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1149 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1153 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1155 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1157 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1163 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1169 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1170 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1171 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1174 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1175 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1184 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1193 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1196 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1197 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1199 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1206 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1207 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1210 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1212 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1215 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1219 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1221 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1223 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1228 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1240 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1242 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1243 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1245 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1248 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1249 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1251 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1252 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1255 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1259 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1261 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1262 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1265 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1266 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1270 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1275 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1276 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1278 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1284 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1288 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1291 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1295 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1296 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1299 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1300 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1303 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1306 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1318 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1319 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1320 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1323 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1325 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1326 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1330 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1331 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1345 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1348 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1352 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1356 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1357 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1365 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1366 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1367 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1369 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1372 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1373 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1387 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1389 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1394 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1397 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1402 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1412 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1413 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1414 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1415 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1421 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1428 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1434 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1436 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1440 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1442 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1443 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1444 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1446 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1450 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1460 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1462 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1474 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1476 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1478 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1479 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1483 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1491 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1498 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1499 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1512 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1519 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1521 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1530 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1531 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1534 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1536 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1537 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1538 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1539 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1543 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1556 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1559 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1562 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1563 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1565 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1566 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1567 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1568 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1574 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1577 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1578 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1579 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1580 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1584 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1586 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1593 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1599 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1607 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1610 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1614 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1615 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1616 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1617 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1619 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1623 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1624 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1628 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1630 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1632 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1634 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1635 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1639 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1643 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1644 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1646 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1648 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1650 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1651 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1652 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1655 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1658 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1664 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1665 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1667 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1676 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1679 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1681 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1682 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1684 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1690 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1715 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1723 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1726 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1731 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1735 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1739 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1740 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1741 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1743 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1748 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1749 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1750 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1752 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1753 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1754 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1756 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1757 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1758 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1759 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1764 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1770 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1773 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1781 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1791 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1796 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1800 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1809 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1820 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1827 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1830 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1839 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1840 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1842 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1844 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1845 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1850 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1859 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1865 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1866 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1867 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1870 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1871 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1872 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1877 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1883 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1888 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1890 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1892 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1897 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1900 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1903 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1907 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1909 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1913 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1917 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1921 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1928 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1930 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1931 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1934 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1936 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1943 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1951 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1954 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1956 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1958 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1960 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1970 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1971 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1974 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1977 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1989 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1996 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 0.744

# %%
from sklearn import preprocessing
from sklearn.manifold import TSNE
import torch
import torchvision
import matplotlib.pyplot as plt
def plot(x_t_train_dataset_t,labels_1):
  tsne = TSNE(n_components=2, verbose=1 ,random_state=42)
  x_t_train_dataset_t = x_t_train_dataset_t.view(len(x_t_train_dataset_t), -1)
  result = tsne.fit_transform(x_t_train_dataset_t)
  scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))
  result = scaler.fit_transform(result)
  fig = plt.figure(figsize=(5, 5))
  ax = fig.add_subplot()
  ax.set_title('t-SNE process')
  ax.scatter(result[:,0], result[:,1],c=labels_1, s=20)

# %%
# This is the visilization of  original images.
t=5
b=256

model = UNetModel(
    in_channels=3,
    model_channels=128,
    out_channels=3,
    #channel_mult=(1, 2, 2),
    attention_resolutions=[]
  )
model.to(device)
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
#train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=b, shuffle=False,num_workers=4,pin_memory=True)

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=b, shuffle=False)
  for step, (images1, labels) in enumerate(train_loader11):

    images1=images1.to(device)
    batch_size=images1.shape[0]
    print(step)
    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
# Out:
# 0
# 1
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.001s...
# [t-SNE] Computed neighbors for 512 samples in 0.196s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 9.282622
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.196053
# [t-SNE] KL divergence after 1000 iterations: 1.203893

# %%
# This is the first layer.
# for t =4
t=4
b=256

model = UNetModel(
    in_channels=3,
    model_channels=128,
    out_channels=3,
    #channel_mult=(1, 2, 2),
    attention_resolutions=[]
  )
model.to(device)
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
#train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=b, shuffle=True,num_workers=4,pin_memory=True)

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    predicted_noise = model(xt1, time)
    images1=gaussian_diffusion.predict_t_1_from_t(xt1, predicted_noise,t)

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
    del predicted_noise
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.001s...
# [t-SNE] Computed neighbors for 512 samples in 0.041s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 15.934987
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.858376
# [t-SNE] KL divergence after 1000 iterations: 1.343952

# %%
# This is the second layer.
t=3
model = UNetModel(
    in_channels=3,
    model_channels=128,
    out_channels=3,
    #channel_mult=(1, 2, 2),
    attention_resolutions=[]
  )
model.to(device)
batch_size=b*2
x_t_train_dataset_t=torch.zeros([b*2,3,32,32])

train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False)
labels_1=torch.zeros([b*2])
model.eval()
with torch.no_grad():
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)

    predicted_noise = model(xt1, time)
    images1=gaussian_diffusion.predict_t_1_from_t(xt1, predicted_noise,t)

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
    del predicted_noise
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.001s...
# [t-SNE] Computed neighbors for 512 samples in 0.062s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 50.140739
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.969543
# [t-SNE] KL divergence after 1000 iterations: 1.374663

# %%
# This is the third layer.
t=2
model = UNetModel(
    in_channels=1,
    model_channels=96,
    out_channels=1,
    channel_mult=(1, 2, 2),
    attention_resolutions=[]
  )
model.to(device)

x_t_train_dataset_t=torch.zeros([b*2,1,28,28])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    predicted_noise = model(xt1, time)
    images1=gaussian_diffusion.predict_t_1_from_t(xt1, predicted_noise,t)

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
    del predicted_noise
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-17fd048b28d0> in <cell line: 15>()
#      17   for step, (images1, labels) in enumerate(train_loader11):
#      18     xt1 = images1.to(device)
# ---> 19     model.load_state_dict(model_parameters[t],strict=True)
#      20     model.eval()
#      21
#
# KeyError: 2

# %%
# This is the fourth layer.
t=1
model = UNetModel(
    in_channels=1,
    model_channels=96,
    out_channels=1,
    channel_mult=(1, 2, 2),
    attention_resolutions=[]
  )
model.to(device)

x_t_train_dataset_t=torch.zeros([b*2,1,28,28])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False,num_workers=2,pin_memory=True)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    predicted_noise = model(xt1, time)
    images1=gaussian_diffusion.predict_t_1_from_t(xt1, predicted_noise,t)

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
    del predicted_noise
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-05b9487951ef> in <cell line: 15>()
#      17   for step, (images1, labels) in enumerate(train_loader11):
#      18     xt1 = images1.to(device)
# ---> 19     model.load_state_dict(model_parameters[t],strict=True)
#      20     model.eval()
#      21
#
# KeyError: 1

# %%
# This is the 5th layer.
t=0
model = UNetModel(
    in_channels=1,
    model_channels=96,
    out_channels=1,
    channel_mult=(1, 2, 2),
    attention_resolutions=[]
  )
model.to(device)

x_t_train_dataset_t=torch.zeros([b*2,1,28,28])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False,num_workers=2,pin_memory=True)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    predicted_noise = model(xt1, time)
    images1=gaussian_diffusion.predict_t_1_from_t(xt1, predicted_noise,t)

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
    del predicted_noise
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-4b02ea63e43f> in <cell line: 15>()
#      17   for step, (images1, labels) in enumerate(train_loader11):
#      18     xt1 = images1.to(device)
# ---> 19     model.load_state_dict(model_parameters[t],strict=True)
#      20     model.eval()
#      21
#
# KeyError: 0
