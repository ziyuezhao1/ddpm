# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyuezhao1/ddpm/blob/main/DDPMfinal1_forcir10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 模型

# %%
# no problem
import os
import math
from abc import abstractmethod

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm

# %%
# 无需更改

def timestep_embedding(timesteps, dim, max_period=10000):
    """Create sinusoidal timestep embeddings.

    Args:
        timesteps (Tensor): a 1-D Tensor of N indices, one per batch element. These may be fractional.
        dim (int): the dimension of the output.
        max_period (int, optional): controls the minimum frequency of the embeddings. Defaults to 10000.

    Returns:
        Tensor: an [N x dim] Tensor of positional embeddings.
    """
    half = dim // 2
    freqs = torch.exp(
        -math.log(max_period) * torch.arange(start=0, end=half, dtype=torch.float32) / half
    ).to(device=timesteps.device)
    args = timesteps[:, None].float() * freqs[None]
    embedding = torch.cat([torch.cos(args), torch.sin(args)], dim=-1)
    if dim % 2:
        embedding = torch.cat([embedding, torch.zeros_like(embedding[:, :1])], dim=-1)
    return embedding

class TimestepBlock(nn.Module):
    """
    Any module where forward() takes timestep embeddings as a second argument.
    """

    @abstractmethod
    def forward(self, x, t):
        """
        Apply the module to `x` given `t` timestep embeddings.
        """
        pass

class TimestepEmbedSequential(nn.Sequential, TimestepBlock):
    """
    A sequential module that passes timestep embeddings to the children that support it as an extra input.
    """

    def forward(self, x, t):
        for layer in self:
            if isinstance(layer, TimestepBlock):
                x = layer(x, t)
            else:
                x = layer(x)
        return x

def norm_layer(channels):
    return nn.GroupNorm(32, channels)

class ResidualBlock(TimestepBlock):
    def __init__(self, in_channels, out_channels, time_channels, dropout):
        super().__init__()
        self.conv1 = nn.Sequential(
            norm_layer(in_channels),
            nn.SiLU(),
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        )

        # pojection for time step embedding
        self.time_emb = nn.Sequential(
            nn.SiLU(),
            nn.Linear(time_channels, out_channels)
        )

        self.conv2 = nn.Sequential(
            norm_layer(out_channels),
            nn.SiLU(),
            nn.Dropout(p=dropout),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        )

        if in_channels != out_channels:
            self.shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        else:
            self.shortcut = nn.Identity()


    def forward(self, x, t):
        """
        `x` has shape `[batch_size, in_dim, height, width]`
        `t` has shape `[batch_size, time_dim]`
        """
        h = self.conv1(x)
        # Add time step embeddings
        h += self.time_emb(t)[:, :, None, None]
        h = self.conv2(h)
        return h + self.shortcut(x)


class AttentionBlock(nn.Module):
    def __init__(self, channels, num_heads=1):
        """
        Attention block with shortcut

        Args:
            channels (int): channels
            num_heads (int, optional): attention heads. Defaults to 1.
        """
        super().__init__()
        self.num_heads = num_heads
        assert channels % num_heads == 0

        self.norm = norm_layer(channels)
        self.qkv = nn.Conv2d(channels, channels * 3, kernel_size=1, bias=False)
        self.proj = nn.Conv2d(channels, channels, kernel_size=1)

    def forward(self, x):
        B, C, H, W = x.shape
        qkv = self.qkv(self.norm(x))
        q, k, v = qkv.reshape(B*self.num_heads, -1, H*W).chunk(3, dim=1)
        scale = 1. / math.sqrt(math.sqrt(C // self.num_heads))
        attn = torch.einsum("bct,bcs->bts", q * scale, k * scale)
        attn = attn.softmax(dim=-1)
        h = torch.einsum("bts,bcs->bct", attn, v)
        h = h.reshape(B, -1, H, W)
        h = self.proj(h)
        return h + x


class Upsample(nn.Module):
    def __init__(self, channels, use_conv):
        super().__init__()
        self.use_conv = use_conv
        if use_conv:
            self.conv = nn.Conv2d(channels, channels, kernel_size=3, padding=1)

    def forward(self, x):
        x = F.interpolate(x, scale_factor=2, mode="nearest")
        if self.use_conv:
            x = self.conv(x)
        return x


class Downsample(nn.Module):
    def __init__(self, channels, use_conv):
        super().__init__()
        self.use_conv = use_conv
        if use_conv:
            self.op = nn.Conv2d(channels, channels, kernel_size=3, stride=2, padding=1)
        else:
            self.op = nn.AvgPool2d(stride=2)

    def forward(self, x):
        return self.op(x)


class UNetModel(nn.Module):
    """
    The full UNet model with attention and timestep embedding
    """
    def __init__(
        self,
        in_channels=3,
        model_channels=128,
        out_channels=3,
        num_res_blocks=2,
        attention_resolutions=(8, 16),
        dropout=0,
        channel_mult=(1, 2, 2, 2),
        conv_resample=True,
        num_heads=4
    ):
        super().__init__()

        self.in_channels = in_channels
        self.model_channels = model_channels
        self.out_channels = out_channels
        self.num_res_blocks = num_res_blocks
        self.attention_resolutions = attention_resolutions
        self.dropout = dropout
        self.channel_mult = channel_mult
        self.conv_resample = conv_resample
        self.num_heads = num_heads

        # time embedding
        time_embed_dim = model_channels * 4
        self.time_embed = nn.Sequential(
            nn.Linear(model_channels, time_embed_dim),
            nn.SiLU(),
            nn.Linear(time_embed_dim, time_embed_dim),
        )

        # down blocks
        self.down_blocks = nn.ModuleList([
            TimestepEmbedSequential(nn.Conv2d(in_channels, model_channels, kernel_size=3, padding=1))
        ])
        down_block_chans = [model_channels]
        ch = model_channels
        ds = 1
        for level, mult in enumerate(channel_mult):
            for _ in range(num_res_blocks):
                layers = [
                    ResidualBlock(ch, mult * model_channels, time_embed_dim, dropout)
                ]
                ch = mult * model_channels
                if ds in attention_resolutions:
                    layers.append(AttentionBlock(ch, num_heads=num_heads))
                self.down_blocks.append(TimestepEmbedSequential(*layers))
                down_block_chans.append(ch)
            if level != len(channel_mult) - 1: # don't use downsample for the last stage
                self.down_blocks.append(TimestepEmbedSequential(Downsample(ch, conv_resample)))
                down_block_chans.append(ch)
                ds *= 2

        # middle block
        self.middle_block = TimestepEmbedSequential(
            ResidualBlock(ch, ch, time_embed_dim, dropout),
            AttentionBlock(ch, num_heads=num_heads),
            ResidualBlock(ch, ch, time_embed_dim, dropout)
        )

        # up blocks
        self.up_blocks = nn.ModuleList([])
        for level, mult in list(enumerate(channel_mult))[::-1]:
            for i in range(num_res_blocks + 1):
                layers = [
                    ResidualBlock(
                        ch + down_block_chans.pop(),
                        model_channels * mult,
                        time_embed_dim,
                        dropout
                    )
                ]
                ch = model_channels * mult
                if ds in attention_resolutions:
                    layers.append(AttentionBlock(ch, num_heads=num_heads))
                if level and i == num_res_blocks:
                    layers.append(Upsample(ch, conv_resample))
                    ds //= 2
                self.up_blocks.append(TimestepEmbedSequential(*layers))

        self.out = nn.Sequential(
            norm_layer(ch),
            nn.SiLU(),
            nn.Conv2d(model_channels, out_channels, kernel_size=3, padding=1),
        )

    def forward(self, x, timesteps):
        """Apply the model to an input batch.

        Args:
            x (Tensor): [N x C x H x W]
            timesteps (Tensor): a 1-D batch of timesteps.

        Returns:
            Tensor: [N x C x ...]
        """
        hs = []
        # time step embedding
        emb = self.time_embed(timestep_embedding(timesteps, self.model_channels))

        # down stage
        h = x
        for module in self.down_blocks:
            h = module(h, emb)
            hs.append(h)
        # middle stage
        h = self.middle_block(h, emb)
        # up stage
        for module in self.up_blocks:
            cat_in = torch.cat([h, hs.pop()], dim=1)
            h = module(cat_in, emb)
        return self.out(h)


def linear_beta_schedule(timesteps):
    """
    beta schedule
    """
    scale = 10 / timesteps
    beta_start = scale * 0.01
    beta_end = scale * 0.9
    return torch.linspace(beta_start, beta_end, timesteps, dtype=torch.float64)


def cosine_beta_schedule(timesteps, s=0.008):
    """
    cosine schedule
    as proposed in https://arxiv.org/abs/2102.09672
    """
    steps = timesteps + 1
    x = torch.linspace(0, timesteps, steps, dtype=torch.float64)
    alphas_cumprod = torch.cos(((x / timesteps) + s) / (1 + s) * math.pi * 0.5) ** 2
    alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
    betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
    return torch.clip(betas, 0, 0.999)

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections.abc import Iterable
from itertools import repeat

DEFAULT_DTYPE = torch.float32


def DEFAULT_INITIALIZER(x, scale=1.):
    """
    PyTorch Xavier uniform initialization: w ~ Uniform(-a, a), where a = gain * (6 / (fan_in + fan_out)) ** .5
    TensorFlow Variance-Scaling initialization (mode="fan_avg", distribution="uniform"):
    w ~ Uniform(-a, a), where a = (6 * scale / (fan_in + fan_out)) ** .5
    Therefore, gain = scale ** .5
    """
    return nn.init.xavier_uniform_(x, gain=math.sqrt(scale or 1e-10))


def ntuple(n, name="parse"):
    def parse(x):
        if isinstance(x, Iterable):
            return tuple(x)
        else:
            return tuple(repeat(x, n))
    parse.__name__ = name
    return parse


pair = ntuple(2, "pair")


class Linear(nn.Module):
    def __init__(
            self,
            in_features,
            out_features,
            bias=True,
            init_scale=1.
    ):
        super(Linear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = nn.Parameter(torch.empty((out_features, in_features), dtype=DEFAULT_DTYPE))
        if bias:
            self.bias = nn.Parameter(torch.empty((out_features, ), dtype=DEFAULT_DTYPE))
        else:
            self.register_parameter('bias', None)
        self.init_scale = init_scale
        self.reset_parameters()

    def reset_parameters(self):
        DEFAULT_INITIALIZER(self.weight, scale=self.init_scale)
        if self.bias is not None:
            nn.init.zeros_(self.bias)

    def forward(self, input):
        return F.linear(input, self.weight, self.bias)

    def extra_repr(self):
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias is not None)


class Conv2d(nn.Module):
    def __init__(
            self,
            in_channels,
            out_channels,
            kernel_size,
            stride=1,
            padding=0,
            dilation=1,
            groups=1,
            bias=True,
            padding_mode="zeros",
            init_scale=1.
    ):
        super(Conv2d, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size = pair(kernel_size)
        self.weight = nn.Parameter(
            torch.empty((
                out_channels, in_channels // groups, kernel_size[0], kernel_size[1]
            ), dtype=DEFAULT_DTYPE))
        if bias:
            self.bias = nn.Parameter(torch.empty((out_channels, ), dtype=DEFAULT_DTYPE))
        else:
            self.register_parameter("bias", None)
        self.stride = pair(stride)
        self.padding = padding if isinstance(padding, str) else pair(padding)
        self.dilation = pair(dilation)
        self.groups = groups
        self.padding_mode = padding_mode
        self.init_scale = init_scale
        self.reset_parameter()

    def reset_parameter(self):
        DEFAULT_INITIALIZER(self.weight, scale=self.init_scale)
        if self.bias is not None:
            nn.init.zeros_(self.bias)

    def extra_repr(self):
        s = ('{in_channels}, {out_channels}, kernel_size={kernel_size}'
             ', stride={stride}')
        if self.padding != (0,) * len(self.padding):
            s += ', padding={padding}'
        if self.dilation != (1,) * len(self.dilation):
            s += ', dilation={dilation}'
        if self.groups != 1:
            s += ', groups={groups}'
        if self.bias is None:
            s += ', bias=False'
        if self.padding_mode != 'zeros':
            s += ', padding_mode={padding_mode}'
        return s.format(**self.__dict__)

    def forward(self, x):
        return F.conv2d(
            x, self.weight, self.bias, stride=self.stride, padding=self.padding,
            dilation=self.dilation, groups=self.groups)


class ValidPad2d(nn.Module):
    def __init__(self, kernel_size, stride, mode="constant", value=0.0):
        super(ValidPad2d, self).__init__()
        self.kernel_size = pair(kernel_size)
        self.stride = pair(stride)
        self.mode = mode
        self.value = value

    def forward(self, x):
        _, _, h, w = x.shape
        (k1, k2), (s1, s2) = self.kernel_size, self.stride
        h_pad, w_pad = s1 * math.ceil((h - k1 + 1) / s1 - 1) + k1 - h, \
                       s2 * math.ceil((w - k2 + 1) / s2 - 1) + k2 - w
        top_pad, bottom_pad = (math.floor(h_pad / 2), math.ceil(h_pad / 2)) if h_pad else (0, 0)
        left_pad, right_pad = (math.floor(w_pad / 2), math.ceil(w_pad / 2)) if w_pad else (0, 0)
        x = F.pad(x, pad=(left_pad, right_pad, top_pad, bottom_pad), mode=self.mode, value=self.value)
        return x


class SamePad2d(nn.Module):
    def __init__(self, kernel_size, stride, mode="constant", value=0.0):
        super(SamePad2d, self).__init__()
        self.kernel_size = pair(kernel_size)
        self.stride = pair(stride)
        self.mode = mode
        self.value = value

    def forward(self, x):
        _, _, h, w = x.shape
        (k1, k2), (s1, s2) = self.kernel_size, self.stride
        h_pad, w_pad = s1 * math.ceil(h / s1 - 1) + k1 - h, s2 * math.ceil(w / s2 - 1) + k2 - w
        top_pad, bottom_pad = (math.floor(h_pad / 2), math.ceil(h_pad / 2)) if h_pad else (0, 0)
        left_pad, right_pad = (math.floor(w_pad / 2), math.ceil(w_pad / 2)) if w_pad else (0, 0)
        x = F.pad(x, pad=(left_pad, right_pad, top_pad, bottom_pad), mode=self.mode, value=self.value)
        return x


class Sequential(nn.Sequential):
    def forward(self, input, **kwargs):
        for module in self:
            input = module(input, **kwargs)
        return input

# %%
import math
import numpy as np
import torch
import torch.nn.functional as F
from typing import Union, Tuple

DEFAULT_DTYPE = torch.float32

@torch.jit.script
def get_timestep_embedding(timesteps, embed_dim: int, dtype: torch.dtype = DEFAULT_DTYPE):
    """
    Adapted from fairseq/fairseq/modules/sinusoidal_positional_embedding.py
    The implementation is slightly different from the decription in Section 3.5 of [1]
    [1] Vaswani, Ashish, et al. "Attention is all you need."
     Advances in neural information processing systems 30 (2017).
    """
    half_dim = embed_dim // 2
    embed = math.log(10000) / (half_dim - 1)
    embed = torch.exp(-torch.arange(half_dim, dtype=dtype, device=timesteps.device) * embed)
    embed = torch.outer(timesteps.ravel().to(dtype), embed)
    embed = torch.cat([torch.sin(embed), torch.cos(embed)], dim=1)
    if embed_dim % 2 == 1:
        embed = F.pad(embed, [0, 1])  # padding the last dimension
    assert embed.dtype == dtype
    return embed


@torch.jit.script
def normal_kl(mean1, logvar1, mean2, logvar2):
    diff_logvar = logvar1 - logvar2
    kl = (-1.0 - diff_logvar).add(
        (mean1 - mean2).pow(2) * torch.exp(-logvar2)).add(
        torch.exp(diff_logvar)).mul(0.5)
    return kl


@torch.jit.script
def approx_std_normal_cdf(x):
    """
    Reference:
    Page, E. “Approximations to the Cumulative Normal Function and Its Inverse for Use on a Pocket Calculator.”
     Applied Statistics 26.1 (1977): 75–76. Web.
    """
    return 0.5 * (1. + torch.tanh(math.sqrt(2. / math.pi) * (x + 0.044715 * torch.pow(x, 3))))


@torch.jit.script
def discretized_gaussian_loglik(
        x, means, log_scale, precision: float = 1./255,
        cutoff: Union[float, Tuple[float, float]] = (-0.999, 0.999), tol: float = 1e-12):
    if isinstance(cutoff, float):
        cutoff = (-cutoff, cutoff)
    # Assumes data is integers [0, 255] rescaled to [-1, 1]
    x_centered = x - means
    inv_stdv = torch.exp(-log_scale)
    upper = inv_stdv * (x_centered + precision)
    cdf_upper = torch.where(
        x > cutoff[1], torch.as_tensor(1, dtype=torch.float32, device=x.device), approx_std_normal_cdf(upper))
    lower = inv_stdv * (x_centered - precision)
    cdf_lower = torch.where(
        x < cutoff[0], torch.as_tensor(0, dtype=torch.float32, device=x.device), approx_std_normal_cdf(lower))
    log_probs = torch.log(torch.clamp(cdf_upper - cdf_lower - tol, min=0).add(tol))
    return log_probs


@torch.jit.script
def continuous_gaussian_loglik(x, mean, logvar):
    x_centered = x - mean
    inv_var = torch.exp(-logvar)
    log_probs = x_centered.pow(2) * inv_var + math.log(2 * math.pi) + logvar
    return log_probs.mul(0.5).neg()


def discrete_klv2d(hist1, hist2, eps=1e-9):
    """
    compute the discretized (empirical) Kullback-Leibler divergence between P_data1 and P_data2
    """
    return np.sum(hist2 * (np.log(hist2 + eps) - np.log(hist1 + eps)))


def hist2d(data, bins, value_range=None):
    """
    compute the 2d histogram matrix for a set of data points
    """
    if bins == "auto":
        bins = math.floor(math.sqrt(len(data) // 10))
    if value_range is not None:
        if isinstance(value_range, (int, float)):
            value_range = ((-value_range, value_range), ) * 2
        if hasattr(value_range, "__iter__"):
            if not hasattr(next(iter(value_range)), "__iter__"):
                value_range = (value_range, ) * 2
    x, y = np.split(data, 2, axis=1)
    x, y = x.squeeze(1), y.squeeze(1)
    return np.histogram2d(x, y, bins=bins, range=value_range)[0]


def flat_mean(x, start_dim=1):
    reduce_dim = [i for i in range(start_dim, x.ndim)]
    return torch.mean(x, dim=reduce_dim)


def flat_sum(x, start_dim=1):
    reduce_dim = [i for i in range(start_dim, x.ndim)]
    return torch.sum(x, dim=reduce_dim)

# %%
import math
import torch
import torch.nn as nn


DEFAULT_NONLINEARITY = nn.SiLU()  # f(x)=x*sigmoid(x)


class DEFAULT_NORMALIZER(nn.GroupNorm):
    def __init__(self, num_channels, num_groups=32):
        super().__init__(num_groups=num_groups, num_channels=num_channels, eps=1e-6)  # PyTorch default eps is 1e-5


class AttentionBlock(nn.Module):
    normalize = DEFAULT_NORMALIZER

    def __init__(
            self,
            in_channels,
            mid_channels=None,
            out_channels=None
    ):
        super(AttentionBlock, self).__init__()
        mid_channels = mid_channels or in_channels
        out_channels = out_channels or in_channels
        self.norm = self.normalize(in_channels)
        self.project_in = Conv2d(in_channels, 3 * mid_channels, 1)
        self.project_out = Conv2d(mid_channels, out_channels, 1, init_scale=0.)
        self.in_channels = in_channels
        self.mid_channels = mid_channels
        self.out_channels = out_channels
        self.skip = nn.Identity() if in_channels == out_channels else Conv2d(in_channels, out_channels, 1)

    @staticmethod
    def qkv(q, k, v):
        B, C, H, W = q.shape
        w = torch.einsum("bchw, bcHW -> bhwHW", q, k)
        w = torch.softmax(
            w.reshape(B, H, W, H * W) / math.sqrt(C), dim=-1
        ).reshape(B, H, W, H, W)
        out = torch.einsum("bhwHW, bcHW -> bchw", w, v)  # this will break the contiguity -> impaired performance
        return out.contiguous()  # force to return a contiguous tensor

    def forward(self, x, **kwargs):
        skip = self.skip(x)
        C = x.shape[1]
        assert C == self.in_channels
        q, k, v = self.project_in(self.norm(x)).chunk(3, dim=1)
        x = self.qkv(q, k, v)
        x = self.project_out(x)
        return x + skip


class ResidualBlock(nn.Module):
    normalize = DEFAULT_NORMALIZER
    nonlinearity = DEFAULT_NONLINEARITY

    def __init__(
            self,
            in_channels,
            out_channels,
            embed_dim,
            drop_rate=0.
    ):
        super(ResidualBlock, self).__init__()
        self.norm1 = self.normalize(in_channels)
        self.conv1 = Conv2d(in_channels, out_channels, 3, 1, 1)
        self.fc = Linear(embed_dim, out_channels)
        self.norm2 = self.normalize(out_channels)
        self.conv2 = Conv2d(out_channels, out_channels, 3, 1, 1, init_scale=0.)
        self.skip = nn.Identity() if in_channels == out_channels else Conv2d(in_channels, out_channels, 1)
        self.dropout = nn.Dropout(p=drop_rate, inplace=True)

    def forward(self, x, t_emb):
        skip = self.skip(x)
        x = self.conv1(self.nonlinearity(self.norm1(x)))
        x += self.fc(self.nonlinearity(t_emb))[:, :, None, None]
        x = self.dropout(self.nonlinearity(self.norm2(x)))
        x = self.conv2(x)
        return x + skip


class UNet(nn.Module):
    normalize = DEFAULT_NORMALIZER
    nonlinearity = DEFAULT_NONLINEARITY

    def __init__(
            self,
            in_channels,
            hid_channels,
            out_channels,
            ch_multipliers,
            num_res_blocks,
            apply_attn,
            time_embedding_dim=None,
            drop_rate=0.,
            resample_with_conv=True
    ):
        super(UNet, self).__init__()
        self.in_channels = in_channels
        self.hid_channels = hid_channels
        self.out_channels = out_channels
        self.time_embedding_dim = time_embedding_dim or 4 * self.hid_channels
        levels = len(ch_multipliers)
        self.ch_multipliers = ch_multipliers
        if isinstance(apply_attn, bool):
            apply_attn = [apply_attn for _ in range(levels)]
        self.apply_attn = apply_attn
        self.num_res_blocks = num_res_blocks
        self.drop_rate = drop_rate
        self.resample_with_conv = resample_with_conv

        self.embed = Sequential(
            Linear(self.hid_channels, self.time_embedding_dim),
            self.nonlinearity,
            Linear(self.time_embedding_dim, self.time_embedding_dim)
        )
        self.in_conv = Conv2d(in_channels, hid_channels, 3, 1, 1)
        self.levels = levels
        self.downsamples = nn.ModuleDict({f"level_{i}": self._get_downsample_by_level(i) for i in range(levels)})
        mid_channels = ch_multipliers[-1] * hid_channels
        embed_dim = self.time_embedding_dim
        self.middle = Sequential(
            ResidualBlock(mid_channels, mid_channels, embed_dim=embed_dim, drop_rate=drop_rate),
            AttentionBlock(mid_channels),
            ResidualBlock(mid_channels, mid_channels, embed_dim=embed_dim, drop_rate=drop_rate)
        )
        self.upsamples = nn.ModuleDict({f"level_{i}": self._get_upsample_by_level(i) for i in range(levels)})
        self.out_conv = Sequential(
            self.normalize(hid_channels),
            self.nonlinearity,
            Conv2d(hid_channels, out_channels, 3, 1, 1, init_scale=0.)
        )

    def _get_block_by_level(self, level):
        block_kwargs = {"embed_dim": self.time_embedding_dim, "drop_rate": self.drop_rate}
        if self.apply_attn[level]:
            def block(in_chans, out_chans):
                return Sequential(
                    ResidualBlock(in_chans, out_chans, **block_kwargs),
                    AttentionBlock(out_chans))
        else:
            def block(in_chans, out_chans):
                return ResidualBlock(in_chans, out_chans, **block_kwargs)
        return block

    def _get_downsample_by_level(self, level):
        block = self._get_block_by_level(level)
        prev_chans = (self.ch_multipliers[level-1] if level else 1) * self.hid_channels
        curr_chans = self.ch_multipliers[level] * self.hid_channels
        modules = nn.ModuleList([block(prev_chans, curr_chans)])
        for _ in range(self.num_res_blocks - 1):
            modules.append(block(curr_chans, curr_chans))
        if level != self.levels - 1:
            if self.resample_with_conv:
                downsample = Sequential(
                    SamePad2d(3, 2),  # custom same padding
                    Conv2d(curr_chans, curr_chans, 3, 2))
            else:
                downsample = nn.AvgPool2d(2)
            modules.append(downsample)
        return modules

    def _get_upsample_by_level(self, level):
        block = self._get_block_by_level(level)
        ch = self.hid_channels
        chs = list(map(lambda x: ch * x, self.ch_multipliers))
        next_chans = ch if level == 0 else chs[level - 1]
        prev_chans = chs[-1] if level == self.levels - 1 else chs[level + 1]
        curr_chans = chs[level]
        modules = nn.ModuleList([block(prev_chans + curr_chans, curr_chans)])
        for _ in range(self.num_res_blocks - 1):
            modules.append(block(2 * curr_chans, curr_chans))
        modules.append(block(next_chans + curr_chans, curr_chans))
        if level != 0:
            """
            Note: the official TensorFlow implementation specifies `align_corners=True`
            However, PyTorch does not support align_corners for nearest interpolation
            to see the difference, run the following example:
            ---------------------------------------------------------------------------
            import numpy as np
            import torch
            import tensorflow as tf

            x = np.arange(9.).reshape(3, 3)
            print(torch.nn.functional.interpolate(torch.as_tensor(x).reshape(1, 1, 3, 3), size=7, mode="nearest"))  # asymmetric
            print(tf.squeeze(tf.compat.v1.image.resize(tf.reshape(tf.convert_to_tensor(x), shape=(3, 3, 1)), size=(7, 7), method="nearest", align_corners=True)))  # symmetric
            ---------------------------------------------------------------------------
            """  # noqa
            upsample = [nn.Upsample(scale_factor=2, mode="nearest")]
            if self.resample_with_conv:
                upsample.append(Conv2d(curr_chans, curr_chans, 3, 1, 1))
            modules.append(Sequential(*upsample))
        return modules

    def forward(self, x, t):
        t_emb = get_timestep_embedding(t, self.hid_channels)
        t_emb = self.embed(t_emb)

        # downsample
        hs = [self.in_conv(x)]
        for i in range(self.levels):
            downsample = self.downsamples[f"level_{i}"]
            for j, layer in enumerate(downsample):  # noqa
                h = hs[-1]
                if j != self.num_res_blocks:
                    hs.append(layer(h, t_emb=t_emb))
                else:
                    hs.append(layer(h))

        # middle
        h = self.middle(hs[-1], t_emb=t_emb)

        # upsample
        for i in range(self.levels-1, -1, -1):
            upsample = self.upsamples[f"level_{i}"]
            for j, layer in enumerate(upsample):  # noqa
                if j != self.num_res_blocks + 1:
                    h = layer(torch.cat([h, hs.pop()], dim=1), t_emb=t_emb)
                else:
                    h = layer(h)

        h = self.out_conv(h)
        return h

# %%
# 需要更改

class GaussianDiffusion:
    def __init__(
        self,
        timesteps=1000,
        beta_schedule='linear'
    ):
        self.timesteps = timesteps

        if beta_schedule == 'linear':
            betas = linear_beta_schedule(timesteps)
        elif beta_schedule == 'cosine':
            betas = cosine_beta_schedule(timesteps)
        else:
            raise ValueError(f'unknown beta schedule {beta_schedule}')
        self.betas = betas

        self.alphas = 1. - self.betas
        self.alphas_cumprod = torch.cumprod(self.alphas, axis=0)
        self.alphas_cumprod_prev = F.pad(self.alphas_cumprod[:-1], (1, 0), value=0.99)

        # calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = torch.sqrt(self.alphas_cumprod)
        self.sqrt_one_minus_alphas_cumprod = torch.sqrt(1.0 - self.alphas_cumprod)
        self.log_one_minus_alphas_cumprod = torch.log(1.0 - self.alphas_cumprod)
        self.sqrt_recip_alphas_cumprod = torch.sqrt(1.0 / self.alphas_cumprod)
        self.sqrt_recipm1_alphas_cumprod = torch.sqrt(1.0 / self.alphas_cumprod - 1)

        # calculations for posterior q(x_{t-1} | x_t, x_0)
        self.posterior_variance = (
            self.betas * (1.0 - self.alphas_cumprod_prev) / (1.0 - self.alphas_cumprod)
        )
        # below: log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = torch.log(self.posterior_variance.clamp(min =1e-20))

        self.posterior_mean_coef1 = (
            self.betas * torch.sqrt(self.alphas_cumprod_prev) / (1.0 - self.alphas_cumprod)
        )
        self.posterior_mean_coef2 = (
            (1.0 - self.alphas_cumprod_prev)
            * torch.sqrt(self.alphas)
            / (1.0 - self.alphas_cumprod)
        )

    def _extract(self, a, t, x_shape):
        # get the param of given timestep t
        batch_size = t.shape[0]
        out = a.to(t.device).gather(0, t).float()
        out = out.reshape(batch_size, *((1,) * (len(x_shape) - 1)))
        return out

    def q_sample(self, x_start, t, noise=None):
        # forward diffusion (using the nice property): q(x_t | x_0)
        if noise is None:
            noise = torch.randn_like(x_start)

        sqrt_alphas_cumprod_t = self._extract(self.sqrt_alphas_cumprod, t, x_start.shape)
        sqrt_one_minus_alphas_cumprod_t = self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start.shape)

        return sqrt_alphas_cumprod_t * x_start + sqrt_one_minus_alphas_cumprod_t * noise

    def q_mean_variance(self, x_start, t):
        # Get the mean and variance of q(x_t | x_0).
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start.shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start.shape)
        log_variance = self._extract(self.log_one_minus_alphas_cumprod, t, x_start.shape)
        return mean, variance, log_variance

    def q_posterior_mean_variance(self, x_start, x_t, t):
        # Compute the mean and variance of the diffusion posterior: q(x_{t-1} | x_t, x_0)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t.shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t.shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t.shape)
        posterior_log_variance_clipped = self._extract(self.posterior_log_variance_clipped, t, x_t.shape)
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def predict_start_from_noise(self, x_t, t, noise):
        # compute x_0 from x_t and pred noise: the reverse of `q_sample`

        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t.shape) * x_t -
            self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t.shape) * noise
        )
    def predict_t_1_from_t(self, x_t, noise,t):
        # compute x_t_1 from x_t and pred noise: the reverse of `q_sample`
        #print(self.alphas[t].to(x_t.device).device)
        #print(self.betas[t].to(x_t.device).device)
        return (
            (1.0/self.alphas[t].to(x_t.device)) * (x_t -
            self.betas[t].to(x_t.device) * noise)
        )

    def p_mean_variance(self, model, x_t, t, clip_denoised=True):
        # compute predicted mean and variance of p(x_{t-1} | x_t)
        # predict noise using model
        pred_noise = model(x_t, t)
        # get the predicted x_0: different from the algorithm2 in the paper
        x_recon = self.predict_start_from_noise(x_t, t, pred_noise)

        if clip_denoised:
            x_recon = torch.clamp(x_recon, min=-1., max=1.)
        model_mean, posterior_variance, posterior_log_variance = self.q_posterior_mean_variance(x_recon, x_t, t)
        return model_mean, posterior_variance, posterior_log_variance

    @torch.no_grad()
    def p_sample(self, model, x_t, t, clip_denoised=True):
        # denoise_step: sample x_{t-1} from x_t and pred_noise
        # predict mean and variance
        model_mean, _, model_log_variance = self.p_mean_variance(model, x_t, t, clip_denoised=clip_denoised)
        noise = torch.randn_like(x_t)
        # no noise when t == 0
        nonzero_mask = ((t != 0).float().view(-1, *([1] * (len(x_t.shape) - 1))))
        # compute x_{t-1}
        pred_img = model_mean + nonzero_mask * (0.5 * model_log_variance).exp() * noise
        return pred_img

    @torch.no_grad()
    def p_sample_loop(self, model, shape):
        # denoise: reverse diffusion
        batch_size = shape[0]
        device = next(model.parameters()).device
        # start from pure noise (for each example in the batch)
        img = torch.randn(shape, device=device)
        imgs = []
        for i in tqdm(reversed(range(0, timesteps)), desc='sampling loop time step', total=timesteps):
            img = self.p_sample(model, img, torch.full((batch_size,), i, device=device, dtype=torch.long))
            imgs.append(img.cpu().numpy())
        return imgs

    @torch.no_grad()
    def p_sample_loop_new(self, model, image):
        # denoise: reverse diffusion
        batch_size = image.shape[0]
        device = next(model.parameters()).device
        img=image
        imgs = []
        for i in tqdm(reversed(range(0, timesteps)), desc='sampling loop time step', total=timesteps):
            img = self.p_sample(model, img, torch.full((batch_size,), i, device=device, dtype=torch.long))
            imgs.append(img.cpu().numpy())
        return imgs


    @torch.no_grad()
    def sample(self, model, image_size, batch_size=8, channels=3):
        # sample new images
        return self.p_sample_loop(model, shape=(batch_size, channels, image_size, image_size))



    def train_losses(self, model, x_start, t):
        # compute train losses
        # generate random noise
        noise = torch.randn_like(x_start)
        # get x_t
        x_noisy = self.q_sample(x_start, t, noise=noise)
        predicted_noise = model(x_noisy, t)
        loss = F.mse_loss(noise, predicted_noise)
        return loss

    def get_parameter(self, model, x_start, t):
        noise = torch.randn_like(x_start)
        # get x_t
        x_noisy = self.q_sample(x_start, t, noise=noise)

        predicted_noise = model(x_noisy, t)

        alphas=self.alphas.to(t.device)
        betas=self.betas.to(t.device)

        sqrt_one_minus_alphas_cumprod=self.sqrt_one_minus_alphas_cumprod.to(t.device)
        mean1,variance_all,posterior_log_variance=self.p_mean_variance(model, x_noisy, t)

        #mean1=alphas[t]*x_noisy-predicted_noise*betas[t]/sqrt_one_minus_alphas_cumprod

        return mean1,variance_all

    def get_parameter2(self, model, x_t, t):
        # get x_t
        #predicted_noise = model(x_t, t)
        #noise = torch.randn_like(x_final)

        predicted_noise = model(x_t, t)

        alphas=self.alphas.to(t.device)
        betas=self.betas.to(t.device)

        sqrt_one_minus_alphas_cumprod=self.sqrt_one_minus_alphas_cumprod.to(t.device)
        mean1,variance_all,posterior_log_variance=self.p_mean_variance(model, x_t, t)

        #mean1=alphas[t]*x_noisy-predicted_noise*betas[t]/sqrt_one_minus_alphas_cumprod

        return mean1,variance_all

# %% [markdown]
# 看看效果

# %%
from PIL import Image
import requests
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

# %matplotlib inline

# %%
url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
image = Image.open(requests.get(url, stream=True).raw)
# image = Image.open("/data/000000039769.jpg")

image_size = 128
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.PILToTensor(),
    transforms.ConvertImageDtype(torch.float),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

x_start = transform(image).unsqueeze(0)

gaussian_diffusion = GaussianDiffusion(timesteps=500)

plt.figure(figsize=(16, 8))
for idx, t in enumerate([0, 50, 100, 200, 499]):
    x_noisy = gaussian_diffusion.q_sample(x_start, t=torch.tensor([t]))
    noisy_image = (x_noisy.squeeze().permute(1, 2, 0) + 1) * 127.5
    noisy_image = noisy_image.numpy().astype(np.uint8)
    plt.subplot(1, 5, 1 + idx)
    plt.imshow(noisy_image)
    plt.axis("off")
    plt.title(f"t={t}")

# %% [markdown]
# ## 训练

# %% [markdown]
# 准备数据集

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset

# %%
class TrainSet(Dataset):
  def __init__(self, original_dataset,label):
    self.original_dataset = original_dataset
    self.label = label

  def __getitem__(self, index):
      image = self.original_dataset[index]
      return image, self.label[index]

  def __len__(self):
      return len(self.original_dataset)

# %%
class BinaryDataset(torch.utils.data.Dataset):
    def __init__(self, original_dataset,indices,label):
        self.original_dataset = original_dataset
        self.indices  = indices
        self.label = label

    def __getitem__(self, index):
        image, _ = self.original_dataset[self.indices[index]]
        return image, self.label

    def __len__(self):
        return len(self.indices)

# %%
batch_size = 64
timesteps = 5

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

# use MNIST dataset
dataset = datasets.MNIST('./data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 240851067.34it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 32449958.16it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 74969825.11it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 3630055.02it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
# use cifar10
dataset = datasets.CIFAR10('./dataset', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./dataset/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:05<00:00, 29265725.83it/s]
# Extracting ./dataset/cifar-10-python.tar.gz to ./dataset

# %%
mnist_indices = [i for i in range(len(dataset)) if dataset[i][1] == 3]
mnist2_indices = [i for i in range(len(dataset)) if dataset[i][1] == 9]
dataset_image_number=256

mnist_dataset = BinaryDataset(dataset, mnist_indices[0:dataset_image_number],label=3 )
mnist2_dataset = BinaryDataset(dataset, mnist2_indices[0:dataset_image_number],label=9 )

mnist_dataset_v = BinaryDataset(dataset, mnist_indices[dataset_image_number+1:dataset_image_number+dataset_image_number],label=3)
mnist2_dataset_v = BinaryDataset(dataset, mnist2_indices[dataset_image_number+1:dataset_image_number+dataset_image_number],label=9 )

# %%
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])

val_dataset=torch.utils.data.ConcatDataset([mnist_dataset_v, mnist2_dataset_v])
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=1, shuffle=True,pin_memory=True)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True,num_workers=4,pin_memory=True)

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# Transform
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# Load CIFAR10 dataset
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True)

# Class labels for CIFAR10
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# Get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Show images
imshow(torchvision.utils.make_grid(images))

# Print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:05<00:00, 28707870.23it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
#  bird   dog  ship  frog

# %% [markdown]
# 模型

# %% [markdown]
# 开始训练

# %%
import torch,gc
gc.collect()
torch.cuda.empty_cache()
from torch.utils.data import Dataset

# %%
# define model and diffusion
device = "cuda" if torch.cuda.is_available() else "cpu"
model = UNetModel(
    in_channels=1,
    model_channels=96,
    out_channels=1,
    channel_mult=(1, 2, 2),
    attention_resolutions=[]
)
model.to(device)

gaussian_diffusion = GaussianDiffusion(timesteps=timesteps)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-41d02f658706> in <cell line: 3>()
#       1 # define model and diffusion
#       2 device = "cuda" if torch.cuda.is_available() else "cpu"
# ----> 3 model = UNetModel(
#       4     in_channels=1,
#       5     model_channels=96,
#
# <ipython-input-2-0b28976890b5> in __init__(self, in_channels, model_channels, out_channels, num_res_blocks, attention_resolutions, dropout, channel_mult, conv_resample, num_heads)
#     208         self.middle_block = TimestepEmbedSequential(
#     209             ResidualBlock(ch, ch, time_embed_dim, dropout),
# --> 210             AttentionBlock(ch, num_heads=num_heads),
#     211             ResidualBlock(ch, ch, time_embed_dim, dropout)
#     212         )
#
# TypeError: AttentionBlock.__init__() got an unexpected keyword argument 'num_heads'

# %%
epochs = 10
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)
device = "cuda" if torch.cuda.is_available() else "cpu"
batch_size = 32
timesteps = 5
loss_batch_average=torch.zeros([epochs,timesteps,int(dataset_image_number/batch_size)])
model_parameters=dict()
x_t_train_dataset1=torch.utils.data.ConcatDataset([mnist_dataset])
x_t_train_dataset2=torch.utils.data.ConcatDataset([mnist2_dataset])
losses = {'loss':[],'loss2':[]}
best_acc=0
for t in range(timesteps-1,-1,-1):
  time = torch.full((batch_size,),t, device=device).long()

  train_loader1 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=True,pin_memory=True)
  train_loader2 = torch.utils.data.DataLoader(x_t_train_dataset2, batch_size=batch_size, shuffle=True,pin_memory=True)
  for epoch in range(epochs):
    batch_size=batch_size
    iteration_of_train_loader2=iter(train_loader2)
    for step, (images1, _) in enumerate(train_loader1):

      xt1 = images1.to(device)
      images2,_=next(iteration_of_train_loader2)
      xt2 = images2.to(device)

      out1 = model(xt1, time)
      out2 = model(xt2, time)
      out1=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(out1)
      out2=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(out2)

      m1 =out1.reshape(batch_size,3*32*32)
      m2 =out2.reshape(batch_size,3*32*32)

      s1=torch.var(m1, dim=0)
      s2=torch.var(m2, dim=0)
      loss2=s1.mean(0)+s2.mean(0)
      loss=0.1*loss2+torch.dot(m1.mean(0) / torch.norm(m1.mean(0)), m2.mean(0) / torch.norm(m2.mean(0)))

      loss_batch_average[epoch,t,step]=loss
      del s1,s2,m1,m2
      print(" this is timesteps",t," this is epoch",epoch,"this is step ",step)
      optimizer.zero_grad()
      loss.backward()

      optimizer.step()
      losses['loss'].append(loss.detach().cpu().numpy())
      losses['loss2'].append(loss2.detach().cpu().numpy())

      loss_batch_average[epoch,t,step]=loss
      #for name, parms in model.named_parameters():
        #print('-->name:', name, '-->grad_requirs:',parms.requires_grad, ' -->grad_value:',parms.grad)
      # print('-->name:', name, parms.data)

      print("loss",loss)
      print("loss2",loss2)
      model_parameters[t]=model.state_dict()

  x_t_train_dataset1_1=torch.zeros([dataset_image_number,3,32,32])
  x_t_train_dataset2_2=torch.zeros([dataset_image_number,3,32,32])

  labels_1=torch.zeros([dataset_image_number])
  labels_2=torch.zeros([dataset_image_number])
  #establish xt_1 for the next loop
  with torch.no_grad():
    for step, (images1, labels) in enumerate(train_loader1):
      xt1 = images1.to(device)

      images1=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))

      x_t_train_dataset1_1[step*batch_size:(step+1)*batch_size,:,:,:]=images1
      labels_1[step*batch_size:(step+1)*batch_size]=labels
    x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset1_1,labels_1)])

  with torch.no_grad():
    for step, (images2, labels2) in enumerate(train_loader2):
      xt2 = images2.to(device)

      images2= transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt2, time))

      x_t_train_dataset2_2[step*batch_size:(step+1)*batch_size,:,:,:]=images2
      labels_2[step*batch_size:(step+1)*batch_size]=labels2
    x_t_train_dataset2=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset2_2,labels_2)])

  model.eval()
  #establish xt_1 for the next loop
  val_acc=0
  with torch.no_grad():
    for step, (image, label) in enumerate(val_loader):
      image = image.to(device)
      x0=image
      for t_v in range(timesteps-1,t-1,-1):

        model.load_state_dict(model_parameters[t_v],strict=True)
        time=torch.full((1,),t_v, device=device)
        x=model(x0, time)
        x0=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(x).to(device)

      a=torch.dot(x_t_train_dataset1_1.reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_t_train_dataset1_1.reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 3 and pred
      b=torch.dot(x_t_train_dataset2_2.reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_t_train_dataset2_2.reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 2 and pred
      if a >= b:
        pred_label= 3
        #print(a,"and",b)
      else:
        pred_label= 9
        #print(a,"and",b)
      if pred_label==label:
        val_acc=val_acc+1
        #print("exact!", pred_label,"the true is ",label)
      else:
        print("find different label at step ", step, pred_label,"the true is ",label)
    print("val_acc",val_acc/len(val_dataset))
    if val_acc/len(val_dataset)>best_acc:
      best_acc=val_acc/len(val_dataset)
      print(best_acc)
      epochs_without_improvement = 0
    else:
      epochs_without_improvement+=1
      print("early stopping at timestep", t,val_acc/len(val_dataset))
      #break
  print("done")
# Out:
#  this is timesteps 4  this is epoch 0 this is step  0
# loss tensor(1., device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(4.9226e-10, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  1
# loss tensor(1.0011, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.0267, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  2
# loss tensor(0.9989, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.0420, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  3
# loss tensor(0.9582, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3199, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  4
# loss tensor(1.0214, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7073, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  5
# loss tensor(0.9999, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  6
# loss tensor(0.9987, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.0573, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  7
# loss tensor(0.9392, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4069, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  0
# loss tensor(0.8524, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4802, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  1
# loss tensor(0.7914, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.3250, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  2
# loss tensor(0.7585, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.3698, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  3
# loss tensor(0.6988, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.2482, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  4
# loss tensor(0.4167, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.9304, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  5
# loss tensor(0.8892, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.8169, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  6
# loss tensor(0.5351, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(3.1685, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  7
# loss tensor(0.0517, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.9717, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  0
# loss tensor(0.3728, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(3.1105, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  1
# loss tensor(0.0108, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.4068, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  2
# loss tensor(0.0703, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.4335, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  3
# loss tensor(-0.3003, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.8700, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  4
# loss tensor(-0.2032, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.4143, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  5
# loss tensor(-0.1234, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.8843, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  6
# loss tensor(-0.3935, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.6302, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  7
# loss tensor(0.1200, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.3977, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  0
# loss tensor(-0.2968, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.3581, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  1
# loss tensor(-0.1987, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.2923, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  2
# loss tensor(-0.3404, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.5846, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  3
# loss tensor(-0.3654, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.8060, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  4
# loss tensor(-0.6940, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.4598, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  5
# loss tensor(-0.4600, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.7955, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  6
# loss tensor(-0.0435, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.6587, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  7
# loss tensor(-0.5203, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2380, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  0
# loss tensor(-0.4573, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.4491, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  1
# loss tensor(-0.6367, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.8023, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  2
# loss tensor(-0.3929, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.1537, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  3
# loss tensor(-0.5846, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.7074, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  4
# loss tensor(-0.3923, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.3816, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  5
# loss tensor(-0.6772, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.8044, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  6
# loss tensor(-0.4630, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2650, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  7
# loss tensor(-0.6694, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8284, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  0
# loss tensor(-0.7484, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0378, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  1
# loss tensor(-0.7372, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8044, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  2
# loss tensor(-0.5147, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9749, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  3
# loss tensor(-0.7619, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1826, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  4
# loss tensor(-0.7766, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1924, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  5
# loss tensor(-0.5351, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.5919, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  6
# loss tensor(-0.7189, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.3757, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  7
# loss tensor(-0.7456, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1421, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  0
# loss tensor(-0.5933, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2684, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  1
# loss tensor(-0.6443, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1161, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  2
# loss tensor(-0.6812, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9207, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  3
# loss tensor(-0.7456, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0711, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  4
# loss tensor(-0.7679, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2635, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  5
# loss tensor(-0.6794, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.5067, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  6
# loss tensor(-0.8137, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0908, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  7
# loss tensor(-0.6606, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2926, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  0
# loss tensor(-0.7929, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0459, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  1
# loss tensor(-0.8035, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7807, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  2
# loss tensor(-0.8509, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5278, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  3
# loss tensor(-0.4879, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7413, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  4
# loss tensor(-0.8409, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7754, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  5
# loss tensor(-0.7861, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8743, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  6
# loss tensor(-0.4976, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9621, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  7
# loss tensor(-0.7995, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0218, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  0
# loss tensor(-0.6183, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0673, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  1
# loss tensor(-0.8339, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7282, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  2
# loss tensor(-0.8485, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8992, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  3
# loss tensor(-0.5984, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0060, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  4
# loss tensor(-0.8242, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7134, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  5
# loss tensor(-0.8810, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5959, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  6
# loss tensor(-0.8062, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7233, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  7
# loss tensor(-0.8470, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5351, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  0
# loss tensor(-0.8670, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5188, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  1
# loss tensor(-0.8580, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5180, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  2
# loss tensor(-0.8853, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5818, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  3
# loss tensor(-0.7898, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7084, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  4
# loss tensor(-0.8568, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4735, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  5
# loss tensor(-0.8302, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5592, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  6
# loss tensor(-0.7453, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4689, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  7
# loss tensor(-0.9072, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3700, device='cuda:0', grad_fn=<AddBackward0>)
# find different label at step  5 3 the true is  tensor([9])
# find different label at step  16 3 the true is  tensor([9])
# find different label at step  22 3 the true is  tensor([9])
# find different label at step  25 9 the true is  tensor([3])
# find different label at step  46 9 the true is  tensor([3])
# find different label at step  49 3 the true is  tensor([9])
# find different label at step  55 9 the true is  tensor([3])
# find different label at step  57 9 the true is  tensor([3])
# find different label at step  61 9 the true is  tensor([3])
# find different label at step  71 3 the true is  tensor([9])
# find different label at step  78 9 the true is  tensor([3])
# find different label at step  80 3 the true is  tensor([9])
# find different label at step  84 9 the true is  tensor([3])
# find different label at step  86 9 the true is  tensor([3])
# find different label at step  87 9 the true is  tensor([3])
# find different label at step  94 3 the true is  tensor([9])
# find different label at step  98 9 the true is  tensor([3])
# find different label at step  100 9 the true is  tensor([3])
# find different label at step  109 3 the true is  tensor([9])
# find different label at step  130 3 the true is  tensor([9])
# find different label at step  135 9 the true is  tensor([3])
# find different label at step  138 9 the true is  tensor([3])
# find different label at step  144 9 the true is  tensor([3])
# find different label at step  146 9 the true is  tensor([3])
# find different label at step  151 9 the true is  tensor([3])
# find different label at step  154 9 the true is  tensor([3])
# find different label at step  155 9 the true is  tensor([3])
# find different label at step  182 3 the true is  tensor([9])
# find different label at step  190 9 the true is  tensor([3])
# find different label at step  194 3 the true is  tensor([9])
# find different label at step  197 3 the true is  tensor([9])
# find different label at step  205 3 the true is  tensor([9])
# find different label at step  216 9 the true is  tensor([3])
# find different label at step  217 9 the true is  tensor([3])
# find different label at step  227 9 the true is  tensor([3])
# find different label at step  230 9 the true is  tensor([3])
# find different label at step  232 9 the true is  tensor([3])
# find different label at step  236 3 the true is  tensor([9])
# find different label at step  240 9 the true is  tensor([3])
# find different label at step  248 9 the true is  tensor([3])
# find different label at step  250 9 the true is  tensor([3])
# find different label at step  263 3 the true is  tensor([9])
# find different label at step  267 9 the true is  tensor([3])
# find different label at step  273 9 the true is  tensor([3])
# find different label at step  293 3 the true is  tensor([9])
# find different label at step  296 9 the true is  tensor([3])
# find different label at step  307 9 the true is  tensor([3])
# find different label at step  309 3 the true is  tensor([9])
# find different label at step  311 3 the true is  tensor([9])
# find different label at step  312 9 the true is  tensor([3])
# find different label at step  316 3 the true is  tensor([9])
# find different label at step  318 9 the true is  tensor([3])
# find different label at step  323 9 the true is  tensor([3])
# find different label at step  326 9 the true is  tensor([3])
# find different label at step  338 3 the true is  tensor([9])
# find different label at step  342 3 the true is  tensor([9])
# find different label at step  346 9 the true is  tensor([3])
# find different label at step  356 9 the true is  tensor([3])
# find different label at step  357 9 the true is  tensor([3])
# find different label at step  358 9 the true is  tensor([3])
# find different label at step  369 3 the true is  tensor([9])
# find different label at step  378 3 the true is  tensor([9])
# find different label at step  380 9 the true is  tensor([3])
# find different label at step  387 3 the true is  tensor([9])
# find different label at step  388 3 the true is  tensor([9])
# find different label at step  393 3 the true is  tensor([9])
# find different label at step  394 9 the true is  tensor([3])
# find different label at step  403 9 the true is  tensor([3])
# find different label at step  406 3 the true is  tensor([9])
# find different label at step  407 3 the true is  tensor([9])
# find different label at step  409 9 the true is  tensor([3])
# find different label at step  417 9 the true is  tensor([3])
# find different label at step  429 3 the true is  tensor([9])
# find different label at step  435 9 the true is  tensor([3])
# find different label at step  436 9 the true is  tensor([3])
# find different label at step  447 3 the true is  tensor([9])
# find different label at step  455 9 the true is  tensor([3])
# find different label at step  457 9 the true is  tensor([3])
# find different label at step  459 9 the true is  tensor([3])
# find different label at step  463 9 the true is  tensor([3])
# find different label at step  466 3 the true is  tensor([9])
# find different label at step  494 3 the true is  tensor([9])
# find different label at step  495 9 the true is  tensor([3])
# find different label at step  504 9 the true is  tensor([3])
# find different label at step  506 9 the true is  tensor([3])
# find different label at step  508 9 the true is  tensor([3])
# val_acc 0.8313725490196079
# 0.8313725490196079
# done
#  this is timesteps 3  this is epoch 0 this is step  0
# loss tensor(-0.7914, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5197, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  1
# loss tensor(-0.8647, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5102, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  2
# loss tensor(-0.8257, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7385, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  3
# loss tensor(-0.9332, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4516, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  4
# loss tensor(-0.8700, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7527, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  5
# loss tensor(-0.8891, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6262, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  6
# loss tensor(-0.8216, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9070, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  7
# loss tensor(-0.8499, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7581, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  0
# loss tensor(-0.9000, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6146, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  1
# loss tensor(-0.9088, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5277, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  2
# loss tensor(-0.9141, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4921, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  3
# loss tensor(-0.9089, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4214, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  4
# loss tensor(-0.8426, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2616, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  5
# loss tensor(-0.8767, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3927, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  6
# loss tensor(-0.9299, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3450, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  7
# loss tensor(-0.9162, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4544, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  0
# loss tensor(-0.9106, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5845, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  1
# loss tensor(-0.9167, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4269, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  2
# loss tensor(-0.9120, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5670, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  3
# loss tensor(-0.9073, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6059, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  4
# loss tensor(-0.8580, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5737, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  5
# loss tensor(-0.9037, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5258, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  6
# loss tensor(-0.9424, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3363, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  7
# loss tensor(-0.8930, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3649, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  0
# loss tensor(-0.9445, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2099, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  1
# loss tensor(-0.7687, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2436, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  2
# loss tensor(-0.7809, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2323, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  3
# loss tensor(-0.7396, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5199, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  4
# loss tensor(-0.9229, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5797, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  5
# loss tensor(-0.7304, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0659, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  6
# loss tensor(-0.8808, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8697, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  7
# loss tensor(-0.8922, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8727, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  0
# loss tensor(-0.8598, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2573, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  1
# loss tensor(-0.8579, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2601, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  2
# loss tensor(-0.8530, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2735, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  3
# loss tensor(-0.8558, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2616, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  4
# loss tensor(-0.7948, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.6722, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  5
# loss tensor(-0.8412, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2876, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  6
# loss tensor(-0.8945, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8396, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  7
# loss tensor(-0.8645, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6673, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  0
# loss tensor(-0.8755, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5650, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  1
# loss tensor(-0.9266, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3985, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  2
# loss tensor(-0.9023, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3904, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  3
# loss tensor(-0.8801, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2963, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  4
# loss tensor(-0.9124, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3082, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  5
# loss tensor(-0.8801, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2121, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  6
# loss tensor(-0.8928, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3196, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  7
# loss tensor(-0.9531, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1966, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  0
# loss tensor(-0.8693, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2654, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  1
# loss tensor(-0.9485, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2156, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  2
# loss tensor(-0.9619, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1458, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  3
# loss tensor(-0.9536, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1747, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  4
# loss tensor(-0.9602, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1515, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  5
# loss tensor(-0.9568, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1658, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  6
# loss tensor(-0.9592, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1848, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  7
# loss tensor(-0.9514, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2563, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  0
# loss tensor(-0.9522, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1570, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  1
# loss tensor(-0.9600, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2154, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  2
# loss tensor(-0.8847, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2821, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  3
# loss tensor(-0.8870, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1564, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  4
# loss tensor(-0.9375, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2257, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  5
# loss tensor(-0.8661, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3271, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  6
# loss tensor(-0.9423, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3267, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  7
# loss tensor(-0.9357, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2942, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  0
# loss tensor(-0.9282, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3116, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  1
# loss tensor(-0.9178, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4364, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  2
# loss tensor(-0.9419, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4328, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  3
# loss tensor(-0.8905, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5152, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  4
# loss tensor(-0.9374, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3760, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  5
# loss tensor(-0.9308, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5347, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  6
# loss tensor(-0.9136, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5347, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  7
# loss tensor(-0.9246, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4899, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  0
# loss tensor(-0.8982, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5823, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  1
# loss tensor(-0.9227, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4112, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  2
# loss tensor(-0.9598, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2370, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  3
# loss tensor(-0.9596, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2404, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  4
# loss tensor(-0.9682, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2018, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  5
# loss tensor(-0.9569, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2125, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  6
# loss tensor(-0.9482, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2561, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  7
# loss tensor(-0.9659, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1711, device='cuda:0', grad_fn=<AddBackward0>)
# find different label at step  3 9 the true is  tensor([3])
# find different label at step  4 9 the true is  tensor([3])
# find different label at step  14 3 the true is  tensor([9])
# find different label at step  20 3 the true is  tensor([9])
# find different label at step  22 9 the true is  tensor([3])
# find different label at step  25 9 the true is  tensor([3])
# find different label at step  26 3 the true is  tensor([9])
# find different label at step  40 9 the true is  tensor([3])
# find different label at step  43 3 the true is  tensor([9])
# find different label at step  47 9 the true is  tensor([3])
# find different label at step  49 9 the true is  tensor([3])
# find different label at step  51 3 the true is  tensor([9])
# find different label at step  53 9 the true is  tensor([3])
# find different label at step  54 9 the true is  tensor([3])
# find different label at step  55 9 the true is  tensor([3])
# find different label at step  56 9 the true is  tensor([3])
# find different label at step  65 9 the true is  tensor([3])
# find different label at step  68 9 the true is  tensor([3])
# find different label at step  70 9 the true is  tensor([3])
# find different label at step  73 9 the true is  tensor([3])
# find different label at step  83 9 the true is  tensor([3])
# find different label at step  89 9 the true is  tensor([3])
# find different label at step  90 9 the true is  tensor([3])
# find different label at step  97 9 the true is  tensor([3])
# find different label at step  98 9 the true is  tensor([3])
# find different label at step  100 9 the true is  tensor([3])
# find different label at step  109 9 the true is  tensor([3])
# find different label at step  118 3 the true is  tensor([9])
# find different label at step  124 9 the true is  tensor([3])
# find different label at step  125 3 the true is  tensor([9])
# find different label at step  126 9 the true is  tensor([3])
# find different label at step  128 9 the true is  tensor([3])
# find different label at step  129 9 the true is  tensor([3])
# find different label at step  131 9 the true is  tensor([3])
# find different label at step  135 9 the true is  tensor([3])
# find different label at step  137 9 the true is  tensor([3])
# find different label at step  141 9 the true is  tensor([3])
# find different label at step  143 9 the true is  tensor([3])
# find different label at step  146 9 the true is  tensor([3])
# find different label at step  149 9 the true is  tensor([3])
# find different label at step  154 3 the true is  tensor([9])
# find different label at step  163 9 the true is  tensor([3])
# find different label at step  164 3 the true is  tensor([9])
# find different label at step  165 9 the true is  tensor([3])
# find different label at step  168 9 the true is  tensor([3])
# find different label at step  169 9 the true is  tensor([3])
# find different label at step  176 9 the true is  tensor([3])
# find different label at step  179 3 the true is  tensor([9])
# find different label at step  182 9 the true is  tensor([3])
# find different label at step  186 9 the true is  tensor([3])
# find different label at step  187 3 the true is  tensor([9])
# find different label at step  188 3 the true is  tensor([9])
# find different label at step  197 9 the true is  tensor([3])
# find different label at step  205 3 the true is  tensor([9])
# find different label at step  208 9 the true is  tensor([3])
# find different label at step  211 9 the true is  tensor([3])
# find different label at step  212 9 the true is  tensor([3])
# find different label at step  220 9 the true is  tensor([3])
# find different label at step  234 9 the true is  tensor([3])
# find different label at step  235 3 the true is  tensor([9])
# find different label at step  237 9 the true is  tensor([3])
# find different label at step  240 9 the true is  tensor([3])
# find different label at step  258 9 the true is  tensor([3])
# find different label at step  261 9 the true is  tensor([3])
# find different label at step  268 9 the true is  tensor([3])
# find different label at step  276 9 the true is  tensor([3])
# find different label at step  282 9 the true is  tensor([3])
# find different label at step  287 9 the true is  tensor([3])
# find different label at step  288 9 the true is  tensor([3])
# find different label at step  303 9 the true is  tensor([3])
# find different label at step  316 9 the true is  tensor([3])
# find different label at step  326 3 the true is  tensor([9])
# find different label at step  329 9 the true is  tensor([3])
# find different label at step  334 3 the true is  tensor([9])
# find different label at step  335 3 the true is  tensor([9])
# find different label at step  337 9 the true is  tensor([3])
# find different label at step  340 9 the true is  tensor([3])
# find different label at step  346 9 the true is  tensor([3])
# find different label at step  350 9 the true is  tensor([3])
# find different label at step  351 9 the true is  tensor([3])
# find different label at step  360 9 the true is  tensor([3])
# find different label at step  364 9 the true is  tensor([3])
# find different label at step  369 9 the true is  tensor([3])
# find different label at step  371 3 the true is  tensor([9])
# find different label at step  374 9 the true is  tensor([3])
# find different label at step  377 9 the true is  tensor([3])
# find different label at step  380 9 the true is  tensor([3])
# find different label at step  387 9 the true is  tensor([3])
# find different label at step  396 3 the true is  tensor([9])
# find different label at step  397 3 the true is  tensor([9])
# find different label at step  404 9 the true is  tensor([3])
# find different label at step  405 3 the true is  tensor([9])
# find different label at step  411 9 the true is  tensor([3])
# find different label at step  413 9 the true is  tensor([3])
# find different label at step  417 9 the true is  tensor([3])
# find different label at step  422 9 the true is  tensor([3])
# find different label at step  438 9 the true is  tensor([3])
# find different label at step  440 9 the true is  tensor([3])
# find different label at step  447 9 the true is  tensor([3])
# find different label at step  448 9 the true is  tensor([3])
# find different label at step  449 3 the true is  tensor([9])
# find different label at step  463 3 the true is  tensor([9])
# find different label at step  464 3 the true is  tensor([9])
# find different label at step  468 9 the true is  tensor([3])
# find different label at step  473 9 the true is  tensor([3])
# find different label at step  474 9 the true is  tensor([3])
# find different label at step  480 9 the true is  tensor([3])
# find different label at step  485 9 the true is  tensor([3])
# find different label at step  500 9 the true is  tensor([3])
# val_acc 0.7862745098039216
# early stopping at timestep 3 0.7862745098039216
# done
#  this is timesteps 2  this is epoch 0 this is step  0
# loss tensor(-0.9477, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1506, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  1
# loss tensor(-0.9583, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1538, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  2
# loss tensor(-0.9504, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1067, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  3
# loss tensor(-0.9178, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1503, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  4
# loss tensor(-0.9376, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1135, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  5
# loss tensor(-0.9509, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1617, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  6
# loss tensor(-0.9457, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1596, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  7
# loss tensor(-0.9625, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1283, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  0
# loss tensor(-0.9675, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1812, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  1
# loss tensor(-0.9505, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2060, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  2
# loss tensor(-0.9483, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2682, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  3
# loss tensor(-0.9648, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2341, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  4
# loss tensor(-0.9634, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2131, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  5
# loss tensor(-0.9634, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1983, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  6
# loss tensor(-0.9204, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3249, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  7
# loss tensor(-0.9475, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3018, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  0
# loss tensor(-0.9496, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2172, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  1
# loss tensor(-0.9591, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2499, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  2
# loss tensor(-0.9531, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2140, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  3
# loss tensor(-0.9671, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1757, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  4
# loss tensor(-0.9390, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2042, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  5
# loss tensor(-0.9465, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1874, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  6
# loss tensor(-0.9742, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1270, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  7
# loss tensor(-0.9536, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2341, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  0
# loss tensor(-0.9805, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1175, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  1
# loss tensor(-0.9411, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2427, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  2
# loss tensor(-0.9699, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1519, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  3
# loss tensor(-0.9515, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1474, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  4
# loss tensor(-0.9448, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1782, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  5
# loss tensor(-0.9413, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2395, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  6
# loss tensor(-0.9486, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1088, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  7
# loss tensor(-0.8902, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1969, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  0
# loss tensor(-0.9606, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2200, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  1
# loss tensor(-0.8789, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2798, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  2
# loss tensor(-0.9603, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2544, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  3
# loss tensor(-0.9625, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2178, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  4
# loss tensor(-0.8716, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4038, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  5
# loss tensor(-0.9496, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3493, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  6
# loss tensor(-0.9347, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4035, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  7
# loss tensor(-0.9006, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4480, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 5 this is step  0
# loss tensor(-0.9114, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4652, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 5 this is step  1
# loss tensor(-0.9388, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4856, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 5 this is step  2
# ...
# loss tensor(-0.9681, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1409, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 3 this is step  7
# loss tensor(-0.9742, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1361, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 4 this is step  0
# loss tensor(-0.9857, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.0492, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 4 this is step  1
# loss tensor(-0.9377, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1883, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 4 this is step  2
# loss tensor(-0.9414, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1286, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 4 this is step  3
# loss tensor(-0.9374, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1175, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 4 this is step  4
# loss tensor(-0.9689, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1884, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 4 this is step  5
# loss tensor(-0.9038, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1946, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 4 this is step  6
# loss tensor(-0.9761, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1408, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 4 this is step  7
# loss tensor(-0.8481, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2293, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  0
# loss tensor(-0.9490, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2639, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  1
# loss tensor(-0.8979, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2955, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  2
# loss tensor(-0.8015, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5422, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  3
# loss tensor(-0.9546, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2954, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  4
# loss tensor(-0.9442, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4760, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  5
# loss tensor(-0.8769, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5922, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  6
# loss tensor(-0.8888, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6584, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  7
# loss tensor(-0.9454, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4324, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  0
# loss tensor(-0.8982, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8069, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  1
# loss tensor(-0.9383, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5563, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  2
# loss tensor(-0.9146, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6668, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  3
# loss tensor(-0.9011, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7419, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  4
# loss tensor(-0.9535, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3666, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  5
# loss tensor(-0.9242, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6113, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  6
# loss tensor(-0.9463, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4229, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  7
# loss tensor(-0.9537, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3127, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  0
# loss tensor(-0.9276, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4196, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  1
# loss tensor(-0.9614, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2911, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  2
# loss tensor(-0.9687, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2665, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  3
# loss tensor(-0.9483, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3222, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  4
# loss tensor(-0.9694, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1823, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  5
# loss tensor(-0.9346, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2430, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  6
# loss tensor(-0.9489, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1846, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  7
# loss tensor(-0.9203, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1577, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  0
# loss tensor(-0.9670, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1642, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  1
# loss tensor(-0.9306, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1203, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  2
# loss tensor(-0.9365, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1917, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  3
# loss tensor(-0.9624, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2238, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  4
# loss tensor(-0.9515, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1924, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  5
# loss tensor(-0.9535, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2024, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  6
# loss tensor(-0.9621, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2788, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  7
# loss tensor(-0.9641, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1798, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  0
# loss tensor(-0.9434, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2399, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  1
# loss tensor(-0.9633, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2558, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  2
# loss tensor(-0.9779, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1167, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  3
# loss tensor(-0.9359, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2017, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  4
# loss tensor(-0.9565, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2412, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  5
# loss tensor(-0.9638, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1949, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  6
# loss tensor(-0.9429, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1994, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  7
# loss tensor(-0.9426, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2673, device='cuda:0', grad_fn=<AddBackward0>)
# find different label at step  0 3 the true is  tensor([9])
# find different label at step  1 9 the true is  tensor([3])
# find different label at step  4 3 the true is  tensor([9])
# find different label at step  15 9 the true is  tensor([3])
# find different label at step  29 9 the true is  tensor([3])
# find different label at step  33 9 the true is  tensor([3])
# find different label at step  39 9 the true is  tensor([3])
# find different label at step  46 9 the true is  tensor([3])
# find different label at step  50 9 the true is  tensor([3])
# find different label at step  52 9 the true is  tensor([3])
# find different label at step  57 9 the true is  tensor([3])
# find different label at step  58 9 the true is  tensor([3])
# find different label at step  59 9 the true is  tensor([3])
# find different label at step  60 9 the true is  tensor([3])
# find different label at step  64 3 the true is  tensor([9])
# find different label at step  68 9 the true is  tensor([3])
# find different label at step  69 3 the true is  tensor([9])
# find different label at step  77 9 the true is  tensor([3])
# find different label at step  90 9 the true is  tensor([3])
# find different label at step  96 3 the true is  tensor([9])
# find different label at step  101 9 the true is  tensor([3])
# find different label at step  104 9 the true is  tensor([3])
# find different label at step  109 9 the true is  tensor([3])
# find different label at step  121 9 the true is  tensor([3])
# find different label at step  126 9 the true is  tensor([3])
# find different label at step  134 9 the true is  tensor([3])
# find different label at step  137 9 the true is  tensor([3])
# find different label at step  146 3 the true is  tensor([9])
# find different label at step  147 9 the true is  tensor([3])
# find different label at step  153 9 the true is  tensor([3])
# find different label at step  154 9 the true is  tensor([3])
# find different label at step  156 9 the true is  tensor([3])
# find different label at step  157 3 the true is  tensor([9])
# find different label at step  159 9 the true is  tensor([3])
# find different label at step  162 3 the true is  tensor([9])
# find different label at step  168 3 the true is  tensor([9])
# find different label at step  169 9 the true is  tensor([3])
# find different label at step  171 9 the true is  tensor([3])
# find different label at step  174 9 the true is  tensor([3])
# find different label at step  179 9 the true is  tensor([3])
# find different label at step  183 9 the true is  tensor([3])
# find different label at step  187 9 the true is  tensor([3])
# find different label at step  193 9 the true is  tensor([3])
# find different label at step  195 9 the true is  tensor([3])
# find different label at step  201 3 the true is  tensor([9])
# find different label at step  203 9 the true is  tensor([3])
# find different label at step  205 9 the true is  tensor([3])
# find different label at step  209 9 the true is  tensor([3])
# find different label at step  219 9 the true is  tensor([3])
# find different label at step  227 3 the true is  tensor([9])
# find different label at step  229 3 the true is  tensor([9])
# find different label at step  231 9 the true is  tensor([3])
# find different label at step  232 9 the true is  tensor([3])
# find different label at step  233 3 the true is  tensor([9])
# find different label at step  234 9 the true is  tensor([3])
# find different label at step  237 9 the true is  tensor([3])
# find different label at step  245 9 the true is  tensor([3])
# find different label at step  246 9 the true is  tensor([3])
# find different label at step  248 9 the true is  tensor([3])
# find different label at step  249 9 the true is  tensor([3])
# find different label at step  254 9 the true is  tensor([3])
# find different label at step  266 9 the true is  tensor([3])
# find different label at step  271 9 the true is  tensor([3])
# find different label at step  273 3 the true is  tensor([9])
# find different label at step  278 9 the true is  tensor([3])
# find different label at step  280 9 the true is  tensor([3])
# find different label at step  281 3 the true is  tensor([9])
# find different label at step  289 9 the true is  tensor([3])
# find different label at step  294 3 the true is  tensor([9])
# find different label at step  297 3 the true is  tensor([9])
# find different label at step  304 9 the true is  tensor([3])
# find different label at step  318 9 the true is  tensor([3])
# find different label at step  322 9 the true is  tensor([3])
# find different label at step  323 9 the true is  tensor([3])
# find different label at step  324 9 the true is  tensor([3])
# find different label at step  332 3 the true is  tensor([9])
# find different label at step  333 3 the true is  tensor([9])
# find different label at step  342 9 the true is  tensor([3])
# find different label at step  345 9 the true is  tensor([3])
# find different label at step  349 9 the true is  tensor([3])
# find different label at step  351 9 the true is  tensor([3])
# find different label at step  354 9 the true is  tensor([3])
# find different label at step  357 9 the true is  tensor([3])
# find different label at step  360 9 the true is  tensor([3])
# find different label at step  365 9 the true is  tensor([3])
# find different label at step  368 3 the true is  tensor([9])
# find different label at step  373 9 the true is  tensor([3])
# find different label at step  375 9 the true is  tensor([3])
# find different label at step  383 3 the true is  tensor([9])
# find different label at step  387 9 the true is  tensor([3])
# find different label at step  392 9 the true is  tensor([3])
# find different label at step  397 3 the true is  tensor([9])
# find different label at step  402 9 the true is  tensor([3])
# find different label at step  408 9 the true is  tensor([3])
# find different label at step  410 9 the true is  tensor([3])
# find different label at step  412 9 the true is  tensor([3])
# find different label at step  423 3 the true is  tensor([9])
# find different label at step  426 3 the true is  tensor([9])
# find different label at step  430 9 the true is  tensor([3])
# find different label at step  434 3 the true is  tensor([9])
# find different label at step  447 9 the true is  tensor([3])
# find different label at step  448 9 the true is  tensor([3])
# find different label at step  450 9 the true is  tensor([3])
# find different label at step  463 3 the true is  tensor([9])
# find different label at step  464 9 the true is  tensor([3])
# find different label at step  478 3 the true is  tensor([9])
# find different label at step  481 3 the true is  tensor([9])
# find different label at step  483 9 the true is  tensor([3])
# find different label at step  485 9 the true is  tensor([3])
# find different label at step  488 9 the true is  tensor([3])
# find different label at step  490 9 the true is  tensor([3])
# find different label at step  495 9 the true is  tensor([3])
# find different label at step  499 3 the true is  tensor([9])
# find different label at step  502 9 the true is  tensor([3])
# find different label at step  504 9 the true is  tensor([3])
# find different label at step  505 3 the true is  tensor([9])
# val_acc 0.7725490196078432
# early stopping at timestep 0 0.7725490196078432
# done

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def plot_stats_in_graph(total_losses, y_axis_label, x_axis_label):

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8,4))
    ax_1 = fig_1.add_subplot(111)
    for k in total_losses.keys():
        if "loss" in k:
            ax_1.plot(np.arange(len(total_losses[k])), total_losses[k], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel(x_axis_label)
    ax_1.set_ylabel(y_axis_label)
plot_stats_in_graph(losses, y_axis_label='Loss', x_axis_label='Number of Steps')
plt.savefig('savefig_example_fortotalloss.png')

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
epochs_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylabel('loss')
plt.xlabel('epoch')
plt.ylim(-1.1,1.1)
plt.plot(epochs_list,a.detach().numpy(),label = ['loss for timestep 5','loss for timestep 4','loss for timestep 3','loss for timestep 2','loss for timestep 1'])
plt.legend()
plt.savefig('savefig_example_forloss.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylim(-1.1,1.1)
plt.plot(timesteps_list,a[:,4].detach().numpy(),label = 'loss for timestep 5')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.savefig('savefig_example_forloss_timestep1.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylim(-1.1,1.1)
plt.plot(timesteps_list,a[:,3].detach().numpy(),label = 'loss for timestep 4')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.savefig('savefig_example_forloss_timestep2.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylim(-1.1,1.1)
plt.plot(timesteps_list,a[:,2].detach().numpy(),label = 'loss for timestep 3')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.savefig('savefig_example_forloss_timestep3.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylim(-1.1,1.1)
plt.plot(timesteps_list,a[:,1].detach().numpy(),label = 'loss for timestep 2')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.savefig('savefig_example_forloss_timestep4.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylim(-1.1,1.1)
plt.plot(timesteps_list,a[:,0].detach().numpy(),label = 'loss for timestep 1')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.savefig('savefig_example_forloss_timestep5.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %% [markdown]
# ## 测试

# %%
# direct calculate the distance and compare them for original images
batch_size=256
train_dataset1 = torch.utils.data.ConcatDataset([mnist_dataset])# this is label 3
train_loader1 = torch.utils.data.DataLoader(train_dataset1, batch_size=batch_size, shuffle=True,pin_memory=True)
x_=torch.zeros([dataset_image_number,3,32,32])
for step, (images, labels) in enumerate(train_loader1):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    x_[step*batch_size:(step+1)*batch_size,:,:,:]=images
x_general=x_[0].mean(0)
print(x_general.shape)
print(x_.shape)
# Out:
# torch.Size([32, 32])
# torch.Size([256, 3, 32, 32])

# %%
# direct calculate the distance and compare them for original images
batch_size=256
train_dataset2 = torch.utils.data.ConcatDataset([mnist2_dataset])# this is label 2
train_loader2 = torch.utils.data.DataLoader(train_dataset2, batch_size=batch_size, shuffle=True,pin_memory=True)
y_=torch.zeros([dataset_image_number,3,32,32])
for step, (images, labels) in enumerate(train_loader2):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    y_[step*batch_size:(step+1)*batch_size,:,:,:]=images
y_general=y_[0].mean(0)
print(y_general.shape)
print(y_.shape)
# Out:
# torch.Size([32, 32])
# torch.Size([256, 3, 32, 32])

# %%
# direct calculate the distance and compare them for original images
accuaracy=0
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=1, shuffle=True,num_workers=4,pin_memory=True)

with torch.no_grad():
  for step, (image, label) in enumerate(train_loader11):
    batch_size = image.shape[0]
    image = image.to(device)
    x0=image
    a=torch.dot(x_.reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_.reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 3 and pred
    b=torch.dot(y_.reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_.reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 2 and pred2 and pred
    if a >= b:
      pred_label= 3
      #print(a,"and",b)
    else:
      pred_label= 9
      #print(a,"and",b)
    if pred_label==label:
      accuaracy=accuaracy+1
      #print("exact!", pred_label,"the true is ",label)
print(accuaracy/len(train_dataset))
# Out:
# 0.7109375

# %% [markdown]
# This is the test

# %%
# establish the x0,x1,x2,x3,x4 for class 1 label3
batch_size=256
train_dataset1 = torch.utils.data.ConcatDataset([mnist_dataset])# this is label 3
train_loader1 = torch.utils.data.DataLoader(train_dataset1, batch_size=batch_size, shuffle=True,pin_memory=True)
T=torch.full((batch_size,),timesteps-1, device=device)
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
timsteps=5
model.to(device)
x_1=torch.zeros([timesteps,dataset_image_number,3,32,32])
for step, (images, labels) in enumerate(train_loader1):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    x0=images
    for t in range(timesteps-1,-1,-1):
      time = torch.full((batch_size,),t, device=device).long()
      # this is label 3
      model.load_state_dict(model_parameters[t],strict=True)
      model.eval()
      time=torch.full((batch_size,),t, device=device)
      x0=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(x0, time))
      x_1[t,step*batch_size:(step+1)*batch_size,:,:,:]=x0
x_1_general=x_1[0].mean(0)
print(x_1_general.shape)
print(x_1.shape)
# Out:
# torch.Size([3, 32, 32])
# torch.Size([5, 256, 3, 32, 32])

# %%
# establish the x0,x1,x2,x3,x4 for class 2 label 2
batch_size=256
train_dataset2 = torch.utils.data.ConcatDataset([mnist2_dataset])# this is label 2
train_loader2 = torch.utils.data.DataLoader(train_dataset2, batch_size=batch_size, shuffle=True,pin_memory=True)
T=torch.full((batch_size,),timesteps-1, device=device)
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)
x_2=torch.zeros([timesteps,dataset_image_number,3,32,32])
for step, (images, labels) in enumerate(train_loader2):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    x0=images
    for t in range(timesteps-1,-1,-1):
      time = torch.full((batch_size,),t, device=device).long()
      # this is label 3
      model.load_state_dict(model_parameters[t],strict=True)
      model.eval()
      time=torch.full((batch_size,),t, device=device)
      x0=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(x0, time))
      x_2[t,step*batch_size:(step+1)*batch_size,:,:,:]=x0

x_2_general=x_2[0].mean(0)
print(x_2_general.shape)
print(x_2.shape)
# Out:
# torch.Size([3, 32, 32])
# torch.Size([5, 256, 3, 32, 32])

# %%
#calculate the mean distance and variances within differenct class
for t in range(timesteps-1,-1,-1):
  innerproduct=torch.dot(x_1[t].reshape(256,3*32*32).mean(0).to(device) / torch.norm(x_1[t].reshape(256,3*32*32).mean(0)).to(device), x_2[t].reshape(256,3*32*32).mean(0).to(device) / torch.norm(x_2[t].reshape(256,3*32*32).mean(0)).to(device)).to(device).mean(0)
  print("inner product",innerproduct)
  m1=x_1[t].reshape(batch_size,3*32*32)
  m2=x_2[t].reshape(batch_size,3*32*32)

  s1=torch.var(m1, dim=0)
  s2=torch.var(m2, dim=0)
  print("variance",s1.mean(0),s2.mean(0))
# Out:
# inner product tensor(-0.9062, device='cuda:0')
# variance tensor(0.1556) tensor(0.0901)
# inner product tensor(-0.9750, device='cuda:0')
# variance tensor(0.1709) tensor(0.0821)
# inner product tensor(-0.9847, device='cuda:0')
# variance tensor(0.1759) tensor(0.0822)
# inner product tensor(-0.9749, device='cuda:0')
# variance tensor(0.1764) tensor(0.0848)
# inner product tensor(-0.9777, device='cuda:0')
# variance tensor(0.1767) tensor(0.0839)

# %%
accuaracy=0
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=1, shuffle=True,num_workers=4,pin_memory=True)
acc=torch.zeros(timesteps)

with torch.no_grad():
  for step, (image, label) in enumerate(train_loader11):
    batch_size = image.shape[0]
    image = image.to(device)
    x0=image
    for t in range(timesteps-1,-1,-1):

      model.load_state_dict(model_parameters[t],strict=True)
      model.eval()
      time=torch.full((batch_size,),t, device=device)
      x0=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(x0, time))
      a=torch.dot(x_1[t].reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_1[t].reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 3 and pred
      b=torch.dot(x_2[t].reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_2[t].reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 2 and pred distance between 2 and pred
      if a >= b:
        pred_label= 3
        print(a,"and",b)
      else:
        pred_label= 9
        #print(a,"and",b)
        #print(pred_label,label)
      if pred_label==label:
        acc[t]=acc[t]+1
      #print("exact!", pred_label,"the true is ",label)
      else:
        print("timestep", t, " find different label at step ", step, pred_label,"the true is ",label)
# Out:
# tensor(0.8614, device='cuda:0') and tensor(-0.9230, device='cuda:0')
# tensor(0.9780, device='cuda:0') and tensor(-0.9910, device='cuda:0')
# tensor(0.9957, device='cuda:0') and tensor(-0.9900, device='cuda:0')
# tensor(0.9913, device='cuda:0') and tensor(-0.9954, device='cuda:0')
# tensor(0.9959, device='cuda:0') and tensor(-0.9927, device='cuda:0')
# timestep 4  find different label at step  1 9 the true is  tensor([3])
# timestep 3  find different label at step  1 9 the true is  tensor([3])
# timestep 2  find different label at step  1 9 the true is  tensor([3])
# timestep 1  find different label at step  1 9 the true is  tensor([3])
# timestep 0  find different label at step  1 9 the true is  tensor([3])
# timestep 4  find different label at step  2 9 the true is  tensor([3])
# timestep 3  find different label at step  2 9 the true is  tensor([3])
# timestep 2  find different label at step  2 9 the true is  tensor([3])
# timestep 1  find different label at step  2 9 the true is  tensor([3])
# timestep 0  find different label at step  2 9 the true is  tensor([3])
# tensor(0.6508, device='cuda:0') and tensor(-0.6889, device='cuda:0')
# tensor(0.8387, device='cuda:0') and tensor(-0.8594, device='cuda:0')
# tensor(0.9805, device='cuda:0') and tensor(-0.9663, device='cuda:0')
# tensor(0.9819, device='cuda:0') and tensor(-0.9967, device='cuda:0')
# tensor(0.9969, device='cuda:0') and tensor(-0.9904, device='cuda:0')
# tensor(0.7069, device='cuda:0') and tensor(-0.8176, device='cuda:0')
# tensor(0.9771, device='cuda:0') and tensor(-0.9868, device='cuda:0')
# tensor(0.9951, device='cuda:0') and tensor(-0.9888, device='cuda:0')
# tensor(0.9908, device='cuda:0') and tensor(-0.9957, device='cuda:0')
# tensor(0.9960, device='cuda:0') and tensor(-0.9925, device='cuda:0')
# tensor(0.7626, device='cuda:0') and tensor(-0.9191, device='cuda:0')
# tensor(0.9536, device='cuda:0') and tensor(-0.9784, device='cuda:0')
# tensor(0.9930, device='cuda:0') and tensor(-0.9849, device='cuda:0')
# tensor(0.9891, device='cuda:0') and tensor(-0.9963, device='cuda:0')
# tensor(0.9962, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.9070, device='cuda:0') and tensor(-0.9889, device='cuda:0')
# tensor(0.9896, device='cuda:0') and tensor(-0.9956, device='cuda:0')
# tensor(0.9969, device='cuda:0') and tensor(-0.9935, device='cuda:0')
# tensor(0.9930, device='cuda:0') and tensor(-0.9941, device='cuda:0')
# tensor(0.9954, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.6482, device='cuda:0') and tensor(-0.8392, device='cuda:0')
# timestep 4  find different label at step  10 3 the true is  tensor([9])
# tensor(0.8857, device='cuda:0') and tensor(-0.9171, device='cuda:0')
# timestep 3  find different label at step  10 3 the true is  tensor([9])
# tensor(0.9871, device='cuda:0') and tensor(-0.9764, device='cuda:0')
# timestep 2  find different label at step  10 3 the true is  tensor([9])
# tensor(0.9857, device='cuda:0') and tensor(-0.9969, device='cuda:0')
# timestep 1  find different label at step  10 3 the true is  tensor([9])
# tensor(0.9967, device='cuda:0') and tensor(-0.9912, device='cuda:0')
# timestep 0  find different label at step  10 3 the true is  tensor([9])
# timestep 4  find different label at step  12 9 the true is  tensor([3])
# timestep 3  find different label at step  12 9 the true is  tensor([3])
# timestep 2  find different label at step  12 9 the true is  tensor([3])
# timestep 1  find different label at step  12 9 the true is  tensor([3])
# timestep 0  find different label at step  12 9 the true is  tensor([3])
# tensor(0.6102, device='cuda:0') and tensor(-0.7360, device='cuda:0')
# tensor(0.9100, device='cuda:0') and tensor(-0.9065, device='cuda:0')
# tensor(0.9873, device='cuda:0') and tensor(-0.9778, device='cuda:0')
# tensor(0.9867, device='cuda:0') and tensor(-0.9965, device='cuda:0')
# tensor(0.9965, device='cuda:0') and tensor(-0.9915, device='cuda:0')
# tensor(0.1192, device='cuda:0') and tensor(-0.3040, device='cuda:0')
# timestep 4  find different label at step  15 3 the true is  tensor([9])
# tensor(0.4704, device='cuda:0') and tensor(-0.4842, device='cuda:0')
# timestep 3  find different label at step  15 3 the true is  tensor([9])
# tensor(0.9482, device='cuda:0') and tensor(-0.9283, device='cuda:0')
# timestep 2  find different label at step  15 3 the true is  tensor([9])
# tensor(0.9674, device='cuda:0') and tensor(-0.9926, device='cuda:0')
# timestep 1  find different label at step  15 3 the true is  tensor([9])
# tensor(0.9974, device='cuda:0') and tensor(-0.9873, device='cuda:0')
# timestep 0  find different label at step  15 3 the true is  tensor([9])
# tensor(0.7543, device='cuda:0') and tensor(-0.8808, device='cuda:0')
# tensor(0.9760, device='cuda:0') and tensor(-0.9927, device='cuda:0')
# tensor(0.9956, device='cuda:0') and tensor(-0.9897, device='cuda:0')
# tensor(0.9911, device='cuda:0') and tensor(-0.9955, device='cuda:0')
# tensor(0.9959, device='cuda:0') and tensor(-0.9926, device='cuda:0')
# tensor(0.3389, device='cuda:0') and tensor(-0.5012, device='cuda:0')
# tensor(0.6958, device='cuda:0') and tensor(-0.7253, device='cuda:0')
# tensor(0.9701, device='cuda:0') and tensor(-0.9535, device='cuda:0')
# tensor(0.9775, device='cuda:0') and tensor(-0.9960, device='cuda:0')
# tensor(0.9972, device='cuda:0') and tensor(-0.9894, device='cuda:0')
# timestep 4  find different label at step  19 9 the true is  tensor([3])
# timestep 3  find different label at step  19 9 the true is  tensor([3])
# timestep 2  find different label at step  19 9 the true is  tensor([3])
# timestep 1  find different label at step  19 9 the true is  tensor([3])
# timestep 0  find different label at step  19 9 the true is  tensor([3])
# tensor(0.7162, device='cuda:0') and tensor(-0.8909, device='cuda:0')
# tensor(0.9348, device='cuda:0') and tensor(-0.9613, device='cuda:0')
# tensor(0.9907, device='cuda:0') and tensor(-0.9815, device='cuda:0')
# tensor(0.9878, device='cuda:0') and tensor(-0.9966, device='cuda:0')
# tensor(0.9964, device='cuda:0') and tensor(-0.9917, device='cuda:0')
# tensor(0.7993, device='cuda:0') and tensor(-0.8944, device='cuda:0')
# tensor(0.9843, device='cuda:0') and tensor(-0.9955, device='cuda:0')
# tensor(0.9965, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.9921, device='cuda:0') and tensor(-0.9948, device='cuda:0')
# tensor(0.9956, device='cuda:0') and tensor(-0.9930, device='cuda:0')
# tensor(0.7132, device='cuda:0') and tensor(-0.7239, device='cuda:0')
# tensor(0.8878, device='cuda:0') and tensor(-0.9059, device='cuda:0')
# tensor(0.9854, device='cuda:0') and tensor(-0.9729, device='cuda:0')
# tensor(0.9843, device='cuda:0') and tensor(-0.9968, device='cuda:0')
# tensor(0.9968, device='cuda:0') and tensor(-0.9909, device='cuda:0')
# tensor(0.7716, device='cuda:0') and tensor(-0.9279, device='cuda:0')
# tensor(0.9655, device='cuda:0') and tensor(-0.9851, device='cuda:0')
# tensor(0.9943, device='cuda:0') and tensor(-0.9874, device='cuda:0')
# tensor(0.9903, device='cuda:0') and tensor(-0.9959, device='cuda:0')
# tensor(0.9961, device='cuda:0') and tensor(-0.9924, device='cuda:0')
# timestep 4  find different label at step  27 9 the true is  tensor([3])
# timestep 3  find different label at step  27 9 the true is  tensor([3])
# timestep 2  find different label at step  27 9 the true is  tensor([3])
# timestep 1  find different label at step  27 9 the true is  tensor([3])
# timestep 0  find different label at step  27 9 the true is  tensor([3])
# tensor(0.8141, device='cuda:0') and tensor(-0.9497, device='cuda:0')
# tensor(0.9733, device='cuda:0') and tensor(-0.9911, device='cuda:0')
# tensor(0.9953, device='cuda:0') and tensor(-0.9892, device='cuda:0')
# tensor(0.9909, device='cuda:0') and tensor(-0.9956, device='cuda:0')
# tensor(0.9959, device='cuda:0') and tensor(-0.9926, device='cuda:0')
# tensor(0.6806, device='cuda:0') and tensor(-0.4022, device='cuda:0')
# tensor(0.8784, device='cuda:0') and tensor(-0.8403, device='cuda:0')
# tensor(0.8520, device='cuda:0') and tensor(-0.8620, device='cuda:0')
# tensor(0.9865, device='cuda:0') and tensor(-0.9541, device='cuda:0')
# tensor(0.9859, device='cuda:0') and tensor(-0.9951, device='cuda:0')
# tensor(0.7153, device='cuda:0') and tensor(-0.8547, device='cuda:0')
# tensor(0.9604, device='cuda:0') and tensor(-0.9832, device='cuda:0')
# tensor(0.9940, device='cuda:0') and tensor(-0.9866, device='cuda:0')
# tensor(0.9897, device='cuda:0') and tensor(-0.9961, device='cuda:0')
# tensor(0.9961, device='cuda:0') and tensor(-0.9923, device='cuda:0')
# tensor(0.9494, device='cuda:0') and tensor(-0.9845, device='cuda:0')
# tensor(0.9913, device='cuda:0') and tensor(-0.9905, device='cuda:0')
# tensor(0.9968, device='cuda:0') and tensor(-0.9948, device='cuda:0')
# tensor(0.9939, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# tensor(0.9951, device='cuda:0') and tensor(-0.9935, device='cuda:0')
# timestep 4  find different label at step  37 9 the true is  tensor([3])
# timestep 3  find different label at step  37 9 the true is  tensor([3])
# timestep 2  find different label at step  37 9 the true is  tensor([3])
# timestep 1  find different label at step  37 9 the true is  tensor([3])
# timestep 0  find different label at step  37 9 the true is  tensor([3])
# tensor(0.6077, device='cuda:0') and tensor(-0.7309, device='cuda:0')
# tensor(0.8862, device='cuda:0') and tensor(-0.9132, device='cuda:0')
# tensor(0.9861, device='cuda:0') and tensor(-0.9751, device='cuda:0')
# tensor(0.9851, device='cuda:0') and tensor(-0.9969, device='cuda:0')
# tensor(0.9967, device='cuda:0') and tensor(-0.9911, device='cuda:0')
# tensor(0.4951, device='cuda:0') and tensor(-0.4378, device='cuda:0')
# tensor(0.5486, device='cuda:0') and tensor(-0.5331, device='cuda:0')
# tensor(0.9205, device='cuda:0') and tensor(-0.9192, device='cuda:0')
# tensor(0.9877, device='cuda:0') and tensor(-0.9822, device='cuda:0')
# tensor(0.9950, device='cuda:0') and tensor(-0.9928, device='cuda:0')
# tensor(0.3899, device='cuda:0') and tensor(-0.3864, device='cuda:0')
# tensor(0.3490, device='cuda:0') and tensor(-0.3472, device='cuda:0')
# tensor(0.8801, device='cuda:0') and tensor(-0.8756, device='cuda:0')
# tensor(0.9768, device='cuda:0') and tensor(-0.9747, device='cuda:0')
# tensor(0.9956, device='cuda:0') and tensor(-0.9907, device='cuda:0')
# tensor(0.9543, device='cuda:0') and tensor(-0.8571, device='cuda:0')
# tensor(0.9807, device='cuda:0') and tensor(-0.9625, device='cuda:0')
# tensor(0.9938, device='cuda:0') and tensor(-0.9951, device='cuda:0')
# tensor(0.9954, device='cuda:0') and tensor(-0.9900, device='cuda:0')
# tensor(0.9943, device='cuda:0') and tensor(-0.9942, device='cuda:0')
# timestep 4  find different label at step  51 9 the true is  tensor([3])
# timestep 3  find different label at step  51 9 the true is  tensor([3])
# timestep 2  find different label at step  51 9 the true is  tensor([3])
# timestep 1  find different label at step  51 9 the true is  tensor([3])
# timestep 0  find different label at step  51 9 the true is  tensor([3])
# tensor(0.7426, device='cuda:0') and tensor(-0.8994, device='cuda:0')
# tensor(0.9522, device='cuda:0') and tensor(-0.9775, device='cuda:0')
# tensor(0.9929, device='cuda:0') and tensor(-0.9848, device='cuda:0')
# tensor(0.9890, device='cuda:0') and tensor(-0.9963, device='cuda:0')
# tensor(0.9963, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.7359, device='cuda:0') and tensor(-0.8981, device='cuda:0')
# tensor(0.9504, device='cuda:0') and tensor(-0.9757, device='cuda:0')
# tensor(0.9927, device='cuda:0') and tensor(-0.9846, device='cuda:0')
# tensor(0.9890, device='cuda:0') and tensor(-0.9964, device='cuda:0')
# tensor(0.9963, device='cuda:0') and tensor(-0.9920, device='cuda:0')
# timestep 4  find different label at step  59 9 the true is  tensor([3])
# timestep 3  find different label at step  59 9 the true is  tensor([3])
# timestep 2  find different label at step  59 9 the true is  tensor([3])
# timestep 1  find different label at step  59 9 the true is  tensor([3])
# timestep 0  find different label at step  59 9 the true is  tensor([3])
# tensor(0.7132, device='cuda:0') and tensor(-0.8023, device='cuda:0')
# tensor(0.9569, device='cuda:0') and tensor(-0.9542, device='cuda:0')
# tensor(0.9930, device='cuda:0') and tensor(-0.9876, device='cuda:0')
# tensor(0.9907, device='cuda:0') and tensor(-0.9954, device='cuda:0')
# tensor(0.9960, device='cuda:0') and tensor(-0.9925, device='cuda:0')
# tensor(0.7754, device='cuda:0') and tensor(-0.8502, device='cuda:0')
# tensor(0.9805, device='cuda:0') and tensor(-0.9878, device='cuda:0')
# tensor(0.9959, device='cuda:0') and tensor(-0.9927, device='cuda:0')
# tensor(0.9929, device='cuda:0') and tensor(-0.9943, device='cuda:0')
# tensor(0.9955, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# tensor(0.1062, device='cuda:0') and tensor(-0.1136, device='cuda:0')
# tensor(0.0631, device='cuda:0') and tensor(-0.0976, device='cuda:0')
# tensor(0.2268, device='cuda:0') and tensor(-0.2314, device='cuda:0')
# tensor(0.3675, device='cuda:0') and tensor(-0.4250, device='cuda:0')
# tensor(0.8760, device='cuda:0') and tensor(-0.8243, device='cuda:0')
# tensor(0.7777, device='cuda:0') and tensor(-0.7142, device='cuda:0')
# tensor(0.9667, device='cuda:0') and tensor(-0.9422, device='cuda:0')
# tensor(0.9936, device='cuda:0') and tensor(-0.9945, device='cuda:0')
# tensor(0.9949, device='cuda:0') and tensor(-0.9915, device='cuda:0')
# tensor(0.9947, device='cuda:0') and tensor(-0.9939, device='cuda:0')
# tensor(0.8847, device='cuda:0') and tensor(-0.9814, device='cuda:0')
# tensor(0.9864, device='cuda:0') and tensor(-0.9944, device='cuda:0')
# tensor(0.9965, device='cuda:0') and tensor(-0.9926, device='cuda:0')
# tensor(0.9926, device='cuda:0') and tensor(-0.9946, device='cuda:0')
# tensor(0.9956, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# timestep 4  find different label at step  69 9 the true is  tensor([3])
# timestep 3  find different label at step  69 9 the true is  tensor([3])
# timestep 2  find different label at step  69 9 the true is  tensor([3])
# timestep 1  find different label at step  69 9 the true is  tensor([3])
# timestep 0  find different label at step  69 9 the true is  tensor([3])
# tensor(0.6420, device='cuda:0') and tensor(-0.5812, device='cuda:0')
# tensor(0.9230, device='cuda:0') and tensor(-0.9264, device='cuda:0')
# tensor(0.9926, device='cuda:0') and tensor(-0.9840, device='cuda:0')
# tensor(0.9884, device='cuda:0') and tensor(-0.9964, device='cuda:0')
# tensor(0.9963, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.5533, device='cuda:0') and tensor(-0.6938, device='cuda:0')
# timestep 4  find different label at step  73 3 the true is  tensor([9])
# tensor(0.9268, device='cuda:0') and tensor(-0.9562, device='cuda:0')
# timestep 3  find different label at step  73 3 the true is  tensor([9])
# tensor(0.9905, device='cuda:0') and tensor(-0.9807, device='cuda:0')
# timestep 2  find different label at step  73 3 the true is  tensor([9])
# tensor(0.9874, device='cuda:0') and tensor(-0.9967, device='cuda:0')
# timestep 1  find different label at step  73 3 the true is  tensor([9])
# tensor(0.9965, device='cuda:0') and tensor(-0.9916, device='cuda:0')
# timestep 0  find different label at step  73 3 the true is  tensor([9])
# tensor(0.3761, device='cuda:0') and tensor(-0.3448, device='cuda:0')
# tensor(0.5375, device='cuda:0') and tensor(-0.5499, device='cuda:0')
# tensor(0.9463, device='cuda:0') and tensor(-0.9266, device='cuda:0')
# tensor(0.9658, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.9974, device='cuda:0') and tensor(-0.9871, device='cuda:0')
# timestep 4  find different label at step  75 9 the true is  tensor([3])
# timestep 3  find different label at step  75 9 the true is  tensor([3])
# timestep 2  find different label at step  75 9 the true is  tensor([3])
# timestep 1  find different label at step  75 9 the true is  tensor([3])
# timestep 0  find different label at step  75 9 the true is  tensor([3])
# tensor(0.9547, device='cuda:0') and tensor(-0.8667, device='cuda:0')
# tensor(0.9807, device='cuda:0') and tensor(-0.9685, device='cuda:0')
# tensor(0.9957, device='cuda:0') and tensor(-0.9949, device='cuda:0')
# tensor(0.9945, device='cuda:0') and tensor(-0.9918, device='cuda:0')
# tensor(0.9948, device='cuda:0') and tensor(-0.9938, device='cuda:0')
# tensor(0.8196, device='cuda:0') and tensor(-0.7869, device='cuda:0')
# tensor(0.9780, device='cuda:0') and tensor(-0.9650, device='cuda:0')
# tensor(0.9950, device='cuda:0') and tensor(-0.9948, device='cuda:0')
# tensor(0.9944, device='cuda:0') and tensor(-0.9924, device='cuda:0')
# tensor(0.9949, device='cuda:0') and tensor(-0.9937, device='cuda:0')
# timestep 4  find different label at step  81 9 the true is  tensor([3])
# timestep 3  find different label at step  81 9 the true is  tensor([3])
# timestep 2  find different label at step  81 9 the true is  tensor([3])
# timestep 1  find different label at step  81 9 the true is  tensor([3])
# timestep 0  find different label at step  81 9 the true is  tensor([3])
# tensor(0.8422, device='cuda:0') and tensor(-0.6528, device='cuda:0')
# tensor(0.9604, device='cuda:0') and tensor(-0.9329, device='cuda:0')
# tensor(0.9885, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.9960, device='cuda:0') and tensor(-0.9871, device='cuda:0')
# tensor(0.9935, device='cuda:0') and tensor(-0.9946, device='cuda:0')
# timestep 4  find different label at step  83 9 the true is  tensor([3])
# timestep 3  find different label at step  83 9 the true is  tensor([3])
# timestep 2  find different label at step  83 9 the true is  tensor([3])
# timestep 1  find different label at step  83 9 the true is  tensor([3])
# timestep 0  find different label at step  83 9 the true is  tensor([3])
# tensor(0.9023, device='cuda:0') and tensor(-0.9785, device='cuda:0')
# tensor(0.9889, device='cuda:0') and tensor(-0.9911, device='cuda:0')
# tensor(0.9967, device='cuda:0') and tensor(-0.9938, device='cuda:0')
# tensor(0.9932, device='cuda:0') and tensor(-0.9940, device='cuda:0')
# tensor(0.9954, device='cuda:0') and tensor(-0.9933, device='cuda:0')
# tensor(0.5768, device='cuda:0') and tensor(-0.5807, device='cuda:0')
# tensor(0.8930, device='cuda:0') and tensor(-0.8736, device='cuda:0')
# tensor(0.9880, device='cuda:0') and tensor(-0.9807, device='cuda:0')
# tensor(0.9882, device='cuda:0') and tensor(-0.9958, device='cuda:0')
# tensor(0.9963, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# timestep 4  find different label at step  89 9 the true is  tensor([3])
# timestep 3  find different label at step  89 9 the true is  tensor([3])
# timestep 2  find different label at step  89 9 the true is  tensor([3])
# timestep 1  find different label at step  89 9 the true is  tensor([3])
# timestep 0  find different label at step  89 9 the true is  tensor([3])
# tensor(0.4068, device='cuda:0') and tensor(-0.0558, device='cuda:0')
# timestep 3  find different label at step  90 9 the true is  tensor([3])
# timestep 2  find different label at step  90 9 the true is  tensor([3])
# timestep 1  find different label at step  90 9 the true is  tensor([3])
# timestep 0  find different label at step  90 9 the true is  tensor([3])
# tensor(0.8829, device='cuda:0') and tensor(-0.9664, device='cuda:0')
# tensor(0.9879, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.9966, device='cuda:0') and tensor(-0.9934, device='cuda:0')
# tensor(0.9930, device='cuda:0') and tensor(-0.9942, device='cuda:0')
# tensor(0.9955, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.4644, device='cuda:0') and tensor(-0.4871, device='cuda:0')
# tensor(0.7140, device='cuda:0') and tensor(-0.7283, device='cuda:0')
# tensor(0.9681, device='cuda:0') and tensor(-0.9513, device='cuda:0')
# tensor(0.9756, device='cuda:0') and tensor(-0.9955, device='cuda:0')
# tensor(0.9972, device='cuda:0') and tensor(-0.9890, device='cuda:0')
# tensor(0.8905, device='cuda:0') and tensor(-0.7889, device='cuda:0')
# tensor(0.9763, device='cuda:0') and tensor(-0.9515, device='cuda:0')
# tensor(0.9927, device='cuda:0') and tensor(-0.9951, device='cuda:0')
# tensor(0.9957, device='cuda:0') and tensor(-0.9894, device='cuda:0')
# tensor(0.9941, device='cuda:0') and tensor(-0.9943, device='cuda:0')
# tensor(0.6044, device='cuda:0') and tensor(-0.6441, device='cuda:0')
# tensor(0.8259, device='cuda:0') and tensor(-0.8113, device='cuda:0')
# tensor(0.9804, device='cuda:0') and tensor(-0.9716, device='cuda:0')
# tensor(0.9863, device='cuda:0') and tensor(-0.9953, device='cuda:0')
# tensor(0.9965, device='cuda:0') and tensor(-0.9915, device='cuda:0')
# timestep 4  find different label at step  99 9 the true is  tensor([3])
# timestep 3  find different label at step  99 9 the true is  tensor([3])
# timestep 2  find different label at step  99 9 the true is  tensor([3])
# timestep 1  find different label at step  99 9 the true is  tensor([3])
# timestep 0  find different label at step  99 9 the true is  tensor([3])
# tensor(0.9199, device='cuda:0') and tensor(-0.7769, device='cuda:0')
# timestep 4  find different label at step  101 3 the true is  tensor([9])
# tensor(0.9704, device='cuda:0') and tensor(-0.9485, device='cuda:0')
# timestep 3  find different label at step  101 3 the true is  tensor([9])
# tensor(0.9925, device='cuda:0') and tensor(-0.9941, device='cuda:0')
# timestep 2  find different label at step  101 3 the true is  tensor([9])
# tensor(0.9955, device='cuda:0') and tensor(-0.9893, device='cuda:0')
# timestep 1  find different label at step  101 3 the true is  tensor([9])
# tensor(0.9941, device='cuda:0') and tensor(-0.9943, device='cuda:0')
# timestep 0  find different label at step  101 3 the true is  tensor([9])
# tensor(-0.0192, device='cuda:0') and tensor(-0.0712, device='cuda:0')
# timestep 3  find different label at step  102 9 the true is  tensor([3])
# tensor(0.2701, device='cuda:0') and tensor(-0.2934, device='cuda:0')
# tensor(0.2897, device='cuda:0') and tensor(-0.3139, device='cuda:0')
# tensor(0.9131, device='cuda:0') and tensor(-0.8811, device='cuda:0')
# timestep 4  find different label at step  103 9 the true is  tensor([3])
# timestep 3  find different label at step  103 9 the true is  tensor([3])
# timestep 2  find different label at step  103 9 the true is  tensor([3])
# timestep 1  find different label at step  103 9 the true is  tensor([3])
# timestep 0  find different label at step  103 9 the true is  tensor([3])
# tensor(0.7261, device='cuda:0') and tensor(-0.8909, device='cuda:0')
# tensor(0.9569, device='cuda:0') and tensor(-0.9777, device='cuda:0')
# tensor(0.9931, device='cuda:0') and tensor(-0.9855, device='cuda:0')
# tensor(0.9894, device='cuda:0') and tensor(-0.9962, device='cuda:0')
# tensor(0.9962, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.5431, device='cuda:0') and tensor(-0.6973, device='cuda:0')
# tensor(0.8511, device='cuda:0') and tensor(-0.8776, device='cuda:0')
# tensor(0.9841, device='cuda:0') and tensor(-0.9721, device='cuda:0')
# tensor(0.9838, device='cuda:0') and tensor(-0.9969, device='cuda:0')
# tensor(0.9968, device='cuda:0') and tensor(-0.9908, device='cuda:0')
# tensor(0.8720, device='cuda:0') and tensor(-0.7108, device='cuda:0')
# tensor(0.9661, device='cuda:0') and tensor(-0.9357, device='cuda:0')
# tensor(0.9882, device='cuda:0') and tensor(-0.9923, device='cuda:0')
# tensor(0.9961, device='cuda:0') and tensor(-0.9869, device='cuda:0')
# tensor(0.9935, device='cuda:0') and tensor(-0.9947, device='cuda:0')
# tensor(0.9055, device='cuda:0') and tensor(-0.9326, device='cuda:0')
# tensor(0.9893, device='cuda:0') and tensor(-0.9836, device='cuda:0')
# tensor(0.9965, device='cuda:0') and tensor(-0.9948, device='cuda:0')
# tensor(0.9939, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.9952, device='cuda:0') and tensor(-0.9935, device='cuda:0')
# tensor(0.3895, device='cuda:0') and tensor(-0.0881, device='cuda:0')
# timestep 3  find different label at step  111 9 the true is  tensor([3])
# timestep 2  find different label at step  111 9 the true is  tensor([3])
# timestep 1  find different label at step  111 9 the true is  tensor([3])
# timestep 0  find different label at step  111 9 the true is  tensor([3])
# tensor(0.4500, device='cuda:0') and tensor(-0.3339, device='cuda:0')
# tensor(0.4026, device='cuda:0') and tensor(-0.4390, device='cuda:0')
# tensor(0.9111, device='cuda:0') and tensor(-0.8806, device='cuda:0')
# tensor(0.9683, device='cuda:0') and tensor(-0.9896, device='cuda:0')
# tensor(0.9972, device='cuda:0') and tensor(-0.9879, device='cuda:0')
# timestep 4  find different label at step  113 9 the true is  tensor([3])
# timestep 3  find different label at step  113 9 the true is  tensor([3])
# timestep 2  find different label at step  113 9 the true is  tensor([3])
# timestep 1  find different label at step  113 9 the true is  tensor([3])
# timestep 0  find different label at step  113 9 the true is  tensor([3])
# tensor(0.5214, device='cuda:0') and tensor(-0.4006, device='cuda:0')
# tensor(0.7800, device='cuda:0') and tensor(-0.7352, device='cuda:0')
# tensor(0.9394, device='cuda:0') and tensor(-0.9444, device='cuda:0')
# tensor(0.9954, device='cuda:0') and tensor(-0.9775, device='cuda:0')
# tensor(0.9918, device='cuda:0') and tensor(-0.9952, device='cuda:0')
# timestep 4  find different label at step  116 9 the true is  tensor([3])
# timestep 3  find different label at step  116 9 the true is  tensor([3])
# timestep 2  find different label at step  116 9 the true is  tensor([3])
# timestep 1  find different label at step  116 9 the true is  tensor([3])
# timestep 0  find different label at step  116 9 the true is  tensor([3])
# timestep 4  find different label at step  120 9 the true is  tensor([3])
# timestep 3  find different label at step  120 9 the true is  tensor([3])
# timestep 2  find different label at step  120 9 the true is  tensor([3])
# timestep 1  find different label at step  120 9 the true is  tensor([3])
# timestep 0  find different label at step  120 9 the true is  tensor([3])
# tensor(0.8810, device='cuda:0') and tensor(-0.8908, device='cuda:0')
# tensor(0.9844, device='cuda:0') and tensor(-0.9862, device='cuda:0')
# tensor(0.9967, device='cuda:0') and tensor(-0.9934, device='cuda:0')
# tensor(0.9931, device='cuda:0') and tensor(-0.9937, device='cuda:0')
# tensor(0.9953, device='cuda:0') and tensor(-0.9933, device='cuda:0')
# timestep 4  find different label at step  123 9 the true is  tensor([3])
# timestep 3  find different label at step  123 9 the true is  tensor([3])
# timestep 2  find different label at step  123 9 the true is  tensor([3])
# timestep 1  find different label at step  123 9 the true is  tensor([3])
# timestep 0  find different label at step  123 9 the true is  tensor([3])
# tensor(0.8229, device='cuda:0') and tensor(-0.8745, device='cuda:0')
# tensor(0.9796, device='cuda:0') and tensor(-0.9886, device='cuda:0')
# tensor(0.9964, device='cuda:0') and tensor(-0.9916, device='cuda:0')
# tensor(0.9920, device='cuda:0') and tensor(-0.9947, device='cuda:0')
# tensor(0.9956, device='cuda:0') and tensor(-0.9930, device='cuda:0')
# tensor(0.5746, device='cuda:0') and tensor(-0.2871, device='cuda:0')
# timestep 4  find different label at step  125 3 the true is  tensor([9])
# tensor(0.6619, device='cuda:0') and tensor(-0.6301, device='cuda:0')
# timestep 3  find different label at step  125 3 the true is  tensor([9])
# tensor(0.3388, device='cuda:0') and tensor(-0.3406, device='cuda:0')
# timestep 2  find different label at step  125 3 the true is  tensor([9])
# tensor(0.7080, device='cuda:0') and tensor(-0.6342, device='cuda:0')
# timestep 1  find different label at step  125 3 the true is  tensor([9])
# tensor(0.2965, device='cuda:0') and tensor(-0.3718, device='cuda:0')
# timestep 0  find different label at step  125 3 the true is  tensor([9])
# tensor(0.6855, device='cuda:0') and tensor(-0.4331, device='cuda:0')
# tensor(0.9055, device='cuda:0') and tensor(-0.8630, device='cuda:0')
# tensor(0.9107, device='cuda:0') and tensor(-0.9208, device='cuda:0')
# tensor(0.9925, device='cuda:0') and tensor(-0.9682, device='cuda:0')
# tensor(0.9894, device='cuda:0') and tensor(-0.9955, device='cuda:0')
# tensor(0.8328, device='cuda:0') and tensor(-0.9527, device='cuda:0')
# tensor(0.9722, device='cuda:0') and tensor(-0.9908, device='cuda:0')
# tensor(0.9953, device='cuda:0') and tensor(-0.9890, device='cuda:0')
# tensor(0.9907, device='cuda:0') and tensor(-0.9957, device='cuda:0')
# tensor(0.9960, device='cuda:0') and tensor(-0.9925, device='cuda:0')
# tensor(0.9110, device='cuda:0') and tensor(-0.9719, device='cuda:0')
# tensor(0.9902, device='cuda:0') and tensor(-0.9898, device='cuda:0')
# tensor(0.9967, device='cuda:0') and tensor(-0.9942, device='cuda:0')
# tensor(0.9935, device='cuda:0') and tensor(-0.9937, device='cuda:0')
# tensor(0.9953, device='cuda:0') and tensor(-0.9934, device='cuda:0')
# tensor(0.7978, device='cuda:0') and tensor(-0.7918, device='cuda:0')
# tensor(0.9748, device='cuda:0') and tensor(-0.9789, device='cuda:0')
# tensor(0.9961, device='cuda:0') and tensor(-0.9915, device='cuda:0')
# tensor(0.9922, device='cuda:0') and tensor(-0.9943, device='cuda:0')
# tensor(0.9956, device='cuda:0') and tensor(-0.9930, device='cuda:0')
# tensor(0.0988, device='cuda:0') and tensor(-0.2550, device='cuda:0')
# timestep 4  find different label at step  136 3 the true is  tensor([9])
# tensor(0.2552, device='cuda:0') and tensor(-0.2829, device='cuda:0')
# timestep 3  find different label at step  136 3 the true is  tensor([9])
# tensor(0.9089, device='cuda:0') and tensor(-0.8804, device='cuda:0')
# timestep 2  find different label at step  136 3 the true is  tensor([9])
# tensor(0.9502, device='cuda:0') and tensor(-0.9835, device='cuda:0')
# timestep 1  find different label at step  136 3 the true is  tensor([9])
# tensor(0.9972, device='cuda:0') and tensor(-0.9841, device='cuda:0')
# timestep 0  find different label at step  136 3 the true is  tensor([9])
# tensor(0.8455, device='cuda:0') and tensor(-0.9533, device='cuda:0')
# tensor(0.9746, device='cuda:0') and tensor(-0.9903, device='cuda:0')
# tensor(0.9951, device='cuda:0') and tensor(-0.9885, device='cuda:0')
# tensor(0.9905, device='cuda:0') and tensor(-0.9958, device='cuda:0')
# tensor(0.9960, device='cuda:0') and tensor(-0.9925, device='cuda:0')
# tensor(0.8770, device='cuda:0') and tensor(-0.7436, device='cuda:0')
# tensor(0.9689, device='cuda:0') and tensor(-0.9409, device='cuda:0')
# tensor(0.9890, device='cuda:0') and tensor(-0.9930, device='cuda:0')
# tensor(0.9961, device='cuda:0') and tensor(-0.9873, device='cuda:0')
# tensor(0.9935, device='cuda:0') and tensor(-0.9946, device='cuda:0')
# tensor(0.7746, device='cuda:0') and tensor(-0.6869, device='cuda:0')
# tensor(0.9516, device='cuda:0') and tensor(-0.9470, device='cuda:0')
# tensor(0.9941, device='cuda:0') and tensor(-0.9886, device='cuda:0')
# tensor(0.9924, device='cuda:0') and tensor(-0.9933, device='cuda:0')
# tensor(0.9953, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.8215, device='cuda:0') and tensor(-0.9487, device='cuda:0')
# tensor(0.9725, device='cuda:0') and tensor(-0.9911, device='cuda:0')
# tensor(0.9953, device='cuda:0') and tensor(-0.9890, device='cuda:0')
# tensor(0.9908, device='cuda:0') and tensor(-0.9957, device='cuda:0')
# tensor(0.9960, device='cuda:0') and tensor(-0.9925, device='cuda:0')
# tensor(0.8399, device='cuda:0') and tensor(-0.9434, device='cuda:0')
# tensor(0.9640, device='cuda:0') and tensor(-0.9858, device='cuda:0')
# tensor(0.9944, device='cuda:0') and tensor(-0.9872, device='cuda:0')
# tensor(0.9900, device='cuda:0') and tensor(-0.9960, device='cuda:0')
# tensor(0.9961, device='cuda:0') and tensor(-0.9923, device='cuda:0')
# tensor(0.9394, device='cuda:0') and tensor(-0.9836, device='cuda:0')
# tensor(0.9919, device='cuda:0') and tensor(-0.9913, device='cuda:0')
# tensor(0.9968, device='cuda:0') and tensor(-0.9949, device='cuda:0')
# tensor(0.9939, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.9951, device='cuda:0') and tensor(-0.9935, device='cuda:0')
# tensor(0.9454, device='cuda:0') and tensor(-0.8789, device='cuda:0')
# timestep 4  find different label at step  149 3 the true is  tensor([9])
# tensor(0.9878, device='cuda:0') and tensor(-0.9764, device='cuda:0')
# timestep 3  find different label at step  149 3 the true is  tensor([9])
# tensor(0.9956, device='cuda:0') and tensor(-0.9954, device='cuda:0')
# timestep 2  find different label at step  149 3 the true is  tensor([9])
# tensor(0.9948, device='cuda:0') and tensor(-0.9915, device='cuda:0')
# timestep 1  find different label at step  149 3 the true is  tensor([9])
# tensor(0.9947, device='cuda:0') and tensor(-0.9939, device='cuda:0')
# timestep 0  find different label at step  149 3 the true is  tensor([9])
# tensor(0.7462, device='cuda:0') and tensor(-0.6239, device='cuda:0')
# timestep 4  find different label at step  152 3 the true is  tensor([9])
# tensor(0.9619, device='cuda:0') and tensor(-0.9313, device='cuda:0')
# timestep 3  find different label at step  152 3 the true is  tensor([9])
# tensor(0.9919, device='cuda:0') and tensor(-0.9946, device='cuda:0')
# timestep 2  find different label at step  152 3 the true is  tensor([9])
# tensor(0.9956, device='cuda:0') and tensor(-0.9899, device='cuda:0')
# timestep 1  find different label at step  152 3 the true is  tensor([9])
# tensor(0.9943, device='cuda:0') and tensor(-0.9942, device='cuda:0')
# timestep 0  find different label at step  152 3 the true is  tensor([9])
# tensor(0.9270, device='cuda:0') and tensor(-0.9738, device='cuda:0')
# tensor(0.9898, device='cuda:0') and tensor(-0.9944, device='cuda:0')
# tensor(0.9968, device='cuda:0') and tensor(-0.9938, device='cuda:0')
# tensor(0.9932, device='cuda:0') and tensor(-0.9940, device='cuda:0')
# tensor(0.9954, device='cuda:0') and tensor(-0.9933, device='cuda:0')
# timestep 4  find different label at step  154 9 the true is  tensor([3])
# timestep 3  find different label at step  154 9 the true is  tensor([3])
# timestep 2  find different label at step  154 9 the true is  tensor([3])
# timestep 1  find different label at step  154 9 the true is  tensor([3])
# timestep 0  find different label at step  154 9 the true is  tensor([3])
# tensor(0.9642, device='cuda:0') and tensor(-0.8770, device='cuda:0')
# tensor(0.9831, device='cuda:0') and tensor(-0.9669, device='cuda:0')
# tensor(0.9946, device='cuda:0') and tensor(-0.9953, device='cuda:0')
# tensor(0.9952, device='cuda:0') and tensor(-0.9906, device='cuda:0')
# tensor(0.9944, device='cuda:0') and tensor(-0.9941, device='cuda:0')
# tensor(0.7548, device='cuda:0') and tensor(-0.9139, device='cuda:0')
# tensor(0.9534, device='cuda:0') and tensor(-0.9783, device='cuda:0')
# tensor(0.9930, device='cuda:0') and tensor(-0.9851, device='cuda:0')
# tensor(0.9892, device='cuda:0') and tensor(-0.9963, device='cuda:0')
# tensor(0.9962, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.8180, device='cuda:0') and tensor(-0.9507, device='cuda:0')
# tensor(0.9699, device='cuda:0') and tensor(-0.9894, device='cuda:0')
# tensor(0.9949, device='cuda:0') and tensor(-0.9883, device='cuda:0')
# tensor(0.9905, device='cuda:0') and tensor(-0.9958, device='cuda:0')
# tensor(0.9960, device='cuda:0') and tensor(-0.9925, device='cuda:0')
# tensor(0.5010, device='cuda:0') and tensor(-0.5139, device='cuda:0')
# tensor(0.8892, device='cuda:0') and tensor(-0.8663, device='cuda:0')
# tensor(0.9880, device='cuda:0') and tensor(-0.9744, device='cuda:0')
# tensor(0.9902, device='cuda:0') and tensor(-0.9958, device='cuda:0')
# tensor(0.9961, device='cuda:0') and tensor(-0.9924, device='cuda:0')
# tensor(0.1371, device='cuda:0') and tensor(-0.1739, device='cuda:0')
# timestep 4  find different label at step  165 3 the true is  tensor([9])
# tensor(0.2733, device='cuda:0') and tensor(-0.2941, device='cuda:0')
# timestep 3  find different label at step  165 3 the true is  tensor([9])
# tensor(0.7242, device='cuda:0') and tensor(-0.6976, device='cuda:0')
# timestep 2  find different label at step  165 3 the true is  tensor([9])
# tensor(0.9134, device='cuda:0') and tensor(-0.9470, device='cuda:0')
# timestep 1  find different label at step  165 3 the true is  tensor([9])
# tensor(0.9955, device='cuda:0') and tensor(-0.9765, device='cuda:0')
# timestep 0  find different label at step  165 3 the true is  tensor([9])
# tensor(0.8053, device='cuda:0') and tensor(-0.9424, device='cuda:0')
# tensor(0.9717, device='cuda:0') and tensor(-0.9906, device='cuda:0')
# tensor(0.9951, device='cuda:0') and tensor(-0.9888, device='cuda:0')
# tensor(0.9908, device='cuda:0') and tensor(-0.9957, device='cuda:0')
# tensor(0.9960, device='cuda:0') and tensor(-0.9925, device='cuda:0')
# tensor(0.8864, device='cuda:0') and tensor(-0.9819, device='cuda:0')
# tensor(0.9841, device='cuda:0') and tensor(-0.9959, device='cuda:0')
# tensor(0.9964, device='cuda:0') and tensor(-0.9917, device='cuda:0')
# tensor(0.9920, device='cuda:0') and tensor(-0.9949, device='cuda:0')
# tensor(0.9957, device='cuda:0') and tensor(-0.9929, device='cuda:0')
# timestep 4  find different label at step  169 9 the true is  tensor([3])
# timestep 3  find different label at step  169 9 the true is  tensor([3])
# timestep 2  find different label at step  169 9 the true is  tensor([3])
# timestep 1  find different label at step  169 9 the true is  tensor([3])
# timestep 0  find different label at step  169 9 the true is  tensor([3])
# tensor(0.4229, device='cuda:0') and tensor(-0.5466, device='cuda:0')
# tensor(0.7217, device='cuda:0') and tensor(-0.7045, device='cuda:0')
# tensor(0.9708, device='cuda:0') and tensor(-0.9591, device='cuda:0')
# tensor(0.9806, device='cuda:0') and tensor(-0.9950, device='cuda:0')
# tensor(0.9970, device='cuda:0') and tensor(-0.9901, device='cuda:0')
# tensor(0.7909, device='cuda:0') and tensor(-0.9178, device='cuda:0')
# tensor(0.9467, device='cuda:0') and tensor(-0.9725, device='cuda:0')
# tensor(0.9926, device='cuda:0') and tensor(-0.9846, device='cuda:0')
# tensor(0.9891, device='cuda:0') and tensor(-0.9963, device='cuda:0')
# tensor(0.9963, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# timestep 4  find different label at step  174 9 the true is  tensor([3])
# timestep 3  find different label at step  174 9 the true is  tensor([3])
# timestep 2  find different label at step  174 9 the true is  tensor([3])
# timestep 1  find different label at step  174 9 the true is  tensor([3])
# timestep 0  find different label at step  174 9 the true is  tensor([3])
# tensor(0.6009, device='cuda:0') and tensor(-0.4273, device='cuda:0')
# tensor(0.7413, device='cuda:0') and tensor(-0.7124, device='cuda:0')
# tensor(0.9033, device='cuda:0') and tensor(-0.9129, device='cuda:0')
# tensor(0.9929, device='cuda:0') and tensor(-0.9681, device='cuda:0')
# tensor(0.9897, device='cuda:0') and tensor(-0.9955, device='cuda:0')
# tensor(0.7063, device='cuda:0') and tensor(-0.8769, device='cuda:0')
# timestep 4  find different label at step  178 3 the true is  tensor([9])
# tensor(0.9420, device='cuda:0') and tensor(-0.9695, device='cuda:0')
# timestep 3  find different label at step  178 3 the true is  tensor([9])
# tensor(0.9918, device='cuda:0') and tensor(-0.9830, device='cuda:0')
# timestep 2  find different label at step  178 3 the true is  tensor([9])
# tensor(0.9883, device='cuda:0') and tensor(-0.9965, device='cuda:0')
# timestep 1  find different label at step  178 3 the true is  tensor([9])
# tensor(0.9964, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# timestep 0  find different label at step  178 3 the true is  tensor([9])
# tensor(0.8028, device='cuda:0') and tensor(-0.9461, device='cuda:0')
# tensor(0.9706, device='cuda:0') and tensor(-0.9895, device='cuda:0')
# tensor(0.9949, device='cuda:0') and tensor(-0.9884, device='cuda:0')
# tensor(0.9906, device='cuda:0') and tensor(-0.9957, device='cuda:0')
# tensor(0.9960, device='cuda:0') and tensor(-0.9925, device='cuda:0')
# tensor(0.8262, device='cuda:0') and tensor(-0.9607, device='cuda:0')
# tensor(0.9686, device='cuda:0') and tensor(-0.9864, device='cuda:0')
# tensor(0.9945, device='cuda:0') and tensor(-0.9876, device='cuda:0')
# tensor(0.9903, device='cuda:0') and tensor(-0.9959, device='cuda:0')
# tensor(0.9961, device='cuda:0') and tensor(-0.9924, device='cuda:0')
# tensor(0.2358, device='cuda:0') and tensor(0.0436, device='cuda:0')
# timestep 3  find different label at step  182 9 the true is  tensor([3])
# timestep 2  find different label at step  182 9 the true is  tensor([3])
# timestep 1  find different label at step  182 9 the true is  tensor([3])
# timestep 0  find different label at step  182 9 the true is  tensor([3])
# timestep 4  find different label at step  185 9 the true is  tensor([3])
# timestep 3  find different label at step  185 9 the true is  tensor([3])
# timestep 2  find different label at step  185 9 the true is  tensor([3])
# timestep 1  find different label at step  185 9 the true is  tensor([3])
# timestep 0  find different label at step  185 9 the true is  tensor([3])
# tensor(0.8519, device='cuda:0') and tensor(-0.9642, device='cuda:0')
# tensor(0.9781, device='cuda:0') and tensor(-0.9939, device='cuda:0')
# tensor(0.9959, device='cuda:0') and tensor(-0.9903, device='cuda:0')
# tensor(0.9914, device='cuda:0') and tensor(-0.9953, device='cuda:0')
# tensor(0.9958, device='cuda:0') and tensor(-0.9927, device='cuda:0')
# timestep 4  find different label at step  188 9 the true is  tensor([3])
# timestep 3  find different label at step  188 9 the true is  tensor([3])
# timestep 2  find different label at step  188 9 the true is  tensor([3])
# timestep 1  find different label at step  188 9 the true is  tensor([3])
# timestep 0  find different label at step  188 9 the true is  tensor([3])
# tensor(0.7907, device='cuda:0') and tensor(-0.9372, device='cuda:0')
# tensor(0.9680, device='cuda:0') and tensor(-0.9880, device='cuda:0')
# tensor(0.9946, device='cuda:0') and tensor(-0.9879, device='cuda:0')
# tensor(0.9904, device='cuda:0') and tensor(-0.9958, device='cuda:0')
# tensor(0.9960, device='cuda:0') and tensor(-0.9924, device='cuda:0')
# tensor(0.7170, device='cuda:0') and tensor(-0.8804, device='cuda:0')
# tensor(0.9523, device='cuda:0') and tensor(-0.9772, device='cuda:0')
# tensor(0.9930, device='cuda:0') and tensor(-0.9849, device='cuda:0')
# tensor(0.9891, device='cuda:0') and tensor(-0.9963, device='cuda:0')
# tensor(0.9962, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.7252, device='cuda:0') and tensor(-0.5458, device='cuda:0')
# tensor(0.9417, device='cuda:0') and tensor(-0.9026, device='cuda:0')
# tensor(0.9685, device='cuda:0') and tensor(-0.9766, device='cuda:0')
# tensor(0.9960, device='cuda:0') and tensor(-0.9813, device='cuda:0')
# tensor(0.9921, device='cuda:0') and tensor(-0.9952, device='cuda:0')
# tensor(0.8921, device='cuda:0') and tensor(-0.9806, device='cuda:0')
# tensor(0.9871, device='cuda:0') and tensor(-0.9939, device='cuda:0')
# tensor(0.9965, device='cuda:0') and tensor(-0.9927, device='cuda:0')
# tensor(0.9926, device='cuda:0') and tensor(-0.9945, device='cuda:0')
# tensor(0.9956, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# timestep 4  find different label at step  198 9 the true is  tensor([3])
# timestep 3  find different label at step  198 9 the true is  tensor([3])
# timestep 2  find different label at step  198 9 the true is  tensor([3])
# timestep 1  find different label at step  198 9 the true is  tensor([3])
# timestep 0  find different label at step  198 9 the true is  tensor([3])
# timestep 4  find different label at step  199 9 the true is  tensor([3])
# timestep 3  find different label at step  199 9 the true is  tensor([3])
# timestep 2  find different label at step  199 9 the true is  tensor([3])
# timestep 1  find different label at step  199 9 the true is  tensor([3])
# timestep 0  find different label at step  199 9 the true is  tensor([3])
# tensor(0.9668, device='cuda:0') and tensor(-0.9457, device='cuda:0')
# tensor(0.9888, device='cuda:0') and tensor(-0.9817, device='cuda:0')
# tensor(0.9963, device='cuda:0') and tensor(-0.9953, device='cuda:0')
# tensor(0.9944, device='cuda:0') and tensor(-0.9923, device='cuda:0')
# tensor(0.9949, device='cuda:0') and tensor(-0.9938, device='cuda:0')
# tensor(0.7704, device='cuda:0') and tensor(-0.9245, device='cuda:0')
# tensor(0.9505, device='cuda:0') and tensor(-0.9740, device='cuda:0')
# tensor(0.9925, device='cuda:0') and tensor(-0.9842, device='cuda:0')
# tensor(0.9888, device='cuda:0') and tensor(-0.9964, device='cuda:0')
# tensor(0.9963, device='cuda:0') and tensor(-0.9920, device='cuda:0')
# timestep 4  find different label at step  203 9 the true is  tensor([3])
# timestep 3  find different label at step  203 9 the true is  tensor([3])
# timestep 2  find different label at step  203 9 the true is  tensor([3])
# timestep 1  find different label at step  203 9 the true is  tensor([3])
# timestep 0  find different label at step  203 9 the true is  tensor([3])
# tensor(0.5063, device='cuda:0') and tensor(-0.6325, device='cuda:0')
# tensor(0.8225, device='cuda:0') and tensor(-0.8512, device='cuda:0')
# tensor(0.9803, device='cuda:0') and tensor(-0.9667, device='cuda:0')
# tensor(0.9818, device='cuda:0') and tensor(-0.9967, device='cuda:0')
# tensor(0.9970, device='cuda:0') and tensor(-0.9903, device='cuda:0')
# tensor(0.6748, device='cuda:0') and tensor(-0.8503, device='cuda:0')
# tensor(0.9399, device='cuda:0') and tensor(-0.9661, device='cuda:0')
# tensor(0.9915, device='cuda:0') and tensor(-0.9828, device='cuda:0')
# tensor(0.9884, device='cuda:0') and tensor(-0.9965, device='cuda:0')
# tensor(0.9964, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# timestep 4  find different label at step  208 9 the true is  tensor([3])
# timestep 3  find different label at step  208 9 the true is  tensor([3])
# timestep 2  find different label at step  208 9 the true is  tensor([3])
# timestep 1  find different label at step  208 9 the true is  tensor([3])
# timestep 0  find different label at step  208 9 the true is  tensor([3])
# tensor(0.8698, device='cuda:0') and tensor(-0.8957, device='cuda:0')
# tensor(0.9837, device='cuda:0') and tensor(-0.9893, device='cuda:0')
# tensor(0.9967, device='cuda:0') and tensor(-0.9928, device='cuda:0')
# tensor(0.9927, device='cuda:0') and tensor(-0.9941, device='cuda:0')
# tensor(0.9955, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.6538, device='cuda:0') and tensor(-0.8415, device='cuda:0')
# tensor(0.9073, device='cuda:0') and tensor(-0.9316, device='cuda:0')
# tensor(0.9877, device='cuda:0') and tensor(-0.9773, device='cuda:0')
# tensor(0.9861, device='cuda:0') and tensor(-0.9968, device='cuda:0')
# tensor(0.9966, device='cuda:0') and tensor(-0.9913, device='cuda:0')
# tensor(0.3863, device='cuda:0') and tensor(-0.5572, device='cuda:0')
# tensor(0.7234, device='cuda:0') and tensor(-0.7209, device='cuda:0')
# tensor(0.9693, device='cuda:0') and tensor(-0.9557, device='cuda:0')
# tensor(0.9787, device='cuda:0') and tensor(-0.9955, device='cuda:0')
# tensor(0.9971, device='cuda:0') and tensor(-0.9896, device='cuda:0')
# tensor(0.7108, device='cuda:0') and tensor(-0.8760, device='cuda:0')
# timestep 4  find different label at step  213 3 the true is  tensor([9])
# tensor(0.9294, device='cuda:0') and tensor(-0.9589, device='cuda:0')
# timestep 3  find different label at step  213 3 the true is  tensor([9])
# tensor(0.9907, device='cuda:0') and tensor(-0.9813, device='cuda:0')
# timestep 2  find different label at step  213 3 the true is  tensor([9])
# tensor(0.9876, device='cuda:0') and tensor(-0.9967, device='cuda:0')
# timestep 1  find different label at step  213 3 the true is  tensor([9])
# tensor(0.9964, device='cuda:0') and tensor(-0.9917, device='cuda:0')
# timestep 0  find different label at step  213 3 the true is  tensor([9])
# tensor(0.9410, device='cuda:0') and tensor(-0.9799, device='cuda:0')
# tensor(0.9923, device='cuda:0') and tensor(-0.9903, device='cuda:0')
# tensor(0.9968, device='cuda:0') and tensor(-0.9949, device='cuda:0')
# tensor(0.9939, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# tensor(0.9951, device='cuda:0') and tensor(-0.9935, device='cuda:0')
# tensor(0.8870, device='cuda:0') and tensor(-0.9566, device='cuda:0')
# tensor(0.9863, device='cuda:0') and tensor(-0.9941, device='cuda:0')
# tensor(0.9968, device='cuda:0') and tensor(-0.9926, device='cuda:0')
# tensor(0.9925, device='cuda:0') and tensor(-0.9945, device='cuda:0')
# tensor(0.9955, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# tensor(0.8331, device='cuda:0') and tensor(-0.9432, device='cuda:0')
# tensor(0.9823, device='cuda:0') and tensor(-0.9909, device='cuda:0')
# tensor(0.9961, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.9923, device='cuda:0') and tensor(-0.9948, device='cuda:0')
# tensor(0.9956, device='cuda:0') and tensor(-0.9930, device='cuda:0')
# ...
# timestep 2  find different label at step  422 3 the true is  tensor([9])
# tensor(0.6906, device='cuda:0') and tensor(-0.6205, device='cuda:0')
# timestep 1  find different label at step  422 3 the true is  tensor([9])
# tensor(0.3498, device='cuda:0') and tensor(-0.4263, device='cuda:0')
# timestep 0  find different label at step  422 3 the true is  tensor([9])
# timestep 4  find different label at step  423 9 the true is  tensor([3])
# timestep 3  find different label at step  423 9 the true is  tensor([3])
# timestep 2  find different label at step  423 9 the true is  tensor([3])
# timestep 1  find different label at step  423 9 the true is  tensor([3])
# timestep 0  find different label at step  423 9 the true is  tensor([3])
# tensor(0.8385, device='cuda:0') and tensor(-0.8096, device='cuda:0')
# tensor(0.9876, device='cuda:0') and tensor(-0.9763, device='cuda:0')
# tensor(0.9955, device='cuda:0') and tensor(-0.9957, device='cuda:0')
# tensor(0.9950, device='cuda:0') and tensor(-0.9914, device='cuda:0')
# tensor(0.9946, device='cuda:0') and tensor(-0.9940, device='cuda:0')
# timestep 4  find different label at step  427 9 the true is  tensor([3])
# timestep 3  find different label at step  427 9 the true is  tensor([3])
# timestep 2  find different label at step  427 9 the true is  tensor([3])
# timestep 1  find different label at step  427 9 the true is  tensor([3])
# timestep 0  find different label at step  427 9 the true is  tensor([3])
# timestep 4  find different label at step  428 9 the true is  tensor([3])
# timestep 3  find different label at step  428 9 the true is  tensor([3])
# timestep 2  find different label at step  428 9 the true is  tensor([3])
# timestep 1  find different label at step  428 9 the true is  tensor([3])
# timestep 0  find different label at step  428 9 the true is  tensor([3])
# tensor(0.8389, device='cuda:0') and tensor(-0.9660, device='cuda:0')
# tensor(0.9774, device='cuda:0') and tensor(-0.9929, device='cuda:0')
# tensor(0.9957, device='cuda:0') and tensor(-0.9900, device='cuda:0')
# tensor(0.9913, device='cuda:0') and tensor(-0.9954, device='cuda:0')
# tensor(0.9959, device='cuda:0') and tensor(-0.9927, device='cuda:0')
# tensor(0.9035, device='cuda:0') and tensor(-0.9892, device='cuda:0')
# tensor(0.9876, device='cuda:0') and tensor(-0.9961, device='cuda:0')
# tensor(0.9967, device='cuda:0') and tensor(-0.9926, device='cuda:0')
# tensor(0.9925, device='cuda:0') and tensor(-0.9945, device='cuda:0')
# tensor(0.9956, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# tensor(0.7374, device='cuda:0') and tensor(-0.4901, device='cuda:0')
# tensor(0.9196, device='cuda:0') and tensor(-0.8805, device='cuda:0')
# tensor(0.9368, device='cuda:0') and tensor(-0.9472, device='cuda:0')
# tensor(0.9946, device='cuda:0') and tensor(-0.9750, device='cuda:0')
# tensor(0.9909, device='cuda:0') and tensor(-0.9954, device='cuda:0')
# tensor(0.8590, device='cuda:0') and tensor(-0.6824, device='cuda:0')
# tensor(0.9611, device='cuda:0') and tensor(-0.9301, device='cuda:0')
# tensor(0.9854, device='cuda:0') and tensor(-0.9904, device='cuda:0')
# tensor(0.9961, device='cuda:0') and tensor(-0.9858, device='cuda:0')
# tensor(0.9932, device='cuda:0') and tensor(-0.9948, device='cuda:0')
# timestep 4  find different label at step  447 9 the true is  tensor([3])
# tensor(0.0758, device='cuda:0') and tensor(-0.0776, device='cuda:0')
# tensor(0.8669, device='cuda:0') and tensor(-0.8459, device='cuda:0')
# tensor(0.8945, device='cuda:0') and tensor(-0.9469, device='cuda:0')
# tensor(0.9954, device='cuda:0') and tensor(-0.9768, device='cuda:0')
# timestep 4  find different label at step  448 9 the true is  tensor([3])
# timestep 3  find different label at step  448 9 the true is  tensor([3])
# timestep 2  find different label at step  448 9 the true is  tensor([3])
# timestep 1  find different label at step  448 9 the true is  tensor([3])
# timestep 0  find different label at step  448 9 the true is  tensor([3])
# tensor(0.8198, device='cuda:0') and tensor(-0.9465, device='cuda:0')
# tensor(0.9778, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.9958, device='cuda:0') and tensor(-0.9903, device='cuda:0')
# tensor(0.9915, device='cuda:0') and tensor(-0.9953, device='cuda:0')
# tensor(0.9958, device='cuda:0') and tensor(-0.9927, device='cuda:0')
# tensor(0.7013, device='cuda:0') and tensor(-0.4305, device='cuda:0')
# tensor(0.8943, device='cuda:0') and tensor(-0.8539, device='cuda:0')
# tensor(0.8847, device='cuda:0') and tensor(-0.8949, device='cuda:0')
# tensor(0.9901, device='cuda:0') and tensor(-0.9620, device='cuda:0')
# tensor(0.9880, device='cuda:0') and tensor(-0.9954, device='cuda:0')
# tensor(0.9253, device='cuda:0') and tensor(-0.8242, device='cuda:0')
# tensor(0.9753, device='cuda:0') and tensor(-0.9665, device='cuda:0')
# tensor(0.9965, device='cuda:0') and tensor(-0.9937, device='cuda:0')
# tensor(0.9935, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.9952, device='cuda:0') and tensor(-0.9935, device='cuda:0')
# timestep 4  find different label at step  453 9 the true is  tensor([3])
# timestep 3  find different label at step  453 9 the true is  tensor([3])
# timestep 2  find different label at step  453 9 the true is  tensor([3])
# timestep 1  find different label at step  453 9 the true is  tensor([3])
# timestep 0  find different label at step  453 9 the true is  tensor([3])
# tensor(0.3469, device='cuda:0') and tensor(-0.0296, device='cuda:0')
# timestep 4  find different label at step  454 3 the true is  tensor([9])
# tensor(0.8943, device='cuda:0') and tensor(-0.7319, device='cuda:0')
# tensor(0.9687, device='cuda:0') and tensor(-0.9428, device='cuda:0')
# tensor(0.9896, device='cuda:0') and tensor(-0.9929, device='cuda:0')
# tensor(0.9959, device='cuda:0') and tensor(-0.9876, device='cuda:0')
# tensor(0.9936, device='cuda:0') and tensor(-0.9946, device='cuda:0')
# tensor(0.8387, device='cuda:0') and tensor(-0.9585, device='cuda:0')
# tensor(0.9725, device='cuda:0') and tensor(-0.9908, device='cuda:0')
# tensor(0.9954, device='cuda:0') and tensor(-0.9891, device='cuda:0')
# tensor(0.9908, device='cuda:0') and tensor(-0.9956, device='cuda:0')
# tensor(0.9959, device='cuda:0') and tensor(-0.9926, device='cuda:0')
# tensor(0.8417, device='cuda:0') and tensor(-0.9540, device='cuda:0')
# tensor(0.9822, device='cuda:0') and tensor(-0.9906, device='cuda:0')
# tensor(0.9959, device='cuda:0') and tensor(-0.9911, device='cuda:0')
# tensor(0.9919, device='cuda:0') and tensor(-0.9951, device='cuda:0')
# tensor(0.9957, device='cuda:0') and tensor(-0.9928, device='cuda:0')
# tensor(0.3447, device='cuda:0') and tensor(-0.3091, device='cuda:0')
# timestep 3  find different label at step  462 9 the true is  tensor([3])
# timestep 2  find different label at step  462 9 the true is  tensor([3])
# timestep 1  find different label at step  462 9 the true is  tensor([3])
# timestep 0  find different label at step  462 9 the true is  tensor([3])
# tensor(0.7604, device='cuda:0') and tensor(-0.5003, device='cuda:0')
# tensor(0.9199, device='cuda:0') and tensor(-0.8826, device='cuda:0')
# tensor(0.9580, device='cuda:0') and tensor(-0.9665, device='cuda:0')
# tensor(0.9955, device='cuda:0') and tensor(-0.9799, device='cuda:0')
# tensor(0.9919, device='cuda:0') and tensor(-0.9952, device='cuda:0')
# tensor(0.7270, device='cuda:0') and tensor(-0.8812, device='cuda:0')
# tensor(0.9586, device='cuda:0') and tensor(-0.9815, device='cuda:0')
# tensor(0.9937, device='cuda:0') and tensor(-0.9863, device='cuda:0')
# tensor(0.9897, device='cuda:0') and tensor(-0.9961, device='cuda:0')
# tensor(0.9962, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# timestep 4  find different label at step  465 9 the true is  tensor([3])
# timestep 3  find different label at step  465 9 the true is  tensor([3])
# timestep 2  find different label at step  465 9 the true is  tensor([3])
# timestep 1  find different label at step  465 9 the true is  tensor([3])
# timestep 0  find different label at step  465 9 the true is  tensor([3])
# tensor(0.8252, device='cuda:0') and tensor(-0.5927, device='cuda:0')
# tensor(0.9473, device='cuda:0') and tensor(-0.9150, device='cuda:0')
# tensor(0.9811, device='cuda:0') and tensor(-0.9868, device='cuda:0')
# tensor(0.9961, device='cuda:0') and tensor(-0.9842, device='cuda:0')
# tensor(0.9928, device='cuda:0') and tensor(-0.9950, device='cuda:0')
# tensor(0.8437, device='cuda:0') and tensor(-0.9541, device='cuda:0')
# tensor(0.9835, device='cuda:0') and tensor(-0.9948, device='cuda:0')
# tensor(0.9963, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.9922, device='cuda:0') and tensor(-0.9948, device='cuda:0')
# tensor(0.9957, device='cuda:0') and tensor(-0.9930, device='cuda:0')
# tensor(0.1065, device='cuda:0') and tensor(-0.1132, device='cuda:0')
# timestep 3  find different label at step  469 3 the true is  tensor([9])
# tensor(0.8833, device='cuda:0') and tensor(-0.8612, device='cuda:0')
# timestep 2  find different label at step  469 3 the true is  tensor([9])
# tensor(0.9220, device='cuda:0') and tensor(-0.9653, device='cuda:0')
# timestep 1  find different label at step  469 3 the true is  tensor([9])
# tensor(0.9963, device='cuda:0') and tensor(-0.9801, device='cuda:0')
# timestep 0  find different label at step  469 3 the true is  tensor([9])
# timestep 4  find different label at step  470 9 the true is  tensor([3])
# timestep 3  find different label at step  470 9 the true is  tensor([3])
# timestep 2  find different label at step  470 9 the true is  tensor([3])
# timestep 1  find different label at step  470 9 the true is  tensor([3])
# timestep 0  find different label at step  470 9 the true is  tensor([3])
# tensor(0.7596, device='cuda:0') and tensor(-0.6042, device='cuda:0')
# tensor(0.9476, device='cuda:0') and tensor(-0.9355, device='cuda:0')
# tensor(0.9939, device='cuda:0') and tensor(-0.9895, device='cuda:0')
# tensor(0.9934, device='cuda:0') and tensor(-0.9923, device='cuda:0')
# tensor(0.9950, device='cuda:0') and tensor(-0.9936, device='cuda:0')
# timestep 4  find different label at step  477 9 the true is  tensor([3])
# timestep 3  find different label at step  477 9 the true is  tensor([3])
# timestep 2  find different label at step  477 9 the true is  tensor([3])
# timestep 1  find different label at step  477 9 the true is  tensor([3])
# timestep 0  find different label at step  477 9 the true is  tensor([3])
# tensor(0.8783, device='cuda:0') and tensor(-0.9794, device='cuda:0')
# tensor(0.9845, device='cuda:0') and tensor(-0.9959, device='cuda:0')
# tensor(0.9965, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.9922, device='cuda:0') and tensor(-0.9948, device='cuda:0')
# tensor(0.9957, device='cuda:0') and tensor(-0.9930, device='cuda:0')
# timestep 4  find different label at step  481 9 the true is  tensor([3])
# timestep 3  find different label at step  481 9 the true is  tensor([3])
# timestep 2  find different label at step  481 9 the true is  tensor([3])
# timestep 1  find different label at step  481 9 the true is  tensor([3])
# timestep 0  find different label at step  481 9 the true is  tensor([3])
# timestep 4  find different label at step  484 9 the true is  tensor([3])
# timestep 3  find different label at step  484 9 the true is  tensor([3])
# timestep 2  find different label at step  484 9 the true is  tensor([3])
# timestep 1  find different label at step  484 9 the true is  tensor([3])
# timestep 0  find different label at step  484 9 the true is  tensor([3])
# timestep 4  find different label at step  487 9 the true is  tensor([3])
# timestep 3  find different label at step  487 9 the true is  tensor([3])
# timestep 2  find different label at step  487 9 the true is  tensor([3])
# timestep 1  find different label at step  487 9 the true is  tensor([3])
# timestep 0  find different label at step  487 9 the true is  tensor([3])
# tensor(0.8058, device='cuda:0') and tensor(-0.7008, device='cuda:0')
# tensor(0.9690, device='cuda:0') and tensor(-0.9386, device='cuda:0')
# tensor(0.9947, device='cuda:0') and tensor(-0.9954, device='cuda:0')
# tensor(0.9950, device='cuda:0') and tensor(-0.9915, device='cuda:0')
# tensor(0.9947, device='cuda:0') and tensor(-0.9939, device='cuda:0')
# timestep 4  find different label at step  490 9 the true is  tensor([3])
# timestep 3  find different label at step  490 9 the true is  tensor([3])
# timestep 2  find different label at step  490 9 the true is  tensor([3])
# timestep 1  find different label at step  490 9 the true is  tensor([3])
# timestep 0  find different label at step  490 9 the true is  tensor([3])
# timestep 4  find different label at step  491 9 the true is  tensor([3])
# timestep 3  find different label at step  491 9 the true is  tensor([3])
# timestep 2  find different label at step  491 9 the true is  tensor([3])
# timestep 1  find different label at step  491 9 the true is  tensor([3])
# timestep 0  find different label at step  491 9 the true is  tensor([3])
# timestep 4  find different label at step  492 9 the true is  tensor([3])
# timestep 3  find different label at step  492 9 the true is  tensor([3])
# timestep 2  find different label at step  492 9 the true is  tensor([3])
# timestep 1  find different label at step  492 9 the true is  tensor([3])
# timestep 0  find different label at step  492 9 the true is  tensor([3])
# tensor(0.9619, device='cuda:0') and tensor(-0.9503, device='cuda:0')
# tensor(0.9908, device='cuda:0') and tensor(-0.9838, device='cuda:0')
# tensor(0.9962, device='cuda:0') and tensor(-0.9955, device='cuda:0')
# tensor(0.9945, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.9948, device='cuda:0') and tensor(-0.9938, device='cuda:0')
# timestep 4  find different label at step  496 9 the true is  tensor([3])
# timestep 3  find different label at step  496 9 the true is  tensor([3])
# timestep 2  find different label at step  496 9 the true is  tensor([3])
# timestep 1  find different label at step  496 9 the true is  tensor([3])
# timestep 0  find different label at step  496 9 the true is  tensor([3])
# timestep 4  find different label at step  497 9 the true is  tensor([3])
# timestep 3  find different label at step  497 9 the true is  tensor([3])
# timestep 2  find different label at step  497 9 the true is  tensor([3])
# timestep 1  find different label at step  497 9 the true is  tensor([3])
# timestep 0  find different label at step  497 9 the true is  tensor([3])
# tensor(0.3687, device='cuda:0') and tensor(-0.5162, device='cuda:0')
# tensor(0.7416, device='cuda:0') and tensor(-0.7754, device='cuda:0')
# tensor(0.9745, device='cuda:0') and tensor(-0.9604, device='cuda:0')
# tensor(0.9797, device='cuda:0') and tensor(-0.9964, device='cuda:0')
# tensor(0.9971, device='cuda:0') and tensor(-0.9899, device='cuda:0')
# timestep 4  find different label at step  499 9 the true is  tensor([3])
# timestep 3  find different label at step  499 9 the true is  tensor([3])
# timestep 2  find different label at step  499 9 the true is  tensor([3])
# timestep 1  find different label at step  499 9 the true is  tensor([3])
# timestep 0  find different label at step  499 9 the true is  tensor([3])
# tensor(0.7927, device='cuda:0') and tensor(-0.8135, device='cuda:0')
# tensor(0.9502, device='cuda:0') and tensor(-0.9691, device='cuda:0')
# tensor(0.9932, device='cuda:0') and tensor(-0.9849, device='cuda:0')
# tensor(0.9890, device='cuda:0') and tensor(-0.9961, device='cuda:0')
# tensor(0.9962, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.9152, device='cuda:0') and tensor(-0.7862, device='cuda:0')
# tensor(0.9767, device='cuda:0') and tensor(-0.9541, device='cuda:0')
# tensor(0.9919, device='cuda:0') and tensor(-0.9944, device='cuda:0')
# tensor(0.9958, device='cuda:0') and tensor(-0.9888, device='cuda:0')
# tensor(0.9940, device='cuda:0') and tensor(-0.9944, device='cuda:0')
# tensor(0.4652, device='cuda:0') and tensor(-0.1501, device='cuda:0')
# timestep 3  find different label at step  510 9 the true is  tensor([3])
# timestep 2  find different label at step  510 9 the true is  tensor([3])
# timestep 1  find different label at step  510 9 the true is  tensor([3])
# timestep 0  find different label at step  510 9 the true is  tensor([3])

# %%
(acc/len(train_dataset))
# Out:
# tensor([0.7676, 0.7676, 0.7656, 0.7656, 0.7812])

# %%
# test dataset
test_dataset = datasets.CIFAR10('./data', train=False, download=True, transform=transform)
#test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

mnist3_indices_test = [i for i in range(len(test_dataset)) if test_dataset[i][1] == 3]
mnist2_indices_test = [i for i in range(len(test_dataset)) if test_dataset[i][1] == 9]

mnist_dataset_test3 = BinaryDataset(test_dataset, mnist3_indices_test,label=3 )
mnist_dataset_test2 = BinaryDataset(test_dataset, mnist2_indices_test,label=9 )

test_dataset = torch.utils.data.ConcatDataset([mnist_dataset_test3, mnist_dataset_test2])
print(len(mnist3_indices_test)/len(test_dataset))
print(len(mnist2_indices_test)/len(test_dataset))
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 49143730.29it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# 0.5
# 0.5

# %%
# test on testset
test_acc=0
model.eval()
with torch.no_grad():
  for step, (image, label) in enumerate(test_loader):
    batch_size = image.shape[0]
    image = image.to(device)
    x0=image
    for t in range(timesteps-1,early_stop_time-1,-1):

      model.load_state_dict(model_parameters[t],strict=True)
      time=torch.full((batch_size,),t, device=device)
      predicted_noiset = model(x0, time)
      x=gaussian_diffusion.predict_t_1_from_t(x0,predicted_noiset,t)
      #x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset1_1,labels_1)])
      x0=x

    a=torch.norm(x0[0,:,:,:]-x_1[early_stop_time].mean(0)[:,:,:].to(device)).to(device)# distance between 3 and pred
    b=torch.norm(x0[0,:,:,:]-x_2[early_stop_time].mean(0)[:,:,:].to(device)).to(device)# distance between 2 and pred
    if a >= b:
      pred_label= 9
      #print(a,"and",b)
    else:
      pred_label= 3
      #print(a,"and",b)
    print(pred_label,label)
    if pred_label==label:
      test_acc=test_acc+1
      #print("exact!", pred_label,"the true is ",label)
    else:
      print("find different label at step ", step, pred_label,"the true is ",label)

print(test_acc/len(test_dataset))
# Out:
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  2 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  8 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  9 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  10 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  16 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  23 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  27 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  33 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  34 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  44 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  45 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  55 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  60 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  66 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  70 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  72 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  80 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  82 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  83 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  91 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  102 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  104 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  105 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  116 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  119 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  120 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  123 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  126 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  131 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  133 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  135 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  136 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  141 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  145 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  146 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  148 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  155 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  160 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  165 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  167 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  171 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  172 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  176 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  177 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  183 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  184 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  188 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  191 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  194 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  199 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  205 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  207 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  220 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  222 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  233 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  239 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  243 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  244 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  246 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  249 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  254 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  256 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  260 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  261 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  268 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  272 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  279 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  293 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  302 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  320 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  324 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  326 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  329 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  332 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  333 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  334 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  335 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  343 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  348 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  351 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  352 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  359 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  365 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  369 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  377 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  381 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  383 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  385 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  390 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  391 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  392 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  394 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  398 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  399 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  400 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  406 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  412 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  413 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  418 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  423 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  425 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  426 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  443 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  448 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  452 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  459 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  463 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  464 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  467 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  468 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  476 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  480 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  481 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  482 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  483 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  489 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  493 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  494 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  504 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  505 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  507 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  509 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  510 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  512 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  527 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  541 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  556 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  560 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  571 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  574 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  576 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  581 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  584 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  587 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  592 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  602 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  604 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  606 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  615 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  617 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  623 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  624 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  632 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  635 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  637 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  638 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  639 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  643 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  647 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  651 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  654 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  656 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  660 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  663 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  665 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  667 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  675 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  677 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  682 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  683 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  687 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  688 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  690 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  693 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  694 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  696 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  697 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  702 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  709 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  711 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  713 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  714 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  715 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  718 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  726 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  730 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  731 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  735 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  744 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  747 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  753 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  755 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  758 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  761 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  763 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  765 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  767 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  769 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  770 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  771 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  773 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  776 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  778 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  779 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  789 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  794 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  795 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  796 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  797 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  807 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  808 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  817 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  830 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  840 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  841 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  843 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  848 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  850 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  851 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  852 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  858 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  871 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  872 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  876 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  877 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  878 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  888 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  889 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  890 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  892 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  893 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  895 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  898 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  901 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  904 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  907 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  910 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  921 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  923 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  924 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  930 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  935 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  945 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  953 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  955 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  959 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  963 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  964 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  965 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  967 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  976 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  978 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  982 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  983 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  985 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  989 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  994 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1001 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1002 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1014 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1015 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1016 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1019 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1025 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1030 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1034 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1037 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1039 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1041 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1044 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1045 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1046 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1054 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1057 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1062 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1071 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1076 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1082 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1084 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1085 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1093 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1096 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1097 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1098 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1101 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1102 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1103 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1105 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1107 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1108 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1109 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1112 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1113 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1114 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1118 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1120 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1131 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1144 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1146 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1148 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1149 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1157 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1160 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1163 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1165 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1169 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1173 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1186 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1189 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1190 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1191 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1193 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1195 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1197 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1198 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1201 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1203 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1205 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1208 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1217 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1219 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1220 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1226 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1238 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1240 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1249 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1252 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1258 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1259 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1263 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1266 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1267 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1270 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1273 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1277 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1279 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1281 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1282 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1286 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1293 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1302 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1303 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1304 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1306 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1307 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1313 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1318 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1322 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1323 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1324 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1325 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1326 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1329 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1336 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1338 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1350 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1351 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1358 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1361 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1363 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1369 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1370 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1371 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1373 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1381 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1388 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1390 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1395 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1396 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1405 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1407 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1423 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1430 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1439 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1441 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1445 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1448 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1450 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1454 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1459 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1461 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1462 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1465 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1474 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1489 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1491 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1492 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1500 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1502 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1503 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1526 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1528 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1531 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1534 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1536 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1538 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1540 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1549 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1553 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1554 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1556 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1558 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1572 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1573 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1575 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1577 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1591 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1593 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1594 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1603 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1604 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1607 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1608 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1609 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1611 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1614 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1619 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1622 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1626 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1631 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1632 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1633 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1634 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1640 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1647 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1648 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1649 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1650 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1659 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1660 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1661 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1671 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1672 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1673 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1674 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1679 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1684 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1685 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1686 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1688 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1691 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1693 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1697 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1698 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1699 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1701 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1709 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1715 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1721 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1730 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1736 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1740 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1744 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1745 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1752 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1763 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1773 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1774 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1777 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1778 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1784 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1787 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1789 9 the true is  tensor([3])
# 3 tensor([9])
# find different label at step  1790 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1796 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1799 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1803 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1804 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1805 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1809 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1810 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1812 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1814 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1819 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1825 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1839 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1843 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1844 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1847 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1858 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1861 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1862 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1867 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1879 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1883 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1885 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1888 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1889 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1893 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1894 9 the true is  tensor([3])
# 9 tensor([3])
# find different label at step  1895 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1900 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1903 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1905 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1920 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1921 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1923 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1924 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1926 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1932 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# find different label at step  1934 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1938 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1939 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1941 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1947 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1949 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1954 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1955 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1956 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1965 3 the true is  tensor([9])
# 3 tensor([9])
# find different label at step  1966 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# find different label at step  1969 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1973 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1975 3 the true is  tensor([9])
# 9 tensor([3])
# find different label at step  1976 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1979 3 the true is  tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# find different label at step  1994 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# find different label at step  1999 9 the true is  tensor([3])
# 0.746

# %%
from sklearn import preprocessing
from sklearn.manifold import TSNE
import torch
import torchvision
import matplotlib.pyplot as plt
def plot(x_t_train_dataset_t,labels_1):
  tsne = TSNE(n_components=2, verbose=1 ,random_state=42)
  x_t_train_dataset_t = x_t_train_dataset_t.view(len(x_t_train_dataset_t), -1)
  result = tsne.fit_transform(x_t_train_dataset_t)
  scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))
  result = scaler.fit_transform(result)
  fig = plt.figure(figsize=(5, 5))
  ax = fig.add_subplot()
  ax.set_title('t-SNE process')
  ax.scatter(result[:,0], result[:,1],c=labels_1, s=20)

# %%
# This is the visilization of  original images.
t=5
b=256
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
#train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=b, shuffle=False,num_workers=4,pin_memory=True)

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=b, shuffle=False)
  for step, (images1, labels) in enumerate(train_loader11):

    images1=images1.to(device)
    batch_size=images1.shape[0]
    print(step)
    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep0.png')
# Out:
# 0
# 1
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.001s...
# [t-SNE] Computed neighbors for 512 samples in 0.046s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 9.282622
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.196053
# [t-SNE] KL divergence after 1000 iterations: 1.203893

# %%
# This is the first layer.
# for t =4
t=4
b=256

model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
#train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=b, shuffle=True,num_workers=4,pin_memory=True)

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    images1 = transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))
    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep1.png')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.002s...
# [t-SNE] Computed neighbors for 512 samples in 0.044s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 3.127504
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.762619
# [t-SNE] KL divergence after 1000 iterations: 0.462890

# %%
# This is the second layer.
t=3
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)
batch_size=b*2
x_t_train_dataset_t=torch.zeros([b*2,3,32,32])

train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False)
labels_1=torch.zeros([b*2])
model.eval()
with torch.no_grad():
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)

    images1 = transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep2.png')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.002s...
# [t-SNE] Computed neighbors for 512 samples in 0.042s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 0.966862
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.274765
# [t-SNE] KL divergence after 1000 iterations: 0.297726

# %%
# This is the third layer.
t=2
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    images1=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep3.png')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.001s...
# [t-SNE] Computed neighbors for 512 samples in 0.041s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 0.382655
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.520050
# [t-SNE] KL divergence after 1000 iterations: 0.238223

# %%
# This is the fourth layer.
t=1

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False,num_workers=2,pin_memory=True)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    images1=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep4.png')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.001s...
# [t-SNE] Computed neighbors for 512 samples in 0.168s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 0.130216
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 47.267094
# [t-SNE] KL divergence after 1000 iterations: 0.187924

# %%
# This is the 5th layer.
t=0

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False,num_workers=2,pin_memory=True)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    images1=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep5.png')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.001s...
# [t-SNE] Computed neighbors for 512 samples in 0.175s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 0.056408
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 46.399590
# [t-SNE] KL divergence after 1000 iterations: 0.170648
