# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyuezhao1/ddpm/blob/main/DDPMfinal1_forcir10new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 模型

# %%
# no problem
import os
import math
from abc import abstractmethod

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm

# %%
# 无需更改

def timestep_embedding(timesteps, dim, max_period=10000):
    """Create sinusoidal timestep embeddings.

    Args:
        timesteps (Tensor): a 1-D Tensor of N indices, one per batch element. These may be fractional.
        dim (int): the dimension of the output.
        max_period (int, optional): controls the minimum frequency of the embeddings. Defaults to 10000.

    Returns:
        Tensor: an [N x dim] Tensor of positional embeddings.
    """
    half = dim // 2
    freqs = torch.exp(
        -math.log(max_period) * torch.arange(start=0, end=half, dtype=torch.float32) / half
    ).to(device=timesteps.device)
    args = timesteps[:, None].float() * freqs[None]
    embedding = torch.cat([torch.cos(args), torch.sin(args)], dim=-1)
    if dim % 2:
        embedding = torch.cat([embedding, torch.zeros_like(embedding[:, :1])], dim=-1)
    return embedding

class TimestepBlock(nn.Module):
    """
    Any module where forward() takes timestep embeddings as a second argument.
    """

    @abstractmethod
    def forward(self, x, t):
        """
        Apply the module to `x` given `t` timestep embeddings.
        """
        pass

class TimestepEmbedSequential(nn.Sequential, TimestepBlock):
    """
    A sequential module that passes timestep embeddings to the children that support it as an extra input.
    """

    def forward(self, x, t):
        for layer in self:
            if isinstance(layer, TimestepBlock):
                x = layer(x, t)
            else:
                x = layer(x)
        return x

def norm_layer(channels):
    return nn.GroupNorm(32, channels)

class ResidualBlock(TimestepBlock):
    def __init__(self, in_channels, out_channels, time_channels, dropout):
        super().__init__()
        self.conv1 = nn.Sequential(
            norm_layer(in_channels),
            nn.SiLU(),
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        )

        # pojection for time step embedding
        self.time_emb = nn.Sequential(
            nn.SiLU(),
            nn.Linear(time_channels, out_channels)
        )

        self.conv2 = nn.Sequential(
            norm_layer(out_channels),
            nn.SiLU(),
            nn.Dropout(p=dropout),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        )

        if in_channels != out_channels:
            self.shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        else:
            self.shortcut = nn.Identity()


    def forward(self, x, t):
        """
        `x` has shape `[batch_size, in_dim, height, width]`
        `t` has shape `[batch_size, time_dim]`
        """
        h = self.conv1(x)
        # Add time step embeddings
        h += self.time_emb(t)[:, :, None, None]
        h = self.conv2(h)
        return h + self.shortcut(x)


class AttentionBlock(nn.Module):
    def __init__(self, channels, num_heads=1):
        """
        Attention block with shortcut

        Args:
            channels (int): channels
            num_heads (int, optional): attention heads. Defaults to 1.
        """
        super().__init__()
        self.num_heads = num_heads
        assert channels % num_heads == 0

        self.norm = norm_layer(channels)
        self.qkv = nn.Conv2d(channels, channels * 3, kernel_size=1, bias=False)
        self.proj = nn.Conv2d(channels, channels, kernel_size=1)

    def forward(self, x):
        B, C, H, W = x.shape
        qkv = self.qkv(self.norm(x))
        q, k, v = qkv.reshape(B*self.num_heads, -1, H*W).chunk(3, dim=1)
        scale = 1. / math.sqrt(math.sqrt(C // self.num_heads))
        attn = torch.einsum("bct,bcs->bts", q * scale, k * scale)
        attn = attn.softmax(dim=-1)
        h = torch.einsum("bts,bcs->bct", attn, v)
        h = h.reshape(B, -1, H, W)
        h = self.proj(h)
        return h + x


class Upsample(nn.Module):
    def __init__(self, channels, use_conv):
        super().__init__()
        self.use_conv = use_conv
        if use_conv:
            self.conv = nn.Conv2d(channels, channels, kernel_size=3, padding=1)

    def forward(self, x):
        x = F.interpolate(x, scale_factor=2, mode="nearest")
        if self.use_conv:
            x = self.conv(x)
        return x


class Downsample(nn.Module):
    def __init__(self, channels, use_conv):
        super().__init__()
        self.use_conv = use_conv
        if use_conv:
            self.op = nn.Conv2d(channels, channels, kernel_size=3, stride=2, padding=1)
        else:
            self.op = nn.AvgPool2d(stride=2)

    def forward(self, x):
        return self.op(x)


class UNetModel(nn.Module):
    """
    The full UNet model with attention and timestep embedding
    """
    def __init__(
        self,
        in_channels=3,
        model_channels=128,
        out_channels=3,
        num_res_blocks=2,
        attention_resolutions=(8, 16),
        dropout=0,
        channel_mult=(1, 2, 2, 2),
        conv_resample=True,
        num_heads=4
    ):
        super().__init__()

        self.in_channels = in_channels
        self.model_channels = model_channels
        self.out_channels = out_channels
        self.num_res_blocks = num_res_blocks
        self.attention_resolutions = attention_resolutions
        self.dropout = dropout
        self.channel_mult = channel_mult
        self.conv_resample = conv_resample
        self.num_heads = num_heads

        # time embedding
        time_embed_dim = model_channels * 4
        self.time_embed = nn.Sequential(
            nn.Linear(model_channels, time_embed_dim),
            nn.SiLU(),
            nn.Linear(time_embed_dim, time_embed_dim),
        )

        # down blocks
        self.down_blocks = nn.ModuleList([
            TimestepEmbedSequential(nn.Conv2d(in_channels, model_channels, kernel_size=3, padding=1))
        ])
        down_block_chans = [model_channels]
        ch = model_channels
        ds = 1
        for level, mult in enumerate(channel_mult):
            for _ in range(num_res_blocks):
                layers = [
                    ResidualBlock(ch, mult * model_channels, time_embed_dim, dropout)
                ]
                ch = mult * model_channels
                if ds in attention_resolutions:
                    layers.append(AttentionBlock(ch, num_heads=num_heads))
                self.down_blocks.append(TimestepEmbedSequential(*layers))
                down_block_chans.append(ch)
            if level != len(channel_mult) - 1: # don't use downsample for the last stage
                self.down_blocks.append(TimestepEmbedSequential(Downsample(ch, conv_resample)))
                down_block_chans.append(ch)
                ds *= 2

        # middle block
        self.middle_block = TimestepEmbedSequential(
            ResidualBlock(ch, ch, time_embed_dim, dropout),
            AttentionBlock(ch, num_heads=num_heads),
            ResidualBlock(ch, ch, time_embed_dim, dropout)
        )

        # up blocks
        self.up_blocks = nn.ModuleList([])
        for level, mult in list(enumerate(channel_mult))[::-1]:
            for i in range(num_res_blocks + 1):
                layers = [
                    ResidualBlock(
                        ch + down_block_chans.pop(),
                        model_channels * mult,
                        time_embed_dim,
                        dropout
                    )
                ]
                ch = model_channels * mult
                if ds in attention_resolutions:
                    layers.append(AttentionBlock(ch, num_heads=num_heads))
                if level and i == num_res_blocks:
                    layers.append(Upsample(ch, conv_resample))
                    ds //= 2
                self.up_blocks.append(TimestepEmbedSequential(*layers))

        self.out = nn.Sequential(
            norm_layer(ch),
            nn.SiLU(),
            nn.Conv2d(model_channels, out_channels, kernel_size=3, padding=1),
        )

    def forward(self, x, timesteps):
        """Apply the model to an input batch.

        Args:
            x (Tensor): [N x C x H x W]
            timesteps (Tensor): a 1-D batch of timesteps.

        Returns:
            Tensor: [N x C x ...]
        """
        hs = []
        # time step embedding
        emb = self.time_embed(timestep_embedding(timesteps, self.model_channels))

        # down stage
        h = x
        for module in self.down_blocks:
            h = module(h, emb)
            hs.append(h)
        # middle stage
        h = self.middle_block(h, emb)
        # up stage
        for module in self.up_blocks:
            cat_in = torch.cat([h, hs.pop()], dim=1)
            h = module(cat_in, emb)
        return self.out(h)


def linear_beta_schedule(timesteps):
    """
    beta schedule
    """
    scale = 10 / timesteps
    beta_start = scale * 0.01
    beta_end = scale * 0.9
    return torch.linspace(beta_start, beta_end, timesteps, dtype=torch.float64)


def cosine_beta_schedule(timesteps, s=0.008):
    """
    cosine schedule
    as proposed in https://arxiv.org/abs/2102.09672
    """
    steps = timesteps + 1
    x = torch.linspace(0, timesteps, steps, dtype=torch.float64)
    alphas_cumprod = torch.cos(((x / timesteps) + s) / (1 + s) * math.pi * 0.5) ** 2
    alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
    betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
    return torch.clip(betas, 0, 0.999)

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections.abc import Iterable
from itertools import repeat

DEFAULT_DTYPE = torch.float32


def DEFAULT_INITIALIZER(x, scale=1.):
    """
    PyTorch Xavier uniform initialization: w ~ Uniform(-a, a), where a = gain * (6 / (fan_in + fan_out)) ** .5
    TensorFlow Variance-Scaling initialization (mode="fan_avg", distribution="uniform"):
    w ~ Uniform(-a, a), where a = (6 * scale / (fan_in + fan_out)) ** .5
    Therefore, gain = scale ** .5
    """
    return nn.init.xavier_uniform_(x, gain=math.sqrt(scale or 1e-10))


def ntuple(n, name="parse"):
    def parse(x):
        if isinstance(x, Iterable):
            return tuple(x)
        else:
            return tuple(repeat(x, n))
    parse.__name__ = name
    return parse


pair = ntuple(2, "pair")


class Linear(nn.Module):
    def __init__(
            self,
            in_features,
            out_features,
            bias=True,
            init_scale=1.
    ):
        super(Linear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weight = nn.Parameter(torch.empty((out_features, in_features), dtype=DEFAULT_DTYPE))
        if bias:
            self.bias = nn.Parameter(torch.empty((out_features, ), dtype=DEFAULT_DTYPE))
        else:
            self.register_parameter('bias', None)
        self.init_scale = init_scale
        self.reset_parameters()

    def reset_parameters(self):
        DEFAULT_INITIALIZER(self.weight, scale=self.init_scale)
        if self.bias is not None:
            nn.init.zeros_(self.bias)

    def forward(self, input):
        return F.linear(input, self.weight, self.bias)

    def extra_repr(self):
        return 'in_features={}, out_features={}, bias={}'.format(
            self.in_features, self.out_features, self.bias is not None)


class Conv2d(nn.Module):
    def __init__(
            self,
            in_channels,
            out_channels,
            kernel_size,
            stride=1,
            padding=0,
            dilation=1,
            groups=1,
            bias=True,
            padding_mode="zeros",
            init_scale=1.
    ):
        super(Conv2d, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size = pair(kernel_size)
        self.weight = nn.Parameter(
            torch.empty((
                out_channels, in_channels // groups, kernel_size[0], kernel_size[1]
            ), dtype=DEFAULT_DTYPE))
        if bias:
            self.bias = nn.Parameter(torch.empty((out_channels, ), dtype=DEFAULT_DTYPE))
        else:
            self.register_parameter("bias", None)
        self.stride = pair(stride)
        self.padding = padding if isinstance(padding, str) else pair(padding)
        self.dilation = pair(dilation)
        self.groups = groups
        self.padding_mode = padding_mode
        self.init_scale = init_scale
        self.reset_parameter()

    def reset_parameter(self):
        DEFAULT_INITIALIZER(self.weight, scale=self.init_scale)
        if self.bias is not None:
            nn.init.zeros_(self.bias)

    def extra_repr(self):
        s = ('{in_channels}, {out_channels}, kernel_size={kernel_size}'
             ', stride={stride}')
        if self.padding != (0,) * len(self.padding):
            s += ', padding={padding}'
        if self.dilation != (1,) * len(self.dilation):
            s += ', dilation={dilation}'
        if self.groups != 1:
            s += ', groups={groups}'
        if self.bias is None:
            s += ', bias=False'
        if self.padding_mode != 'zeros':
            s += ', padding_mode={padding_mode}'
        return s.format(**self.__dict__)

    def forward(self, x):
        return F.conv2d(
            x, self.weight, self.bias, stride=self.stride, padding=self.padding,
            dilation=self.dilation, groups=self.groups)


class ValidPad2d(nn.Module):
    def __init__(self, kernel_size, stride, mode="constant", value=0.0):
        super(ValidPad2d, self).__init__()
        self.kernel_size = pair(kernel_size)
        self.stride = pair(stride)
        self.mode = mode
        self.value = value

    def forward(self, x):
        _, _, h, w = x.shape
        (k1, k2), (s1, s2) = self.kernel_size, self.stride
        h_pad, w_pad = s1 * math.ceil((h - k1 + 1) / s1 - 1) + k1 - h, \
                       s2 * math.ceil((w - k2 + 1) / s2 - 1) + k2 - w
        top_pad, bottom_pad = (math.floor(h_pad / 2), math.ceil(h_pad / 2)) if h_pad else (0, 0)
        left_pad, right_pad = (math.floor(w_pad / 2), math.ceil(w_pad / 2)) if w_pad else (0, 0)
        x = F.pad(x, pad=(left_pad, right_pad, top_pad, bottom_pad), mode=self.mode, value=self.value)
        return x


class SamePad2d(nn.Module):
    def __init__(self, kernel_size, stride, mode="constant", value=0.0):
        super(SamePad2d, self).__init__()
        self.kernel_size = pair(kernel_size)
        self.stride = pair(stride)
        self.mode = mode
        self.value = value

    def forward(self, x):
        _, _, h, w = x.shape
        (k1, k2), (s1, s2) = self.kernel_size, self.stride
        h_pad, w_pad = s1 * math.ceil(h / s1 - 1) + k1 - h, s2 * math.ceil(w / s2 - 1) + k2 - w
        top_pad, bottom_pad = (math.floor(h_pad / 2), math.ceil(h_pad / 2)) if h_pad else (0, 0)
        left_pad, right_pad = (math.floor(w_pad / 2), math.ceil(w_pad / 2)) if w_pad else (0, 0)
        x = F.pad(x, pad=(left_pad, right_pad, top_pad, bottom_pad), mode=self.mode, value=self.value)
        return x


class Sequential(nn.Sequential):
    def forward(self, input, **kwargs):
        for module in self:
            input = module(input, **kwargs)
        return input

# %%
import math
import numpy as np
import torch
import torch.nn.functional as F
from typing import Union, Tuple

DEFAULT_DTYPE = torch.float32

@torch.jit.script
def get_timestep_embedding(timesteps, embed_dim: int, dtype: torch.dtype = DEFAULT_DTYPE):
    """
    Adapted from fairseq/fairseq/modules/sinusoidal_positional_embedding.py
    The implementation is slightly different from the decription in Section 3.5 of [1]
    [1] Vaswani, Ashish, et al. "Attention is all you need."
     Advances in neural information processing systems 30 (2017).
    """
    half_dim = embed_dim // 2
    embed = math.log(10000) / (half_dim - 1)
    embed = torch.exp(-torch.arange(half_dim, dtype=dtype, device=timesteps.device) * embed)
    embed = torch.outer(timesteps.ravel().to(dtype), embed)
    embed = torch.cat([torch.sin(embed), torch.cos(embed)], dim=1)
    if embed_dim % 2 == 1:
        embed = F.pad(embed, [0, 1])  # padding the last dimension
    assert embed.dtype == dtype
    return embed


@torch.jit.script
def normal_kl(mean1, logvar1, mean2, logvar2):
    diff_logvar = logvar1 - logvar2
    kl = (-1.0 - diff_logvar).add(
        (mean1 - mean2).pow(2) * torch.exp(-logvar2)).add(
        torch.exp(diff_logvar)).mul(0.5)
    return kl


@torch.jit.script
def approx_std_normal_cdf(x):
    """
    Reference:
    Page, E. “Approximations to the Cumulative Normal Function and Its Inverse for Use on a Pocket Calculator.”
     Applied Statistics 26.1 (1977): 75–76. Web.
    """
    return 0.5 * (1. + torch.tanh(math.sqrt(2. / math.pi) * (x + 0.044715 * torch.pow(x, 3))))


@torch.jit.script
def discretized_gaussian_loglik(
        x, means, log_scale, precision: float = 1./255,
        cutoff: Union[float, Tuple[float, float]] = (-0.999, 0.999), tol: float = 1e-12):
    if isinstance(cutoff, float):
        cutoff = (-cutoff, cutoff)
    # Assumes data is integers [0, 255] rescaled to [-1, 1]
    x_centered = x - means
    inv_stdv = torch.exp(-log_scale)
    upper = inv_stdv * (x_centered + precision)
    cdf_upper = torch.where(
        x > cutoff[1], torch.as_tensor(1, dtype=torch.float32, device=x.device), approx_std_normal_cdf(upper))
    lower = inv_stdv * (x_centered - precision)
    cdf_lower = torch.where(
        x < cutoff[0], torch.as_tensor(0, dtype=torch.float32, device=x.device), approx_std_normal_cdf(lower))
    log_probs = torch.log(torch.clamp(cdf_upper - cdf_lower - tol, min=0).add(tol))
    return log_probs


@torch.jit.script
def continuous_gaussian_loglik(x, mean, logvar):
    x_centered = x - mean
    inv_var = torch.exp(-logvar)
    log_probs = x_centered.pow(2) * inv_var + math.log(2 * math.pi) + logvar
    return log_probs.mul(0.5).neg()


def discrete_klv2d(hist1, hist2, eps=1e-9):
    """
    compute the discretized (empirical) Kullback-Leibler divergence between P_data1 and P_data2
    """
    return np.sum(hist2 * (np.log(hist2 + eps) - np.log(hist1 + eps)))


def hist2d(data, bins, value_range=None):
    """
    compute the 2d histogram matrix for a set of data points
    """
    if bins == "auto":
        bins = math.floor(math.sqrt(len(data) // 10))
    if value_range is not None:
        if isinstance(value_range, (int, float)):
            value_range = ((-value_range, value_range), ) * 2
        if hasattr(value_range, "__iter__"):
            if not hasattr(next(iter(value_range)), "__iter__"):
                value_range = (value_range, ) * 2
    x, y = np.split(data, 2, axis=1)
    x, y = x.squeeze(1), y.squeeze(1)
    return np.histogram2d(x, y, bins=bins, range=value_range)[0]


def flat_mean(x, start_dim=1):
    reduce_dim = [i for i in range(start_dim, x.ndim)]
    return torch.mean(x, dim=reduce_dim)


def flat_sum(x, start_dim=1):
    reduce_dim = [i for i in range(start_dim, x.ndim)]
    return torch.sum(x, dim=reduce_dim)

# %%
import math
import torch
import torch.nn as nn


DEFAULT_NONLINEARITY = nn.SiLU()  # f(x)=x*sigmoid(x)


class DEFAULT_NORMALIZER(nn.GroupNorm):
    def __init__(self, num_channels, num_groups=32):
        super().__init__(num_groups=num_groups, num_channels=num_channels, eps=1e-6)  # PyTorch default eps is 1e-5


class AttentionBlock(nn.Module):
    normalize = DEFAULT_NORMALIZER

    def __init__(
            self,
            in_channels,
            mid_channels=None,
            out_channels=None
    ):
        super(AttentionBlock, self).__init__()
        mid_channels = mid_channels or in_channels
        out_channels = out_channels or in_channels
        self.norm = self.normalize(in_channels)
        self.project_in = Conv2d(in_channels, 3 * mid_channels, 1)
        self.project_out = Conv2d(mid_channels, out_channels, 1, init_scale=0.)
        self.in_channels = in_channels
        self.mid_channels = mid_channels
        self.out_channels = out_channels
        self.skip = nn.Identity() if in_channels == out_channels else Conv2d(in_channels, out_channels, 1)

    @staticmethod
    def qkv(q, k, v):
        B, C, H, W = q.shape
        w = torch.einsum("bchw, bcHW -> bhwHW", q, k)
        w = torch.softmax(
            w.reshape(B, H, W, H * W) / math.sqrt(C), dim=-1
        ).reshape(B, H, W, H, W)
        out = torch.einsum("bhwHW, bcHW -> bchw", w, v)  # this will break the contiguity -> impaired performance
        return out.contiguous()  # force to return a contiguous tensor

    def forward(self, x, **kwargs):
        skip = self.skip(x)
        C = x.shape[1]
        assert C == self.in_channels
        q, k, v = self.project_in(self.norm(x)).chunk(3, dim=1)
        x = self.qkv(q, k, v)
        x = self.project_out(x)
        return x + skip


class ResidualBlock(nn.Module):
    normalize = DEFAULT_NORMALIZER
    nonlinearity = DEFAULT_NONLINEARITY

    def __init__(
            self,
            in_channels,
            out_channels,
            embed_dim,
            drop_rate=0.
    ):
        super(ResidualBlock, self).__init__()
        self.norm1 = self.normalize(in_channels)
        self.conv1 = Conv2d(in_channels, out_channels, 3, 1, 1)
        self.fc = Linear(embed_dim, out_channels)
        self.norm2 = self.normalize(out_channels)
        self.conv2 = Conv2d(out_channels, out_channels, 3, 1, 1, init_scale=0.)
        self.skip = nn.Identity() if in_channels == out_channels else Conv2d(in_channels, out_channels, 1)
        self.dropout = nn.Dropout(p=drop_rate, inplace=True)

    def forward(self, x, t_emb):
        skip = self.skip(x)
        x = self.conv1(self.nonlinearity(self.norm1(x)))
        x += self.fc(self.nonlinearity(t_emb))[:, :, None, None]
        x = self.dropout(self.nonlinearity(self.norm2(x)))
        x = self.conv2(x)
        return x + skip


class UNet(nn.Module):
    normalize = DEFAULT_NORMALIZER
    nonlinearity = DEFAULT_NONLINEARITY

    def __init__(
            self,
            in_channels,
            hid_channels,
            out_channels,
            ch_multipliers,
            num_res_blocks,
            apply_attn,
            time_embedding_dim=None,
            drop_rate=0.,
            resample_with_conv=True
    ):
        super(UNet, self).__init__()
        self.in_channels = in_channels
        self.hid_channels = hid_channels
        self.out_channels = out_channels
        self.time_embedding_dim = time_embedding_dim or 4 * self.hid_channels
        levels = len(ch_multipliers)
        self.ch_multipliers = ch_multipliers
        if isinstance(apply_attn, bool):
            apply_attn = [apply_attn for _ in range(levels)]
        self.apply_attn = apply_attn
        self.num_res_blocks = num_res_blocks
        self.drop_rate = drop_rate
        self.resample_with_conv = resample_with_conv

        self.embed = Sequential(
            Linear(self.hid_channels, self.time_embedding_dim),
            self.nonlinearity,
            Linear(self.time_embedding_dim, self.time_embedding_dim)
        )
        self.in_conv = Conv2d(in_channels, hid_channels, 3, 1, 1)
        self.levels = levels
        self.downsamples = nn.ModuleDict({f"level_{i}": self._get_downsample_by_level(i) for i in range(levels)})
        mid_channels = ch_multipliers[-1] * hid_channels
        embed_dim = self.time_embedding_dim
        self.middle = Sequential(
            ResidualBlock(mid_channels, mid_channels, embed_dim=embed_dim, drop_rate=drop_rate),
            AttentionBlock(mid_channels),
            ResidualBlock(mid_channels, mid_channels, embed_dim=embed_dim, drop_rate=drop_rate)
        )
        self.upsamples = nn.ModuleDict({f"level_{i}": self._get_upsample_by_level(i) for i in range(levels)})
        self.out_conv = Sequential(
            self.normalize(hid_channels),
            self.nonlinearity,
            Conv2d(hid_channels, out_channels, 3, 1, 1, init_scale=0.)
        )

    def _get_block_by_level(self, level):
        block_kwargs = {"embed_dim": self.time_embedding_dim, "drop_rate": self.drop_rate}
        if self.apply_attn[level]:
            def block(in_chans, out_chans):
                return Sequential(
                    ResidualBlock(in_chans, out_chans, **block_kwargs),
                    AttentionBlock(out_chans))
        else:
            def block(in_chans, out_chans):
                return ResidualBlock(in_chans, out_chans, **block_kwargs)
        return block

    def _get_downsample_by_level(self, level):
        block = self._get_block_by_level(level)
        prev_chans = (self.ch_multipliers[level-1] if level else 1) * self.hid_channels
        curr_chans = self.ch_multipliers[level] * self.hid_channels
        modules = nn.ModuleList([block(prev_chans, curr_chans)])
        for _ in range(self.num_res_blocks - 1):
            modules.append(block(curr_chans, curr_chans))
        if level != self.levels - 1:
            if self.resample_with_conv:
                downsample = Sequential(
                    SamePad2d(3, 2),  # custom same padding
                    Conv2d(curr_chans, curr_chans, 3, 2))
            else:
                downsample = nn.AvgPool2d(2)
            modules.append(downsample)
        return modules

    def _get_upsample_by_level(self, level):
        block = self._get_block_by_level(level)
        ch = self.hid_channels
        chs = list(map(lambda x: ch * x, self.ch_multipliers))
        next_chans = ch if level == 0 else chs[level - 1]
        prev_chans = chs[-1] if level == self.levels - 1 else chs[level + 1]
        curr_chans = chs[level]
        modules = nn.ModuleList([block(prev_chans + curr_chans, curr_chans)])
        for _ in range(self.num_res_blocks - 1):
            modules.append(block(2 * curr_chans, curr_chans))
        modules.append(block(next_chans + curr_chans, curr_chans))
        if level != 0:
            """
            Note: the official TensorFlow implementation specifies `align_corners=True`
            However, PyTorch does not support align_corners for nearest interpolation
            to see the difference, run the following example:
            ---------------------------------------------------------------------------
            import numpy as np
            import torch
            import tensorflow as tf

            x = np.arange(9.).reshape(3, 3)
            print(torch.nn.functional.interpolate(torch.as_tensor(x).reshape(1, 1, 3, 3), size=7, mode="nearest"))  # asymmetric
            print(tf.squeeze(tf.compat.v1.image.resize(tf.reshape(tf.convert_to_tensor(x), shape=(3, 3, 1)), size=(7, 7), method="nearest", align_corners=True)))  # symmetric
            ---------------------------------------------------------------------------
            """  # noqa
            upsample = [nn.Upsample(scale_factor=2, mode="nearest")]
            if self.resample_with_conv:
                upsample.append(Conv2d(curr_chans, curr_chans, 3, 1, 1))
            modules.append(Sequential(*upsample))
        return modules

    def forward(self, x, t):
        t_emb = get_timestep_embedding(t, self.hid_channels)
        t_emb = self.embed(t_emb)

        # downsample
        hs = [self.in_conv(x)]
        for i in range(self.levels):
            downsample = self.downsamples[f"level_{i}"]
            for j, layer in enumerate(downsample):  # noqa
                h = hs[-1]
                if j != self.num_res_blocks:
                    hs.append(layer(h, t_emb=t_emb))
                else:
                    hs.append(layer(h))

        # middle
        h = self.middle(hs[-1], t_emb=t_emb)

        # upsample
        for i in range(self.levels-1, -1, -1):
            upsample = self.upsamples[f"level_{i}"]
            for j, layer in enumerate(upsample):  # noqa
                if j != self.num_res_blocks + 1:
                    h = layer(torch.cat([h, hs.pop()], dim=1), t_emb=t_emb)
                else:
                    h = layer(h)

        h = self.out_conv(h)
        return h

# %%
# 需要更改

class GaussianDiffusion:
    def __init__(
        self,
        timesteps=1000,
        beta_schedule='linear'
    ):
        self.timesteps = timesteps

        if beta_schedule == 'linear':
            betas = linear_beta_schedule(timesteps)
        elif beta_schedule == 'cosine':
            betas = cosine_beta_schedule(timesteps)
        else:
            raise ValueError(f'unknown beta schedule {beta_schedule}')
        self.betas = betas

        self.alphas = 1. - self.betas
        self.alphas_cumprod = torch.cumprod(self.alphas, axis=0)
        self.alphas_cumprod_prev = F.pad(self.alphas_cumprod[:-1], (1, 0), value=0.99)

        # calculations for diffusion q(x_t | x_{t-1}) and others
        self.sqrt_alphas_cumprod = torch.sqrt(self.alphas_cumprod)
        self.sqrt_one_minus_alphas_cumprod = torch.sqrt(1.0 - self.alphas_cumprod)
        self.log_one_minus_alphas_cumprod = torch.log(1.0 - self.alphas_cumprod)
        self.sqrt_recip_alphas_cumprod = torch.sqrt(1.0 / self.alphas_cumprod)
        self.sqrt_recipm1_alphas_cumprod = torch.sqrt(1.0 / self.alphas_cumprod - 1)

        # calculations for posterior q(x_{t-1} | x_t, x_0)
        self.posterior_variance = (
            self.betas * (1.0 - self.alphas_cumprod_prev) / (1.0 - self.alphas_cumprod)
        )
        # below: log calculation clipped because the posterior variance is 0 at the beginning
        # of the diffusion chain
        self.posterior_log_variance_clipped = torch.log(self.posterior_variance.clamp(min =1e-20))

        self.posterior_mean_coef1 = (
            self.betas * torch.sqrt(self.alphas_cumprod_prev) / (1.0 - self.alphas_cumprod)
        )
        self.posterior_mean_coef2 = (
            (1.0 - self.alphas_cumprod_prev)
            * torch.sqrt(self.alphas)
            / (1.0 - self.alphas_cumprod)
        )

    def _extract(self, a, t, x_shape):
        # get the param of given timestep t
        batch_size = t.shape[0]
        out = a.to(t.device).gather(0, t).float()
        out = out.reshape(batch_size, *((1,) * (len(x_shape) - 1)))
        return out

    def q_sample(self, x_start, t, noise=None):
        # forward diffusion (using the nice property): q(x_t | x_0)
        if noise is None:
            noise = torch.randn_like(x_start)

        sqrt_alphas_cumprod_t = self._extract(self.sqrt_alphas_cumprod, t, x_start.shape)
        sqrt_one_minus_alphas_cumprod_t = self._extract(self.sqrt_one_minus_alphas_cumprod, t, x_start.shape)

        return sqrt_alphas_cumprod_t * x_start + sqrt_one_minus_alphas_cumprod_t * noise

    def q_mean_variance(self, x_start, t):
        # Get the mean and variance of q(x_t | x_0).
        mean = self._extract(self.sqrt_alphas_cumprod, t, x_start.shape) * x_start
        variance = self._extract(1.0 - self.alphas_cumprod, t, x_start.shape)
        log_variance = self._extract(self.log_one_minus_alphas_cumprod, t, x_start.shape)
        return mean, variance, log_variance

    def q_posterior_mean_variance(self, x_start, x_t, t):
        # Compute the mean and variance of the diffusion posterior: q(x_{t-1} | x_t, x_0)
        posterior_mean = (
            self._extract(self.posterior_mean_coef1, t, x_t.shape) * x_start
            + self._extract(self.posterior_mean_coef2, t, x_t.shape) * x_t
        )
        posterior_variance = self._extract(self.posterior_variance, t, x_t.shape)
        posterior_log_variance_clipped = self._extract(self.posterior_log_variance_clipped, t, x_t.shape)
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def predict_start_from_noise(self, x_t, t, noise):
        # compute x_0 from x_t and pred noise: the reverse of `q_sample`

        return (
            self._extract(self.sqrt_recip_alphas_cumprod, t, x_t.shape) * x_t -
            self._extract(self.sqrt_recipm1_alphas_cumprod, t, x_t.shape) * noise
        )
    def predict_t_1_from_t(self, x_t, noise,t):
        # compute x_t_1 from x_t and pred noise: the reverse of `q_sample`
        #print(self.alphas[t].to(x_t.device).device)
        #print(self.betas[t].to(x_t.device).device)
        return (
            (1.0/self.alphas[t].to(x_t.device)) * (x_t -
            self.betas[t].to(x_t.device) * noise)
        )

    def p_mean_variance(self, model, x_t, t, clip_denoised=True):
        # compute predicted mean and variance of p(x_{t-1} | x_t)
        # predict noise using model
        pred_noise = model(x_t, t)
        # get the predicted x_0: different from the algorithm2 in the paper
        x_recon = self.predict_start_from_noise(x_t, t, pred_noise)

        if clip_denoised:
            x_recon = torch.clamp(x_recon, min=-1., max=1.)
        model_mean, posterior_variance, posterior_log_variance = self.q_posterior_mean_variance(x_recon, x_t, t)
        return model_mean, posterior_variance, posterior_log_variance

    @torch.no_grad()
    def p_sample(self, model, x_t, t, clip_denoised=True):
        # denoise_step: sample x_{t-1} from x_t and pred_noise
        # predict mean and variance
        model_mean, _, model_log_variance = self.p_mean_variance(model, x_t, t, clip_denoised=clip_denoised)
        noise = torch.randn_like(x_t)
        # no noise when t == 0
        nonzero_mask = ((t != 0).float().view(-1, *([1] * (len(x_t.shape) - 1))))
        # compute x_{t-1}
        pred_img = model_mean + nonzero_mask * (0.5 * model_log_variance).exp() * noise
        return pred_img

    @torch.no_grad()
    def p_sample_loop(self, model, shape):
        # denoise: reverse diffusion
        batch_size = shape[0]
        device = next(model.parameters()).device
        # start from pure noise (for each example in the batch)
        img = torch.randn(shape, device=device)
        imgs = []
        for i in tqdm(reversed(range(0, timesteps)), desc='sampling loop time step', total=timesteps):
            img = self.p_sample(model, img, torch.full((batch_size,), i, device=device, dtype=torch.long))
            imgs.append(img.cpu().numpy())
        return imgs

    @torch.no_grad()
    def p_sample_loop_new(self, model, image):
        # denoise: reverse diffusion
        batch_size = image.shape[0]
        device = next(model.parameters()).device
        img=image
        imgs = []
        for i in tqdm(reversed(range(0, timesteps)), desc='sampling loop time step', total=timesteps):
            img = self.p_sample(model, img, torch.full((batch_size,), i, device=device, dtype=torch.long))
            imgs.append(img.cpu().numpy())
        return imgs


    @torch.no_grad()
    def sample(self, model, image_size, batch_size=8, channels=3):
        # sample new images
        return self.p_sample_loop(model, shape=(batch_size, channels, image_size, image_size))



    def train_losses(self, model, x_start, t):
        # compute train losses
        # generate random noise
        noise = torch.randn_like(x_start)
        # get x_t
        x_noisy = self.q_sample(x_start, t, noise=noise)
        predicted_noise = model(x_noisy, t)
        loss = F.mse_loss(noise, predicted_noise)
        return loss

    def get_parameter(self, model, x_start, t):
        noise = torch.randn_like(x_start)
        # get x_t
        x_noisy = self.q_sample(x_start, t, noise=noise)

        predicted_noise = model(x_noisy, t)

        alphas=self.alphas.to(t.device)
        betas=self.betas.to(t.device)

        sqrt_one_minus_alphas_cumprod=self.sqrt_one_minus_alphas_cumprod.to(t.device)
        mean1,variance_all,posterior_log_variance=self.p_mean_variance(model, x_noisy, t)

        #mean1=alphas[t]*x_noisy-predicted_noise*betas[t]/sqrt_one_minus_alphas_cumprod

        return mean1,variance_all

    def get_parameter2(self, model, x_t, t):
        # get x_t
        #predicted_noise = model(x_t, t)
        #noise = torch.randn_like(x_final)

        predicted_noise = model(x_t, t)

        alphas=self.alphas.to(t.device)
        betas=self.betas.to(t.device)

        sqrt_one_minus_alphas_cumprod=self.sqrt_one_minus_alphas_cumprod.to(t.device)
        mean1,variance_all,posterior_log_variance=self.p_mean_variance(model, x_t, t)

        #mean1=alphas[t]*x_noisy-predicted_noise*betas[t]/sqrt_one_minus_alphas_cumprod

        return mean1,variance_all

# %% [markdown]
# 看看效果

# %%
from PIL import Image
import requests
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

# %matplotlib inline

# %%
url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
image = Image.open(requests.get(url, stream=True).raw)
# image = Image.open("/data/000000039769.jpg")

image_size = 128
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.PILToTensor(),
    transforms.ConvertImageDtype(torch.float),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

x_start = transform(image).unsqueeze(0)

gaussian_diffusion = GaussianDiffusion(timesteps=500)

plt.figure(figsize=(16, 8))
for idx, t in enumerate([0, 50, 100, 200, 499]):
    x_noisy = gaussian_diffusion.q_sample(x_start, t=torch.tensor([t]))
    noisy_image = (x_noisy.squeeze().permute(1, 2, 0) + 1) * 127.5
    noisy_image = noisy_image.numpy().astype(np.uint8)
    plt.subplot(1, 5, 1 + idx)
    plt.imshow(noisy_image)
    plt.axis("off")
    plt.title(f"t={t}")

# %% [markdown]
# ## 训练

# %% [markdown]
# 准备数据集

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset

# %%
class TrainSet(Dataset):
  def __init__(self, original_dataset,label):
    self.original_dataset = original_dataset
    self.label = label

  def __getitem__(self, index):
      image = self.original_dataset[index]
      return image, self.label[index]

  def __len__(self):
      return len(self.original_dataset)

# %%
class BinaryDataset(torch.utils.data.Dataset):
    def __init__(self, original_dataset,indices,label):
        self.original_dataset = original_dataset
        self.indices  = indices
        self.label = label

    def __getitem__(self, index):
        image, _ = self.original_dataset[self.indices[index]]
        return image, self.label

    def __len__(self):
        return len(self.indices)

# %%
batch_size = 64
timesteps = 5

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

# use MNIST dataset
dataset = datasets.MNIST('./data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 152967167.33it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 28759661.40it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 55572539.51it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 5107380.37it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
# use cifar10
dataset = datasets.CIFAR10('./dataset', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./dataset/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 49152059.88it/s]
# Extracting ./dataset/cifar-10-python.tar.gz to ./dataset

# %%
mnist_indices = [i for i in range(len(dataset)) if dataset[i][1] == 3]
mnist2_indices = [i for i in range(len(dataset)) if dataset[i][1] == 9]
dataset_image_number=256

mnist_dataset = BinaryDataset(dataset, mnist_indices[0:dataset_image_number],label=3 )
mnist2_dataset = BinaryDataset(dataset, mnist2_indices[0:dataset_image_number],label=9 )

mnist_dataset_v = BinaryDataset(dataset, mnist_indices[dataset_image_number+1:dataset_image_number+dataset_image_number],label=3)
mnist2_dataset_v = BinaryDataset(dataset, mnist2_indices[dataset_image_number+1:dataset_image_number+dataset_image_number],label=9 )

# %%
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])

val_dataset=torch.utils.data.ConcatDataset([mnist_dataset_v, mnist2_dataset_v])
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=1, shuffle=True,pin_memory=True)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True,num_workers=4,pin_memory=True)

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# Transform
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# Load CIFAR10 dataset
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True)

# Class labels for CIFAR10
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# Get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Show images
imshow(torchvision.utils.make_grid(images))

# Print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 47457544.03it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
#   car  frog  bird  ship

# %% [markdown]
# 模型

# %% [markdown]
# 开始训练

# %%
import torch,gc
gc.collect()
torch.cuda.empty_cache()
from torch.utils.data import Dataset

# %%
# define model and diffusion
device = "cuda" if torch.cuda.is_available() else "cpu"
model = UNetModel(
    in_channels=1,
    model_channels=96,
    out_channels=1,
    channel_mult=(1, 2, 2),
    attention_resolutions=[]
)
model.to(device)

gaussian_diffusion = GaussianDiffusion(timesteps=timesteps)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-41d02f658706> in <cell line: 3>()
#       1 # define model and diffusion
#       2 device = "cuda" if torch.cuda.is_available() else "cpu"
# ----> 3 model = UNetModel(
#       4     in_channels=1,
#       5     model_channels=96,
#
# <ipython-input-3-0b28976890b5> in __init__(self, in_channels, model_channels, out_channels, num_res_blocks, attention_resolutions, dropout, channel_mult, conv_resample, num_heads)
#     208         self.middle_block = TimestepEmbedSequential(
#     209             ResidualBlock(ch, ch, time_embed_dim, dropout),
# --> 210             AttentionBlock(ch, num_heads=num_heads),
#     211             ResidualBlock(ch, ch, time_embed_dim, dropout)
#     212         )
#
# TypeError: AttentionBlock.__init__() got an unexpected keyword argument 'num_heads'

# %%
epochs = 10
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)
device = "cuda" if torch.cuda.is_available() else "cpu"
batch_size = 32
timesteps = 5
loss_batch_average=torch.zeros([epochs,timesteps,int(dataset_image_number/batch_size)])
model_parameters=dict()
x_t_train_dataset1=torch.utils.data.ConcatDataset([mnist_dataset])
x_t_train_dataset2=torch.utils.data.ConcatDataset([mnist2_dataset])
losses = {'loss':[],'loss2':[]}
best_acc=0
for t in range(timesteps-1,-1,-1):
  time = torch.full((batch_size,),t, device=device).long()

  train_loader1 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=True,pin_memory=True)
  train_loader2 = torch.utils.data.DataLoader(x_t_train_dataset2, batch_size=batch_size, shuffle=True,pin_memory=True)
  for epoch in range(epochs):
    batch_size=batch_size
    iteration_of_train_loader2=iter(train_loader2)
    for step, (images1, _) in enumerate(train_loader1):

      xt1 = images1.to(device)
      images2,_=next(iteration_of_train_loader2)
      xt2 = images2.to(device)

      out1 = model(xt1, time)
      out2 = model(xt2, time)
      out1=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(out1)
      out2=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(out2)

      m1 =out1.reshape(batch_size,3*32*32)
      m2 =out2.reshape(batch_size,3*32*32)

      s1=torch.var(m1, dim=0)
      s2=torch.var(m2, dim=0)
      loss2=s1.mean(0)+s2.mean(0)
      loss=0.1*loss2+torch.dot(m1.mean(0) / torch.norm(m1.mean(0)), m2.mean(0) / torch.norm(m2.mean(0)))

      loss_batch_average[epoch,t,step]=loss
      del s1,s2,m1,m2
      print(" this is timesteps",t," this is epoch",epoch,"this is step ",step)
      optimizer.zero_grad()
      loss.backward()

      optimizer.step()
      losses['loss'].append(loss.detach().cpu().numpy())
      losses['loss2'].append(loss2.detach().cpu().numpy())

      loss_batch_average[epoch,t,step]=loss
      #for name, parms in model.named_parameters():
        #print('-->name:', name, '-->grad_requirs:',parms.requires_grad, ' -->grad_value:',parms.grad)
      # print('-->name:', name, parms.data)

      print("loss",loss)
      print("loss2",loss2)
      model_parameters[t]=model.state_dict()

  x_t_train_dataset1_1=torch.zeros([dataset_image_number,3,32,32])
  x_t_train_dataset2_2=torch.zeros([dataset_image_number,3,32,32])

  labels_1=torch.zeros([dataset_image_number])
  labels_2=torch.zeros([dataset_image_number])
  #establish xt_1 for the next loop
  with torch.no_grad():
    for step, (images1, labels) in enumerate(train_loader1):
      xt1 = images1.to(device)

      images1=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))

      x_t_train_dataset1_1[step*batch_size:(step+1)*batch_size,:,:,:]=images1
      labels_1[step*batch_size:(step+1)*batch_size]=labels
    x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset1_1,labels_1)])

  with torch.no_grad():
    for step, (images2, labels2) in enumerate(train_loader2):
      xt2 = images2.to(device)

      images2= transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt2, time))

      x_t_train_dataset2_2[step*batch_size:(step+1)*batch_size,:,:,:]=images2
      labels_2[step*batch_size:(step+1)*batch_size]=labels2
    x_t_train_dataset2=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset2_2,labels_2)])

  model.eval()
  #establish xt_1 for the next loop
  val_acc=0
  with torch.no_grad():
    for step, (image, label) in enumerate(val_loader):
      image = image.to(device)
      x0=image
      for t_v in range(timesteps-1,t-1,-1):

        model.load_state_dict(model_parameters[t_v],strict=True)
        time=torch.full((1,),t_v, device=device)
        x=model(x0, time)
        x0=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(x).to(device)

      a=torch.dot(x_t_train_dataset1_1.reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_t_train_dataset1_1.reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 3 and pred
      b=torch.dot(x_t_train_dataset2_2.reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_t_train_dataset2_2.reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 2 and pred
      if a >= b:
        pred_label= 3
        #print(a,"and",b)
      else:
        pred_label= 9
        #print(a,"and",b)
      if pred_label==label:
        val_acc=val_acc+1
        #print("exact!", pred_label,"the true is ",label)
      else:
        print("find different label at step ", step, pred_label,"the true is ",label)
    print("val_acc",val_acc/len(val_dataset))
    if val_acc/len(val_dataset)>best_acc:
      best_acc=val_acc/len(val_dataset)
      print(best_acc)
      epochs_without_improvement = 0
    else:
      epochs_without_improvement+=1
      print("early stopping at timestep", t,val_acc/len(val_dataset))
      #break
  print("done")
# Out:
#  this is timesteps 4  this is epoch 0 this is step  0
# loss tensor(1., device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(3.3661e-10, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  1
# loss tensor(1.0015, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1406, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  2
# loss tensor(0.9998, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  3
# loss tensor(1.0060, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1143, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  4
# loss tensor(0.9991, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.0029, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  5
# loss tensor(0.9981, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  6
# loss tensor(0.9786, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.0350, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 0 this is step  7
# loss tensor(0.7636, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3379, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  0
# loss tensor(0.6248, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1079, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  1
# loss tensor(0.5653, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.9861, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  2
# loss tensor(0.7922, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.0168, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  3
# loss tensor(0.5118, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.3050, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  4
# loss tensor(0.2675, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.3303, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  5
# loss tensor(0.6250, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.2410, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  6
# loss tensor(0.7565, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.1885, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 1 this is step  7
# loss tensor(0.5080, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.7097, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  0
# loss tensor(0.5912, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2294, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  1
# loss tensor(0.1873, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8519, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  2
# loss tensor(0.0942, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8784, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  3
# loss tensor(0.0491, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.3442, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  4
# loss tensor(0.0668, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.7103, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  5
# loss tensor(-0.3161, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.8962, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  6
# loss tensor(0.4598, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.2082, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 2 this is step  7
# loss tensor(-0.2050, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.6892, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  0
# loss tensor(0.1416, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.4822, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  1
# loss tensor(-0.1725, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.3932, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  2
# loss tensor(0.0457, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.3930, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  3
# loss tensor(-0.4154, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.1056, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  4
# loss tensor(-0.0155, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.0089, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  5
# loss tensor(-0.0787, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.6209, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  6
# loss tensor(-0.5446, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2801, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 3 this is step  7
# loss tensor(0.2864, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.3653, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  0
# loss tensor(-0.2065, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8673, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  1
# loss tensor(-0.5072, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9112, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  2
# loss tensor(-0.3438, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1104, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  3
# loss tensor(-0.5469, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2376, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  4
# loss tensor(-0.4995, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.5661, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  5
# loss tensor(0.0167, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.8033, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  6
# loss tensor(-0.2162, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.2555, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 4 this is step  7
# loss tensor(-0.2374, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.3093, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  0
# loss tensor(-0.3631, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(2.0666, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  1
# loss tensor(-0.4431, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.5867, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  2
# loss tensor(-0.5435, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.7404, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  3
# loss tensor(-0.5363, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.7148, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  4
# loss tensor(-0.4520, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9905, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  5
# loss tensor(-0.7235, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2015, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  6
# loss tensor(-0.5354, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.3782, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 5 this is step  7
# loss tensor(-0.5274, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.3475, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  0
# loss tensor(-0.5497, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2088, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  1
# loss tensor(-0.5571, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2136, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  2
# loss tensor(-0.6544, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2360, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  3
# loss tensor(-0.7123, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0624, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  4
# loss tensor(-0.7098, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0215, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  5
# loss tensor(-0.7593, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9571, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  6
# loss tensor(-0.5877, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7768, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 6 this is step  7
# loss tensor(-0.7872, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9149, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  0
# loss tensor(-0.7223, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9566, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  1
# loss tensor(-0.8195, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8958, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  2
# loss tensor(-0.7865, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9907, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  3
# loss tensor(-0.7423, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0285, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  4
# loss tensor(-0.4607, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9287, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  5
# loss tensor(-0.7987, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9860, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  6
# loss tensor(-0.5731, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0556, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 7 this is step  7
# loss tensor(-0.6682, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0921, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  0
# loss tensor(-0.8250, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9580, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  1
# loss tensor(-0.6381, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1272, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  2
# loss tensor(-0.7819, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9941, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  3
# loss tensor(-0.8298, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7708, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  4
# loss tensor(-0.7436, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9056, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  5
# loss tensor(-0.7235, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0751, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  6
# loss tensor(-0.8344, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7317, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 8 this is step  7
# loss tensor(-0.6810, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6481, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  0
# loss tensor(-0.6821, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7298, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  1
# loss tensor(-0.8186, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7778, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  2
# loss tensor(-0.7456, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6710, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  3
# loss tensor(-0.8144, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6578, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  4
# loss tensor(-0.6671, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8674, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  5
# loss tensor(-0.8556, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8056, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  6
# loss tensor(-0.8722, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8064, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 4  this is epoch 9 this is step  7
# loss tensor(-0.8775, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6965, device='cuda:0', grad_fn=<AddBackward0>)
# find different label at step  3 9 the true is  tensor([3])
# find different label at step  7 3 the true is  tensor([9])
# find different label at step  14 3 the true is  tensor([9])
# find different label at step  19 3 the true is  tensor([9])
# find different label at step  20 9 the true is  tensor([3])
# find different label at step  21 9 the true is  tensor([3])
# find different label at step  23 3 the true is  tensor([9])
# find different label at step  31 3 the true is  tensor([9])
# find different label at step  32 3 the true is  tensor([9])
# find different label at step  47 3 the true is  tensor([9])
# find different label at step  49 3 the true is  tensor([9])
# find different label at step  51 3 the true is  tensor([9])
# find different label at step  53 3 the true is  tensor([9])
# find different label at step  70 9 the true is  tensor([3])
# find different label at step  78 9 the true is  tensor([3])
# find different label at step  90 3 the true is  tensor([9])
# find different label at step  122 3 the true is  tensor([9])
# find different label at step  127 3 the true is  tensor([9])
# find different label at step  134 3 the true is  tensor([9])
# find different label at step  136 3 the true is  tensor([9])
# find different label at step  163 3 the true is  tensor([9])
# find different label at step  170 9 the true is  tensor([3])
# find different label at step  174 3 the true is  tensor([9])
# find different label at step  184 3 the true is  tensor([9])
# find different label at step  185 3 the true is  tensor([9])
# find different label at step  186 3 the true is  tensor([9])
# find different label at step  189 3 the true is  tensor([9])
# find different label at step  192 9 the true is  tensor([3])
# find different label at step  197 3 the true is  tensor([9])
# find different label at step  198 9 the true is  tensor([3])
# find different label at step  204 9 the true is  tensor([3])
# find different label at step  206 9 the true is  tensor([3])
# find different label at step  208 9 the true is  tensor([3])
# find different label at step  210 9 the true is  tensor([3])
# find different label at step  215 3 the true is  tensor([9])
# find different label at step  216 3 the true is  tensor([9])
# find different label at step  221 9 the true is  tensor([3])
# find different label at step  222 3 the true is  tensor([9])
# find different label at step  230 9 the true is  tensor([3])
# find different label at step  235 3 the true is  tensor([9])
# find different label at step  240 3 the true is  tensor([9])
# find different label at step  248 3 the true is  tensor([9])
# find different label at step  249 3 the true is  tensor([9])
# find different label at step  257 3 the true is  tensor([9])
# find different label at step  267 3 the true is  tensor([9])
# find different label at step  272 3 the true is  tensor([9])
# find different label at step  285 9 the true is  tensor([3])
# find different label at step  291 9 the true is  tensor([3])
# find different label at step  295 3 the true is  tensor([9])
# find different label at step  301 3 the true is  tensor([9])
# find different label at step  303 9 the true is  tensor([3])
# find different label at step  319 9 the true is  tensor([3])
# find different label at step  325 9 the true is  tensor([3])
# find different label at step  335 9 the true is  tensor([3])
# find different label at step  346 9 the true is  tensor([3])
# find different label at step  349 3 the true is  tensor([9])
# find different label at step  362 3 the true is  tensor([9])
# find different label at step  366 9 the true is  tensor([3])
# find different label at step  386 3 the true is  tensor([9])
# find different label at step  393 3 the true is  tensor([9])
# find different label at step  408 3 the true is  tensor([9])
# find different label at step  413 3 the true is  tensor([9])
# find different label at step  419 9 the true is  tensor([3])
# find different label at step  423 9 the true is  tensor([3])
# find different label at step  424 9 the true is  tensor([3])
# find different label at step  433 9 the true is  tensor([3])
# find different label at step  437 9 the true is  tensor([3])
# find different label at step  447 9 the true is  tensor([3])
# find different label at step  451 9 the true is  tensor([3])
# find different label at step  452 3 the true is  tensor([9])
# find different label at step  456 9 the true is  tensor([3])
# find different label at step  461 3 the true is  tensor([9])
# find different label at step  463 3 the true is  tensor([9])
# find different label at step  479 9 the true is  tensor([3])
# find different label at step  491 3 the true is  tensor([9])
# find different label at step  493 3 the true is  tensor([9])
# find different label at step  498 3 the true is  tensor([9])
# find different label at step  503 3 the true is  tensor([9])
# find different label at step  506 9 the true is  tensor([3])
# val_acc 0.8450980392156863
# 0.8450980392156863
# done
#  this is timesteps 3  this is epoch 0 this is step  0
# loss tensor(-0.6649, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6912, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  1
# loss tensor(-0.6838, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8155, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  2
# loss tensor(-0.8273, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7279, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  3
# loss tensor(-0.8243, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7032, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  4
# loss tensor(-0.8863, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5665, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  5
# loss tensor(-0.8610, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4514, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  6
# loss tensor(-0.8676, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5211, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 0 this is step  7
# loss tensor(-0.8386, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5048, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  0
# loss tensor(-0.8790, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5166, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  1
# loss tensor(-0.8320, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3779, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  2
# loss tensor(-0.9129, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2990, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  3
# loss tensor(-0.7703, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2941, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  4
# loss tensor(-0.7639, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1927, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  5
# loss tensor(-0.8747, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2805, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  6
# loss tensor(-0.8949, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4160, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 1 this is step  7
# loss tensor(-0.5577, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7146, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  0
# loss tensor(-0.8312, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8274, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  1
# loss tensor(-0.6741, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9005, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  2
# loss tensor(-0.7955, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9180, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  3
# loss tensor(-0.8342, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1645, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  4
# loss tensor(-0.8001, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.5588, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  5
# loss tensor(-0.7484, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2982, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  6
# loss tensor(-0.7464, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.4920, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 2 this is step  7
# loss tensor(-0.7846, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.3627, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  0
# loss tensor(-0.8566, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1788, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  1
# loss tensor(-0.7957, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2932, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  2
# loss tensor(-0.8430, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7620, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  3
# loss tensor(-0.7373, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1381, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  4
# loss tensor(-0.8285, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1565, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  5
# loss tensor(-0.8514, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0090, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  6
# loss tensor(-0.8652, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8645, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 3 this is step  7
# loss tensor(-0.7269, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8073, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  0
# loss tensor(-0.9118, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6027, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  1
# loss tensor(-0.7161, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7186, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  2
# loss tensor(-0.9030, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3345, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  3
# loss tensor(-0.9252, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3590, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  4
# loss tensor(-0.7180, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4843, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  5
# loss tensor(-0.8239, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4246, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  6
# loss tensor(-0.9011, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3529, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 4 this is step  7
# loss tensor(-0.8731, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3342, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  0
# loss tensor(-0.9522, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2149, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  1
# loss tensor(-0.9457, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1871, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  2
# loss tensor(-0.9202, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2685, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  3
# loss tensor(-0.8514, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1638, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  4
# loss tensor(-0.2575, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2161, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  5
# loss tensor(-0.9240, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2499, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  6
# loss tensor(-0.7785, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4074, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 5 this is step  7
# loss tensor(-0.7804, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5656, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  0
# loss tensor(-0.8981, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6944, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  1
# loss tensor(-0.8076, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7548, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  2
# loss tensor(-0.7952, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8178, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  3
# loss tensor(-0.7262, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1729, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  4
# loss tensor(-0.8768, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8573, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  5
# loss tensor(-0.8428, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.2871, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  6
# loss tensor(-0.7577, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.4663, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 6 this is step  7
# loss tensor(-0.6775, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.3361, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  0
# loss tensor(-0.7590, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.7768, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  1
# loss tensor(-0.8567, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1175, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  2
# loss tensor(-0.8046, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1487, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  3
# loss tensor(-0.8266, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9512, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  4
# loss tensor(-0.8167, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0432, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  5
# loss tensor(-0.8843, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8793, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  6
# loss tensor(-0.9080, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7623, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 7 this is step  7
# loss tensor(-0.9035, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7080, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  0
# loss tensor(-0.8822, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6790, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  1
# loss tensor(-0.8936, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5930, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  2
# loss tensor(-0.8967, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6404, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  3
# loss tensor(-0.8953, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5011, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  4
# loss tensor(-0.8663, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4273, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  5
# loss tensor(-0.9043, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4923, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  6
# loss tensor(-0.9148, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4031, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 8 this is step  7
# loss tensor(-0.8610, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2919, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  0
# loss tensor(-0.8743, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3554, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  1
# loss tensor(-0.9079, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2517, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  2
# loss tensor(-0.8168, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2171, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  3
# loss tensor(-0.8335, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3780, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  4
# loss tensor(-0.9028, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4517, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  5
# loss tensor(-0.6285, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4525, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  6
# loss tensor(-0.9051, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4587, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 3  this is epoch 9 this is step  7
# loss tensor(-0.9177, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5388, device='cuda:0', grad_fn=<AddBackward0>)
# find different label at step  0 9 the true is  tensor([3])
# find different label at step  4 9 the true is  tensor([3])
# find different label at step  5 9 the true is  tensor([3])
# find different label at step  7 9 the true is  tensor([3])
# find different label at step  13 3 the true is  tensor([9])
# find different label at step  15 9 the true is  tensor([3])
# find different label at step  19 9 the true is  tensor([3])
# find different label at step  29 3 the true is  tensor([9])
# find different label at step  33 9 the true is  tensor([3])
# find different label at step  40 3 the true is  tensor([9])
# find different label at step  42 9 the true is  tensor([3])
# find different label at step  47 3 the true is  tensor([9])
# find different label at step  53 9 the true is  tensor([3])
# find different label at step  55 9 the true is  tensor([3])
# find different label at step  56 9 the true is  tensor([3])
# find different label at step  73 3 the true is  tensor([9])
# find different label at step  81 9 the true is  tensor([3])
# find different label at step  92 9 the true is  tensor([3])
# find different label at step  93 9 the true is  tensor([3])
# find different label at step  94 9 the true is  tensor([3])
# find different label at step  96 9 the true is  tensor([3])
# find different label at step  98 3 the true is  tensor([9])
# find different label at step  102 9 the true is  tensor([3])
# find different label at step  117 9 the true is  tensor([3])
# find different label at step  119 9 the true is  tensor([3])
# find different label at step  120 9 the true is  tensor([3])
# find different label at step  125 3 the true is  tensor([9])
# find different label at step  126 3 the true is  tensor([9])
# find different label at step  127 9 the true is  tensor([3])
# find different label at step  128 9 the true is  tensor([3])
# find different label at step  130 3 the true is  tensor([9])
# find different label at step  131 9 the true is  tensor([3])
# find different label at step  133 9 the true is  tensor([3])
# find different label at step  138 9 the true is  tensor([3])
# find different label at step  152 9 the true is  tensor([3])
# find different label at step  159 3 the true is  tensor([9])
# find different label at step  160 9 the true is  tensor([3])
# find different label at step  161 9 the true is  tensor([3])
# find different label at step  164 9 the true is  tensor([3])
# find different label at step  167 3 the true is  tensor([9])
# find different label at step  176 9 the true is  tensor([3])
# find different label at step  178 9 the true is  tensor([3])
# find different label at step  179 9 the true is  tensor([3])
# find different label at step  188 9 the true is  tensor([3])
# find different label at step  192 3 the true is  tensor([9])
# find different label at step  199 9 the true is  tensor([3])
# find different label at step  203 9 the true is  tensor([3])
# find different label at step  205 3 the true is  tensor([9])
# find different label at step  206 9 the true is  tensor([3])
# find different label at step  209 9 the true is  tensor([3])
# find different label at step  211 9 the true is  tensor([3])
# find different label at step  212 3 the true is  tensor([9])
# find different label at step  215 9 the true is  tensor([3])
# find different label at step  222 3 the true is  tensor([9])
# find different label at step  223 9 the true is  tensor([3])
# find different label at step  232 9 the true is  tensor([3])
# find different label at step  241 9 the true is  tensor([3])
# find different label at step  243 9 the true is  tensor([3])
# find different label at step  250 9 the true is  tensor([3])
# find different label at step  251 9 the true is  tensor([3])
# find different label at step  257 9 the true is  tensor([3])
# find different label at step  261 9 the true is  tensor([3])
# find different label at step  265 3 the true is  tensor([9])
# find different label at step  271 3 the true is  tensor([9])
# find different label at step  283 9 the true is  tensor([3])
# find different label at step  293 9 the true is  tensor([3])
# find different label at step  294 9 the true is  tensor([3])
# find different label at step  297 9 the true is  tensor([3])
# find different label at step  298 9 the true is  tensor([3])
# find different label at step  301 9 the true is  tensor([3])
# find different label at step  303 3 the true is  tensor([9])
# find different label at step  312 9 the true is  tensor([3])
# find different label at step  317 3 the true is  tensor([9])
# find different label at step  318 3 the true is  tensor([9])
# find different label at step  322 3 the true is  tensor([9])
# find different label at step  324 9 the true is  tensor([3])
# find different label at step  325 9 the true is  tensor([3])
# find different label at step  326 9 the true is  tensor([3])
# find different label at step  328 9 the true is  tensor([3])
# find different label at step  330 9 the true is  tensor([3])
# find different label at step  341 9 the true is  tensor([3])
# find different label at step  352 9 the true is  tensor([3])
# find different label at step  356 9 the true is  tensor([3])
# find different label at step  359 3 the true is  tensor([9])
# find different label at step  372 9 the true is  tensor([3])
# find different label at step  375 3 the true is  tensor([9])
# find different label at step  376 9 the true is  tensor([3])
# find different label at step  377 9 the true is  tensor([3])
# find different label at step  379 3 the true is  tensor([9])
# find different label at step  388 9 the true is  tensor([3])
# find different label at step  391 9 the true is  tensor([3])
# find different label at step  408 9 the true is  tensor([3])
# find different label at step  413 9 the true is  tensor([3])
# find different label at step  423 9 the true is  tensor([3])
# find different label at step  432 3 the true is  tensor([9])
# find different label at step  437 9 the true is  tensor([3])
# find different label at step  439 9 the true is  tensor([3])
# find different label at step  441 9 the true is  tensor([3])
# find different label at step  450 9 the true is  tensor([3])
# find different label at step  451 3 the true is  tensor([9])
# find different label at step  453 9 the true is  tensor([3])
# find different label at step  458 9 the true is  tensor([3])
# find different label at step  479 9 the true is  tensor([3])
# find different label at step  480 3 the true is  tensor([9])
# find different label at step  489 3 the true is  tensor([9])
# find different label at step  493 9 the true is  tensor([3])
# find different label at step  498 3 the true is  tensor([9])
# find different label at step  508 9 the true is  tensor([3])
# val_acc 0.788235294117647
# early stopping at timestep 3 0.788235294117647
# done
#  this is timesteps 2  this is epoch 0 this is step  0
# loss tensor(-0.5393, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6272, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  1
# loss tensor(-0.8002, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5282, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  2
# loss tensor(-0.8485, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8506, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  3
# loss tensor(-0.8592, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0810, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  4
# loss tensor(-0.7473, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1080, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  5
# loss tensor(-0.8735, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6553, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  6
# loss tensor(-0.8548, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9530, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 0 this is step  7
# loss tensor(-0.8608, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.1799, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  0
# loss tensor(-0.8027, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.3211, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  1
# loss tensor(-0.8554, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0865, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  2
# loss tensor(-0.8770, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.9397, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  3
# loss tensor(-0.8616, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(1.0908, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  4
# loss tensor(-0.8755, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.8226, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  5
# loss tensor(-0.9167, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7349, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  6
# loss tensor(-0.8761, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7670, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 1 this is step  7
# loss tensor(-0.9382, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5322, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  0
# loss tensor(-0.8525, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7536, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  1
# loss tensor(-0.9225, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6070, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  2
# loss tensor(-0.8437, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5640, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  3
# loss tensor(-0.8894, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5358, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  4
# loss tensor(-0.9059, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3512, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  5
# loss tensor(-0.9029, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3380, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  6
# loss tensor(-0.9318, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3388, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 2 this is step  7
# loss tensor(-0.9684, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1941, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  0
# loss tensor(-0.8763, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2849, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  1
# loss tensor(-0.9397, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2689, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  2
# loss tensor(-0.8572, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3023, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  3
# loss tensor(-0.8945, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3484, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  4
# loss tensor(-0.8480, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2447, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  5
# loss tensor(-0.9062, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2685, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  6
# loss tensor(-0.9513, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3101, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 3 this is step  7
# loss tensor(-0.9130, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3015, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  0
# loss tensor(-0.8861, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3605, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  1
# loss tensor(-0.8957, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4660, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  2
# loss tensor(-0.8451, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3405, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  3
# loss tensor(-0.7518, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4176, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  4
# loss tensor(-0.9410, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2981, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  5
# loss tensor(-0.9145, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4412, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  6
# loss tensor(-0.9046, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3899, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 4 this is step  7
# loss tensor(-0.6307, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7110, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 5 this is step  0
# loss tensor(-0.9304, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5745, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 5 this is step  1
# loss tensor(-0.8377, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7384, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 5 this is step  2
# loss tensor(-0.7717, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.7519, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 5 this is step  3
# loss tensor(-0.8742, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6399, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 2  this is epoch 5 this is step  4
# loss tensor(-0.9185, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.6963, device='cuda:0', grad_fn=<AddBackward0>)
# ...
# loss2 tensor(0.1067, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 4 this is step  6
# loss tensor(-0.9655, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1419, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 4 this is step  7
# loss tensor(-0.9145, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1687, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  0
# loss tensor(-0.9820, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1222, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  1
# loss tensor(-0.9016, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2057, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  2
# loss tensor(-0.9699, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2062, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  3
# loss tensor(-0.9249, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1713, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  4
# loss tensor(-0.9531, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2151, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  5
# loss tensor(-0.9597, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2965, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  6
# loss tensor(-0.9397, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2480, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 5 this is step  7
# loss tensor(-0.9479, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3477, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  0
# loss tensor(-0.9598, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3000, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  1
# loss tensor(-0.9092, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3541, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  2
# loss tensor(-0.9613, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3216, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  3
# loss tensor(-0.9570, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2614, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  4
# loss tensor(-0.9341, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3189, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  5
# loss tensor(-0.9713, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2276, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  6
# loss tensor(-0.9517, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3773, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 6 this is step  7
# loss tensor(-0.9572, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2658, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  0
# loss tensor(-0.9598, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2854, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  1
# loss tensor(-0.9641, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2961, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  2
# loss tensor(-0.9431, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2370, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  3
# loss tensor(-0.9785, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1614, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  4
# loss tensor(-0.9816, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1435, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  5
# loss tensor(-0.8891, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3257, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  6
# loss tensor(-0.9446, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2660, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 7 this is step  7
# loss tensor(-0.8999, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2256, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  0
# loss tensor(-0.9739, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2047, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  1
# loss tensor(-0.8499, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3083, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  2
# loss tensor(-0.9627, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.1831, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  3
# loss tensor(-0.8478, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2418, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  4
# loss tensor(-0.9476, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2751, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  5
# loss tensor(-0.9602, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2628, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  6
# loss tensor(-0.9380, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2984, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 8 this is step  7
# loss tensor(-0.8486, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4673, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  0
# loss tensor(-0.9644, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.2861, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  1
# loss tensor(-0.8576, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4385, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  2
# loss tensor(-0.9241, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.3257, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  3
# loss tensor(-0.9418, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4584, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  4
# loss tensor(-0.9254, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4574, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  5
# loss tensor(-0.9118, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4338, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  6
# loss tensor(-0.9377, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.4670, device='cuda:0', grad_fn=<AddBackward0>)
#  this is timesteps 0  this is epoch 9 this is step  7
# loss tensor(-0.9461, device='cuda:0', grad_fn=<AddBackward0>)
# loss2 tensor(0.5066, device='cuda:0', grad_fn=<AddBackward0>)
# find different label at step  1 9 the true is  tensor([3])
# find different label at step  3 9 the true is  tensor([3])
# find different label at step  9 9 the true is  tensor([3])
# find different label at step  12 9 the true is  tensor([3])
# find different label at step  14 9 the true is  tensor([3])
# find different label at step  16 3 the true is  tensor([9])
# find different label at step  17 9 the true is  tensor([3])
# find different label at step  18 9 the true is  tensor([3])
# find different label at step  24 9 the true is  tensor([3])
# find different label at step  30 3 the true is  tensor([9])
# find different label at step  32 9 the true is  tensor([3])
# find different label at step  37 9 the true is  tensor([3])
# find different label at step  39 9 the true is  tensor([3])
# find different label at step  40 9 the true is  tensor([3])
# find different label at step  42 9 the true is  tensor([3])
# find different label at step  44 3 the true is  tensor([9])
# find different label at step  45 9 the true is  tensor([3])
# find different label at step  48 9 the true is  tensor([3])
# find different label at step  50 9 the true is  tensor([3])
# find different label at step  55 9 the true is  tensor([3])
# find different label at step  57 9 the true is  tensor([3])
# find different label at step  60 9 the true is  tensor([3])
# find different label at step  65 9 the true is  tensor([3])
# find different label at step  66 9 the true is  tensor([3])
# find different label at step  67 9 the true is  tensor([3])
# find different label at step  69 3 the true is  tensor([9])
# find different label at step  71 9 the true is  tensor([3])
# find different label at step  72 9 the true is  tensor([3])
# find different label at step  76 9 the true is  tensor([3])
# find different label at step  83 3 the true is  tensor([9])
# find different label at step  91 9 the true is  tensor([3])
# find different label at step  94 9 the true is  tensor([3])
# find different label at step  99 9 the true is  tensor([3])
# find different label at step  100 3 the true is  tensor([9])
# find different label at step  105 9 the true is  tensor([3])
# find different label at step  108 9 the true is  tensor([3])
# find different label at step  111 9 the true is  tensor([3])
# find different label at step  123 9 the true is  tensor([3])
# find different label at step  128 9 the true is  tensor([3])
# find different label at step  129 9 the true is  tensor([3])
# find different label at step  139 9 the true is  tensor([3])
# find different label at step  147 9 the true is  tensor([3])
# find different label at step  148 3 the true is  tensor([9])
# find different label at step  150 9 the true is  tensor([3])
# find different label at step  152 3 the true is  tensor([9])
# find different label at step  154 9 the true is  tensor([3])
# find different label at step  155 9 the true is  tensor([3])
# find different label at step  157 9 the true is  tensor([3])
# find different label at step  158 3 the true is  tensor([9])
# find different label at step  160 9 the true is  tensor([3])
# find different label at step  163 9 the true is  tensor([3])
# find different label at step  164 3 the true is  tensor([9])
# find different label at step  171 9 the true is  tensor([3])
# find different label at step  174 3 the true is  tensor([9])
# find different label at step  179 9 the true is  tensor([3])
# find different label at step  181 3 the true is  tensor([9])
# find different label at step  190 9 the true is  tensor([3])
# find different label at step  192 9 the true is  tensor([3])
# find different label at step  193 9 the true is  tensor([3])
# find different label at step  195 9 the true is  tensor([3])
# find different label at step  196 9 the true is  tensor([3])
# find different label at step  198 9 the true is  tensor([3])
# find different label at step  203 9 the true is  tensor([3])
# find different label at step  204 9 the true is  tensor([3])
# find different label at step  205 9 the true is  tensor([3])
# find different label at step  215 9 the true is  tensor([3])
# find different label at step  216 9 the true is  tensor([3])
# find different label at step  217 9 the true is  tensor([3])
# find different label at step  218 3 the true is  tensor([9])
# find different label at step  223 9 the true is  tensor([3])
# find different label at step  225 9 the true is  tensor([3])
# find different label at step  229 9 the true is  tensor([3])
# find different label at step  230 9 the true is  tensor([3])
# find different label at step  235 9 the true is  tensor([3])
# find different label at step  237 9 the true is  tensor([3])
# find different label at step  239 9 the true is  tensor([3])
# find different label at step  241 3 the true is  tensor([9])
# find different label at step  247 3 the true is  tensor([9])
# find different label at step  248 3 the true is  tensor([9])
# find different label at step  273 9 the true is  tensor([3])
# find different label at step  278 9 the true is  tensor([3])
# find different label at step  281 9 the true is  tensor([3])
# find different label at step  283 3 the true is  tensor([9])
# find different label at step  284 9 the true is  tensor([3])
# find different label at step  286 9 the true is  tensor([3])
# find different label at step  290 3 the true is  tensor([9])
# find different label at step  293 9 the true is  tensor([3])
# find different label at step  299 3 the true is  tensor([9])
# find different label at step  300 3 the true is  tensor([9])
# find different label at step  301 3 the true is  tensor([9])
# find different label at step  305 3 the true is  tensor([9])
# find different label at step  307 9 the true is  tensor([3])
# find different label at step  319 9 the true is  tensor([3])
# find different label at step  322 9 the true is  tensor([3])
# find different label at step  323 9 the true is  tensor([3])
# find different label at step  325 9 the true is  tensor([3])
# find different label at step  326 9 the true is  tensor([3])
# find different label at step  331 9 the true is  tensor([3])
# find different label at step  350 9 the true is  tensor([3])
# find different label at step  364 9 the true is  tensor([3])
# find different label at step  370 9 the true is  tensor([3])
# find different label at step  378 9 the true is  tensor([3])
# find different label at step  379 9 the true is  tensor([3])
# find different label at step  380 9 the true is  tensor([3])
# find different label at step  381 9 the true is  tensor([3])
# find different label at step  382 9 the true is  tensor([3])
# find different label at step  389 9 the true is  tensor([3])
# find different label at step  390 9 the true is  tensor([3])
# find different label at step  392 9 the true is  tensor([3])
# find different label at step  395 9 the true is  tensor([3])
# find different label at step  396 9 the true is  tensor([3])
# find different label at step  398 3 the true is  tensor([9])
# find different label at step  402 9 the true is  tensor([3])
# find different label at step  403 9 the true is  tensor([3])
# find different label at step  404 9 the true is  tensor([3])
# find different label at step  406 3 the true is  tensor([9])
# find different label at step  408 3 the true is  tensor([9])
# find different label at step  412 9 the true is  tensor([3])
# find different label at step  416 9 the true is  tensor([3])
# find different label at step  426 9 the true is  tensor([3])
# find different label at step  428 9 the true is  tensor([3])
# find different label at step  436 9 the true is  tensor([3])
# find different label at step  437 9 the true is  tensor([3])
# find different label at step  443 9 the true is  tensor([3])
# find different label at step  473 9 the true is  tensor([3])
# find different label at step  478 3 the true is  tensor([9])
# find different label at step  480 9 the true is  tensor([3])
# find different label at step  482 9 the true is  tensor([3])
# find different label at step  489 9 the true is  tensor([3])
# find different label at step  491 3 the true is  tensor([9])
# find different label at step  492 9 the true is  tensor([3])
# find different label at step  497 9 the true is  tensor([3])
# find different label at step  498 9 the true is  tensor([3])
# find different label at step  499 9 the true is  tensor([3])
# find different label at step  502 9 the true is  tensor([3])
# find different label at step  507 3 the true is  tensor([9])
# find different label at step  509 9 the true is  tensor([3])
# val_acc 0.7313725490196078
# early stopping at timestep 0 0.7313725490196078
# done

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def plot_stats_in_graph(total_losses, y_axis_label, x_axis_label):

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8,4))
    ax_1 = fig_1.add_subplot(111)
    for k in total_losses.keys():
        if "loss" in k:
            ax_1.plot(np.arange(len(total_losses[k])), total_losses[k], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel(x_axis_label)
    ax_1.set_ylabel(y_axis_label)
plot_stats_in_graph(losses, y_axis_label='Loss', x_axis_label='Number of Steps')
plt.savefig('savefig_example_fortotalloss.png')

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
epochs_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylabel('loss')
plt.xlabel('epoch')
plt.ylim(-1.1,1.1)
plt.plot(epochs_list,a.detach().numpy(),label = ['loss for timestep 1','loss for timestep 2','loss for timestep 3','loss for timestep 4','loss for timestep 5'])
plt.legend()
plt.savefig('savefig_example_forloss.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylim(-1.1,1.1)
plt.plot(timesteps_list,a[:,4].detach().numpy(),label = 'loss for timestep 5')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.savefig('savefig_example_forloss_timestep1.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylim(-1.1,1.1)
plt.plot(timesteps_list,a[:,3].detach().numpy(),label = 'loss for timestep 4')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.savefig('savefig_example_forloss_timestep2.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylim(-1.1,1.1)
plt.plot(timesteps_list,a[:,2].detach().numpy(),label = 'loss for timestep 3')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.savefig('savefig_example_forloss_timestep3.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylim(-1.1,1.1)
plt.plot(timesteps_list,a[:,1].detach().numpy(),label = 'loss for timestep 2')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.savefig('savefig_example_forloss_timestep4.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %%
from logging import StringTemplateStyle
# for timestep=9, plot the average loss function for different batchs
timesteps_list=[i for i in range(0,epochs)]
a=loss_batch_average.mean(2)
print(a.shape)
plt.figure()
plt.ylim(-1.1,1.1)
plt.plot(timesteps_list,a[:,0].detach().numpy(),label = 'loss for timestep 1')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.savefig('savefig_example_forloss_timestep5.png')
plt.show()
# Out:
# torch.Size([10, 5])

# %% [markdown]
# ## 测试

# %%
# direct calculate the distance and compare them for original images
batch_size=256
train_dataset1 = torch.utils.data.ConcatDataset([mnist_dataset])# this is label 3
train_loader1 = torch.utils.data.DataLoader(train_dataset1, batch_size=batch_size, shuffle=True,pin_memory=True)
x_=torch.zeros([dataset_image_number,3,32,32])
for step, (images, labels) in enumerate(train_loader1):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    x_[step*batch_size:(step+1)*batch_size,:,:,:]=images
x_general=x_[0].mean(0)
print(x_general.shape)
print(x_.shape)
# Out:
# torch.Size([32, 32])
# torch.Size([256, 3, 32, 32])

# %%
# direct calculate the distance and compare them for original images
batch_size=256
train_dataset2 = torch.utils.data.ConcatDataset([mnist2_dataset])# this is label 2
train_loader2 = torch.utils.data.DataLoader(train_dataset2, batch_size=batch_size, shuffle=True,pin_memory=True)
y_=torch.zeros([dataset_image_number,3,32,32])
for step, (images, labels) in enumerate(train_loader2):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    y_[step*batch_size:(step+1)*batch_size,:,:,:]=images
y_general=y_[0].mean(0)
print(y_general.shape)
print(y_.shape)
# Out:
# torch.Size([32, 32])
# torch.Size([256, 3, 32, 32])

# %%
# direct calculate the distance and compare them for original images
accuaracy=0
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=1, shuffle=True,num_workers=4,pin_memory=True)

with torch.no_grad():
  for step, (image, label) in enumerate(train_loader11):
    batch_size = image.shape[0]
    image = image.to(device)
    x0=image
    a=torch.dot(x_.reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_.reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 3 and pred
    b=torch.dot(y_.reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_.reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 2 and pred2 and pred
    if a >= b:
      pred_label= 3
      #print(a,"and",b)
    else:
      pred_label= 9
      #print(a,"and",b)
    if pred_label==label:
      accuaracy=accuaracy+1
      #print("exact!", pred_label,"the true is ",label)
print(accuaracy/len(train_dataset))
# Out:
# 0.7109375

# %% [markdown]
# This is the test

# %%
# establish the x0,x1,x2,x3,x4 for class 1 label3
batch_size=256
train_dataset1 = torch.utils.data.ConcatDataset([mnist_dataset])# this is label 3
train_loader1 = torch.utils.data.DataLoader(train_dataset1, batch_size=batch_size, shuffle=True,pin_memory=True)
T=torch.full((batch_size,),timesteps-1, device=device)
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
timsteps=5
model.to(device)
x_1=torch.zeros([timesteps,dataset_image_number,3,32,32])
for step, (images, labels) in enumerate(train_loader1):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    x0=images
    for t in range(timesteps-1,-1,-1):
      time = torch.full((batch_size,),t, device=device).long()
      # this is label 3
      model.load_state_dict(model_parameters[t],strict=True)
      model.eval()
      time=torch.full((batch_size,),t, device=device)
      x0=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(x0, time))
      x_1[t,step*batch_size:(step+1)*batch_size,:,:,:]=x0
x_1_general=x_1[0].mean(0)
print(x_1_general.shape)
print(x_1.shape)
# Out:
# torch.Size([3, 32, 32])
# torch.Size([5, 256, 3, 32, 32])

# %%
# establish the x0,x1,x2,x3,x4 for class 2 label 2
batch_size=256
train_dataset2 = torch.utils.data.ConcatDataset([mnist2_dataset])# this is label 2
train_loader2 = torch.utils.data.DataLoader(train_dataset2, batch_size=batch_size, shuffle=True,pin_memory=True)
T=torch.full((batch_size,),timesteps-1, device=device)
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)
x_2=torch.zeros([timesteps,dataset_image_number,3,32,32])
for step, (images, labels) in enumerate(train_loader2):
  with torch.no_grad():
    batch_size = images.shape[0]
    images = images.to(device)
    x0=images
    for t in range(timesteps-1,-1,-1):
      time = torch.full((batch_size,),t, device=device).long()
      # this is label 3
      model.load_state_dict(model_parameters[t],strict=True)
      model.eval()
      time=torch.full((batch_size,),t, device=device)
      x0=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(x0, time))
      x_2[t,step*batch_size:(step+1)*batch_size,:,:,:]=x0

x_2_general=x_2[0].mean(0)
print(x_2_general.shape)
print(x_2.shape)
# Out:
# torch.Size([3, 32, 32])
# torch.Size([5, 256, 3, 32, 32])

# %%
#calculate the mean distance and variances within differenct class
for t in range(timesteps-1,-1,-1):
  innerproduct=torch.dot(x_1[t].reshape(256,3*32*32).mean(0).to(device) / torch.norm(x_1[t].reshape(256,3*32*32).mean(0)).to(device), x_2[t].reshape(256,3*32*32).mean(0).to(device) / torch.norm(x_2[t].reshape(256,3*32*32).mean(0)).to(device)).to(device).mean(0)
  print("inner product",innerproduct)
  m1=x_1[t].reshape(batch_size,3*32*32)
  m2=x_2[t].reshape(batch_size,3*32*32)

  s1=torch.var(m1, dim=0)
  s2=torch.var(m2, dim=0)
  print("variance",s1.mean(0),s2.mean(0))
# Out:
# inner product tensor(0.1266, device='cuda:0')
# variance tensor(0.1786) tensor(0.1060)
# inner product tensor(-0.5827, device='cuda:0')
# variance tensor(0.2676) tensor(0.1149)
# inner product tensor(-0.5156, device='cuda:0')
# variance tensor(0.3174) tensor(0.1185)
# inner product tensor(-0.9463, device='cuda:0')
# variance tensor(0.3397) tensor(0.1168)
# inner product tensor(-0.2314, device='cuda:0')
# variance tensor(0.3511) tensor(0.1169)

# %%
accuaracy=0
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=1, shuffle=True,num_workers=4,pin_memory=True)
acc=torch.zeros(timesteps)

with torch.no_grad():
  for step, (image, label) in enumerate(train_loader11):
    batch_size = image.shape[0]
    image = image.to(device)
    x0=image
    for t in range(timesteps-1,-1,-1):

      model.load_state_dict(model_parameters[t],strict=True)
      model.eval()
      time=torch.full((batch_size,),t, device=device)
      x0=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(x0, time))
      a=torch.dot(x_1[t].reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_1[t].reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 3 and pred
      b=torch.dot(x_2[t].reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_2[t].reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 2 and pred distance between 2 and pred
      if a >= b:
        pred_label= 3
        print(a,"and",b)
      else:
        pred_label= 9
        #print(a,"and",b)
        #print(pred_label,label)
      if pred_label==label:
        acc[t]=acc[t]+1
      #print("exact!", pred_label,"the true is ",label)
      else:
        print("timestep", t, " find different label at step ", step, pred_label,"the true is ",label)
# Out:
# tensor(0.1546, device='cuda:0') and tensor(-0.9031, device='cuda:0')
# tensor(0.5978, device='cuda:0') and tensor(-0.9924, device='cuda:0')
# tensor(0.4615, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# tensor(0.9502, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# tensor(0.3062, device='cuda:0') and tensor(-0.9920, device='cuda:0')
# tensor(0.3816, device='cuda:0') and tensor(-0.8092, device='cuda:0')
# tensor(0.6339, device='cuda:0') and tensor(-0.9791, device='cuda:0')
# tensor(0.5429, device='cuda:0') and tensor(-0.9910, device='cuda:0')
# tensor(0.9637, device='cuda:0') and tensor(-0.9912, device='cuda:0')
# tensor(0.3286, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.1179, device='cuda:0') and tensor(-0.9583, device='cuda:0')
# tensor(0.5963, device='cuda:0') and tensor(-0.9965, device='cuda:0')
# tensor(0.4818, device='cuda:0') and tensor(-0.9951, device='cuda:0')
# tensor(0.9547, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.3128, device='cuda:0') and tensor(-0.9923, device='cuda:0')
# timestep 4  find different label at step  4 9 the true is  tensor([3])
# timestep 3  find different label at step  4 9 the true is  tensor([3])
# timestep 2  find different label at step  4 9 the true is  tensor([3])
# timestep 1  find different label at step  4 9 the true is  tensor([3])
# timestep 0  find different label at step  4 9 the true is  tensor([3])
# timestep 4  find different label at step  6 9 the true is  tensor([3])
# timestep 3  find different label at step  6 9 the true is  tensor([3])
# timestep 2  find different label at step  6 9 the true is  tensor([3])
# timestep 1  find different label at step  6 9 the true is  tensor([3])
# timestep 0  find different label at step  6 9 the true is  tensor([3])
# tensor(0.4546, device='cuda:0') and tensor(-0.6994, device='cuda:0')
# tensor(0.6904, device='cuda:0') and tensor(-0.9557, device='cuda:0')
# tensor(0.4881, device='cuda:0') and tensor(-0.9893, device='cuda:0')
# tensor(0.9575, device='cuda:0') and tensor(-0.9943, device='cuda:0')
# tensor(0.3199, device='cuda:0') and tensor(-0.9914, device='cuda:0')
# timestep 4  find different label at step  9 9 the true is  tensor([3])
# timestep 3  find different label at step  9 9 the true is  tensor([3])
# timestep 2  find different label at step  9 9 the true is  tensor([3])
# timestep 1  find different label at step  9 9 the true is  tensor([3])
# timestep 0  find different label at step  9 9 the true is  tensor([3])
# tensor(0.3291, device='cuda:0') and tensor(-0.7441, device='cuda:0')
# tensor(0.6497, device='cuda:0') and tensor(-0.9563, device='cuda:0')
# tensor(0.5469, device='cuda:0') and tensor(-0.9895, device='cuda:0')
# tensor(0.9618, device='cuda:0') and tensor(-0.9914, device='cuda:0')
# tensor(0.3202, device='cuda:0') and tensor(-0.9928, device='cuda:0')
# tensor(0.6097, device='cuda:0') and tensor(0.2948, device='cuda:0')
# tensor(0.6376, device='cuda:0') and tensor(-0.1892, device='cuda:0')
# tensor(0.5943, device='cuda:0') and tensor(-0.5539, device='cuda:0')
# tensor(0.8137, device='cuda:0') and tensor(-0.7688, device='cuda:0')
# tensor(0.2116, device='cuda:0') and tensor(-0.9344, device='cuda:0')
# timestep 4  find different label at step  15 9 the true is  tensor([3])
# timestep 3  find different label at step  15 9 the true is  tensor([3])
# timestep 2  find different label at step  15 9 the true is  tensor([3])
# timestep 1  find different label at step  15 9 the true is  tensor([3])
# timestep 0  find different label at step  15 9 the true is  tensor([3])
# tensor(0.3869, device='cuda:0') and tensor(-0.7301, device='cuda:0')
# tensor(0.6099, device='cuda:0') and tensor(-0.9656, device='cuda:0')
# tensor(0.4625, device='cuda:0') and tensor(-0.9865, device='cuda:0')
# tensor(0.9432, device='cuda:0') and tensor(-0.9913, device='cuda:0')
# tensor(0.2934, device='cuda:0') and tensor(-0.9916, device='cuda:0')
# timestep 4  find different label at step  18 9 the true is  tensor([3])
# timestep 3  find different label at step  18 9 the true is  tensor([3])
# timestep 2  find different label at step  18 9 the true is  tensor([3])
# timestep 1  find different label at step  18 9 the true is  tensor([3])
# timestep 0  find different label at step  18 9 the true is  tensor([3])
# tensor(0.6354, device='cuda:0') and tensor(-0.3317, device='cuda:0')
# tensor(0.7488, device='cuda:0') and tensor(-0.8254, device='cuda:0')
# tensor(0.6313, device='cuda:0') and tensor(-0.9468, device='cuda:0')
# tensor(0.9749, device='cuda:0') and tensor(-0.9782, device='cuda:0')
# tensor(0.3542, device='cuda:0') and tensor(-0.9883, device='cuda:0')
# tensor(0.5423, device='cuda:0') and tensor(0.0548, device='cuda:0')
# tensor(0.4584, device='cuda:0') and tensor(-0.1603, device='cuda:0')
# tensor(0.5897, device='cuda:0') and tensor(-0.0910, device='cuda:0')
# tensor(0.4112, device='cuda:0') and tensor(-0.2286, device='cuda:0')
# tensor(0.4831, device='cuda:0') and tensor(-0.1193, device='cuda:0')
# timestep 4  find different label at step  27 9 the true is  tensor([3])
# timestep 3  find different label at step  27 9 the true is  tensor([3])
# timestep 2  find different label at step  27 9 the true is  tensor([3])
# timestep 1  find different label at step  27 9 the true is  tensor([3])
# timestep 0  find different label at step  27 9 the true is  tensor([3])
# tensor(0.5256, device='cuda:0') and tensor(0.2313, device='cuda:0')
# tensor(0.3264, device='cuda:0') and tensor(-0.1031, device='cuda:0')
# tensor(0.1643, device='cuda:0') and tensor(-0.0995, device='cuda:0')
# tensor(0.2632, device='cuda:0') and tensor(-0.3614, device='cuda:0')
# tensor(-0.2119, device='cuda:0') and tensor(-0.4860, device='cuda:0')
# tensor(0.6816, device='cuda:0') and tensor(0.2933, device='cuda:0')
# timestep 3  find different label at step  29 9 the true is  tensor([3])
# timestep 2  find different label at step  29 9 the true is  tensor([3])
# timestep 1  find different label at step  29 9 the true is  tensor([3])
# timestep 0  find different label at step  29 9 the true is  tensor([3])
# tensor(0.2288, device='cuda:0') and tensor(-0.9058, device='cuda:0')
# tensor(0.6266, device='cuda:0') and tensor(-0.9968, device='cuda:0')
# tensor(0.4850, device='cuda:0') and tensor(-0.9953, device='cuda:0')
# tensor(0.9563, device='cuda:0') and tensor(-0.9934, device='cuda:0')
# tensor(0.3165, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# timestep 4  find different label at step  33 9 the true is  tensor([3])
# timestep 3  find different label at step  33 9 the true is  tensor([3])
# timestep 2  find different label at step  33 9 the true is  tensor([3])
# timestep 1  find different label at step  33 9 the true is  tensor([3])
# timestep 0  find different label at step  33 9 the true is  tensor([3])
# tensor(0.6501, device='cuda:0') and tensor(0.4026, device='cuda:0')
# timestep 3  find different label at step  34 9 the true is  tensor([3])
# timestep 2  find different label at step  34 9 the true is  tensor([3])
# timestep 1  find different label at step  34 9 the true is  tensor([3])
# timestep 0  find different label at step  34 9 the true is  tensor([3])
# timestep 4  find different label at step  39 9 the true is  tensor([3])
# timestep 3  find different label at step  39 9 the true is  tensor([3])
# timestep 2  find different label at step  39 9 the true is  tensor([3])
# timestep 1  find different label at step  39 9 the true is  tensor([3])
# timestep 0  find different label at step  39 9 the true is  tensor([3])
# tensor(0.3132, device='cuda:0') and tensor(-0.8382, device='cuda:0')
# tensor(0.6251, device='cuda:0') and tensor(-0.9943, device='cuda:0')
# tensor(0.4808, device='cuda:0') and tensor(-0.9953, device='cuda:0')
# tensor(0.9560, device='cuda:0') and tensor(-0.9935, device='cuda:0')
# tensor(0.3158, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.4855, device='cuda:0') and tensor(0.3951, device='cuda:0')
# timestep 3  find different label at step  41 9 the true is  tensor([3])
# timestep 2  find different label at step  41 9 the true is  tensor([3])
# timestep 1  find different label at step  41 9 the true is  tensor([3])
# timestep 0  find different label at step  41 9 the true is  tensor([3])
# tensor(0.4869, device='cuda:0') and tensor(-0.6609, device='cuda:0')
# tensor(0.6547, device='cuda:0') and tensor(-0.9845, device='cuda:0')
# tensor(0.4912, device='cuda:0') and tensor(-0.9955, device='cuda:0')
# tensor(0.9569, device='cuda:0') and tensor(-0.9934, device='cuda:0')
# tensor(0.3164, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# timestep 4  find different label at step  45 9 the true is  tensor([3])
# timestep 3  find different label at step  45 9 the true is  tensor([3])
# timestep 2  find different label at step  45 9 the true is  tensor([3])
# timestep 1  find different label at step  45 9 the true is  tensor([3])
# timestep 0  find different label at step  45 9 the true is  tensor([3])
# tensor(0.4082, device='cuda:0') and tensor(-0.7643, device='cuda:0')
# tensor(0.6673, device='cuda:0') and tensor(-0.9851, device='cuda:0')
# tensor(0.4859, device='cuda:0') and tensor(-0.9937, device='cuda:0')
# tensor(0.9585, device='cuda:0') and tensor(-0.9935, device='cuda:0')
# tensor(0.3214, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.6105, device='cuda:0') and tensor(-0.3682, device='cuda:0')
# tensor(0.7270, device='cuda:0') and tensor(-0.8974, device='cuda:0')
# tensor(0.5565, device='cuda:0') and tensor(-0.9842, device='cuda:0')
# tensor(0.9628, device='cuda:0') and tensor(-0.9909, device='cuda:0')
# tensor(0.3218, device='cuda:0') and tensor(-0.9928, device='cuda:0')
# tensor(0.4668, device='cuda:0') and tensor(-0.7084, device='cuda:0')
# tensor(0.6812, device='cuda:0') and tensor(-0.9776, device='cuda:0')
# tensor(0.4768, device='cuda:0') and tensor(-0.9933, device='cuda:0')
# tensor(0.9564, device='cuda:0') and tensor(-0.9941, device='cuda:0')
# tensor(0.3178, device='cuda:0') and tensor(-0.9918, device='cuda:0')
# timestep 4  find different label at step  52 9 the true is  tensor([3])
# timestep 3  find different label at step  52 9 the true is  tensor([3])
# timestep 2  find different label at step  52 9 the true is  tensor([3])
# timestep 1  find different label at step  52 9 the true is  tensor([3])
# timestep 0  find different label at step  52 9 the true is  tensor([3])
# tensor(0.4521, device='cuda:0') and tensor(0.0974, device='cuda:0')
# tensor(0.6068, device='cuda:0') and tensor(-0.3873, device='cuda:0')
# tensor(0.5389, device='cuda:0') and tensor(-0.7317, device='cuda:0')
# tensor(0.8706, device='cuda:0') and tensor(-0.8825, device='cuda:0')
# tensor(0.2050, device='cuda:0') and tensor(-0.9613, device='cuda:0')
# tensor(0.6362, device='cuda:0') and tensor(-0.0117, device='cuda:0')
# tensor(0.5707, device='cuda:0') and tensor(-0.2076, device='cuda:0')
# tensor(0.6975, device='cuda:0') and tensor(-0.2228, device='cuda:0')
# tensor(0.5393, device='cuda:0') and tensor(-0.3737, device='cuda:0')
# tensor(0.4827, device='cuda:0') and tensor(-0.3435, device='cuda:0')
# timestep 4  find different label at step  55 9 the true is  tensor([3])
# timestep 3  find different label at step  55 9 the true is  tensor([3])
# timestep 2  find different label at step  55 9 the true is  tensor([3])
# timestep 1  find different label at step  55 9 the true is  tensor([3])
# timestep 0  find different label at step  55 9 the true is  tensor([3])
# tensor(0.1329, device='cuda:0') and tensor(-0.9540, device='cuda:0')
# tensor(0.6142, device='cuda:0') and tensor(-0.9969, device='cuda:0')
# tensor(0.4935, device='cuda:0') and tensor(-0.9953, device='cuda:0')
# tensor(0.9580, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# tensor(0.3188, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.4495, device='cuda:0') and tensor(-0.6225, device='cuda:0')
# tensor(0.7216, device='cuda:0') and tensor(-0.9280, device='cuda:0')
# tensor(0.5505, device='cuda:0') and tensor(-0.9891, device='cuda:0')
# tensor(0.9652, device='cuda:0') and tensor(-0.9913, device='cuda:0')
# tensor(0.3282, device='cuda:0') and tensor(-0.9923, device='cuda:0')
# timestep 4  find different label at step  60 9 the true is  tensor([3])
# timestep 3  find different label at step  60 9 the true is  tensor([3])
# timestep 2  find different label at step  60 9 the true is  tensor([3])
# timestep 1  find different label at step  60 9 the true is  tensor([3])
# timestep 0  find different label at step  60 9 the true is  tensor([3])
# tensor(0.8133, device='cuda:0') and tensor(0.4854, device='cuda:0')
# timestep 4  find different label at step  62 3 the true is  tensor([9])
# tensor(0.7200, device='cuda:0') and tensor(-0.2930, device='cuda:0')
# tensor(0.7305, device='cuda:0') and tensor(-0.8792, device='cuda:0')
# tensor(0.5029, device='cuda:0') and tensor(-0.9813, device='cuda:0')
# tensor(0.9484, device='cuda:0') and tensor(-0.9904, device='cuda:0')
# tensor(0.2951, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# timestep 4  find different label at step  66 9 the true is  tensor([3])
# timestep 3  find different label at step  66 9 the true is  tensor([3])
# timestep 2  find different label at step  66 9 the true is  tensor([3])
# timestep 1  find different label at step  66 9 the true is  tensor([3])
# timestep 0  find different label at step  66 9 the true is  tensor([3])
# timestep 4  find different label at step  68 9 the true is  tensor([3])
# timestep 3  find different label at step  68 9 the true is  tensor([3])
# timestep 2  find different label at step  68 9 the true is  tensor([3])
# timestep 1  find different label at step  68 9 the true is  tensor([3])
# timestep 0  find different label at step  68 9 the true is  tensor([3])
# tensor(0.5690, device='cuda:0') and tensor(-0.5623, device='cuda:0')
# tensor(0.6952, device='cuda:0') and tensor(-0.9392, device='cuda:0')
# tensor(0.5832, device='cuda:0') and tensor(-0.9818, device='cuda:0')
# tensor(0.9678, device='cuda:0') and tensor(-0.9887, device='cuda:0')
# tensor(0.3342, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.5887, device='cuda:0') and tensor(-0.5054, device='cuda:0')
# tensor(0.6422, device='cuda:0') and tensor(-0.9533, device='cuda:0')
# tensor(0.4695, device='cuda:0') and tensor(-0.9871, device='cuda:0')
# tensor(0.9451, device='cuda:0') and tensor(-0.9915, device='cuda:0')
# tensor(0.2947, device='cuda:0') and tensor(-0.9918, device='cuda:0')
# tensor(0.5182, device='cuda:0') and tensor(-0.4580, device='cuda:0')
# tensor(0.7571, device='cuda:0') and tensor(-0.8320, device='cuda:0')
# tensor(0.6233, device='cuda:0') and tensor(-0.9544, device='cuda:0')
# tensor(0.9749, device='cuda:0') and tensor(-0.9808, device='cuda:0')
# tensor(0.3499, device='cuda:0') and tensor(-0.9893, device='cuda:0')
# tensor(0.6805, device='cuda:0') and tensor(-0.1682, device='cuda:0')
# timestep 4  find different label at step  73 3 the true is  tensor([9])
# tensor(0.5890, device='cuda:0') and tensor(-0.6881, device='cuda:0')
# timestep 3  find different label at step  73 3 the true is  tensor([9])
# tensor(0.3928, device='cuda:0') and tensor(-0.8617, device='cuda:0')
# timestep 2  find different label at step  73 3 the true is  tensor([9])
# tensor(0.8880, device='cuda:0') and tensor(-0.9735, device='cuda:0')
# timestep 1  find different label at step  73 3 the true is  tensor([9])
# tensor(0.2619, device='cuda:0') and tensor(-0.9857, device='cuda:0')
# timestep 0  find different label at step  73 3 the true is  tensor([9])
# tensor(0.5016, device='cuda:0') and tensor(-0.2763, device='cuda:0')
# tensor(0.5573, device='cuda:0') and tensor(-0.7805, device='cuda:0')
# tensor(0.3561, device='cuda:0') and tensor(-0.9081, device='cuda:0')
# tensor(0.8872, device='cuda:0') and tensor(-0.9638, device='cuda:0')
# tensor(0.2296, device='cuda:0') and tensor(-0.9814, device='cuda:0')
# tensor(0.6174, device='cuda:0') and tensor(0.2615, device='cuda:0')
# timestep 3  find different label at step  76 9 the true is  tensor([3])
# timestep 2  find different label at step  76 9 the true is  tensor([3])
# timestep 1  find different label at step  76 9 the true is  tensor([3])
# timestep 0  find different label at step  76 9 the true is  tensor([3])
# timestep 4  find different label at step  78 9 the true is  tensor([3])
# timestep 3  find different label at step  78 9 the true is  tensor([3])
# timestep 2  find different label at step  78 9 the true is  tensor([3])
# timestep 1  find different label at step  78 9 the true is  tensor([3])
# timestep 0  find different label at step  78 9 the true is  tensor([3])
# tensor(0.2162, device='cuda:0') and tensor(-0.9097, device='cuda:0')
# tensor(0.6107, device='cuda:0') and tensor(-0.9965, device='cuda:0')
# tensor(0.4726, device='cuda:0') and tensor(-0.9948, device='cuda:0')
# tensor(0.9536, device='cuda:0') and tensor(-0.9934, device='cuda:0')
# tensor(0.3115, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.4725, device='cuda:0') and tensor(-0.5155, device='cuda:0')
# tensor(0.7124, device='cuda:0') and tensor(-0.7812, device='cuda:0')
# tensor(0.6663, device='cuda:0') and tensor(-0.9040, device='cuda:0')
# tensor(0.9758, device='cuda:0') and tensor(-0.9656, device='cuda:0')
# tensor(0.3716, device='cuda:0') and tensor(-0.9829, device='cuda:0')
# tensor(0.3864, device='cuda:0') and tensor(-0.8434, device='cuda:0')
# tensor(0.6218, device='cuda:0') and tensor(-0.9952, device='cuda:0')
# tensor(0.4951, device='cuda:0') and tensor(-0.9956, device='cuda:0')
# tensor(0.9567, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# tensor(0.3160, device='cuda:0') and tensor(-0.9923, device='cuda:0')
# tensor(0.0635, device='cuda:0') and tensor(-0.9729, device='cuda:0')
# tensor(0.5987, device='cuda:0') and tensor(-0.9971, device='cuda:0')
# tensor(0.4819, device='cuda:0') and tensor(-0.9952, device='cuda:0')
# tensor(0.9551, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.3135, device='cuda:0') and tensor(-0.9923, device='cuda:0')
# timestep 4  find different label at step  83 9 the true is  tensor([3])
# timestep 3  find different label at step  83 9 the true is  tensor([3])
# timestep 2  find different label at step  83 9 the true is  tensor([3])
# timestep 1  find different label at step  83 9 the true is  tensor([3])
# timestep 0  find different label at step  83 9 the true is  tensor([3])
# tensor(0.6525, device='cuda:0') and tensor(-0.3054, device='cuda:0')
# tensor(0.7475, device='cuda:0') and tensor(-0.7678, device='cuda:0')
# tensor(0.6873, device='cuda:0') and tensor(-0.9199, device='cuda:0')
# tensor(0.9761, device='cuda:0') and tensor(-0.9738, device='cuda:0')
# tensor(0.3608, device='cuda:0') and tensor(-0.9859, device='cuda:0')
# timestep 4  find different label at step  86 9 the true is  tensor([3])
# timestep 3  find different label at step  86 9 the true is  tensor([3])
# timestep 2  find different label at step  86 9 the true is  tensor([3])
# timestep 1  find different label at step  86 9 the true is  tensor([3])
# timestep 0  find different label at step  86 9 the true is  tensor([3])
# tensor(0.5784, device='cuda:0') and tensor(-0.5008, device='cuda:0')
# tensor(0.7588, device='cuda:0') and tensor(-0.8795, device='cuda:0')
# tensor(0.6098, device='cuda:0') and tensor(-0.9731, device='cuda:0')
# tensor(0.9717, device='cuda:0') and tensor(-0.9865, device='cuda:0')
# tensor(0.3402, device='cuda:0') and tensor(-0.9909, device='cuda:0')
# tensor(0.2378, device='cuda:0') and tensor(-0.9048, device='cuda:0')
# tensor(0.6173, device='cuda:0') and tensor(-0.9933, device='cuda:0')
# tensor(0.5088, device='cuda:0') and tensor(-0.9949, device='cuda:0')
# tensor(0.9600, device='cuda:0') and tensor(-0.9927, device='cuda:0')
# tensor(0.3216, device='cuda:0') and tensor(-0.9923, device='cuda:0')
# tensor(0.6927, device='cuda:0') and tensor(0.4401, device='cuda:0')
# timestep 3  find different label at step  90 9 the true is  tensor([3])
# timestep 2  find different label at step  90 9 the true is  tensor([3])
# timestep 1  find different label at step  90 9 the true is  tensor([3])
# timestep 0  find different label at step  90 9 the true is  tensor([3])
# timestep 4  find different label at step  93 9 the true is  tensor([3])
# timestep 3  find different label at step  93 9 the true is  tensor([3])
# timestep 2  find different label at step  93 9 the true is  tensor([3])
# timestep 1  find different label at step  93 9 the true is  tensor([3])
# timestep 0  find different label at step  93 9 the true is  tensor([3])
# tensor(0.2449, device='cuda:0') and tensor(-0.9111, device='cuda:0')
# tensor(0.6122, device='cuda:0') and tensor(-0.9971, device='cuda:0')
# tensor(0.4875, device='cuda:0') and tensor(-0.9954, device='cuda:0')
# tensor(0.9563, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.3156, device='cuda:0') and tensor(-0.9923, device='cuda:0')
# tensor(0.4435, device='cuda:0') and tensor(-0.2675, device='cuda:0')
# tensor(0.5884, device='cuda:0') and tensor(-0.7625, device='cuda:0')
# tensor(0.4150, device='cuda:0') and tensor(-0.9288, device='cuda:0')
# tensor(0.9085, device='cuda:0') and tensor(-0.9765, device='cuda:0')
# tensor(0.2491, device='cuda:0') and tensor(-0.9858, device='cuda:0')
# tensor(0.5524, device='cuda:0') and tensor(-0.6090, device='cuda:0')
# tensor(0.7008, device='cuda:0') and tensor(-0.9604, device='cuda:0')
# tensor(0.5395, device='cuda:0') and tensor(-0.9930, device='cuda:0')
# tensor(0.9619, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.3213, device='cuda:0') and tensor(-0.9927, device='cuda:0')
# timestep 4  find different label at step  98 9 the true is  tensor([3])
# timestep 3  find different label at step  98 9 the true is  tensor([3])
# timestep 2  find different label at step  98 9 the true is  tensor([3])
# timestep 1  find different label at step  98 9 the true is  tensor([3])
# timestep 0  find different label at step  98 9 the true is  tensor([3])
# tensor(0.5355, device='cuda:0') and tensor(-0.5764, device='cuda:0')
# tensor(0.6677, device='cuda:0') and tensor(-0.9366, device='cuda:0')
# tensor(0.4356, device='cuda:0') and tensor(-0.9854, device='cuda:0')
# tensor(0.9486, device='cuda:0') and tensor(-0.9946, device='cuda:0')
# tensor(0.3098, device='cuda:0') and tensor(-0.9912, device='cuda:0')
# timestep 4  find different label at step  100 9 the true is  tensor([3])
# timestep 3  find different label at step  100 9 the true is  tensor([3])
# timestep 2  find different label at step  100 9 the true is  tensor([3])
# timestep 1  find different label at step  100 9 the true is  tensor([3])
# timestep 0  find different label at step  100 9 the true is  tensor([3])
# tensor(0.3875, device='cuda:0') and tensor(-0.6402, device='cuda:0')
# timestep 4  find different label at step  101 3 the true is  tensor([9])
# tensor(0.6630, device='cuda:0') and tensor(-0.9193, device='cuda:0')
# timestep 3  find different label at step  101 3 the true is  tensor([9])
# tensor(0.5470, device='cuda:0') and tensor(-0.9795, device='cuda:0')
# timestep 2  find different label at step  101 3 the true is  tensor([9])
# tensor(0.9577, device='cuda:0') and tensor(-0.9902, device='cuda:0')
# timestep 1  find different label at step  101 3 the true is  tensor([9])
# tensor(0.3078, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# timestep 0  find different label at step  101 3 the true is  tensor([9])
# tensor(0.3797, device='cuda:0') and tensor(0.0951, device='cuda:0')
# tensor(0.3646, device='cuda:0') and tensor(-0.0836, device='cuda:0')
# tensor(0.4730, device='cuda:0') and tensor(0.0499, device='cuda:0')
# tensor(0.2824, device='cuda:0') and tensor(-0.0782, device='cuda:0')
# tensor(0.4572, device='cuda:0') and tensor(0.0715, device='cuda:0')
# timestep 4  find different label at step  106 9 the true is  tensor([3])
# timestep 3  find different label at step  106 9 the true is  tensor([3])
# timestep 2  find different label at step  106 9 the true is  tensor([3])
# timestep 1  find different label at step  106 9 the true is  tensor([3])
# timestep 0  find different label at step  106 9 the true is  tensor([3])
# tensor(0.5296, device='cuda:0') and tensor(0.1220, device='cuda:0')
# timestep 4  find different label at step  108 3 the true is  tensor([9])
# tensor(0.4044, device='cuda:0') and tensor(0.0141, device='cuda:0')
# timestep 3  find different label at step  108 3 the true is  tensor([9])
# tensor(0.4147, device='cuda:0') and tensor(0.1773, device='cuda:0')
# timestep 2  find different label at step  108 3 the true is  tensor([9])
# tensor(0.1159, device='cuda:0') and tensor(0.1001, device='cuda:0')
# timestep 1  find different label at step  108 3 the true is  tensor([9])
# tensor(0.4010, device='cuda:0') and tensor(0.2608, device='cuda:0')
# timestep 0  find different label at step  108 3 the true is  tensor([9])
# tensor(0.6062, device='cuda:0') and tensor(0.2367, device='cuda:0')
# tensor(0.3923, device='cuda:0') and tensor(0.1196, device='cuda:0')
# tensor(0.3943, device='cuda:0') and tensor(0.2395, device='cuda:0')
# timestep 1  find different label at step  109 9 the true is  tensor([3])
# tensor(0.3738, device='cuda:0') and tensor(0.3261, device='cuda:0')
# tensor(0.4169, device='cuda:0') and tensor(-0.7602, device='cuda:0')
# timestep 4  find different label at step  110 3 the true is  tensor([9])
# tensor(0.6412, device='cuda:0') and tensor(-0.9784, device='cuda:0')
# timestep 3  find different label at step  110 3 the true is  tensor([9])
# tensor(0.5417, device='cuda:0') and tensor(-0.9917, device='cuda:0')
# timestep 2  find different label at step  110 3 the true is  tensor([9])
# tensor(0.9631, device='cuda:0') and tensor(-0.9914, device='cuda:0')
# timestep 1  find different label at step  110 3 the true is  tensor([9])
# tensor(0.3263, device='cuda:0') and tensor(-0.9924, device='cuda:0')
# timestep 0  find different label at step  110 3 the true is  tensor([9])
# tensor(0.1714, device='cuda:0') and tensor(-0.8989, device='cuda:0')
# tensor(0.6384, device='cuda:0') and tensor(-0.9860, device='cuda:0')
# tensor(0.5213, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.9628, device='cuda:0') and tensor(-0.9920, device='cuda:0')
# tensor(0.3285, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# timestep 4  find different label at step  112 9 the true is  tensor([3])
# timestep 3  find different label at step  112 9 the true is  tensor([3])
# timestep 2  find different label at step  112 9 the true is  tensor([3])
# timestep 1  find different label at step  112 9 the true is  tensor([3])
# timestep 0  find different label at step  112 9 the true is  tensor([3])
# timestep 4  find different label at step  115 9 the true is  tensor([3])
# timestep 3  find different label at step  115 9 the true is  tensor([3])
# timestep 2  find different label at step  115 9 the true is  tensor([3])
# timestep 1  find different label at step  115 9 the true is  tensor([3])
# timestep 0  find different label at step  115 9 the true is  tensor([3])
# tensor(0.1189, device='cuda:0') and tensor(-0.9339, device='cuda:0')
# tensor(0.6310, device='cuda:0') and tensor(-0.9892, device='cuda:0')
# tensor(0.5172, device='cuda:0') and tensor(-0.9931, device='cuda:0')
# tensor(0.9620, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.3266, device='cuda:0') and tensor(-0.9920, device='cuda:0')
# timestep 4  find different label at step  117 9 the true is  tensor([3])
# timestep 3  find different label at step  117 9 the true is  tensor([3])
# timestep 2  find different label at step  117 9 the true is  tensor([3])
# timestep 1  find different label at step  117 9 the true is  tensor([3])
# timestep 0  find different label at step  117 9 the true is  tensor([3])
# timestep 4  find different label at step  125 9 the true is  tensor([3])
# timestep 3  find different label at step  125 9 the true is  tensor([3])
# timestep 2  find different label at step  125 9 the true is  tensor([3])
# timestep 1  find different label at step  125 9 the true is  tensor([3])
# timestep 0  find different label at step  125 9 the true is  tensor([3])
# tensor(0.5902, device='cuda:0') and tensor(0.5728, device='cuda:0')
# timestep 4  find different label at step  126 3 the true is  tensor([9])
# tensor(0.5133, device='cuda:0') and tensor(-0.7302, device='cuda:0')
# tensor(0.6729, device='cuda:0') and tensor(-0.9814, device='cuda:0')
# tensor(0.5235, device='cuda:0') and tensor(-0.9916, device='cuda:0')
# tensor(0.9634, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.3296, device='cuda:0') and tensor(-0.9918, device='cuda:0')
# timestep 4  find different label at step  129 9 the true is  tensor([3])
# timestep 3  find different label at step  129 9 the true is  tensor([3])
# timestep 2  find different label at step  129 9 the true is  tensor([3])
# timestep 1  find different label at step  129 9 the true is  tensor([3])
# timestep 0  find different label at step  129 9 the true is  tensor([3])
# tensor(0.7879, device='cuda:0') and tensor(-0.3883, device='cuda:0')
# tensor(0.7042, device='cuda:0') and tensor(-0.9700, device='cuda:0')
# tensor(0.4662, device='cuda:0') and tensor(-0.9943, device='cuda:0')
# tensor(0.9525, device='cuda:0') and tensor(-0.9939, device='cuda:0')
# tensor(0.3115, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.3476, device='cuda:0') and tensor(0.2527, device='cuda:0')
# tensor(0.4418, device='cuda:0') and tensor(0.1029, device='cuda:0')
# tensor(0.4064, device='cuda:0') and tensor(0.2116, device='cuda:0')
# timestep 1  find different label at step  132 9 the true is  tensor([3])
# timestep 0  find different label at step  132 9 the true is  tensor([3])
# tensor(0.2621, device='cuda:0') and tensor(-0.9011, device='cuda:0')
# tensor(0.6234, device='cuda:0') and tensor(-0.9972, device='cuda:0')
# tensor(0.4795, device='cuda:0') and tensor(-0.9953, device='cuda:0')
# tensor(0.9555, device='cuda:0') and tensor(-0.9934, device='cuda:0')
# tensor(0.3149, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.4502, device='cuda:0') and tensor(0.2448, device='cuda:0')
# timestep 4  find different label at step  141 3 the true is  tensor([9])
# tensor(0.5922, device='cuda:0') and tensor(-0.2044, device='cuda:0')
# timestep 3  find different label at step  141 3 the true is  tensor([9])
# tensor(0.5653, device='cuda:0') and tensor(-0.5233, device='cuda:0')
# timestep 2  find different label at step  141 3 the true is  tensor([9])
# tensor(0.8034, device='cuda:0') and tensor(-0.7508, device='cuda:0')
# timestep 1  find different label at step  141 3 the true is  tensor([9])
# tensor(0.2282, device='cuda:0') and tensor(-0.9222, device='cuda:0')
# timestep 0  find different label at step  141 3 the true is  tensor([9])
# tensor(0.5637, device='cuda:0') and tensor(-0.4964, device='cuda:0')
# tensor(0.6259, device='cuda:0') and tensor(-0.9299, device='cuda:0')
# tensor(0.4089, device='cuda:0') and tensor(-0.9787, device='cuda:0')
# tensor(0.9361, device='cuda:0') and tensor(-0.9917, device='cuda:0')
# tensor(0.2898, device='cuda:0') and tensor(-0.9906, device='cuda:0')
# tensor(0.2062, device='cuda:0') and tensor(-0.8823, device='cuda:0')
# tensor(0.5876, device='cuda:0') and tensor(-0.9828, device='cuda:0')
# tensor(0.4772, device='cuda:0') and tensor(-0.9913, device='cuda:0')
# tensor(0.9489, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.3020, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.3387, device='cuda:0') and tensor(-0.1357, device='cuda:0')
# tensor(0.2063, device='cuda:0') and tensor(-0.4139, device='cuda:0')
# tensor(-0.0233, device='cuda:0') and tensor(-0.4415, device='cuda:0')
# tensor(0.4237, device='cuda:0') and tensor(-0.6071, device='cuda:0')
# tensor(-0.2037, device='cuda:0') and tensor(-0.6867, device='cuda:0')
# tensor(0.6258, device='cuda:0') and tensor(0.0077, device='cuda:0')
# tensor(0.2594, device='cuda:0') and tensor(-0.2790, device='cuda:0')
# tensor(0.0660, device='cuda:0') and tensor(-0.3331, device='cuda:0')
# tensor(0.3303, device='cuda:0') and tensor(-0.5344, device='cuda:0')
# tensor(-0.2385, device='cuda:0') and tensor(-0.6329, device='cuda:0')
# timestep 4  find different label at step  150 9 the true is  tensor([3])
# timestep 3  find different label at step  150 9 the true is  tensor([3])
# timestep 2  find different label at step  150 9 the true is  tensor([3])
# timestep 1  find different label at step  150 9 the true is  tensor([3])
# timestep 0  find different label at step  150 9 the true is  tensor([3])
# tensor(0.3074, device='cuda:0') and tensor(-0.7927, device='cuda:0')
# tensor(0.6147, device='cuda:0') and tensor(-0.9801, device='cuda:0')
# tensor(0.4405, device='cuda:0') and tensor(-0.9891, device='cuda:0')
# tensor(0.9445, device='cuda:0') and tensor(-0.9926, device='cuda:0')
# tensor(0.2983, device='cuda:0') and tensor(-0.9915, device='cuda:0')
# tensor(0.2588, device='cuda:0') and tensor(-0.8158, device='cuda:0')
# tensor(0.6177, device='cuda:0') and tensor(-0.9729, device='cuda:0')
# tensor(0.5241, device='cuda:0') and tensor(-0.9920, device='cuda:0')
# tensor(0.9576, device='cuda:0') and tensor(-0.9920, device='cuda:0')
# tensor(0.3137, device='cuda:0') and tensor(-0.9928, device='cuda:0')
# timestep 4  find different label at step  154 9 the true is  tensor([3])
# timestep 3  find different label at step  154 9 the true is  tensor([3])
# timestep 2  find different label at step  154 9 the true is  tensor([3])
# timestep 1  find different label at step  154 9 the true is  tensor([3])
# timestep 0  find different label at step  154 9 the true is  tensor([3])
# tensor(0.3040, device='cuda:0') and tensor(-0.8433, device='cuda:0')
# tensor(0.6486, device='cuda:0') and tensor(-0.9930, device='cuda:0')
# tensor(0.4844, device='cuda:0') and tensor(-0.9951, device='cuda:0')
# tensor(0.9571, device='cuda:0') and tensor(-0.9936, device='cuda:0')
# tensor(0.3179, device='cuda:0') and tensor(-0.9920, device='cuda:0')
# tensor(0.6179, device='cuda:0') and tensor(0.5451, device='cuda:0')
# timestep 3  find different label at step  161 9 the true is  tensor([3])
# timestep 2  find different label at step  161 9 the true is  tensor([3])
# timestep 1  find different label at step  161 9 the true is  tensor([3])
# timestep 0  find different label at step  161 9 the true is  tensor([3])
# tensor(0.1886, device='cuda:0') and tensor(-0.9347, device='cuda:0')
# tensor(0.6186, device='cuda:0') and tensor(-0.9947, device='cuda:0')
# tensor(0.5046, device='cuda:0') and tensor(-0.9948, device='cuda:0')
# tensor(0.9597, device='cuda:0') and tensor(-0.9928, device='cuda:0')
# tensor(0.3217, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.6313, device='cuda:0') and tensor(-0.1240, device='cuda:0')
# tensor(0.3788, device='cuda:0') and tensor(-0.5296, device='cuda:0')
# tensor(0.1385, device='cuda:0') and tensor(-0.6530, device='cuda:0')
# tensor(0.6670, device='cuda:0') and tensor(-0.8198, device='cuda:0')
# tensor(0.0513, device='cuda:0') and tensor(-0.9069, device='cuda:0')
# timestep 4  find different label at step  169 9 the true is  tensor([3])
# timestep 3  find different label at step  169 9 the true is  tensor([3])
# timestep 2  find different label at step  169 9 the true is  tensor([3])
# timestep 1  find different label at step  169 9 the true is  tensor([3])
# timestep 0  find different label at step  169 9 the true is  tensor([3])
# timestep 4  find different label at step  171 9 the true is  tensor([3])
# timestep 3  find different label at step  171 9 the true is  tensor([3])
# timestep 2  find different label at step  171 9 the true is  tensor([3])
# timestep 1  find different label at step  171 9 the true is  tensor([3])
# timestep 0  find different label at step  171 9 the true is  tensor([3])
# tensor(0.3945, device='cuda:0') and tensor(-0.2564, device='cuda:0')
# tensor(0.5732, device='cuda:0') and tensor(-0.4856, device='cuda:0')
# tensor(0.6854, device='cuda:0') and tensor(-0.4841, device='cuda:0')
# tensor(0.7684, device='cuda:0') and tensor(-0.6400, device='cuda:0')
# tensor(0.4788, device='cuda:0') and tensor(-0.7106, device='cuda:0')
# tensor(0.7244, device='cuda:0') and tensor(-0.1145, device='cuda:0')
# timestep 4  find different label at step  174 3 the true is  tensor([9])
# tensor(0.6837, device='cuda:0') and tensor(-0.5730, device='cuda:0')
# timestep 3  find different label at step  174 3 the true is  tensor([9])
# tensor(0.4813, device='cuda:0') and tensor(-0.7808, device='cuda:0')
# timestep 2  find different label at step  174 3 the true is  tensor([9])
# tensor(0.8809, device='cuda:0') and tensor(-0.9554, device='cuda:0')
# timestep 1  find different label at step  174 3 the true is  tensor([9])
# tensor(0.2994, device='cuda:0') and tensor(-0.9831, device='cuda:0')
# timestep 0  find different label at step  174 3 the true is  tensor([9])
# tensor(0.4291, device='cuda:0') and tensor(0.1926, device='cuda:0')
# tensor(0.4306, device='cuda:0') and tensor(0.0867, device='cuda:0')
# tensor(0.3946, device='cuda:0') and tensor(0.2194, device='cuda:0')
# timestep 1  find different label at step  177 9 the true is  tensor([3])
# timestep 0  find different label at step  177 9 the true is  tensor([3])
# tensor(0.7985, device='cuda:0') and tensor(0.1823, device='cuda:0')
# tensor(0.3553, device='cuda:0') and tensor(0.1047, device='cuda:0')
# timestep 2  find different label at step  178 9 the true is  tensor([3])
# timestep 1  find different label at step  178 9 the true is  tensor([3])
# timestep 0  find different label at step  178 9 the true is  tensor([3])
# tensor(0.3633, device='cuda:0') and tensor(-0.7719, device='cuda:0')
# tensor(0.6512, device='cuda:0') and tensor(-0.9654, device='cuda:0')
# tensor(0.5602, device='cuda:0') and tensor(-0.9855, device='cuda:0')
# tensor(0.9671, device='cuda:0') and tensor(-0.9895, device='cuda:0')
# tensor(0.3361, device='cuda:0') and tensor(-0.9914, device='cuda:0')
# tensor(0.7482, device='cuda:0') and tensor(0.0216, device='cuda:0')
# timestep 4  find different label at step  181 3 the true is  tensor([9])
# tensor(0.6971, device='cuda:0') and tensor(-0.5893, device='cuda:0')
# timestep 3  find different label at step  181 3 the true is  tensor([9])
# tensor(0.4894, device='cuda:0') and tensor(-0.8752, device='cuda:0')
# timestep 2  find different label at step  181 3 the true is  tensor([9])
# tensor(0.9286, device='cuda:0') and tensor(-0.9864, device='cuda:0')
# timestep 1  find different label at step  181 3 the true is  tensor([9])
# tensor(0.2921, device='cuda:0') and tensor(-0.9908, device='cuda:0')
# timestep 0  find different label at step  181 3 the true is  tensor([9])
# tensor(0.5775, device='cuda:0') and tensor(0.4180, device='cuda:0')
# timestep 4  find different label at step  182 3 the true is  tensor([9])
# tensor(-0.0341, device='cuda:0') and tensor(-0.9650, device='cuda:0')
# tensor(0.5952, device='cuda:0') and tensor(-0.9956, device='cuda:0')
# tensor(0.4682, device='cuda:0') and tensor(-0.9942, device='cuda:0')
# tensor(0.9522, device='cuda:0') and tensor(-0.9933, device='cuda:0')
# tensor(0.3095, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.5081, device='cuda:0') and tensor(-0.4042, device='cuda:0')
# tensor(0.7259, device='cuda:0') and tensor(-0.7890, device='cuda:0')
# tensor(0.6470, device='cuda:0') and tensor(-0.9056, device='cuda:0')
# tensor(0.9735, device='cuda:0') and tensor(-0.9665, device='cuda:0')
# tensor(0.3737, device='cuda:0') and tensor(-0.9824, device='cuda:0')
# timestep 4  find different label at step  187 9 the true is  tensor([3])
# timestep 3  find different label at step  187 9 the true is  tensor([3])
# timestep 2  find different label at step  187 9 the true is  tensor([3])
# timestep 1  find different label at step  187 9 the true is  tensor([3])
# timestep 0  find different label at step  187 9 the true is  tensor([3])
# tensor(0.4547, device='cuda:0') and tensor(0.3650, device='cuda:0')
# tensor(0.3028, device='cuda:0') and tensor(0.2876, device='cuda:0')
# timestep 2  find different label at step  188 9 the true is  tensor([3])
# timestep 1  find different label at step  188 9 the true is  tensor([3])
# timestep 0  find different label at step  188 9 the true is  tensor([3])
# timestep 4  find different label at step  192 9 the true is  tensor([3])
# timestep 3  find different label at step  192 9 the true is  tensor([3])
# timestep 2  find different label at step  192 9 the true is  tensor([3])
# timestep 1  find different label at step  192 9 the true is  tensor([3])
# timestep 0  find different label at step  192 9 the true is  tensor([3])
# tensor(0.3306, device='cuda:0') and tensor(0.1099, device='cuda:0')
# tensor(0.3793, device='cuda:0') and tensor(-0.0412, device='cuda:0')
# tensor(0.4393, device='cuda:0') and tensor(0.0982, device='cuda:0')
# tensor(0.2253, device='cuda:0') and tensor(-0.0107, device='cuda:0')
# tensor(0.4391, device='cuda:0') and tensor(0.1459, device='cuda:0')
# tensor(0.5739, device='cuda:0') and tensor(0.1655, device='cuda:0')
# timestep 4  find different label at step  195 3 the true is  tensor([9])
# tensor(0.3999, device='cuda:0') and tensor(0.0174, device='cuda:0')
# timestep 3  find different label at step  195 3 the true is  tensor([9])
# tensor(0.4814, device='cuda:0') and tensor(0.1214, device='cuda:0')
# timestep 2  find different label at step  195 3 the true is  tensor([9])
# tensor(0.1857, device='cuda:0') and tensor(0.0154, device='cuda:0')
# timestep 1  find different label at step  195 3 the true is  tensor([9])
# tensor(0.4231, device='cuda:0') and tensor(0.1753, device='cuda:0')
# timestep 0  find different label at step  195 3 the true is  tensor([9])
# tensor(0.8106, device='cuda:0') and tensor(-0.3568, device='cuda:0')
# tensor(0.7718, device='cuda:0') and tensor(-0.9276, device='cuda:0')
# tensor(0.4875, device='cuda:0') and tensor(-0.9913, device='cuda:0')
# tensor(0.9570, device='cuda:0') and tensor(-0.9945, device='cuda:0')
# tensor(0.3194, device='cuda:0') and tensor(-0.9915, device='cuda:0')
# timestep 4  find different label at step  200 9 the true is  tensor([3])
# timestep 3  find different label at step  200 9 the true is  tensor([3])
# timestep 2  find different label at step  200 9 the true is  tensor([3])
# timestep 1  find different label at step  200 9 the true is  tensor([3])
# timestep 0  find different label at step  200 9 the true is  tensor([3])
# tensor(0.3715, device='cuda:0') and tensor(0.1822, device='cuda:0')
# tensor(0.4516, device='cuda:0') and tensor(0.0078, device='cuda:0')
# tensor(0.4496, device='cuda:0') and tensor(0.1085, device='cuda:0')
# tensor(0.2018, device='cuda:0') and tensor(0.0183, device='cuda:0')
# tensor(0.4263, device='cuda:0') and tensor(0.1778, device='cuda:0')
# tensor(0.4989, device='cuda:0') and tensor(-0.7262, device='cuda:0')
# tensor(0.6709, device='cuda:0') and tensor(-0.9852, device='cuda:0')
# tensor(0.4842, device='cuda:0') and tensor(-0.9941, device='cuda:0')
# tensor(0.9580, device='cuda:0') and tensor(-0.9936, device='cuda:0')
# tensor(0.3206, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.4897, device='cuda:0') and tensor(-0.5524, device='cuda:0')
# tensor(0.6814, device='cuda:0') and tensor(-0.9128, device='cuda:0')
# tensor(0.5613, device='cuda:0') and tensor(-0.9768, device='cuda:0')
# tensor(0.9602, device='cuda:0') and tensor(-0.9895, device='cuda:0')
# tensor(0.3111, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.4334, device='cuda:0') and tensor(-0.7241, device='cuda:0')
# tensor(0.6786, device='cuda:0') and tensor(-0.9657, device='cuda:0')
# tensor(0.5239, device='cuda:0') and tensor(-0.9905, device='cuda:0')
# tensor(0.9629, device='cuda:0') and tensor(-0.9928, device='cuda:0')
# tensor(0.3277, device='cuda:0') and tensor(-0.9916, device='cuda:0')
# timestep 4  find different label at step  207 9 the true is  tensor([3])
# timestep 3  find different label at step  207 9 the true is  tensor([3])
# timestep 2  find different label at step  207 9 the true is  tensor([3])
# timestep 1  find different label at step  207 9 the true is  tensor([3])
# timestep 0  find different label at step  207 9 the true is  tensor([3])
# tensor(0.6200, device='cuda:0') and tensor(0.3297, device='cuda:0')
# timestep 3  find different label at step  208 9 the true is  tensor([3])
# timestep 2  find different label at step  208 9 the true is  tensor([3])
# timestep 1  find different label at step  208 9 the true is  tensor([3])
# timestep 0  find different label at step  208 9 the true is  tensor([3])
# timestep 4  find different label at step  209 9 the true is  tensor([3])
# timestep 3  find different label at step  209 9 the true is  tensor([3])
# timestep 2  find different label at step  209 9 the true is  tensor([3])
# timestep 1  find different label at step  209 9 the true is  tensor([3])
# timestep 0  find different label at step  209 9 the true is  tensor([3])
# tensor(0.6106, device='cuda:0') and tensor(0.2193, device='cuda:0')
# timestep 4  find different label at step  210 3 the true is  tensor([9])
# tensor(0.4331, device='cuda:0') and tensor(0.1431, device='cuda:0')
# timestep 3  find different label at step  210 3 the true is  tensor([9])
# tensor(0.4718, device='cuda:0') and tensor(0.1968, device='cuda:0')
# timestep 2  find different label at step  210 3 the true is  tensor([9])
# tensor(0.3675, device='cuda:0') and tensor(0.3188, device='cuda:0')
# timestep 0  find different label at step  210 3 the true is  tensor([9])
# tensor(0.6236, device='cuda:0') and tensor(0.4045, device='cuda:0')
# tensor(0.4704, device='cuda:0') and tensor(0.1664, device='cuda:0')
# tensor(0.3390, device='cuda:0') and tensor(0.3006, device='cuda:0')
# timestep 1  find different label at step  211 9 the true is  tensor([3])
# timestep 0  find different label at step  211 9 the true is  tensor([3])
# tensor(0.2277, device='cuda:0') and tensor(-0.8459, device='cuda:0')
# tensor(0.5923, device='cuda:0') and tensor(-0.9806, device='cuda:0')
# tensor(0.4637, device='cuda:0') and tensor(-0.9901, device='cuda:0')
# tensor(0.9468, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.2987, device='cuda:0') and tensor(-0.9920, device='cuda:0')
# timestep 4  find different label at step  217 9 the true is  tensor([3])
# timestep 3  find different label at step  217 9 the true is  tensor([3])
# timestep 2  find different label at step  217 9 the true is  tensor([3])
# timestep 1  find different label at step  217 9 the true is  tensor([3])
# timestep 0  find different label at step  217 9 the true is  tensor([3])
# timestep 4  find different label at step  220 9 the true is  tensor([3])
# timestep 3  find different label at step  220 9 the true is  tensor([3])
# timestep 2  find different label at step  220 9 the true is  tensor([3])
# timestep 1  find different label at step  220 9 the true is  tensor([3])
# timestep 0  find different label at step  220 9 the true is  tensor([3])
# timestep 4  find different label at step  221 9 the true is  tensor([3])
# timestep 3  find different label at step  221 9 the true is  tensor([3])
# timestep 2  find different label at step  221 9 the true is  tensor([3])
# timestep 1  find different label at step  221 9 the true is  tensor([3])
# timestep 0  find different label at step  221 9 the true is  tensor([3])
# timestep 4  find different label at step  222 9 the true is  tensor([3])
# timestep 3  find different label at step  222 9 the true is  tensor([3])
# timestep 2  find different label at step  222 9 the true is  tensor([3])
# timestep 1  find different label at step  222 9 the true is  tensor([3])
# timestep 0  find different label at step  222 9 the true is  tensor([3])
# timestep 4  find different label at step  223 9 the true is  tensor([3])
# timestep 3  find different label at step  223 9 the true is  tensor([3])
# timestep 2  find different label at step  223 9 the true is  tensor([3])
# timestep 1  find different label at step  223 9 the true is  tensor([3])
# timestep 0  find different label at step  223 9 the true is  tensor([3])
# tensor(0.7017, device='cuda:0') and tensor(-0.5300, device='cuda:0')
# tensor(0.7230, device='cuda:0') and tensor(-0.9718, device='cuda:0')
# tensor(0.5180, device='cuda:0') and tensor(-0.9946, device='cuda:0')
# tensor(0.9614, device='cuda:0') and tensor(-0.9928, device='cuda:0')
# tensor(0.3245, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# timestep 4  find different label at step  227 9 the true is  tensor([3])
# timestep 3  find different label at step  227 9 the true is  tensor([3])
# timestep 2  find different label at step  227 9 the true is  tensor([3])
# timestep 1  find different label at step  227 9 the true is  tensor([3])
# timestep 0  find different label at step  227 9 the true is  tensor([3])
# timestep 4  find different label at step  231 9 the true is  tensor([3])
# timestep 3  find different label at step  231 9 the true is  tensor([3])
# ...
# timestep 3  find different label at step  433 9 the true is  tensor([3])
# timestep 2  find different label at step  433 9 the true is  tensor([3])
# timestep 1  find different label at step  433 9 the true is  tensor([3])
# timestep 0  find different label at step  433 9 the true is  tensor([3])
# timestep 4  find different label at step  435 9 the true is  tensor([3])
# timestep 3  find different label at step  435 9 the true is  tensor([3])
# timestep 2  find different label at step  435 9 the true is  tensor([3])
# timestep 1  find different label at step  435 9 the true is  tensor([3])
# timestep 0  find different label at step  435 9 the true is  tensor([3])
# tensor(0.8777, device='cuda:0') and tensor(0.1118, device='cuda:0')
# tensor(0.8004, device='cuda:0') and tensor(-0.5949, device='cuda:0')
# tensor(0.6166, device='cuda:0') and tensor(-0.9010, device='cuda:0')
# tensor(0.9465, device='cuda:0') and tensor(-0.9677, device='cuda:0')
# tensor(0.2883, device='cuda:0') and tensor(-0.9901, device='cuda:0')
# tensor(0.2157, device='cuda:0') and tensor(0.1925, device='cuda:0')
# timestep 3  find different label at step  437 9 the true is  tensor([3])
# timestep 2  find different label at step  437 9 the true is  tensor([3])
# timestep 1  find different label at step  437 9 the true is  tensor([3])
# timestep 0  find different label at step  437 9 the true is  tensor([3])
# tensor(0.3449, device='cuda:0') and tensor(-0.7559, device='cuda:0')
# timestep 4  find different label at step  443 3 the true is  tensor([9])
# tensor(0.6431, device='cuda:0') and tensor(-0.9651, device='cuda:0')
# timestep 3  find different label at step  443 3 the true is  tensor([9])
# tensor(0.5375, device='cuda:0') and tensor(-0.9910, device='cuda:0')
# timestep 2  find different label at step  443 3 the true is  tensor([9])
# tensor(0.9600, device='cuda:0') and tensor(-0.9917, device='cuda:0')
# timestep 1  find different label at step  443 3 the true is  tensor([9])
# tensor(0.3173, device='cuda:0') and tensor(-0.9928, device='cuda:0')
# timestep 0  find different label at step  443 3 the true is  tensor([9])
# tensor(0.5640, device='cuda:0') and tensor(-0.6570, device='cuda:0')
# tensor(0.6987, device='cuda:0') and tensor(-0.9751, device='cuda:0')
# tensor(0.4905, device='cuda:0') and tensor(-0.9933, device='cuda:0')
# tensor(0.9590, device='cuda:0') and tensor(-0.9936, device='cuda:0')
# tensor(0.3226, device='cuda:0') and tensor(-0.9918, device='cuda:0')
# tensor(0.2792, device='cuda:0') and tensor(-0.8691, device='cuda:0')
# tensor(0.6144, device='cuda:0') and tensor(-0.9950, device='cuda:0')
# tensor(0.4711, device='cuda:0') and tensor(-0.9947, device='cuda:0')
# tensor(0.9529, device='cuda:0') and tensor(-0.9933, device='cuda:0')
# tensor(0.3099, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.7493, device='cuda:0') and tensor(0.0074, device='cuda:0')
# tensor(0.6922, device='cuda:0') and tensor(-0.3801, device='cuda:0')
# tensor(0.7771, device='cuda:0') and tensor(-0.5115, device='cuda:0')
# tensor(0.8173, device='cuda:0') and tensor(-0.7033, device='cuda:0')
# tensor(0.4510, device='cuda:0') and tensor(-0.8054, device='cuda:0')
# timestep 4  find different label at step  455 9 the true is  tensor([3])
# tensor(0.0164, device='cuda:0') and tensor(-0.1124, device='cuda:0')
# timestep 2  find different label at step  455 9 the true is  tensor([3])
# tensor(0.0008, device='cuda:0') and tensor(-0.1937, device='cuda:0')
# timestep 0  find different label at step  455 9 the true is  tensor([3])
# tensor(0.7022, device='cuda:0') and tensor(0.3350, device='cuda:0')
# timestep 4  find different label at step  458 3 the true is  tensor([9])
# timestep 4  find different label at step  459 9 the true is  tensor([3])
# timestep 3  find different label at step  459 9 the true is  tensor([3])
# timestep 2  find different label at step  459 9 the true is  tensor([3])
# timestep 1  find different label at step  459 9 the true is  tensor([3])
# timestep 0  find different label at step  459 9 the true is  tensor([3])
# timestep 4  find different label at step  460 9 the true is  tensor([3])
# timestep 3  find different label at step  460 9 the true is  tensor([3])
# timestep 2  find different label at step  460 9 the true is  tensor([3])
# timestep 1  find different label at step  460 9 the true is  tensor([3])
# timestep 0  find different label at step  460 9 the true is  tensor([3])
# tensor(0.6997, device='cuda:0') and tensor(-0.0598, device='cuda:0')
# tensor(0.5027, device='cuda:0') and tensor(-0.5515, device='cuda:0')
# tensor(0.3494, device='cuda:0') and tensor(-0.7844, device='cuda:0')
# tensor(0.8377, device='cuda:0') and tensor(-0.9412, device='cuda:0')
# tensor(0.2018, device='cuda:0') and tensor(-0.9731, device='cuda:0')
# tensor(0.3621, device='cuda:0') and tensor(-0.7217, device='cuda:0')
# tensor(0.6948, device='cuda:0') and tensor(-0.9284, device='cuda:0')
# tensor(0.5820, device='cuda:0') and tensor(-0.9768, device='cuda:0')
# tensor(0.9704, device='cuda:0') and tensor(-0.9874, device='cuda:0')
# tensor(0.3429, device='cuda:0') and tensor(-0.9906, device='cuda:0')
# tensor(0.6953, device='cuda:0') and tensor(0.2895, device='cuda:0')
# tensor(0.3251, device='cuda:0') and tensor(0.1315, device='cuda:0')
# tensor(0.3595, device='cuda:0') and tensor(0.2788, device='cuda:0')
# timestep 1  find different label at step  463 9 the true is  tensor([3])
# timestep 0  find different label at step  463 9 the true is  tensor([3])
# tensor(0.5632, device='cuda:0') and tensor(-0.0925, device='cuda:0')
# timestep 4  find different label at step  465 3 the true is  tensor([9])
# tensor(0.6982, device='cuda:0') and tensor(-0.6396, device='cuda:0')
# timestep 3  find different label at step  465 3 the true is  tensor([9])
# tensor(0.6118, device='cuda:0') and tensor(-0.8803, device='cuda:0')
# timestep 2  find different label at step  465 3 the true is  tensor([9])
# tensor(0.9574, device='cuda:0') and tensor(-0.9579, device='cuda:0')
# timestep 1  find different label at step  465 3 the true is  tensor([9])
# tensor(0.3013, device='cuda:0') and tensor(-0.9877, device='cuda:0')
# timestep 0  find different label at step  465 3 the true is  tensor([9])
# tensor(0.6233, device='cuda:0') and tensor(-0.0081, device='cuda:0')
# tensor(0.7710, device='cuda:0') and tensor(-0.5288, device='cuda:0')
# tensor(0.6551, device='cuda:0') and tensor(-0.8676, device='cuda:0')
# tensor(0.9573, device='cuda:0') and tensor(-0.9613, device='cuda:0')
# tensor(0.2951, device='cuda:0') and tensor(-0.9883, device='cuda:0')
# tensor(0.5422, device='cuda:0') and tensor(0.1381, device='cuda:0')
# tensor(0.4238, device='cuda:0') and tensor(0.0472, device='cuda:0')
# tensor(0.4441, device='cuda:0') and tensor(0.1590, device='cuda:0')
# tensor(0.1365, device='cuda:0') and tensor(0.0839, device='cuda:0')
# tensor(0.4004, device='cuda:0') and tensor(0.2432, device='cuda:0')
# tensor(0.5385, device='cuda:0') and tensor(-0.6044, device='cuda:0')
# tensor(0.6796, device='cuda:0') and tensor(-0.9521, device='cuda:0')
# tensor(0.5021, device='cuda:0') and tensor(-0.9897, device='cuda:0')
# tensor(0.9504, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.3015, device='cuda:0') and tensor(-0.9924, device='cuda:0')
# tensor(0.3648, device='cuda:0') and tensor(-0.7948, device='cuda:0')
# tensor(0.6452, device='cuda:0') and tensor(-0.9824, device='cuda:0')
# tensor(0.5321, device='cuda:0') and tensor(-0.9932, device='cuda:0')
# tensor(0.9628, device='cuda:0') and tensor(-0.9919, device='cuda:0')
# tensor(0.3262, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.7915, device='cuda:0') and tensor(0.2714, device='cuda:0')
# timestep 3  find different label at step  478 9 the true is  tensor([3])
# timestep 2  find different label at step  478 9 the true is  tensor([3])
# timestep 1  find different label at step  478 9 the true is  tensor([3])
# timestep 0  find different label at step  478 9 the true is  tensor([3])
# timestep 4  find different label at step  479 9 the true is  tensor([3])
# timestep 3  find different label at step  479 9 the true is  tensor([3])
# timestep 2  find different label at step  479 9 the true is  tensor([3])
# timestep 1  find different label at step  479 9 the true is  tensor([3])
# timestep 0  find different label at step  479 9 the true is  tensor([3])
# tensor(0.4086, device='cuda:0') and tensor(-0.6645, device='cuda:0')
# timestep 4  find different label at step  482 3 the true is  tensor([9])
# tensor(0.6250, device='cuda:0') and tensor(-0.9391, device='cuda:0')
# timestep 3  find different label at step  482 3 the true is  tensor([9])
# tensor(0.4857, device='cuda:0') and tensor(-0.9818, device='cuda:0')
# timestep 2  find different label at step  482 3 the true is  tensor([9])
# tensor(0.9450, device='cuda:0') and tensor(-0.9902, device='cuda:0')
# timestep 1  find different label at step  482 3 the true is  tensor([9])
# tensor(0.2914, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# timestep 0  find different label at step  482 3 the true is  tensor([9])
# tensor(0.3889, device='cuda:0') and tensor(-0.7813, device='cuda:0')
# timestep 4  find different label at step  483 3 the true is  tensor([9])
# tensor(0.6534, device='cuda:0') and tensor(-0.9740, device='cuda:0')
# timestep 3  find different label at step  483 3 the true is  tensor([9])
# tensor(0.5476, device='cuda:0') and tensor(-0.9886, device='cuda:0')
# timestep 2  find different label at step  483 3 the true is  tensor([9])
# tensor(0.9657, device='cuda:0') and tensor(-0.9905, device='cuda:0')
# timestep 1  find different label at step  483 3 the true is  tensor([9])
# tensor(0.3330, device='cuda:0') and tensor(-0.9917, device='cuda:0')
# timestep 0  find different label at step  483 3 the true is  tensor([9])
# tensor(0.5879, device='cuda:0') and tensor(-0.1455, device='cuda:0')
# tensor(0.7046, device='cuda:0') and tensor(-0.6733, device='cuda:0')
# tensor(0.5283, device='cuda:0') and tensor(-0.9359, device='cuda:0')
# tensor(0.9426, device='cuda:0') and tensor(-0.9840, device='cuda:0')
# tensor(0.2758, device='cuda:0') and tensor(-0.9912, device='cuda:0')
# tensor(0.3740, device='cuda:0') and tensor(-0.5336, device='cuda:0')
# tensor(0.7129, device='cuda:0') and tensor(-0.8351, device='cuda:0')
# tensor(0.6296, device='cuda:0') and tensor(-0.9430, device='cuda:0')
# tensor(0.9753, device='cuda:0') and tensor(-0.9767, device='cuda:0')
# tensor(0.3576, device='cuda:0') and tensor(-0.9875, device='cuda:0')
# timestep 4  find different label at step  488 9 the true is  tensor([3])
# timestep 3  find different label at step  488 9 the true is  tensor([3])
# timestep 2  find different label at step  488 9 the true is  tensor([3])
# timestep 1  find different label at step  488 9 the true is  tensor([3])
# timestep 0  find different label at step  488 9 the true is  tensor([3])
# tensor(0.4620, device='cuda:0') and tensor(-0.6628, device='cuda:0')
# tensor(0.6209, device='cuda:0') and tensor(-0.9754, device='cuda:0')
# tensor(0.4713, device='cuda:0') and tensor(-0.9913, device='cuda:0')
# tensor(0.9485, device='cuda:0') and tensor(-0.9924, device='cuda:0')
# tensor(0.3008, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.4181, device='cuda:0') and tensor(0.3655, device='cuda:0')
# tensor(0.2498, device='cuda:0') and tensor(0.1426, device='cuda:0')
# timestep 2  find different label at step  493 9 the true is  tensor([3])
# timestep 1  find different label at step  493 9 the true is  tensor([3])
# timestep 0  find different label at step  493 9 the true is  tensor([3])
# tensor(0.1961, device='cuda:0') and tensor(-0.9210, device='cuda:0')
# tensor(0.6114, device='cuda:0') and tensor(-0.9947, device='cuda:0')
# tensor(0.4662, device='cuda:0') and tensor(-0.9942, device='cuda:0')
# tensor(0.9519, device='cuda:0') and tensor(-0.9934, device='cuda:0')
# tensor(0.3091, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.2238, device='cuda:0') and tensor(-0.8949, device='cuda:0')
# tensor(0.6275, device='cuda:0') and tensor(-0.9917, device='cuda:0')
# tensor(0.5105, device='cuda:0') and tensor(-0.9942, device='cuda:0')
# tensor(0.9607, device='cuda:0') and tensor(-0.9925, device='cuda:0')
# tensor(0.3237, device='cuda:0') and tensor(-0.9922, device='cuda:0')
# tensor(0.5085, device='cuda:0') and tensor(-0.6240, device='cuda:0')
# tensor(0.6943, device='cuda:0') and tensor(-0.9482, device='cuda:0')
# tensor(0.5664, device='cuda:0') and tensor(-0.9810, device='cuda:0')
# tensor(0.9683, device='cuda:0') and tensor(-0.9885, device='cuda:0')
# tensor(0.3409, device='cuda:0') and tensor(-0.9908, device='cuda:0')
# tensor(0.5721, device='cuda:0') and tensor(0.4095, device='cuda:0')
# timestep 3  find different label at step  499 9 the true is  tensor([3])
# timestep 2  find different label at step  499 9 the true is  tensor([3])
# timestep 1  find different label at step  499 9 the true is  tensor([3])
# timestep 0  find different label at step  499 9 the true is  tensor([3])
# timestep 4  find different label at step  500 9 the true is  tensor([3])
# timestep 3  find different label at step  500 9 the true is  tensor([3])
# timestep 2  find different label at step  500 9 the true is  tensor([3])
# timestep 1  find different label at step  500 9 the true is  tensor([3])
# timestep 0  find different label at step  500 9 the true is  tensor([3])
# timestep 4  find different label at step  502 9 the true is  tensor([3])
# tensor(0.3993, device='cuda:0') and tensor(0.0696, device='cuda:0')
# tensor(0.2403, device='cuda:0') and tensor(-0.1235, device='cuda:0')
# tensor(0.4494, device='cuda:0') and tensor(-0.4572, device='cuda:0')
# tensor(-0.0697, device='cuda:0') and tensor(-0.7339, device='cuda:0')
# timestep 4  find different label at step  503 9 the true is  tensor([3])
# timestep 3  find different label at step  503 9 the true is  tensor([3])
# timestep 2  find different label at step  503 9 the true is  tensor([3])
# timestep 1  find different label at step  503 9 the true is  tensor([3])
# timestep 0  find different label at step  503 9 the true is  tensor([3])
# tensor(0.6608, device='cuda:0') and tensor(-0.2774, device='cuda:0')
# tensor(0.7947, device='cuda:0') and tensor(-0.7595, device='cuda:0')
# tensor(0.6340, device='cuda:0') and tensor(-0.9518, device='cuda:0')
# tensor(0.9719, device='cuda:0') and tensor(-0.9839, device='cuda:0')
# tensor(0.3303, device='cuda:0') and tensor(-0.9918, device='cuda:0')
# timestep 4  find different label at step  506 9 the true is  tensor([3])
# timestep 3  find different label at step  506 9 the true is  tensor([3])
# timestep 2  find different label at step  506 9 the true is  tensor([3])
# timestep 1  find different label at step  506 9 the true is  tensor([3])
# timestep 0  find different label at step  506 9 the true is  tensor([3])
# tensor(0.6927, device='cuda:0') and tensor(-0.3801, device='cuda:0')
# tensor(0.7710, device='cuda:0') and tensor(-0.9018, device='cuda:0')
# tensor(0.4908, device='cuda:0') and tensor(-0.9940, device='cuda:0')
# tensor(0.9546, device='cuda:0') and tensor(-0.9945, device='cuda:0')
# tensor(0.3138, device='cuda:0') and tensor(-0.9920, device='cuda:0')
# timestep 4  find different label at step  508 9 the true is  tensor([3])
# timestep 3  find different label at step  508 9 the true is  tensor([3])
# timestep 2  find different label at step  508 9 the true is  tensor([3])
# timestep 1  find different label at step  508 9 the true is  tensor([3])
# timestep 0  find different label at step  508 9 the true is  tensor([3])
# tensor(0.1422, device='cuda:0') and tensor(-0.8865, device='cuda:0')
# tensor(0.6081, device='cuda:0') and tensor(-0.9935, device='cuda:0')
# tensor(0.4701, device='cuda:0') and tensor(-0.9946, device='cuda:0')
# tensor(0.9544, device='cuda:0') and tensor(-0.9935, device='cuda:0')
# tensor(0.3134, device='cuda:0') and tensor(-0.9921, device='cuda:0')
# tensor(0.2897, device='cuda:0') and tensor(-0.8951, device='cuda:0')
# tensor(0.6299, device='cuda:0') and tensor(-0.9971, device='cuda:0')
# tensor(0.4844, device='cuda:0') and tensor(-0.9956, device='cuda:0')
# tensor(0.9564, device='cuda:0') and tensor(-0.9934, device='cuda:0')
# tensor(0.3161, device='cuda:0') and tensor(-0.9922, device='cuda:0')

# %%
(acc/len(train_dataset))
# Out:
# tensor([0.7207, 0.7227, 0.7305, 0.7461, 0.7559])

# %%
# test dataset
test_dataset = datasets.CIFAR10('./data', train=False, download=True, transform=transform)
#test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

mnist3_indices_test = [i for i in range(len(test_dataset)) if test_dataset[i][1] == 3]
mnist2_indices_test = [i for i in range(len(test_dataset)) if test_dataset[i][1] == 9]

mnist_dataset_test3 = BinaryDataset(test_dataset, mnist3_indices_test,label=3 )
mnist_dataset_test2 = BinaryDataset(test_dataset, mnist2_indices_test,label=9 )

test_dataset = torch.utils.data.ConcatDataset([mnist_dataset_test3, mnist_dataset_test2])
print(len(mnist3_indices_test)/len(test_dataset))
print(len(mnist2_indices_test)/len(test_dataset))
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=True)
# Out:
# Files already downloaded and verified
# 0.5
# 0.5

# %%
test_accuaracy=0
test_acc=torch.zeros(timesteps)

with torch.no_grad():
  for step, (image, label) in enumerate(test_loader):
    batch_size = image.shape[0]
    image = image.to(device)
    x0=image
    for t in range(timesteps-1,-1,-1):

      model.load_state_dict(model_parameters[t],strict=True)
      model.eval()
      time=torch.full((batch_size,),t, device=device)
      x0=transforms.Normalize(0.5, 0.5)(model(x0, time))
      a=torch.dot(x_1[t].reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_1[t].reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 3 and pred
      b=torch.dot(x_2[t].reshape(dataset_image_number,3*32*32).mean(0).to(device) / torch.norm(x_2[t].reshape(dataset_image_number,3*32*32).mean(0)).to(device), x0.reshape(1,3*32*32).mean(0).to(device) / torch.norm(x0.reshape(1,3*32*32).mean(0)).to(device)).to(device)# distance between 2 and pred distance between 2 and pred
      if a >= b:
        pred_label= 3
        #print(a,"and",b)
      else:
        pred_label= 9
        #print(a,"and",b)
      print(pred_label,label)
      if pred_label==label:
        test_acc[t]=test_acc[t]+1
      #print("exact!", pred_label,"the true is ",label)
      else:
        print("timestep", t, " find different label at step ", step, pred_label,"the true is ",label)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1205 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1205 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1205 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1205 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1205 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1206 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1206 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1206 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1206 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1206 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1209 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1209 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1209 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1209 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1209 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1211 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1211 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1211 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1211 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1211 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1217 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1217 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1217 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1217 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1217 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1218 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1218 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1218 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1218 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1218 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1228 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1228 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1228 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1228 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1228 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1231 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1231 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1231 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1231 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1231 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1233 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1233 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1233 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1233 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1233 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1235 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1235 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1235 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1235 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1235 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1244 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1244 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1244 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1244 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1244 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1249 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1249 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1249 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1249 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1249 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1250 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1250 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1250 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1250 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1250 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1251 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1251 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1251 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1251 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1251 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1255 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1255 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1255 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1255 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1255 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1256 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1256 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1256 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1256 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1256 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1260 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1260 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1260 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1260 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1260 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1265 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1265 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1265 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1265 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1265 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1267 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1267 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1267 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1267 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1267 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1268 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1268 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1268 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1268 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1268 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1271 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1271 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1271 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1271 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1271 9 the true is  tensor([3])
# 9 tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1272 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1272 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1272 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1272 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1275 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1278 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1278 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1278 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1278 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1278 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1281 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1281 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1281 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1281 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1282 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1282 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1282 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1282 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1284 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1284 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1284 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1292 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1292 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1292 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1292 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1292 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1293 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1293 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1293 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1293 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1293 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1294 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1294 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1294 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1294 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1294 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1297 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1297 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1297 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1297 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1297 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1301 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1301 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1301 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1301 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1303 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1303 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1303 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1303 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1303 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1307 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1307 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1307 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1307 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1307 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1308 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1308 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1308 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1308 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1309 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1309 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1309 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1309 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1309 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1310 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1310 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1310 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1310 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1310 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1313 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1314 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1314 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1314 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1314 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1314 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1326 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1326 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1326 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1326 3 the true is  tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1327 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1327 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1327 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1327 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1327 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1332 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1332 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1332 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1332 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1333 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1333 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1333 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1333 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1336 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1337 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1337 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1337 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1337 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1337 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1341 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1341 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1341 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1341 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1342 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1342 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1342 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1342 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1343 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1343 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1343 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1343 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1343 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1349 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1349 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1349 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1349 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1349 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1351 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1351 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1351 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1351 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1351 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1352 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1352 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1352 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1352 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1352 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1356 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1358 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1358 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1358 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1358 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1358 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1359 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1359 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1359 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1359 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1359 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1360 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1360 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1360 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1360 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1360 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1368 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1368 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1368 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1368 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1368 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1376 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1376 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1376 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1376 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1376 3 the true is  tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1377 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1377 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1377 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1377 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1377 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1382 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1382 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1383 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1383 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1383 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1383 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1383 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1401 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1401 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1401 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1401 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1401 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1402 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1402 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1402 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1402 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1402 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1403 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1403 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1403 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1403 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1403 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1404 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1404 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1404 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1404 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1404 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1413 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1413 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1416 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1416 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1416 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1418 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1418 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1418 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1418 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1419 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1419 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1419 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1419 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1419 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1422 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1422 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1422 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1422 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1422 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1424 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1424 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1424 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1424 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1424 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1429 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1429 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1429 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1429 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1429 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1431 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1431 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1431 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1431 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1431 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1440 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1440 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1440 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1440 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1440 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1447 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1447 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1447 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1447 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1447 9 the true is  tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1448 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1448 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1448 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1448 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1450 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1450 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1450 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1450 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1451 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1451 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1451 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1451 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1451 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1452 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1452 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1452 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1452 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1452 3 the true is  tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1453 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1453 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1453 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1453 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1453 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1458 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1458 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1458 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1458 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1458 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1460 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1460 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1460 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1460 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1460 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1461 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1461 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1461 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1461 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1461 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1463 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1463 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1463 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1463 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1463 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1468 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1468 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1468 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1468 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1468 3 the true is  tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1469 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1469 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1469 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1469 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1469 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1470 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1470 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1470 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1470 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1470 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# ...
# 3 tensor([9])
# timestep 3  find different label at step  1898 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1898 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1898 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1898 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1906 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1906 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1906 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1906 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1906 9 the true is  tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1907 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1907 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1907 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1907 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1907 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1913 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1913 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1913 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1913 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1913 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1915 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1915 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1915 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1915 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1915 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1933 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1933 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1933 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1933 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1933 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1934 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1934 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1934 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1934 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1934 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1938 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1938 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1938 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1938 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1938 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1942 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1942 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1942 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1942 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1942 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1944 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1951 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1951 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1951 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1951 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1951 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1954 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1954 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1954 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1954 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1954 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1955 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1955 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1955 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1955 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1955 3 the true is  tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1956 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1956 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1956 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1956 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1957 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1957 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1957 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1957 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1957 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1963 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1963 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1963 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1963 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1964 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1964 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1964 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1964 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1964 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([9])
# timestep 4  find different label at step  1966 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1974 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1974 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1974 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1974 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1974 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1975 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1975 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1975 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1975 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1975 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1979 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1979 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1979 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1979 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1979 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1981 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1981 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1981 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1981 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1981 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 4  find different label at step  1982 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1982 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1982 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1982 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1982 9 the true is  tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([3])
# timestep 4  find different label at step  1988 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 3  find different label at step  1988 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 2  find different label at step  1988 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 1  find different label at step  1988 9 the true is  tensor([3])
# 9 tensor([3])
# timestep 0  find different label at step  1988 9 the true is  tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1991 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1991 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1991 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1991 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1991 3 the true is  tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([9])
# timestep 4  find different label at step  1994 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 3  find different label at step  1994 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 2  find different label at step  1994 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 1  find different label at step  1994 3 the true is  tensor([9])
# 3 tensor([9])
# timestep 0  find different label at step  1994 3 the true is  tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 9 tensor([9])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])
# 3 tensor([3])

# %%
(test_acc/len(test_dataset))
# Out:
# tensor([0.7150, 0.7175, 0.7200, 0.7285, 0.7475])

# %%
from sklearn import preprocessing
from sklearn.manifold import TSNE
import torch
import torchvision
import matplotlib.pyplot as plt
def plot(x_t_train_dataset_t,labels_1):
  tsne = TSNE(n_components=2, verbose=1 ,random_state=42)
  x_t_train_dataset_t = x_t_train_dataset_t.view(len(x_t_train_dataset_t), -1)
  result = tsne.fit_transform(x_t_train_dataset_t)
  scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))
  result = scaler.fit_transform(result)
  fig = plt.figure(figsize=(5, 5))
  ax = fig.add_subplot()
  ax.set_title('t-SNE process')
  ax.scatter(result[:,0], result[:,1],c=labels_1, s=20)

# %%
# This is the visilization of  original images.
t=5
b=256
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
#train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=b, shuffle=False,num_workers=4,pin_memory=True)

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=b, shuffle=False)
  for step, (images1, labels) in enumerate(train_loader11):

    images1=images1.to(device)
    batch_size=images1.shape[0]
    print(step)
    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep0.png')
# Out:
# 0
# 1
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.001s...
# [t-SNE] Computed neighbors for 512 samples in 0.046s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 9.282622
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.196053
# [t-SNE] KL divergence after 1000 iterations: 1.203893

# %%
# This is the first layer.
# for t =4
t=4
b=256

model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)
train_dataset = torch.utils.data.ConcatDataset([mnist_dataset, mnist2_dataset])
#train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=b, shuffle=True,num_workers=4,pin_memory=True)

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    images1 = transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))
    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep1.png')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.002s...
# [t-SNE] Computed neighbors for 512 samples in 0.044s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 3.127504
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.762619
# [t-SNE] KL divergence after 1000 iterations: 0.462890

# %%
# This is the second layer.
t=3
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)
batch_size=b*2
x_t_train_dataset_t=torch.zeros([b*2,3,32,32])

train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False)
labels_1=torch.zeros([b*2])
model.eval()
with torch.no_grad():
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)

    images1 = transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep2.png')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.002s...
# [t-SNE] Computed neighbors for 512 samples in 0.042s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 0.966862
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.274765
# [t-SNE] KL divergence after 1000 iterations: 0.297726

# %%
# This is the third layer.
t=2
model = UNet(3, 128, 3, (1, 2, 3), 2, (False, True, False))
model.to(device)

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    images1=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep3.png')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.001s...
# [t-SNE] Computed neighbors for 512 samples in 0.041s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 0.382655
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.520050
# [t-SNE] KL divergence after 1000 iterations: 0.238223

# %%
# This is the fourth layer.
t=1

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False,num_workers=2,pin_memory=True)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    images1=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep4.png')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.001s...
# [t-SNE] Computed neighbors for 512 samples in 0.168s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 0.130216
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 47.267094
# [t-SNE] KL divergence after 1000 iterations: 0.187924

# %%
# This is the 5th layer.
t=0

x_t_train_dataset_t=torch.zeros([b*2,3,32,32])
labels_1=torch.zeros([b*2])

with torch.no_grad():
  train_loader11 = torch.utils.data.DataLoader(x_t_train_dataset1, batch_size=batch_size, shuffle=False,num_workers=2,pin_memory=True)
  for step, (images1, labels) in enumerate(train_loader11):
    xt1 = images1.to(device)
    model.load_state_dict(model_parameters[t],strict=True)
    model.eval()

    images1=transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(model(xt1, time))

    x_t_train_dataset_t[step*batch_size:(step+1)*batch_size,:,:,:]=images1
    labels_1[step*batch_size:(step+1)*batch_size]=labels
  x_t_train_dataset1=torch.utils.data.ConcatDataset([TrainSet(x_t_train_dataset_t,labels_1)])
  plot(x_t_train_dataset_t,labels_1)
  plt.savefig('savefig_example_tsne_timestep5.png')
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 512 samples in 0.001s...
# [t-SNE] Computed neighbors for 512 samples in 0.175s...
# [t-SNE] Computed conditional probabilities for sample 512 / 512
# [t-SNE] Mean sigma: 0.056408
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 46.399590
# [t-SNE] KL divergence after 1000 iterations: 0.170648
